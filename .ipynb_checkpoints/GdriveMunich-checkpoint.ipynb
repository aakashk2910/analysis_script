# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import time
import datetime
import filterbyip as fbi
import Cdf
import Pmf

# %%
# %autosave 0
# Out:
# Autosave disabled

# %%
import warnings
warnings.filterwarnings('ignore')

# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from IPython.core.display import HTML
css = open('style-table.css').read() + open('style-notebook.css').read()
HTML('<style>{}</style>'.format(css))
# Out:
# <style>body {
#     margin: 0;
#     font-family: Helvetica;
# }
# table.dataframe {
#     border-collapse: collapse;
#     border: none;
# }
# table.dataframe tr {
#     border: none;
# }
# table.dataframe td, table.dataframe th {
#     margin: 0;
#     border: 1px solid white;
#     padding-left: 0.25em;
#     padding-right: 0.25em;
# }
# table.dataframe th:not(:empty) {
#     background-color: #fec;
#     text-align: left;
#     font-weight: normal;
# }
# table.dataframe tr:nth-child(2) th:empty {
#     border-left: none;
#     border-right: 1px dashed #888;
# }
# table.dataframe td {
#     border: 2px solid #ccf;
#     background-color: #f4f4ff;
# }
# h3 {
#     color: white;
#     background-color: black;
#     padding: 0.5em;
# }
#
# .CodeMirror {
#     font-family: 'Consolas';
# }
#
# div.cell.code_cell {
#     font-family: 'Consolas';
# }
#
# div.output_area pre {
#     font-family: 'Consolas';
# }
# </style>

# %%
#change 
tcp_tls_data = "./data2020/output_curl_gdrive.csv"
quic_data = "./data2020/output_quic_gdrive.csv"
gdrive = "./data2020/gdrive_id.csv"

# %%
scol_names = ['TimeOfMeasurement', 'Url', 'Ip', 'Port', 'DnsLookupTime', 'TCPHandshakeTime', 'ConnectionEstablishmentTime', 'TTFB', 'TotalDownloadTime', 'HttpResponse', 'HTTPVersion', 'Protocol']
tcol_names = ['TimeOfMeasurement', 'Url', 'Path', 'Ip', 'Port', 'DNSTime', 'ConnectionEstablishmentTime', 'TTFB', 'TotalDownloadTime', 'HttpResponse', 'Protocol']
g_names = ['size', 'id']

# %%
t = pd.read_csv(quic_data, ';', names=tcol_names, header=None)
s = pd.read_csv(tcp_tls_data, ';', names=scol_names, header=None)
gd = pd.read_csv(gdrive, ',', names=g_names, header=None)

# %%
t = t.dropna()
s=s.dropna()
s['TTFB']=s['TTFB']-s['DnsLookupTime']
s['TotalDownloadTime']=s['TotalDownloadTime']-s['DnsLookupTime']

# %%
import re
def extract_id(path):
    id = re.search('\*\/(.*)\?', path)
    return id.group(1)

# %%
t['id'] = t['Path'].apply(extract_id)

# %%
import re
def substitute(string):
    replaced = string
    if re.search('K', string):
        replaced = re.sub('K','', string)
    if re.search('M', string):
        replaced = re.sub('M','000', string)
    if re.search('G', string):
        replaced = re.sub('G','000000', string)
    return replaced

# %%
gd['size'] = gd['size'].apply(substitute)

# %%
s['id'] = s['Url'].apply(extract_id)

# %%
t['Url'] = t['Url'] + t['Path']

# %%
t = t.join(gd.set_index('id'), on='id', rsuffix='_right')

# %%
s = s.join(gd.set_index('id'), on='id', rsuffix='_right')

# %%
t['size'] = t['size'].astype(int)
s['size'] = s['size'].astype(int)
t['TotalDownloadTime'] = t['TotalDownloadTime'].astype(float)
s['TotalDownloadTime'] = s['TotalDownloadTime'].astype(float)

# %%
t['Throughput'] = (t['size']/t['TotalDownloadTime'])

# %%
s['Throughput'] = (s['size']/s['TotalDownloadTime'])

# %%
t.head()
# Out:
#    TimeOfMeasurement                                                Url  \
# 0         1588764796  doc-10-4c-docs.googleusercontent.com/docs/secu...
# 1         1588764796  doc-10-4c-docs.googleusercontent.com/docs/secu...
# 2         1588764797  doc-10-4c-docs.googleusercontent.com/docs/secu...
# 4         1588764797  doc-10-4c-docs.googleusercontent.com/docs/secu...
# 5         1588764797  doc-10-4c-docs.googleusercontent.com/docs/secu...
#
#                                                 Path  \
# 0  /docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp...
# 1  /docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp...
# 2  /docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp...
# 4  /docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp...
# 5  /docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp...
#
#                          Ip  Port  DNSTime  ConnectionEstablishmentTime  \
# 0              172.217.18.1   443    1.105                       34.420
# 1              172.217.18.1   443    0.573                       33.889
# 2              172.217.18.1   443    0.629                       33.792
# 4  2a00:1450:4001:800::2001   443    0.458                       34.266
# 5  2a00:1450:4001:800::2001   443    0.499                       31.849
#
#       TTFB  TotalDownloadTime  HttpResponse Protocol  \
# 0  161.184            161.263         403.0     Q043
# 1  161.883            162.213         403.0     Q046
# 2  159.707            159.794         403.0     Q050
# 4  161.883            161.995         403.0     Q043
# 5  156.558            156.644         403.0     Q046
#
#                                   id  size  Throughput
# 0  1C45gZCBtJHnjNACQIagfJ2fTRKQaZ9k6     1    0.006201
# 1  1C45gZCBtJHnjNACQIagfJ2fTRKQaZ9k6     1    0.006165
# 2  1C45gZCBtJHnjNACQIagfJ2fTRKQaZ9k6     1    0.006258
# 4  1C45gZCBtJHnjNACQIagfJ2fTRKQaZ9k6     1    0.006173
# 5  1C45gZCBtJHnjNACQIagfJ2fTRKQaZ9k6     1    0.006384

# %%
t.tail()
# Out:
#        TimeOfMeasurement                                                Url  \
# 68969         1589726937  doc-08-4c-docs.googleusercontent.com/docs/secu...
# 68971         1589726942  doc-08-4c-docs.googleusercontent.com/docs/secu...
# 68972         1589726949  doc-08-4c-docs.googleusercontent.com/docs/secu...
# 68973         1589726956  doc-08-4c-docs.googleusercontent.com/docs/secu...
# 68975         1589727002  doc-0s-4c-docs.googleusercontent.com/docs/secu...
#
#                                                     Path  \
# 68969  /docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp...
# 68971  /docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp...
# 68972  /docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp...
# 68973  /docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp...
# 68975  /docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp...
#
#                              Ip  Port  DNSTime  ConnectionEstablishmentTime  \
# 68969            216.58.212.129   443    0.632                       33.078
# 68971  2a00:1450:4001:801::2001   443    0.551                       32.236
# 68972  2a00:1450:4001:801::2001   443   28.793                       32.315
# 68973  2a00:1450:4001:801::2001   443    0.600                       32.528
# 68975            216.58.212.129   443    0.560                       32.729
#
#           TTFB  TotalDownloadTime  HttpResponse Protocol  \
# 68969  307.285            307.361         403.0     Q050
# 68971  982.994            983.069         403.0     Q043
# 68972  828.115            828.229         403.0     Q046
# 68973  552.346            552.420         403.0     Q050
# 68975  482.052            482.143         403.0     Q043
#
#                                       id  size  Throughput
# 68969  1Zr-g4qROFzaq_vZ4JnHneEb9JyRSUBXb    20    0.065070
# 68971  1Zr-g4qROFzaq_vZ4JnHneEb9JyRSUBXb    20    0.020344
# 68972  1Zr-g4qROFzaq_vZ4JnHneEb9JyRSUBXb    20    0.024148
# 68973  1Zr-g4qROFzaq_vZ4JnHneEb9JyRSUBXb    20    0.036204
# 68975  1yaWxao4WnEPwFSifCvpiMNTqnXSinoV3    50    0.103704

# %%
s.head()
# Out:
#    TimeOfMeasurement                                                Url  \
# 0         1588764797  doc-10-4c-docs.googleusercontent.com/docs/secu...
# 1         1588764798  doc-10-4c-docs.googleusercontent.com/docs/secu...
# 2         1588764798  doc-10-4c-docs.googleusercontent.com/docs/secu...
# 3         1588764798  doc-10-4c-docs.googleusercontent.com/docs/secu...
# 4         1588764800  doc-0g-4c-docs.googleusercontent.com/docs/secu...
#
#                          Ip  Port  DnsLookupTime  TCPHandshakeTime  \
# 0              172.217.18.1   443          4.169             9.146
# 1              172.217.18.1   443          4.173             9.101
# 2  2a00:1450:4001:800::2001   443          4.140             8.482
# 3  2a00:1450:4001:800::2001   443          4.188             8.517
# 4              172.217.18.1   443          4.171             9.158
#
#    ConnectionEstablishmentTime     TTFB  TotalDownloadTime  HttpResponse  \
# 0                       82.785  210.513            210.539           403
# 1                       69.682  199.158            199.227           403
# 2                       68.503  192.883            192.909           403
# 3                       66.558  191.757            191.836           403
# 4                       71.751  196.487            196.515           403
#
#   HTTPVersion    Protocol                                 id  size  Throughput
# 0    HTTP/1.1  TCP/TLS1.2  1C45gZCBtJHnjNACQIagfJ2fTRKQaZ9k6     1    0.004750
# 1       HTTP2  TCP/TLS1.2  1C45gZCBtJHnjNACQIagfJ2fTRKQaZ9k6     1    0.005019
# 2    HTTP/1.1  TCP/TLS1.2  1C45gZCBtJHnjNACQIagfJ2fTRKQaZ9k6     1    0.005184
# 3       HTTP2  TCP/TLS1.2  1C45gZCBtJHnjNACQIagfJ2fTRKQaZ9k6     1    0.005213
# 4    HTTP/1.1  TCP/TLS1.2  1yv4XxH7R74il-bxBS5Mz8Oiw6W7vwUFM     2    0.010177

# %%
s.tail()
# Out:
#        TimeOfMeasurement                                                Url  \
# 34425         1589726918  doc-0s-4c-docs.googleusercontent.com/docs/secu...
# 34426         1589726976  doc-08-4c-docs.googleusercontent.com/docs/secu...
# 34427         1589726986  doc-08-4c-docs.googleusercontent.com/docs/secu...
# 34428         1589726994  doc-08-4c-docs.googleusercontent.com/docs/secu...
# 34429         1589727002  doc-08-4c-docs.googleusercontent.com/docs/secu...
#
#                              Ip  Port  DnsLookupTime  TCPHandshakeTime  \
# 34425  2a00:1450:4001:801::2001   443          4.216             8.611
# 34426            216.58.212.129   443          4.161             8.875
# 34427            216.58.212.129   443          4.170             8.936
# 34428  2a00:1450:4001:801::2001   443          4.186             8.792
# 34429  2a00:1450:4001:801::2001   443          4.167             8.522
#
#        ConnectionEstablishmentTime       TTFB  TotalDownloadTime  \
# 34425                       66.096  10049.050          10049.105
# 34426                       72.206  10032.248          10032.285
# 34427                       67.997   9814.690           9814.772
# 34428                       68.363   8233.405           8233.442
# 34429                       69.232   8331.197           8331.270
#
#        HttpResponse HTTPVersion    Protocol  \
# 34425           403       HTTP2  TCP/TLS1.2
# 34426           403    HTTP/1.1  TCP/TLS1.2
# 34427           403       HTTP2  TCP/TLS1.2
# 34428           403    HTTP/1.1  TCP/TLS1.2
# 34429           403       HTTP2  TCP/TLS1.2
#
#                                       id  size  Throughput
# 34425  1k7mg8XpQmW-jpO85yq3giwVUeL82NJhx    10    0.000995
# 34426  1Zr-g4qROFzaq_vZ4JnHneEb9JyRSUBXb    20    0.001994
# 34427  1Zr-g4qROFzaq_vZ4JnHneEb9JyRSUBXb    20    0.002038
# 34428  1Zr-g4qROFzaq_vZ4JnHneEb9JyRSUBXb    20    0.002429
# 34429  1Zr-g4qROFzaq_vZ4JnHneEb9JyRSUBXb    20    0.002401

# %%
gd.head()
# Out:
#   size                                 id
# 0    1  1C45gZCBtJHnjNACQIagfJ2fTRKQaZ9k6
# 1    2  1yv4XxH7R74il-bxBS5Mz8Oiw6W7vwUFM
# 2    5  1sGGy4K1J3p0OQlLxUgbgsErokyBADg6g
# 3   10  1k7mg8XpQmW-jpO85yq3giwVUeL82NJhx
# 4   20  1Zr-g4qROFzaq_vZ4JnHneEb9JyRSUBXb

# %%
t = t.dropna()
s = s.dropna()

# %%
def filter_by_ip(df, column):
  """reads a DataFrame, calls fbi.filter_v{4,6} to get DataFrames with rows
     containing only v4, v6 endpoints. Returns the two DataFrame as a tuple"""

  dfv6 = fbi.filter_v6(df, column)
  dfv4 = fbi.filter_v4(df, column)
  return dfv4, dfv6

# %%
quic4, quic6 = filter_by_ip(t, column = 'Ip')

# %%
tcp4, tcp6 = filter_by_ip(s, column = 'Ip')

# %%
quic4 = quic4.loc[quic4['size']<500]
tcp4 = tcp4.loc[tcp4['size']<500]

# %%
quic43 = quic4.loc[t['Protocol'] == 'Q043']
quic46 = quic4.loc[t['Protocol'] == 'Q046']
quic50 = quic4.loc[t['Protocol'] == 'Q050']
quicietf = quic4.loc[t['Protocol'] == 'FF000018']

# %%
quic43_6 = quic6.loc[t['Protocol'] == 'Q043']
quic46_6 = quic6.loc[t['Protocol'] == 'Q046']
quic50_6 = quic6.loc[t['Protocol'] == 'Q050']
quicietf_6 = quic6.loc[t['Protocol'] == 'FF000018']

# %%
tcp12 = tcp4.loc[s['Protocol'] == 'TCP/TLS1.2']
tcp13 = tcp4.loc[s['Protocol'] == 'TCP/TLS1.3']

# %%
tcp12_6 = tcp6.loc[s['Protocol'] == 'TCP/TLS1.2']
tcp13_6 = tcp6.loc[s['Protocol'] == 'TCP/TLS1.3']

# %%
x = Cdf.MakeCdfFromList(quic43['ConnectionEstablishmentTime'].values)
x1 = Cdf.MakeCdfFromList(quic46['ConnectionEstablishmentTime'].values)
x3 = Cdf.MakeCdfFromList(quic50['ConnectionEstablishmentTime'].values)
x5 = Cdf.MakeCdfFromList(quicietf['ConnectionEstablishmentTime'].values)
x4 = Cdf.MakeCdfFromList(tcp13['ConnectionEstablishmentTime'].values)
x2 = Cdf.MakeCdfFromList(tcp12['ConnectionEstablishmentTime'].values)

# %%
fig = plt.figure(figsize = (10,3))
plt.rcParams['font.size'] = 12
ax = plt.gca()
yticks = np.arange(0,1.1,0.2)

#Q043
plt.plot(x.xs, x.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'orange')
#Q046
plt.plot(x1.xs, x1.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'red')
#Q050
plt.plot(x3.xs, x3.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'green')
#Q0ietf
plt.plot(x5.xs, x5.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'blue')
#TLS1.2
plt.plot(x2.xs, x2.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'cyan')
#TLS1.3
plt.plot(x4.xs, x4.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'black')


ax = fig.axes[0]
ax.grid(False)
ax.set_yticks(yticks)
ax.set_ylim([0,1.05])
#ax.set_xlim([20, 100])
ax.set_xscale('log')
ax.set_xlabel('latency (x-axis is cut)', fontsize=12)
ax.set_ylabel('CDF', fontsize=12)

plt.legend(['Q043', 'Q046', 'Q050', 'IETF', 'TLS1.2', 'TLS 1.3'], fontsize=11, loc='best')

ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.yaxis.set_ticks_position('left')
ax.xaxis.set_ticks_position('bottom')
ax.spines['bottom'].set_position(('axes', -0.05))
ax.spines['left'].set_position(('axes', -0.05))

ax3 = ax.twinx()
ax3.spines['right'].set_color('none')
ax3.spines['top'].set_color('none')
ax3.spines['left'].set_color('none')
ax3.spines['bottom'].set_color('none')
ax3.yaxis.set_ticks_position('none')
plt.setp(ax3.get_yticklabels(), visible=False)

plt.title('Handshake Times with IPv4', fontsize=12, y=1.05)
plt.savefig('./plots2020/gdriveMunich/handshake_times_ipv4_otherthan200.png', format='png', bbox_inches='tight')
# Out:
# findfont: Font family ['monospace'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['monospace'] not found. Falling back to DejaVu Sans.

# %%
x = Cdf.MakeCdfFromList(quic43_6['ConnectionEstablishmentTime'].values)
x1 =Cdf.MakeCdfFromList(quic46_6['ConnectionEstablishmentTime'].values)
x3 = Cdf.MakeCdfFromList(quic50_6['ConnectionEstablishmentTime'].values)
x5 = Cdf.MakeCdfFromList(quicietf_6['ConnectionEstablishmentTime'].values)
x4 = Cdf.MakeCdfFromList(tcp13_6['ConnectionEstablishmentTime'].values)
x2 =Cdf.MakeCdfFromList(tcp12_6['ConnectionEstablishmentTime'].values)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-36-619c3bd94a3d> in <module>
#       1 x = Cdf.MakeCdfFromList(quic43_6['ConnectionEstablishmentTime'].values)
# ----> 2 x1 =Cdf.MakeCdfFromList(quic36_6['ConnectionEstablishmentTime'].values)
#       3 x3 = Cdf.MakeCdfFromList(quic50_6['ConnectionEstablishmentTime'].values)
#       4 x5 = Cdf.MakeCdfFromList(quicietf_6['ConnectionEstablishmentTime'].values)
#       5 x4 = Cdf.MakeCdfFromList(tcp13_6['ConnectionEstablishmentTime'].values)
#
# NameError: name 'quic36_6' is not defined

# %%
fig = plt.figure(figsize = (10,3))
plt.rcParams['font.size'] = 12
ax = plt.gca()
yticks = np.arange(0,1.1,0.2)

#Q043
plt.plot(x.xs, x.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'orange')
#Q046
plt.plot(x1.xs, x1.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'red')
#Q050
plt.plot(x3.xs, x3.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'green')
#ietf
plt.plot(x5.xs, x5.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'blue')
#TLS1.2
plt.plot(x2.xs, x2.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'cyan')
#TLS1.3
plt.plot(x4.xs, x4.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'black')


ax = fig.axes[0]
ax.grid(False)
ax.set_yticks(yticks)
ax.set_ylim([0,1.05])
#ax.set_xlim([20,100])
ax.set_xscale('log')
ax.set_xlabel('latency (x-axis is cut)', fontsize=12)
ax.set_ylabel('CDF', fontsize=12)

plt.legend(['Q043', 'Q046', 'Q050', 'IETF', 'TLS1.2', 'TLS 1.3'], fontsize=11, loc='best')

ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.yaxis.set_ticks_position('left')
ax.xaxis.set_ticks_position('bottom')
ax.spines['bottom'].set_position(('axes', -0.05))
ax.spines['left'].set_position(('axes', -0.05))

ax3 = ax.twinx()
ax3.spines['right'].set_color('none')
ax3.spines['top'].set_color('none')
ax3.spines['left'].set_color('none')
ax3.spines['bottom'].set_color('none')
ax3.yaxis.set_ticks_position('none')
plt.setp(ax3.get_yticklabels(), visible=False)

plt.title('Handshake Times with IPv6', fontsize=12, y=1.05)
plt.savefig('./plots2020/gdriveMunich/handshake_times_ipv6.png', format='png', bbox_inches='tight')

# %%
x = Cdf.MakeCdfFromList(quic43['TTFB'].values)
x1 =Cdf.MakeCdfFromList(quic46['TTFB'].values)
x3 = Cdf.MakeCdfFromList(quic50['TTFB'].values)
x5 = Cdf.MakeCdfFromList(quicietf['TTFB'].values)
x4 = Cdf.MakeCdfFromList(tcp13['TTFB'].values)
x2 =Cdf.MakeCdfFromList(tcp12['TTFB'].values)

# %%
fig = plt.figure(figsize = (10,3))
plt.rcParams['font.size'] = 12
ax = plt.gca()
yticks = np.arange(0,1.1,0.2)

#Q043
plt.plot(x.xs, x.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'orange')
#Q046
plt.plot(x1.xs, x1.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'red')
#Q050
plt.plot(x3.xs, x3.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'green')
#IETF
plt.plot(x5.xs, x5.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'blue')
#TLS1.2
plt.plot(x2.xs, x2.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'cyan')
#TLS1.3
plt.plot(x4.xs, x4.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'black')


ax = fig.axes[0]
ax.grid(False)
ax.set_yticks(yticks)
ax.set_ylim([0,1.05])
#ax.set_xlim([100, 600])
ax.set_xscale('log')
ax.set_xlabel('TTFB', fontsize=12)
ax.set_ylabel('CDF', fontsize=12)

plt.legend(['Q043', 'Q046', 'Q050', 'IETF', 'TLS1.2', 'TLS 1.3'], fontsize=11, loc='best')

ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.yaxis.set_ticks_position('left')
ax.xaxis.set_ticks_position('bottom')
ax.spines['bottom'].set_position(('axes', -0.05))
ax.spines['left'].set_position(('axes', -0.05))

ax3 = ax.twinx()
ax3.spines['right'].set_color('none')
ax3.spines['top'].set_color('none')
ax3.spines['left'].set_color('none')
ax3.spines['bottom'].set_color('none')
ax3.yaxis.set_ticks_position('none')
plt.setp(ax3.get_yticklabels(), visible=False)

plt.title('TTFB with IPv4', fontsize=12, y=1.05)
plt.savefig('./plots2020/gdriveMunich/TTFB_ipv4.png', format='png', bbox_inches='tight')

# %%
x = Cdf.MakeCdfFromList(quic43_6['TTFB'].values)
x1 =Cdf.MakeCdfFromList(quic46_6['TTFB'].values)
x3 = Cdf.MakeCdfFromList(quic50_6['TTFB'].values)
x5 = Cdf.MakeCdfFromList(quicietf_6['TTFB'].values)
x4 = Cdf.MakeCdfFromList(tcp13_6['TTFB'].values)
x2 =Cdf.MakeCdfFromList(tcp12_6['TTFB'].values)

# %%
fig = plt.figure(figsize = (10,3))
plt.rcParams['font.size'] = 12
ax = plt.gca()
yticks = np.arange(0,1.1,0.2)

#Q043
plt.plot(x.xs, x.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'orange')
#Q046
plt.plot(x1.xs, x1.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'red')
#Q050
plt.plot(x3.xs, x3.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'green')
#IETF
plt.plot(x5.xs, x5.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'blue')
#TLS1.2
plt.plot(x2.xs, x2.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'cyan')
#TLS1.3
plt.plot(x4.xs, x4.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'black')


ax = fig.axes[0]
ax.grid(False)
ax.set_yticks(yticks)
ax.set_ylim([0,1.05])
#ax.set_xlim([100,400])
#ax.set_xlim([0,10])
ax.set_xscale('log')
ax.set_xlabel('TTFB', fontsize=12)
ax.set_ylabel('CDF', fontsize=12)

plt.legend(['Q043', 'Q046', 'Q050', 'IETF', 'TLS1.2', 'TLS 1.3'], fontsize=11, loc='best')

ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.yaxis.set_ticks_position('left')
ax.xaxis.set_ticks_position('bottom')
ax.spines['bottom'].set_position(('axes', -0.05))
ax.spines['left'].set_position(('axes', -0.05))

ax3 = ax.twinx()
ax3.spines['right'].set_color('none')
ax3.spines['top'].set_color('none')
ax3.spines['left'].set_color('none')
ax3.spines['bottom'].set_color('none')
ax3.yaxis.set_ticks_position('none')
plt.setp(ax3.get_yticklabels(), visible=False)

plt.title('TTFB with IPv6', fontsize=12, y=1.05)
plt.savefig('./plots2020/gdriveMunich/TTFB_ipv6.png', format='png', bbox_inches='tight')

# %%
x = Cdf.MakeCdfFromList(quic43['TotalDownloadTime'].values)
x1 =Cdf.MakeCdfFromList(quic46['TotalDownloadTime'].values)
x3 = Cdf.MakeCdfFromList(quic50['TotalDownloadTime'].values)
x5 = Cdf.MakeCdfFromList(quicietf['TotalDownloadTime'].values)
x4 = Cdf.MakeCdfFromList(tcp13['TotalDownloadTime'].values)
x2 =Cdf.MakeCdfFromList(tcp12['TotalDownloadTime'].values)

# %%
fig = plt.figure(figsize = (10,3))
plt.rcParams['font.size'] = 12
ax = plt.gca()
yticks = np.arange(0,1.1,0.2)

#Q043
plt.plot(x.xs, x.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'orange')
#Q046
plt.plot(x1.xs, x1.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'red')
#Q050
plt.plot(x3.xs, x3.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'green')
#IETF
plt.plot(x5.xs, x5.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'blue')
#TLS1.2
plt.plot(x2.xs, x2.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'cyan')
#TLS1.3
plt.plot(x4.xs, x4.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'black')


ax = fig.axes[0]
ax.grid(False)
ax.set_yticks(yticks)
ax.set_ylim([0,1.05])
#ax.set_xlim([100,800])
#ax.set_xlim([0,10])
ax.set_xscale('log')
ax.set_xlabel('TotalDownloadTime', fontsize=12)
ax.set_ylabel('CDF', fontsize=12)

plt.legend(['Q043', 'Q046', 'Q050', 'IETF', 'TLS1.2', 'TLS 1.3'], fontsize=11, loc='best')

ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.yaxis.set_ticks_position('left')
ax.xaxis.set_ticks_position('bottom')
ax.spines['bottom'].set_position(('axes', -0.05))
ax.spines['left'].set_position(('axes', -0.05))

ax3 = ax.twinx()
ax3.spines['right'].set_color('none')
ax3.spines['top'].set_color('none')
ax3.spines['left'].set_color('none')
ax3.spines['bottom'].set_color('none')
ax3.yaxis.set_ticks_position('none')
plt.setp(ax3.get_yticklabels(), visible=False)

plt.title('TotalDownloadTime with IPv4', fontsize=12, y=1.05)
plt.savefig('./plots2020/gdriveMunich/TotalDownloadTime_ipv4.png', format='png', bbox_inches='tight')

# %%
x = Cdf.MakeCdfFromList(quic43_6['TotalDownloadTime'].values)
x1 =Cdf.MakeCdfFromList(quic46_6['TotalDownloadTime'].values)
x3 = Cdf.MakeCdfFromList(quic50_6['TotalDownloadTime'].values)
x5 = Cdf.MakeCdfFromList(quicietf_6['TotalDownloadTime'].values)
x4 = Cdf.MakeCdfFromList(tcp13_6['TotalDownloadTime'].values)
x2 =Cdf.MakeCdfFromList(tcp12_6['TotalDownloadTime'].values)

# %%
fig = plt.figure(figsize = (10,3))
plt.rcParams['font.size'] = 12
ax = plt.gca()
yticks = np.arange(0,1.1,0.2)

#Q043
plt.plot(x.xs, x.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'orange')
#Q046
plt.plot(x1.xs, x1.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'red')
#Q050
plt.plot(x3.xs, x3.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'green')
#IETF
plt.plot(x5.xs, x5.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'blue')
#TLS1.2
plt.plot(x2.xs, x2.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'cyan')
#TLS1.3
plt.plot(x4.xs, x4.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'black')


ax = fig.axes[0]
ax.grid(False)
ax.set_yticks(yticks)
ax.set_ylim([0,1.05])
#ax.set_xlim([100,800])
#ax.set_xlim([0,10])
ax.set_xscale('log')
ax.set_xlabel('TotalDownloadTime', fontsize=12)
ax.set_ylabel('CDF', fontsize=12)

plt.legend(['Q043', 'Q046', 'Q050', 'IETF', 'TLS1.2', 'TLS 1.3'], fontsize=11, loc='best')

ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.yaxis.set_ticks_position('left')
ax.xaxis.set_ticks_position('bottom')
ax.spines['bottom'].set_position(('axes', -0.05))
ax.spines['left'].set_position(('axes', -0.05))

ax3 = ax.twinx()
ax3.spines['right'].set_color('none')
ax3.spines['top'].set_color('none')
ax3.spines['left'].set_color('none')
ax3.spines['bottom'].set_color('none')
ax3.yaxis.set_ticks_position('none')
plt.setp(ax3.get_yticklabels(), visible=False)

plt.title('TotalDownloadTime with IPv6', fontsize=12, y=1.05)
plt.savefig('./plots2020/gdriveMunich/TotalDownloadTime_ipv6.png', format='png', bbox_inches='tight')

# %%
x = Cdf.MakeCdfFromList(quic43['Throughput'].values)
x1 =Cdf.MakeCdfFromList(quic46['Throughput'].values)
x3 = Cdf.MakeCdfFromList(quic50['Throughput'].values)
x5 = Cdf.MakeCdfFromList(quicietf['Throughput'].values)
x4 = Cdf.MakeCdfFromList(tcp13['Throughput'].values)
x2 =Cdf.MakeCdfFromList(tcp12['Throughput'].values)

# %%
fig = plt.figure(figsize = (10,3))
plt.rcParams['font.size'] = 12
ax = plt.gca()
yticks = np.arange(0,1.1,0.2)

#Q043
plt.plot(x.xs, x.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'orange')
#Q046
plt.plot(x1.xs, x1.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'red')
#Q050
plt.plot(x3.xs, x3.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'green')
#IETF
plt.plot(x5.xs, x5.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'blue')
#TLS1.2
plt.plot(x2.xs, x2.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'cyan')
#TLS1.3
plt.plot(x4.xs, x4.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'black')


ax = fig.axes[0]
ax.grid(False)
ax.set_yticks(yticks)
ax.set_ylim([0,1.05])
#ax.set_xlim([0,700])
#ax.set_xlim([0,10])
ax.set_xscale('log')
ax.set_xlabel('Throughput in MB/s', fontsize=12)
ax.set_ylabel('CDF', fontsize=12)

plt.legend(['Q043', 'Q046', 'Q050', 'IETF', 'TLS1.2', 'TLS 1.3'], fontsize=11, loc='best')

ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.yaxis.set_ticks_position('left')
ax.xaxis.set_ticks_position('bottom')
ax.spines['bottom'].set_position(('axes', -0.05))
ax.spines['left'].set_position(('axes', -0.05))

ax3 = ax.twinx()
ax3.spines['right'].set_color('none')
ax3.spines['top'].set_color('none')
ax3.spines['left'].set_color('none')
ax3.spines['bottom'].set_color('none')
ax3.yaxis.set_ticks_position('none')
plt.setp(ax3.get_yticklabels(), visible=False)

plt.title('Throughput with IPv4', fontsize=12, y=1.05)
plt.savefig('./plots2020/gdriveMunich/Throughput_ipv4.png', format='png', bbox_inches='tight')

# %%
x = Cdf.MakeCdfFromList(quic43_6['Throughput'].values)
x1 =Cdf.MakeCdfFromList(quic46_6['Throughput'].values)
x3 = Cdf.MakeCdfFromList(quic50_6['Throughput'].values)
x5 = Cdf.MakeCdfFromList(quicietf_6['Throughput'].values)
x4 = Cdf.MakeCdfFromList(tcp13_6['Throughput'].values)
x2 =Cdf.MakeCdfFromList(tcp12_6['Throughput'].values)

# %%
fig = plt.figure(figsize = (10,3))
plt.rcParams['font.size'] = 12
ax = plt.gca()
yticks = np.arange(0,1.1,0.2)

#Q043
plt.plot(x.xs, x.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'orange')
#Q046
plt.plot(x1.xs, x1.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'red')
#Q050
plt.plot(x3.xs, x3.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'green')
#IETF
plt.plot(x5.xs, x5.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'blue')
#TLS1.2
plt.plot(x2.xs, x2.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'cyan')
#TLS1.3
plt.plot(x4.xs, x4.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'black')


ax = fig.axes[0]
ax.grid(False)
ax.set_yticks(yticks)
ax.set_ylim([0,1.05])
#ax.set_xlim([0,700])
#ax.set_xlim([0,10])
ax.set_xscale('log')
ax.set_xlabel('Throughput in MB/s', fontsize=12)
ax.set_ylabel('CDF', fontsize=12)

plt.legend(['Q043', 'Q039', 'Q044', 'Q035', 'TLS1.2', 'TLS 1.3'], fontsize=11, loc='best')

ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.yaxis.set_ticks_position('left')
ax.xaxis.set_ticks_position('bottom')
ax.spines['bottom'].set_position(('axes', -0.05))
ax.spines['left'].set_position(('axes', -0.05))

ax3 = ax.twinx()
ax3.spines['right'].set_color('none')
ax3.spines['top'].set_color('none')
ax3.spines['left'].set_color('none')
ax3.spines['bottom'].set_color('none')
ax3.yaxis.set_ticks_position('none')
plt.setp(ax3.get_yticklabels(), visible=False)

plt.title('Throughput with IPv6', fontsize=12, y=1.05)
plt.savefig('./plots2020/gdriveMunich/Throughput_ipv6.png', format='png', bbox_inches='tight')

# %%
quic_mean= quic4.groupby('size', as_index=False).mean()
tcp_mean= tcp4.groupby('size', as_index=False).mean()

quic_mean.head()

quic_mean.tail()
# Out:
#    size  TimeOfMeasurement   Port   DNSTime  ConnectionEstablishmentTime  \
# 3    10       1.589265e+09  443.0  0.950384                    34.110203
# 4    20       1.589265e+09  443.0  0.954068                    33.979582
# 5    50       1.589264e+09  443.0  1.055467                    33.934755
# 6   100       1.589264e+09  443.0  0.912574                    33.913682
# 7   200       1.589264e+09  443.0  0.958669                    33.986303
#
#          TTFB  TotalDownloadTime  HttpResponse  Throughput
# 3  457.471693         457.564160         403.0    0.102921
# 4  455.387019         455.475810         403.0    0.180865
# 5  473.760873         473.231316         403.0    1.019589
# 6  468.711966         467.562191         403.0    4.303652
# 7  488.753921         488.849627         403.0    1.579158

# %%
fig = plt.figure(figsize = (20,6))
plt.rcParams['font.size'] = 12
ax = plt.gca()
#yticks = np.arange(1000,100000000,10000)

#Quic
#plt.plot(quic4['size'], quic4['Throughput'], marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'orange')

#plt.plot(tcp4['size'], tcp4['Throughput'], marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'blue')
plt.plot(quic_mean['size'], quic_mean['Throughput'], marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'orange')

plt.plot(tcp_mean['size'], tcp_mean['Throughput'], marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'blue')

ax = fig.axes[0]
ax.grid(False)
#ax.set_yticks(yticks)
#ax.set_ylim([0,1.05])
#ax.set_xlim([0,700])
#ax.set_xlim([0,10])
ax.set_xscale('linear')
ax.set_xlabel('Size in KB', fontsize=12)
ax.set_ylabel('Throughput in MB/s', fontsize=12)

plt.legend(['Quic', 'TLS'], fontsize=11, loc='best')

ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.yaxis.set_ticks_position('left')
ax.xaxis.set_ticks_position('bottom')
ax.spines['bottom'].set_position(('axes', -0.05))
ax.spines['left'].set_position(('axes', -0.05))

ax3 = ax.twinx()
ax3.spines['right'].set_color('none')
ax3.spines['top'].set_color('none')
ax3.spines['left'].set_color('none')
ax3.spines['bottom'].set_color('none')
ax3.yaxis.set_ticks_position('none')
plt.setp(ax3.get_yticklabels(), visible=False)

plt.title('Size vs Throughput_ipv4', fontsize=12, y=1.05)
plt.savefig('./plots2020/gdriveMunich/sizevsThroughput_ipv4.png', format='png', bbox_inches='tight')

# %%
quic_mean= quic6.groupby('size', as_index=False).mean()
tcp_mean= tcp6.groupby('size', as_index=False).mean()

quic_mean.head()

quic_mean.tail()
# Out:
#       size  TimeOfMeasurement   Port   DNSTime  ConnectionEstablishmentTime  \
# 11    5000       1.589264e+09  443.0  1.143972                    33.584736
# 12   10000       1.589264e+09  443.0  1.225406                    33.061660
# 13   20000       1.589264e+09  443.0  0.964068                    32.972646
# 14   50000       1.589264e+09  443.0  0.971245                    33.007821
# 15  100000       1.589264e+09  443.0  1.340986                    33.025248
#
#           TTFB  TotalDownloadTime  HttpResponse  Throughput
# 11  466.171102         465.722241         403.0  106.757367
# 12  474.471713         474.569854         403.0  157.926400
# 13  480.596038         480.695789         403.0  162.454411
# 14  485.228883         485.325318         403.0  390.424743
# 15  475.549122         475.648027         403.0  743.772004

# %%
fig = plt.figure(figsize = (20,6))
plt.rcParams['font.size'] = 12
ax = plt.gca()
#yticks = np.arange(1000,100000000,10000)

#Quic
#plt.plot(quic6['size'], quic6['Throughput'], marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'orange')

#plt.plot(tcp6['size'], tcp6['Throughput'], marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'blue')
plt.plot(quic_mean['size'], quic_mean['Throughput'], marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'orange')

plt.plot(tcp_mean['size'], tcp_mean['Throughput'], marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'blue')

ax = fig.axes[0]
ax.grid(False)
#ax.set_yticks(yticks)
#ax.set_ylim([0,1.05])
#ax.set_xlim([0,700])
#ax.set_xlim([0,10])
ax.set_xscale('linear')
ax.set_xlabel('Size in KB', fontsize=12)
ax.set_ylabel('Throughput in MB/s', fontsize=12)

plt.legend(['Quic', 'TLS'], fontsize=11, loc='best')

ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.yaxis.set_ticks_position('left')
ax.xaxis.set_ticks_position('bottom')
ax.spines['bottom'].set_position(('axes', -0.05))
ax.spines['left'].set_position(('axes', -0.05))

ax3 = ax.twinx()
ax3.spines['right'].set_color('none')
ax3.spines['top'].set_color('none')
ax3.spines['left'].set_color('none')
ax3.spines['bottom'].set_color('none')
ax3.yaxis.set_ticks_position('none')
plt.setp(ax3.get_yticklabels(), visible=False)

plt.title('Size vs Throughput_ipv6', fontsize=12, y=1.05)
plt.savefig('./plots2020/gdriveMunich/sizevsThroughput_ipv6.png', format='png', bbox_inches='tight')
