# %%
import pandas as pd
import numpy as np
import matplotlib
matplotlib.use('PS') 
import matplotlib.pyplot as plt
import time
import datetime
import filterbyip as fbi
import Cdf
import Pmf

# %%
def print_percentiles(c, name):
    if c == 0:
        return null
    else:
        print('-----------------------------\n')
        print('percentile values distribution for %s\n' % name)

        print('20th Percentile:%f\n' % c.Percentile(20))    
        print('25th Percentile:%f\n' % c.Percentile(25))
        print('40th Percentile:%f\n' % c.Percentile(40))
        print('50th Percentile:%f\n' % c.Percentile(50))
        print('60th Percentile:%f\n' % c.Percentile(60))
        print('75th Percentile:%f\n' % c.Percentile(75))
        print('80th Percentile:%f\n' % c.Percentile(80))    
        print('90th Percentile:%f\n' % c.Percentile(90))
        print('99th Percentile:%f\n' % c.Percentile(99))

        print('-----------------------------\n')

# %%
def write_percentiles(filename, c):
	with open(filename, 'w') as f:
		f.write('values; percentile\n')
		for x, y in zip(c.xs, c.ps):
			f.write('%.2f, %.2f\n'%(x, y))

# %%
# %autosave 20
# Out:
# Autosaving every 20 seconds

# %%
import warnings
warnings.filterwarnings('ignore')

# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from IPython.core.display import HTML
css = open('style-table.css').read() + open('style-notebook.css').read()
HTML('<style>{}</style>'.format(css))
# Out:
# <style>body {
#     margin: 0;
#     font-family: Helvetica;
# }
# table.dataframe {
#     border-collapse: collapse;
#     border: none;
# }
# table.dataframe tr {
#     border: none;
# }
# table.dataframe td, table.dataframe th {
#     margin: 0;
#     border: 1px solid white;
#     padding-left: 0.25em;
#     padding-right: 0.25em;
# }
# table.dataframe th:not(:empty) {
#     background-color: #fec;
#     text-align: left;
#     font-weight: normal;
# }
# table.dataframe tr:nth-child(2) th:empty {
#     border-left: none;
#     border-right: 1px dashed #888;
# }
# table.dataframe td {
#     border: 2px solid #ccf;
#     background-color: #f4f4ff;
# }
# h3 {
#     color: white;
#     background-color: black;
#     padding: 0.5em;
# }
#
# .CodeMirror {
#     font-family: 'Consolas';
# }
#
# div.cell.code_cell {
#     font-family: 'Consolas';
# }
#
# div.output_area pre {
#     font-family: 'Consolas';
# }
# </style>

# %%
tcp_tls_data = "./AWS_results/CapeTown/data/output_curl_data.csv"
quic_data = "./AWS_results/CapeTown/data/output_quic.csv"

# %%
scol_names = ['TimeOfMeasurement', 'Url', 'Ip', 'Port', 'DnsLookupTime', 'TCPHandshakeTime', 'ConnectionEstablishmentTime', 'TTFB', 'TotalDownloadTime', 'HttpResponse', 'HTTPVersion', 'Protocol']
tcol_names = ['TimeOfMeasurement', 'Url', 'Path', 'Ip', 'Port', 'DNSTime', 'ConnectionEstablishmentTime', 'TTFB', 'TotalDownloadTime', 'HttpResponse', 'Protocol']

# %%
t = pd.read_csv(quic_data, ';', names=tcol_names, header=None)
s = pd.read_csv(tcp_tls_data, ';', names=scol_names, header=None)

# %%
t = t.dropna()
s = s.dropna()

# %%
#t = t[t['TimeOfMeasurement'] > 1581721201]
#s = s[s['TimeOfMeasurement'] > 1581721201]

# %%
s['TTFB']=s['TTFB']-s['DnsLookupTime']
s['TotalDownloadTime']=s['TotalDownloadTime']-s['DnsLookupTime']

# %%
s.count()
# Out:
# TimeOfMeasurement              1349329
# Url                            1349329
# Ip                             1349329
# Port                           1349329
# DnsLookupTime                  1349329
# TCPHandshakeTime               1349329
# ConnectionEstablishmentTime    1349329
# TTFB                           1349329
# TotalDownloadTime              1349329
# HttpResponse                   1349329
# HTTPVersion                    1349329
# Protocol                       1349329
# dtype: int64

# %%
s.head()
# Out:
#    TimeOfMeasurement             Url              Ip  Port  DnsLookupTime  \
# 0         1589587201  www.google.com  172.217.170.36   443          4.148
# 1         1589587202  www.google.com  172.217.170.36   443          4.162
# 2         1589587203    facebook.com   185.60.219.35   443        252.904
# 3         1589587203    facebook.com   185.60.219.35   443          4.143
# 4         1589587204    facebook.com   185.60.219.35   443          4.143
#
#    TCPHandshakeTime  ConnectionEstablishmentTime     TTFB  TotalDownloadTime  \
# 0            16.342                      242.914  481.779            509.655
# 1            16.413                      255.056  480.821            502.341
# 2            16.281                       82.231  316.124            316.146
# 3            16.256                       66.961  294.778            294.801
# 4            16.320                       83.363  313.633            313.657
#
#    HttpResponse HTTPVersion    Protocol
# 0           200    HTTP/1.1  TCP/TLS1.2
# 1           200       HTTP2  TCP/TLS1.2
# 2           301    HTTP/1.1  TCP/TLS1.2
# 3           301    HTTP/1.1  TCP/TLS1.3
# 4           301       HTTP2  TCP/TLS1.2

# %%
t.count()
# Out:
# TimeOfMeasurement              744283
# Url                            744283
# Path                           744283
# Ip                             744283
# Port                           744283
# DNSTime                        744283
# ConnectionEstablishmentTime    744283
# TTFB                           744283
# TotalDownloadTime              744283
# HttpResponse                   744283
# Protocol                       744283
# dtype: int64

# %%
t.head()
# Out:
#    TimeOfMeasurement                        Url Path              Ip Port  \
# 0       1.589587e+09  www.0dayrox2.blogspot.com    /  172.217.170.65  443
# 1       1.589587e+09  www.0dayrox2.blogspot.com    /  172.217.170.65  443
# 2       1.589587e+09  www.0dayrox2.blogspot.com    /  172.217.170.65  443
# 8       1.589587e+09   www.0dayrox.blogspot.com    /  172.217.170.33  443
# 9       1.589587e+09   www.0dayrox.blogspot.com    /  172.217.170.33  443
#
#    DNSTime  ConnectionEstablishmentTime     TTFB  TotalDownloadTime  \
# 0  347.245                      372.930  318.241            678.709
# 1    0.423                      364.186  800.422            160.957
# 2    0.350                      365.495  273.920            651.475
# 8  341.801                      373.314  788.356            151.801
# 9    0.366                      371.684  778.456            139.038
#
#    HttpResponse Protocol
# 0         404.0     Q043
# 1         404.0     Q046
# 2         404.0     Q050
# 8         404.0     Q043
# 9         404.0     Q046

# %%
def timestamp2human(timestamp):
    return datetime.datetime.fromtimestamp(int(timestamp)).strftime('%c')

# %%
s['TimeOfMeasurement'] = s['TimeOfMeasurement'].apply(timestamp2human)

# %%
s.head()
# Out:
#           TimeOfMeasurement             Url              Ip  Port  \
# 0  Sat May 16 02:00:01 2020  www.google.com  172.217.170.36   443
# 1  Sat May 16 02:00:02 2020  www.google.com  172.217.170.36   443
# 2  Sat May 16 02:00:03 2020    facebook.com   185.60.219.35   443
# 3  Sat May 16 02:00:03 2020    facebook.com   185.60.219.35   443
# 4  Sat May 16 02:00:04 2020    facebook.com   185.60.219.35   443
#
#    DnsLookupTime  TCPHandshakeTime  ConnectionEstablishmentTime     TTFB  \
# 0          4.148            16.342                      242.914  481.779
# 1          4.162            16.413                      255.056  480.821
# 2        252.904            16.281                       82.231  316.124
# 3          4.143            16.256                       66.961  294.778
# 4          4.143            16.320                       83.363  313.633
#
#    TotalDownloadTime  HttpResponse HTTPVersion    Protocol
# 0            509.655           200    HTTP/1.1  TCP/TLS1.2
# 1            502.341           200       HTTP2  TCP/TLS1.2
# 2            316.146           301    HTTP/1.1  TCP/TLS1.2
# 3            294.801           301    HTTP/1.1  TCP/TLS1.3
# 4            313.657           301       HTTP2  TCP/TLS1.2

# %%
s.tail()
# Out:
#                 TimeOfMeasurement                        Url              Ip  \
# 1349324  Wed May 20 17:43:05 2020                 flaconi.de  54.208.219.191
# 1349325  Wed May 20 17:43:05 2020  www.herecomestheguide.com   104.22.11.240
# 1349326  Wed May 20 17:43:06 2020                fanproj.com   193.39.255.52
# 1349327  Wed May 20 17:43:06 2020             www.buanzo.org     104.26.6.52
# 1349328  Wed May 20 17:43:06 2020               biquxuan.com   104.27.184.55
#
#          Port  DnsLookupTime  TCPHandshakeTime  ConnectionEstablishmentTime  \
# 1349324   443         28.273           215.938                      685.568
# 1349325   443        252.805           141.499                      466.547
# 1349326   443        252.742           147.329                      492.612
# 1349327   443         28.284           141.853                      461.539
# 1349328   443         28.285           141.469                      476.330
#
#              TTFB  TotalDownloadTime  HttpResponse HTTPVersion    Protocol
# 1349324   901.970            901.988           301    HTTP/1.1  TCP/TLS1.2
# 1349325  1113.622           1351.590           200    HTTP/1.1  TCP/TLS1.2
# 1349326   640.685            684.284           302    HTTP/1.1  TCP/TLS1.2
# 1349327   898.440            898.468           302    HTTP/1.1  TCP/TLS1.2
# 1349328   809.457            809.495           301    HTTP/1.1  TCP/TLS1.2

# %%
#t['TimeOfMeasurement'] = t['TimeOfMeasurement'].apply(timestamp2human)

# %%
t.head()
# Out:
#    TimeOfMeasurement                        Url Path              Ip Port  \
# 0       1.589587e+09  www.0dayrox2.blogspot.com    /  172.217.170.65  443
# 1       1.589587e+09  www.0dayrox2.blogspot.com    /  172.217.170.65  443
# 2       1.589587e+09  www.0dayrox2.blogspot.com    /  172.217.170.65  443
# 8       1.589587e+09   www.0dayrox.blogspot.com    /  172.217.170.33  443
# 9       1.589587e+09   www.0dayrox.blogspot.com    /  172.217.170.33  443
#
#    DNSTime  ConnectionEstablishmentTime     TTFB  TotalDownloadTime  \
# 0  347.245                      372.930  318.241            678.709
# 1    0.423                      364.186  800.422            160.957
# 2    0.350                      365.495  273.920            651.475
# 8  341.801                      373.314  788.356            151.801
# 9    0.366                      371.684  778.456            139.038
#
#    HttpResponse Protocol
# 0         404.0     Q043
# 1         404.0     Q046
# 2         404.0     Q050
# 8         404.0     Q043
# 9         404.0     Q046

# %%
t.tail()
# Out:
#          TimeOfMeasurement                                    Url Path  \
# 2112243       1.589989e+09  www.eigo-net-slang-jiten.blogspot.com    /
# 2112244       1.589989e+09         www.linuxiumcomau.blogspot.com    /
# 2112245       1.589989e+09  www.eigo-net-slang-jiten.blogspot.com    /
# 2112251       1.589989e+09         www.linuxiumcomau.blogspot.com    /
# 2112252       1.589989e+09         www.linuxiumcomau.blogspot.com    /
#
#                      Ip Port  DNSTime  ConnectionEstablishmentTime     TTFB  \
# 2112243  216.58.223.129  443    1.017                      382.325  727.119
# 2112244  216.58.223.129  443  170.449                      382.129  752.708
# 2112245  172.217.170.33  443    1.244                      382.812  713.655
# 2112251  216.58.223.129  443  170.173                      373.044  727.269
# 2112252  216.58.223.129  443    1.186                      374.318  733.448
#
#          TotalDownloadTime  HttpResponse Protocol
# 2112243            727.166         301.0     Q046
# 2112244            752.743         301.0     Q043
# 2112245            713.706         301.0     Q050
# 2112251            727.314         301.0     Q046
# 2112252            733.492         301.0     Q050

# %%
def filter_by_ip(df, column):
  """reads a DataFrame, calls fbi.filter_v{4,6} to get DataFrames with rows
     containing only v4, v6 endpoints. Returns the two DataFrame as a tuple"""

  dfv6 = fbi.filter_v6(df, column)
  dfv4 = fbi.filter_v4(df, column)
  return dfv4, dfv6

# %%
#quic4, quic6 = filter_by_ip(t, column = 'Ip')
quic4 = t[t['Ip'].str.contains("\.")]
quic6 = t[t['Ip'].str.contains("\:")]

# %%
quic4.count()
# Out:
# TimeOfMeasurement              744283
# Url                            744283
# Path                           744283
# Ip                             744283
# Port                           744283
# DNSTime                        744283
# ConnectionEstablishmentTime    744283
# TTFB                           744283
# TotalDownloadTime              744283
# HttpResponse                   744283
# Protocol                       744283
# dtype: int64

# %%
quic4.head()
# Out:
#    TimeOfMeasurement                        Url Path              Ip Port  \
# 0       1.589587e+09  www.0dayrox2.blogspot.com    /  172.217.170.65  443
# 1       1.589587e+09  www.0dayrox2.blogspot.com    /  172.217.170.65  443
# 2       1.589587e+09  www.0dayrox2.blogspot.com    /  172.217.170.65  443
# 8       1.589587e+09   www.0dayrox.blogspot.com    /  172.217.170.33  443
# 9       1.589587e+09   www.0dayrox.blogspot.com    /  172.217.170.33  443
#
#    DNSTime  ConnectionEstablishmentTime     TTFB  TotalDownloadTime  \
# 0  347.245                      372.930  318.241            678.709
# 1    0.423                      364.186  800.422            160.957
# 2    0.350                      365.495  273.920            651.475
# 8  341.801                      373.314  788.356            151.801
# 9    0.366                      371.684  778.456            139.038
#
#    HttpResponse Protocol
# 0         404.0     Q043
# 1         404.0     Q046
# 2         404.0     Q050
# 8         404.0     Q043
# 9         404.0     Q046

# %%
quic6.count()
# Out:
# TimeOfMeasurement              0
# Url                            0
# Path                           0
# Ip                             0
# Port                           0
# DNSTime                        0
# ConnectionEstablishmentTime    0
# TTFB                           0
# TotalDownloadTime              0
# HttpResponse                   0
# Protocol                       0
# dtype: int64

# %%
quic6.head()
# Out:
# Empty DataFrame
# Columns: [TimeOfMeasurement, Url, Path, Ip, Port, DNSTime, ConnectionEstablishmentTime, TTFB, TotalDownloadTime, HttpResponse, Protocol]
# Index: []

# %%
#tcp4, tcp6 = filter_by_ip(s, column = 'Ip')
tcp4 = s[s['Ip'].str.contains("\.")]
tcp6 = s[s['Ip'].str.contains("\:")]

# %%
tcp4.count()
# Out:
# TimeOfMeasurement              1349329
# Url                            1349329
# Ip                             1349329
# Port                           1349329
# DnsLookupTime                  1349329
# TCPHandshakeTime               1349329
# ConnectionEstablishmentTime    1349329
# TTFB                           1349329
# TotalDownloadTime              1349329
# HttpResponse                   1349329
# HTTPVersion                    1349329
# Protocol                       1349329
# dtype: int64

# %%
tcp4.head()
# Out:
#           TimeOfMeasurement             Url              Ip  Port  \
# 0  Sat May 16 02:00:01 2020  www.google.com  172.217.170.36   443
# 1  Sat May 16 02:00:02 2020  www.google.com  172.217.170.36   443
# 2  Sat May 16 02:00:03 2020    facebook.com   185.60.219.35   443
# 3  Sat May 16 02:00:03 2020    facebook.com   185.60.219.35   443
# 4  Sat May 16 02:00:04 2020    facebook.com   185.60.219.35   443
#
#    DnsLookupTime  TCPHandshakeTime  ConnectionEstablishmentTime     TTFB  \
# 0          4.148            16.342                      242.914  481.779
# 1          4.162            16.413                      255.056  480.821
# 2        252.904            16.281                       82.231  316.124
# 3          4.143            16.256                       66.961  294.778
# 4          4.143            16.320                       83.363  313.633
#
#    TotalDownloadTime  HttpResponse HTTPVersion    Protocol
# 0            509.655           200    HTTP/1.1  TCP/TLS1.2
# 1            502.341           200       HTTP2  TCP/TLS1.2
# 2            316.146           301    HTTP/1.1  TCP/TLS1.2
# 3            294.801           301    HTTP/1.1  TCP/TLS1.3
# 4            313.657           301       HTTP2  TCP/TLS1.2

# %%
tcp6.count()
# Out:
# TimeOfMeasurement              0
# Url                            0
# Ip                             0
# Port                           0
# DnsLookupTime                  0
# TCPHandshakeTime               0
# ConnectionEstablishmentTime    0
# TTFB                           0
# TotalDownloadTime              0
# HttpResponse                   0
# HTTPVersion                    0
# Protocol                       0
# dtype: int64

# %%
tcp6.head()
# Out:
# Empty DataFrame
# Columns: [TimeOfMeasurement, Url, Ip, Port, DnsLookupTime, TCPHandshakeTime, ConnectionEstablishmentTime, TTFB, TotalDownloadTime, HttpResponse, HTTPVersion, Protocol]
# Index: []

# %%
quic43 = quic4.loc[t['Protocol'] == 'Q043']
quic46 = quic4.loc[t['Protocol'] == 'Q046']
quic50 = quic4.loc[t['Protocol'] == 'Q050']
quicID24 = quic4.loc[t['Protocol'] == 'FF000018']
quic98 = quic4.loc[t['Protocol'] == '']

# %%
quic43.count()
# Out:
# TimeOfMeasurement              249584
# Url                            249584
# Path                           249584
# Ip                             249584
# Port                           249584
# DNSTime                        249584
# ConnectionEstablishmentTime    249584
# TTFB                           249584
# TotalDownloadTime              249584
# HttpResponse                   249584
# Protocol                       249584
# dtype: int64

# %%
quic43.head()
# Out:
#     TimeOfMeasurement                                      Url Path  \
# 0        1.589587e+09                www.0dayrox2.blogspot.com    /
# 8        1.589587e+09                 www.0dayrox.blogspot.com    /
# 16       1.589587e+09  www.100leccionesdeguitarra.blogspot.com    /
# 24       1.589587e+09                      www.100negocios.com    /
# 40       1.589587e+09                 www.1100021.blogspot.com    /
#
#                 Ip Port  DNSTime  ConnectionEstablishmentTime     TTFB  \
# 0   172.217.170.65  443  347.245                      372.930  318.241
# 8   172.217.170.33  443  341.801                      373.314  788.356
# 16  216.58.223.129  443  335.728                      372.671  710.640
# 24   66.198.240.11  443  754.037                      491.258  275.414
# 40  216.58.223.129  443  335.093                      363.384  274.837
#
#     TotalDownloadTime  HttpResponse Protocol
# 0             678.709         404.0     Q043
# 8             151.801         404.0     Q043
# 16            710.682         301.0     Q043
# 24            846.099         200.0     Q043
# 40            274.886         301.0     Q043

# %%
quic43.tail()
# Out:
#          TimeOfMeasurement                                    Url Path  \
# 2112211       1.589989e+09              www.egyyfast.blogspot.com    /
# 2112226       1.589989e+09              www.ehsaas71.blogspot.com    /
# 2112227       1.589989e+09    www.linuxdicasesuporte.blogspot.com    /
# 2112242       1.589989e+09  www.eigo-net-slang-jiten.blogspot.com    /
# 2112244       1.589989e+09         www.linuxiumcomau.blogspot.com    /
#
#                      Ip Port  DNSTime  ConnectionEstablishmentTime     TTFB  \
# 2112211  172.217.170.65  443  169.425                      379.025  726.000
# 2112226  216.58.223.129  443  166.443                      382.462  721.717
# 2112227  216.58.223.129  443  170.881                      377.827  765.806
# 2112242  216.58.223.129  443  168.907                      369.763  717.225
# 2112244  216.58.223.129  443  170.449                      382.129  752.708
#
#          TotalDownloadTime  HttpResponse Protocol
# 2112211            726.049         301.0     Q043
# 2112226            721.933         301.0     Q043
# 2112227            765.839         301.0     Q043
# 2112242            717.317         301.0     Q043
# 2112244            752.743         301.0     Q043

# %%
quic46.count()
# Out:
# TimeOfMeasurement              246958
# Url                            246958
# Path                           246958
# Ip                             246958
# Port                           246958
# DNSTime                        246958
# ConnectionEstablishmentTime    246958
# TTFB                           246958
# TotalDownloadTime              246958
# HttpResponse                   246958
# Protocol                       246958
# dtype: int64

# %%
quic46.head()
# Out:
#     TimeOfMeasurement                                      Url Path  \
# 1        1.589587e+09                www.0dayrox2.blogspot.com    /
# 9        1.589587e+09                 www.0dayrox.blogspot.com    /
# 17       1.589587e+09  www.100leccionesdeguitarra.blogspot.com    /
# 25       1.589587e+09                      www.100negocios.com    /
# 41       1.589587e+09                 www.1100021.blogspot.com    /
#
#                 Ip Port  DNSTime  ConnectionEstablishmentTime     TTFB  \
# 1   172.217.170.65  443    0.423                      364.186  800.422
# 9   172.217.170.33  443    0.366                      371.684  778.456
# 17  216.58.223.129  443    0.364                      364.597  700.345
# 25   66.198.240.11  443    0.337                      491.489  218.640
# 41  216.58.223.129  443    0.376                      372.372  726.923
#
#     TotalDownloadTime  HttpResponse Protocol
# 1             160.957         404.0     Q046
# 9             139.038         404.0     Q046
# 17            700.390         301.0     Q046
# 25            790.981         200.0     Q046
# 41            726.976         301.0     Q046

# %%
quic46.tail()
# Out:
#          TimeOfMeasurement                                    Url Path  \
# 2112213       1.589989e+09              www.egyyfast.blogspot.com    /
# 2112228       1.589989e+09              www.ehsaas71.blogspot.com    /
# 2112229       1.589989e+09    www.linuxdicasesuporte.blogspot.com    /
# 2112243       1.589989e+09  www.eigo-net-slang-jiten.blogspot.com    /
# 2112251       1.589989e+09         www.linuxiumcomau.blogspot.com    /
#
#                      Ip Port  DNSTime  ConnectionEstablishmentTime     TTFB  \
# 2112213  216.58.223.129  443  169.257                      376.082  708.042
# 2112228   172.217.170.1  443  166.115                      398.820  747.995
# 2112229  216.58.223.129  443  166.304                      375.458  762.597
# 2112243  216.58.223.129  443    1.017                      382.325  727.119
# 2112251  216.58.223.129  443  170.173                      373.044  727.269
#
#          TotalDownloadTime  HttpResponse Protocol
# 2112213            708.094         301.0     Q046
# 2112228            748.040         301.0     Q046
# 2112229            762.925         301.0     Q046
# 2112243            727.166         301.0     Q046
# 2112251            727.314         301.0     Q046

# %%
quic50.count()
# Out:
# TimeOfMeasurement              244226
# Url                            244226
# Path                           244226
# Ip                             244226
# Port                           244226
# DNSTime                        244226
# ConnectionEstablishmentTime    244226
# TTFB                           244226
# TotalDownloadTime              244226
# HttpResponse                   244226
# Protocol                       244226
# dtype: int64

# %%
quic50.head()
# Out:
#     TimeOfMeasurement                                      Url Path  \
# 2        1.589587e+09                www.0dayrox2.blogspot.com    /
# 10       1.589587e+09                 www.0dayrox.blogspot.com    /
# 18       1.589587e+09  www.100leccionesdeguitarra.blogspot.com    /
# 26       1.589587e+09                      www.100negocios.com    /
# 42       1.589587e+09                 www.1100021.blogspot.com    /
#
#                 Ip Port  DNSTime  ConnectionEstablishmentTime     TTFB  \
# 2   172.217.170.65  443    0.350                      365.495  273.920
# 10  172.217.170.33  443    0.371                      367.150  791.875
# 18  216.58.223.129  443    0.378                      369.371  691.907
# 26   66.198.240.11  443    0.377                      491.364  227.626
# 42  216.58.223.129  443    0.437                      363.318  725.682
#
#     TotalDownloadTime  HttpResponse Protocol
# 2             651.475         404.0     Q050
# 10            150.681         404.0     Q050
# 18            691.950         301.0     Q050
# 26            824.312         200.0     Q050
# 42            725.729         301.0     Q050

# %%
quic50.tail()
# Out:
#          TimeOfMeasurement                                    Url Path  \
# 2112220       1.589989e+09         www.linux-avenger.blogspot.com    /
# 2112230       1.589989e+09              www.ehsaas71.blogspot.com    /
# 2112236       1.589989e+09    www.linuxdicasesuporte.blogspot.com    /
# 2112245       1.589989e+09  www.eigo-net-slang-jiten.blogspot.com    /
# 2112252       1.589989e+09         www.linuxiumcomau.blogspot.com    /
#
#                      Ip Port  DNSTime  ConnectionEstablishmentTime     TTFB  \
# 2112220  172.217.170.65  443    0.410                      379.986  900.078
# 2112230   172.217.170.1  443    0.964                      379.658  732.490
# 2112236   172.217.170.1  443  166.643                      382.052  745.859
# 2112245  172.217.170.33  443    1.244                      382.812  713.655
# 2112252  216.58.223.129  443    1.186                      374.318  733.448
#
#          TotalDownloadTime  HttpResponse Protocol
# 2112220            900.121         301.0     Q050
# 2112230            732.536         301.0     Q050
# 2112236            745.912         301.0     Q050
# 2112245            713.706         301.0     Q050
# 2112252            733.492         301.0     Q050

# %%
quicID24.count()
# Out:
# TimeOfMeasurement              3515
# Url                            3515
# Path                           3515
# Ip                             3515
# Port                           3515
# DNSTime                        3515
# ConnectionEstablishmentTime    3515
# TTFB                           3515
# TotalDownloadTime              3515
# HttpResponse                   3515
# Protocol                       3515
# dtype: int64

# %%
quicID24.head()
# Out:
#       TimeOfMeasurement                        Url Path               Ip Port  \
# 554        1.589588e+09       www.9999999views.com    /   178.32.108.178  443
# 1053       1.589588e+09  www.afriqueconnection.com    /    72.249.49.210  443
# 1249       1.589588e+09             www.akaian.com    /     150.95.55.38  443
# 1517       1.589588e+09            www.allzine.org    /  194.150.248.139  443
# 1597       1.589588e+09      www.altoonaworks.info    /    72.249.49.192  443
#
#       DNSTime  ConnectionEstablishmentTime     TTFB  TotalDownloadTime  \
# 554     0.438                      150.336  299.309            299.362
# 1053    0.370                      259.223  654.761            308.426
# 1249    0.431                      529.180  907.700            907.740
# 1517    0.398                      187.820  378.090            378.130
# 1597    0.410                      405.577  660.963            667.646
#
#       HttpResponse  Protocol
# 554          301.0  FF000018
# 1053         200.0  FF000018
# 1249         301.0  FF000018
# 1517         200.0  FF000018
# 1597         200.0  FF000018

# %%
quicID24.tail()
# Out:
#          TimeOfMeasurement                     Url Path               Ip Port  \
# 2109977       1.589989e+09     www.kmfnandini.coop    /    65.99.240.118  443
# 2110462       1.589989e+09       www.kpop24hrs.com    /    103.82.250.60  443
# 2110787       1.589989e+09  www.tehnicavizuala.com    /  176.126.202.166  443
# 2111167       1.589989e+09   www.language.exchange    /    51.77.170.153  443
# 2111661       1.589989e+09     www.dynamictic.info    /   188.165.14.151  443
#
#          DNSTime  ConnectionEstablishmentTime     TTFB  TotalDownloadTime  \
# 2109977    5.635                      405.775  695.525            262.226
# 2110462    0.303                      419.220  692.561            692.609
# 2110787    0.457                      351.148  549.266            549.290
# 2111167    0.361                      301.798  450.943            450.990
# 2111661    0.328                      299.803  448.734            448.783
#
#          HttpResponse  Protocol
# 2109977         200.0  FF000018
# 2110462         302.0  FF000018
# 2110787         301.0  FF000018
# 2111167         301.0  FF000018
# 2111661         301.0  FF000018

# %%
quic43_6 = quic6.loc[t['Protocol'] == 'Q043']
quic46_6 = quic6.loc[t['Protocol'] == 'Q046']
quic50_6 = quic6.loc[t['Protocol'] == 'Q050']
#quic98_6 = quic6.loc[t['Protocol'] == '']
quicID24_6 = quic6.loc[t['Protocol'] == 'FF000018']

# %%
quic43_6.count()
# Out:
# TimeOfMeasurement              0
# Url                            0
# Path                           0
# Ip                             0
# Port                           0
# DNSTime                        0
# ConnectionEstablishmentTime    0
# TTFB                           0
# TotalDownloadTime              0
# HttpResponse                   0
# Protocol                       0
# dtype: int64

# %%
quic43_6.head()
# Out:
# Empty DataFrame
# Columns: [TimeOfMeasurement, Url, Path, Ip, Port, DNSTime, ConnectionEstablishmentTime, TTFB, TotalDownloadTime, HttpResponse, Protocol]
# Index: []

# %%
quic43_6.tail()
# Out:
# Empty DataFrame
# Columns: [TimeOfMeasurement, Url, Path, Ip, Port, DNSTime, ConnectionEstablishmentTime, TTFB, TotalDownloadTime, HttpResponse, Protocol]
# Index: []

# %%
quic46_6.count()
# Out:
# TimeOfMeasurement              0
# Url                            0
# Path                           0
# Ip                             0
# Port                           0
# DNSTime                        0
# ConnectionEstablishmentTime    0
# TTFB                           0
# TotalDownloadTime              0
# HttpResponse                   0
# Protocol                       0
# dtype: int64

# %%
quic46_6.head()
# Out:
# Empty DataFrame
# Columns: [TimeOfMeasurement, Url, Path, Ip, Port, DNSTime, ConnectionEstablishmentTime, TTFB, TotalDownloadTime, HttpResponse, Protocol]
# Index: []

# %%
quic46_6.tail()
# Out:
# Empty DataFrame
# Columns: [TimeOfMeasurement, Url, Path, Ip, Port, DNSTime, ConnectionEstablishmentTime, TTFB, TotalDownloadTime, HttpResponse, Protocol]
# Index: []

# %%
quic50_6.count()
# Out:
# TimeOfMeasurement              0
# Url                            0
# Path                           0
# Ip                             0
# Port                           0
# DNSTime                        0
# ConnectionEstablishmentTime    0
# TTFB                           0
# TotalDownloadTime              0
# HttpResponse                   0
# Protocol                       0
# dtype: int64

# %%
quic50_6.head()
# Out:
# Empty DataFrame
# Columns: [TimeOfMeasurement, Url, Path, Ip, Port, DNSTime, ConnectionEstablishmentTime, TTFB, TotalDownloadTime, HttpResponse, Protocol]
# Index: []

# %%
quic50_6.tail()
# Out:
# Empty DataFrame
# Columns: [TimeOfMeasurement, Url, Path, Ip, Port, DNSTime, ConnectionEstablishmentTime, TTFB, TotalDownloadTime, HttpResponse, Protocol]
# Index: []

# %%
quicID24_6.count()
# Out:
# TimeOfMeasurement              0
# Url                            0
# Path                           0
# Ip                             0
# Port                           0
# DNSTime                        0
# ConnectionEstablishmentTime    0
# TTFB                           0
# TotalDownloadTime              0
# HttpResponse                   0
# Protocol                       0
# dtype: int64

# %%
quicID24_6.head()
# Out:
# Empty DataFrame
# Columns: [TimeOfMeasurement, Url, Path, Ip, Port, DNSTime, ConnectionEstablishmentTime, TTFB, TotalDownloadTime, HttpResponse, Protocol]
# Index: []

# %%
quicID24_6.tail()
# Out:
# Empty DataFrame
# Columns: [TimeOfMeasurement, Url, Path, Ip, Port, DNSTime, ConnectionEstablishmentTime, TTFB, TotalDownloadTime, HttpResponse, Protocol]
# Index: []

# %%
tcp12 = tcp4.loc[s['Protocol'] == 'TCP/TLS1.2']
tcp13 = tcp4.loc[s['Protocol'] == 'TCP/TLS1.3']

# %%
tcp12.count()
# Out:
# TimeOfMeasurement              1347501
# Url                            1347501
# Ip                             1347501
# Port                           1347501
# DnsLookupTime                  1347501
# TCPHandshakeTime               1347501
# ConnectionEstablishmentTime    1347501
# TTFB                           1347501
# TotalDownloadTime              1347501
# HttpResponse                   1347501
# HTTPVersion                    1347501
# Protocol                       1347501
# dtype: int64

# %%
tcp12.head()
# Out:
#           TimeOfMeasurement             Url              Ip  Port  \
# 0  Sat May 16 02:00:01 2020  www.google.com  172.217.170.36   443
# 1  Sat May 16 02:00:02 2020  www.google.com  172.217.170.36   443
# 2  Sat May 16 02:00:03 2020    facebook.com   185.60.219.35   443
# 4  Sat May 16 02:00:04 2020    facebook.com   185.60.219.35   443
# 6  Sat May 16 02:00:05 2020   instagram.com   3.212.216.198   443
#
#    DnsLookupTime  TCPHandshakeTime  ConnectionEstablishmentTime     TTFB  \
# 0          4.148            16.342                      242.914  481.779
# 1          4.162            16.413                      255.056  480.821
# 2        252.904            16.281                       82.231  316.124
# 4          4.143            16.320                       83.363  313.633
# 6        252.935           216.190                      709.628  973.305
#
#    TotalDownloadTime  HttpResponse HTTPVersion    Protocol
# 0            509.655           200    HTTP/1.1  TCP/TLS1.2
# 1            502.341           200       HTTP2  TCP/TLS1.2
# 2            316.146           301    HTTP/1.1  TCP/TLS1.2
# 4            313.657           301       HTTP2  TCP/TLS1.2
# 6            973.341           301    HTTP/1.1  TCP/TLS1.2

# %%
tcp12.tail()
# Out:
#                 TimeOfMeasurement                        Url              Ip  \
# 1349324  Wed May 20 17:43:05 2020                 flaconi.de  54.208.219.191
# 1349325  Wed May 20 17:43:05 2020  www.herecomestheguide.com   104.22.11.240
# 1349326  Wed May 20 17:43:06 2020                fanproj.com   193.39.255.52
# 1349327  Wed May 20 17:43:06 2020             www.buanzo.org     104.26.6.52
# 1349328  Wed May 20 17:43:06 2020               biquxuan.com   104.27.184.55
#
#          Port  DnsLookupTime  TCPHandshakeTime  ConnectionEstablishmentTime  \
# 1349324   443         28.273           215.938                      685.568
# 1349325   443        252.805           141.499                      466.547
# 1349326   443        252.742           147.329                      492.612
# 1349327   443         28.284           141.853                      461.539
# 1349328   443         28.285           141.469                      476.330
#
#              TTFB  TotalDownloadTime  HttpResponse HTTPVersion    Protocol
# 1349324   901.970            901.988           301    HTTP/1.1  TCP/TLS1.2
# 1349325  1113.622           1351.590           200    HTTP/1.1  TCP/TLS1.2
# 1349326   640.685            684.284           302    HTTP/1.1  TCP/TLS1.2
# 1349327   898.440            898.468           302    HTTP/1.1  TCP/TLS1.2
# 1349328   809.457            809.495           301    HTTP/1.1  TCP/TLS1.2

# %%
tcp13.count()
# Out:
# TimeOfMeasurement              1828
# Url                            1828
# Ip                             1828
# Port                           1828
# DnsLookupTime                  1828
# TCPHandshakeTime               1828
# ConnectionEstablishmentTime    1828
# TTFB                           1828
# TotalDownloadTime              1828
# HttpResponse                   1828
# HTTPVersion                    1828
# Protocol                       1828
# dtype: int64

# %%
tcp13.head()
# Out:
#            TimeOfMeasurement               Url             Ip  Port  \
# 3   Sat May 16 02:00:03 2020      facebook.com  185.60.219.35   443
# 5   Sat May 16 02:00:04 2020      facebook.com  185.60.219.35   443
# 7   Sat May 16 02:00:06 2020     instagram.com    54.85.7.239   443
# 9   Sat May 16 02:00:08 2020     instagram.com  3.218.162.209   443
# 11  Sat May 16 02:00:09 2020  www.whatsapp.com  185.60.219.53   443
#
#     DnsLookupTime  TCPHandshakeTime  ConnectionEstablishmentTime     TTFB  \
# 3           4.143            16.256                       66.961  294.778
# 5           4.159            16.238                       66.418  298.712
# 7           4.212           216.207                      476.819  753.283
# 9           4.207           216.207                      473.963  749.437
# 11         12.237            16.259                       65.740  299.278
#
#     TotalDownloadTime  HttpResponse HTTPVersion    Protocol
# 3             294.801           301    HTTP/1.1  TCP/TLS1.3
# 5             298.735           301       HTTP2  TCP/TLS1.3
# 7             753.320           301    HTTP/1.1  TCP/TLS1.3
# 9             749.463           301       HTTP2  TCP/TLS1.3
# 11            299.301           302    HTTP/1.1  TCP/TLS1.3

# %%
tcp13.tail()
# Out:
#                 TimeOfMeasurement           Url             Ip  Port  \
# 1348060  Wed May 20 17:37:58 2020    compari.ro  80.249.166.55   443
# 1348690  Wed May 20 17:40:48 2020  arukereso.hu  80.249.166.52   443
# 1348697  Wed May 20 17:40:49 2020  arukereso.hu  80.249.166.53   443
# 1348883  Wed May 20 17:41:25 2020   adnegah.net   46.4.185.113   443
# 1348894  Wed May 20 17:41:26 2020   adnegah.net   46.4.185.113   443
#
#          DnsLookupTime  TCPHandshakeTime  ConnectionEstablishmentTime  \
# 1348060          4.128           196.519                      430.578
# 1348690          4.142           189.587                      446.308
# 1348697          4.133           189.697                      416.399
# 1348883          4.101           203.798                      489.210
# 1348894          4.130           203.712                      453.270
#
#             TTFB  TotalDownloadTime  HttpResponse HTTPVersion    Protocol
# 1348060  642.135            642.155           301       HTTP2  TCP/TLS1.3
# 1348690  649.613            649.643           301    HTTP/1.1  TCP/TLS1.3
# 1348697  615.411            615.429           301       HTTP2  TCP/TLS1.3
# 1348883  693.516            693.549           403    HTTP/1.1  TCP/TLS1.3
# 1348894  657.258            657.273           403       HTTP2  TCP/TLS1.3

# %%
tcp12_6 = tcp6.loc[s['Protocol'] == 'TCP/TLS1.2']
tcp13_6 = tcp6.loc[s['Protocol'] == 'TCP/TLS1.3']

# %%
tcp12_6.count()
# Out:
# TimeOfMeasurement              0
# Url                            0
# Ip                             0
# Port                           0
# DnsLookupTime                  0
# TCPHandshakeTime               0
# ConnectionEstablishmentTime    0
# TTFB                           0
# TotalDownloadTime              0
# HttpResponse                   0
# HTTPVersion                    0
# Protocol                       0
# dtype: int64

# %%
tcp12_6.head()
# Out:
# Empty DataFrame
# Columns: [TimeOfMeasurement, Url, Ip, Port, DnsLookupTime, TCPHandshakeTime, ConnectionEstablishmentTime, TTFB, TotalDownloadTime, HttpResponse, HTTPVersion, Protocol]
# Index: []

# %%
tcp12_6.tail()
# Out:
# Empty DataFrame
# Columns: [TimeOfMeasurement, Url, Ip, Port, DnsLookupTime, TCPHandshakeTime, ConnectionEstablishmentTime, TTFB, TotalDownloadTime, HttpResponse, HTTPVersion, Protocol]
# Index: []

# %%
tcp13_6.count()
# Out:
# TimeOfMeasurement              0
# Url                            0
# Ip                             0
# Port                           0
# DnsLookupTime                  0
# TCPHandshakeTime               0
# ConnectionEstablishmentTime    0
# TTFB                           0
# TotalDownloadTime              0
# HttpResponse                   0
# HTTPVersion                    0
# Protocol                       0
# dtype: int64

# %%
tcp13_6.head()
# Out:
# Empty DataFrame
# Columns: [TimeOfMeasurement, Url, Ip, Port, DnsLookupTime, TCPHandshakeTime, ConnectionEstablishmentTime, TTFB, TotalDownloadTime, HttpResponse, HTTPVersion, Protocol]
# Index: []

# %%
tcp13_6.tail()
# Out:
# Empty DataFrame
# Columns: [TimeOfMeasurement, Url, Ip, Port, DnsLookupTime, TCPHandshakeTime, ConnectionEstablishmentTime, TTFB, TotalDownloadTime, HttpResponse, HTTPVersion, Protocol]
# Index: []

# %%
x = Cdf.MakeCdfFromList(quic43['ConnectionEstablishmentTime'].values)
x1 =Cdf.MakeCdfFromList(quic50['ConnectionEstablishmentTime'].values)
x3 = Cdf.MakeCdfFromList(quic46['ConnectionEstablishmentTime'].values)
#x5 = Cdf.MakeCdfFromList(quic98['ConnectionEstablishmentTime'].values)
x6 = Cdf.MakeCdfFromList(quicID24['ConnectionEstablishmentTime'].values)
x4 = Cdf.MakeCdfFromList(tcp13['ConnectionEstablishmentTime'].values)
x2 =Cdf.MakeCdfFromList(tcp12['ConnectionEstablishmentTime'].values)

# %%
print_percentiles(x1, 'Q050')
print_percentiles(x2, 'tcp12')
print_percentiles(x3, 'Q046')
print_percentiles(x4, 'tcp13')
#print_percentiles(x5, 'Q098')
print_percentiles(x6, 'IETF h3-24')
print_percentiles(x, 'Q043')
# Out:
# -----------------------------
#
# percentile values distribution for Q050
#
# 20th Percentile:360.027000
#
# 25th Percentile:363.204000
#
# 40th Percentile:367.943000
#
# 50th Percentile:369.761000
#
# 60th Percentile:372.568000
#
# 75th Percentile:377.142000
#
# 80th Percentile:378.724000
#
# 90th Percentile:397.157000
#
# 99th Percentile:725.075000
#
# -----------------------------
#
# -----------------------------
#
# percentile values distribution for tcp12
#
# 20th Percentile:51.450000
#
# 25th Percentile:63.537000
#
# 40th Percentile:460.835000
#
# 50th Percentile:462.716000
#
# 60th Percentile:464.625000
#
# 75th Percentile:470.318000
#
# 80th Percentile:473.883000
#
# 90th Percentile:525.141000
#
# 99th Percentile:1064.478000
#
# -----------------------------
#
# -----------------------------
#
# percentile values distribution for Q046
#
# 20th Percentile:359.945000
#
# 25th Percentile:363.153000
#
# 40th Percentile:367.901000
#
# 50th Percentile:369.766000
#
# 60th Percentile:372.593000
#
# 75th Percentile:377.195000
#
# 80th Percentile:378.932000
#
# 90th Percentile:419.686000
#
# 99th Percentile:754.827000
#
# -----------------------------
#
# -----------------------------
#
# percentile values distribution for tcp13
#
# 20th Percentile:68.725000
#
# 25th Percentile:76.923000
#
# 40th Percentile:416.459000
#
# 50th Percentile:442.325000
#
# 60th Percentile:583.146000
#
# 75th Percentile:651.630000
#
# 80th Percentile:657.365000
#
# 90th Percentile:695.480000
#
# 99th Percentile:768.639000
#
# -----------------------------
#
# -----------------------------
#
# percentile values distribution for IETF h3-24
#
# 20th Percentile:207.838000
#
# 25th Percentile:214.758000
#
# 40th Percentile:289.262000
#
# 50th Percentile:305.574000
#
# 60th Percentile:345.250000
#
# 75th Percentile:406.080000
#
# 80th Percentile:418.655000
#
# 90th Percentile:528.201000
#
# 99th Percentile:536.050000
#
# -----------------------------
#
# -----------------------------
#
# percentile values distribution for Q043
#
# 20th Percentile:359.986000
#
# 25th Percentile:363.197000
#
# 40th Percentile:367.933000
#
# 50th Percentile:369.846000
#
# 60th Percentile:372.681000
#
# 75th Percentile:377.391000
#
# 80th Percentile:379.344000
#
# 90th Percentile:423.706000
#
# 99th Percentile:755.677000
#
# -----------------------------

# %%
data = {'$\\bf{Protocol}$': ['Q043', 'Q046', 'Q050', 'IETF ID-24', 'TCP1.2', 'TCP1.3'],
	'$\\bf{25th}$': ["{:.2f}".format(x.Percentile(25)), "{:.2f}".format(x3.Percentile(25)), "{:.2f}".format(x1.Percentile(25)), "{:.2f}".format(x6.Percentile(25)), "{:.2f}".format(x2.Percentile(25)), "{:.2f}".format(x4.Percentile(25))],
	'$\\bf{50th}$': ["{:.2f}".format(x.Percentile(50)), "{:.2f}".format(x3.Percentile(50)), "{:.2f}".format(x1.Percentile(50)), "{:.2f}".format(x6.Percentile(50)), "{:.2f}".format(x2.Percentile(50)), "{:.2f}".format(x4.Percentile(50))],
	'$\\bf{75th}$': ["{:.2f}".format(x.Percentile(75)), "{:.2f}".format(x3.Percentile(75)), "{:.2f}".format(x1.Percentile(75)), "{:.2f}".format(x6.Percentile(75)), "{:.2f}".format(x2.Percentile(75)), "{:.2f}".format(x4.Percentile(75))],
	'$\\bf{80th}$': ["{:.2f}".format(x.Percentile(80)), "{:.2f}".format(x3.Percentile(80)), "{:.2f}".format(x1.Percentile(80)), "{:.2f}".format(x6.Percentile(80)), "{:.2f}".format(x2.Percentile(80)), "{:.2f}".format(x4.Percentile(80))],
    '$\\bf{90th}$': ["{:.2f}".format(x.Percentile(90)), "{:.2f}".format(x3.Percentile(90)), "{:.2f}".format(x1.Percentile(90)), "{:.2f}".format(x6.Percentile(90)), "{:.2f}".format(x2.Percentile(90)), "{:.2f}".format(x4.Percentile(90))]
        }    

df_percentile = pd.DataFrame(data)

fig, ax = plt.subplots()

# hide axes
fig.patch.set_visible(False)
ax.axis('off')
ax.axis('tight')

ax.table(cellText=df_percentile.values, colLabels=df_percentile.columns, loc='center', cellLoc='center')

fig.tight_layout()
plt.savefig('./AWS/CapeTown/handshake_times_ipv4_percentile.png', format='png', bbox_inches='tight')
# Out:
# findfont: Font family ['monospace'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['monospace'] not found. Falling back to DejaVu Sans.

# %%
write_percentiles('Q050.csv', x1)
write_percentiles('tcp12.csv', x2)
write_percentiles('Q046.csv', x3)
write_percentiles('tcp13.csv', x4)
#write_percentiles('Q098.csv', x5)
write_percentiles('IETFh3-24', x6)
write_percentiles('Q043.csv', x)

# %%
fig = plt.figure(figsize = (10,3))
plt.rcParams['font.size'] = 12
ax = plt.gca()
yticks = np.arange(0,1.1,0.2)

#Q043
plt.plot(x.xs, x.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'orange')
#Q050
plt.plot(x1.xs, x1.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'red')
#Q046
plt.plot(x3.xs, x3.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'cyan')
#Q098
#plt.plot(x5.xs, x5.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'blue')
#IETF h3-24
plt.plot(x6.xs, x6.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color='yellow')
#TLS1.2
plt.plot(x2.xs, x2.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'green')
#TLS1.3
plt.plot(x4.xs, x4.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'black')


ax = fig.axes[0]
ax.grid(False)
ax.set_yticks(yticks)
#ax.set_ylim([0,1.05])
ax.set_xlim([0.01, 54000])
ax.set_xscale('log')
ax.set_xlabel('latency (x-axis is cut)', fontsize=12)
ax.set_ylabel('CDF', fontsize=12)

plt.legend(['Q043', 'Q050', 'Q046', 'IETF h3-24', 'TLS1.2', 'TLS1.3'], fontsize=11, loc='best')

ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.yaxis.set_ticks_position('left')
ax.xaxis.set_ticks_position('bottom')
ax.spines['bottom'].set_position(('axes', -0.05))
ax.spines['left'].set_position(('axes', -0.05))

ax3 = ax.twinx()
ax3.spines['right'].set_color('none')
ax3.spines['top'].set_color('none')
ax3.spines['left'].set_color('none')
ax3.spines['bottom'].set_color('none')
ax3.yaxis.set_ticks_position('none')
##ax3.set_ylabel('[\'16th May - \'20thMay')
plt.setp(ax3.get_yticklabels(), visible=False)

plt.title('Handshake Times with IPv4', fontsize=12, y=1.05)
plt.savefig('./AWS/CapeTown/handshake_times_ipv4.png', format='png', bbox_inches='tight')
# Out:
# findfont: Font family ['monospace'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['monospace'] not found. Falling back to DejaVu Sans.

# %%
x = Cdf.MakeCdfFromList(quic43['TTFB'].values)
x1 =Cdf.MakeCdfFromList(quic50['TTFB'].values)
x3 = Cdf.MakeCdfFromList(quic46['TTFB'].values)
#x5 = Cdf.MakeCdfFromList(quic98['TTFB'].values)
x6 = Cdf.MakeCdfFromList(quicID24['TTFB'].values)
x4 = Cdf.MakeCdfFromList(tcp13['TTFB'].values)
x2 =Cdf.MakeCdfFromList(tcp12['TTFB'].values)

# %%
write_percentiles('Q050.csv', x1)
write_percentiles('tcp12.csv', x2)
write_percentiles('Q046.csv', x3)
write_percentiles('tcp13.csv', x4)
#write_percentiles('Q098.csv', x5)
write_percentiles('IETFh3-24.csv', x6)
write_percentiles('Q043.csv', x)

# %%
print_percentiles(x1, 'Q050')
print_percentiles(x2, 'tcp12')
print_percentiles(x3, 'Q046')
print_percentiles(x4, 'tcp13')
#print_percentiles(x5, 'Q098')
print_percentiles(x6, 'IETFh3-24')
print_percentiles(x, 'Q043')
# Out:
# -----------------------------
#
# percentile values distribution for Q050
#
# 20th Percentile:385.819000
#
# 25th Percentile:497.074000
#
# 40th Percentile:650.104000
#
# 50th Percentile:681.344000
#
# 60th Percentile:694.796000
#
# 75th Percentile:714.314000
#
# 80th Percentile:722.964000
#
# 90th Percentile:755.774000
#
# 99th Percentile:959.709000
#
# -----------------------------
#
# -----------------------------
#
# percentile values distribution for tcp12
#
# 20th Percentile:601.190000
#
# 25th Percentile:615.128000
#
# 40th Percentile:659.529000
#
# 50th Percentile:723.565000
#
# 60th Percentile:814.589000
#
# 75th Percentile:1011.749000
#
# 80th Percentile:1115.343000
#
# 90th Percentile:1364.191000
#
# 99th Percentile:3185.313000
#
# -----------------------------
#
# -----------------------------
#
# percentile values distribution for Q046
#
# 20th Percentile:385.826000
#
# 25th Percentile:496.113000
#
# 40th Percentile:646.094000
#
# 50th Percentile:680.649000
#
# 60th Percentile:694.446000
#
# 75th Percentile:714.158000
#
# 80th Percentile:722.981000
#
# 90th Percentile:756.136000
#
# 99th Percentile:959.658000
#
# -----------------------------
#
# -----------------------------
#
# percentile values distribution for tcp13
#
# 20th Percentile:308.413000
#
# 25th Percentile:318.205000
#
# 40th Percentile:620.103000
#
# 50th Percentile:655.315000
#
# 60th Percentile:941.316000
#
# 75th Percentile:1161.764000
#
# 80th Percentile:1172.874000
#
# 90th Percentile:1195.364000
#
# 99th Percentile:1552.366000
#
# -----------------------------
#
# -----------------------------
#
# percentile values distribution for IETFh3-24
#
# 20th Percentile:351.591000
#
# 25th Percentile:355.330000
#
# 40th Percentile:448.354000
#
# 50th Percentile:475.882000
#
# 60th Percentile:518.239000
#
# 75th Percentile:612.244000
#
# 80th Percentile:661.232000
#
# 90th Percentile:830.239000
#
# 99th Percentile:965.785000
#
# -----------------------------
#
# -----------------------------
#
# percentile values distribution for Q043
#
# 20th Percentile:438.372000
#
# 25th Percentile:524.842000
#
# 40th Percentile:661.193000
#
# 50th Percentile:685.732000
#
# 60th Percentile:698.917000
#
# 75th Percentile:719.909000
#
# 80th Percentile:729.702000
#
# 90th Percentile:766.274000
#
# 99th Percentile:965.065000
#
# -----------------------------

# %%
data = {'$\\bf{Protocol}$': ['Q043', 'Q046', 'Q050', 'IETF ID-24', 'TCP1.2', 'TCP1.3'],
	'$\\bf{25th}$': ["{:.2f}".format(x.Percentile(25)), "{:.2f}".format(x3.Percentile(25)), "{:.2f}".format(x1.Percentile(25)), "{:.2f}".format(x6.Percentile(25)), "{:.2f}".format(x2.Percentile(25)), "{:.2f}".format(x4.Percentile(25))],
	'$\\bf{50th}$': ["{:.2f}".format(x.Percentile(50)), "{:.2f}".format(x3.Percentile(50)), "{:.2f}".format(x1.Percentile(50)), "{:.2f}".format(x6.Percentile(50)), "{:.2f}".format(x2.Percentile(50)), "{:.2f}".format(x4.Percentile(50))],
	'$\\bf{75th}$': ["{:.2f}".format(x.Percentile(75)), "{:.2f}".format(x3.Percentile(75)), "{:.2f}".format(x1.Percentile(75)), "{:.2f}".format(x6.Percentile(75)), "{:.2f}".format(x2.Percentile(75)), "{:.2f}".format(x4.Percentile(75))],
	'$\\bf{80th}$': ["{:.2f}".format(x.Percentile(80)), "{:.2f}".format(x3.Percentile(80)), "{:.2f}".format(x1.Percentile(80)), "{:.2f}".format(x6.Percentile(80)), "{:.2f}".format(x2.Percentile(80)), "{:.2f}".format(x4.Percentile(80))],
    '$\\bf{90th}$': ["{:.2f}".format(x.Percentile(90)), "{:.2f}".format(x3.Percentile(90)), "{:.2f}".format(x1.Percentile(90)), "{:.2f}".format(x6.Percentile(90)), "{:.2f}".format(x2.Percentile(90)), "{:.2f}".format(x4.Percentile(90))]
        }    

df_percentile = pd.DataFrame(data)

fig, ax = plt.subplots()

# hide axes
fig.patch.set_visible(False)
ax.axis('off')
ax.axis('tight')

ax.table(cellText=df_percentile.values, colLabels=df_percentile.columns, loc='center', cellLoc='center')

fig.tight_layout()
plt.savefig('./AWS/CapeTown/TTFB_ipv4_percentile.png', format='png', bbox_inches='tight')
# Out:
# findfont: Font family ['monospace'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['monospace'] not found. Falling back to DejaVu Sans.

# %%
fig = plt.figure(figsize = (10,3))
plt.rcParams['font.size'] = 12
ax = plt.gca()
yticks = np.arange(0,1.1,0.2)

#Q043
plt.plot(x.xs, x.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'orange')
#Q050
plt.plot(x1.xs, x1.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'red')
#Q046
plt.plot(x3.xs, x3.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'cyan')
#Q098
#plt.plot(x5.xs, x5.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'blue')
#IETF h3-24
plt.plot(x6.xs, x6.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'yellow')
#TLS1.2
plt.plot(x2.xs, x2.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'green')
#TLS1.3
plt.plot(x4.xs, x4.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'black')


ax = fig.axes[0]
ax.grid(False)
ax.set_yticks(yticks)
#ax.set_ylim([0,1.05])
ax.set_xlim([0.01,58000])
ax.set_xscale('log')
ax.set_xlabel('TTFB', fontsize=12)
ax.set_ylabel('CDF', fontsize=12)

plt.legend(['Q043', 'Q050', 'Q046', 'IETFh3-24', 'TLS1.2', 'TLS1.3'], fontsize=11, loc='best')

ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.yaxis.set_ticks_position('left')
ax.xaxis.set_ticks_position('bottom')
ax.spines['bottom'].set_position(('axes', -0.05))
ax.spines['left'].set_position(('axes', -0.05))

ax3 = ax.twinx()
ax3.spines['right'].set_color('none')
ax3.spines['top'].set_color('none')
ax3.spines['left'].set_color('none')
ax3.spines['bottom'].set_color('none')
ax3.yaxis.set_ticks_position('none')
##ax3.set_ylabel('[\'16thMay - \'20th May')
plt.setp(ax3.get_yticklabels(), visible=False)

plt.title('TTFB with IPv4', fontsize=12, y=1.05)
plt.savefig('./AWS/CapeTown/TTFB_ipv4.png', format='png', bbox_inches='tight')

# %%
x = Cdf.MakeCdfFromList(quic43['TotalDownloadTime'].values)
x1 =Cdf.MakeCdfFromList(quic50['TotalDownloadTime'].values)
x3 = Cdf.MakeCdfFromList(quic46['TotalDownloadTime'].values)
#x5 = Cdf.MakeCdfFromList(quic98['TotalDownloadTime'].values)
x6 = Cdf.MakeCdfFromList(quicID24['TotalDownloadTime'].values)
x4 = Cdf.MakeCdfFromList(tcp13['TotalDownloadTime'].values)
x2 =Cdf.MakeCdfFromList(tcp12['TotalDownloadTime'].values)

# %%
write_percentiles('Q050.csv', x1)
write_percentiles('tcp12.csv', x2)
write_percentiles('Q046.csv', x3)
write_percentiles('tcp13.csv', x4)
#write_percentiles('Q098.csv', x5)
write_percentiles('IETFh3-24.csv', x6)
write_percentiles('Q043.csv', x)

# %%
print_percentiles(x1, 'Q050')
print_percentiles(x2, 'tcp12')
print_percentiles(x3, 'Q046')
print_percentiles(x4, 'tcp13')
#print_percentiles(x5, 'Q098')
print_percentiles(x6, 'IETFh3-24')
print_percentiles(x, 'Q043')
# Out:
# -----------------------------
#
# percentile values distribution for Q050
#
# 20th Percentile:318.480000
#
# 25th Percentile:400.961000
#
# 40th Percentile:611.071000
#
# 50th Percentile:674.568000
#
# 60th Percentile:690.424000
#
# 75th Percentile:709.162000
#
# 80th Percentile:716.563000
#
# 90th Percentile:741.442000
#
# 99th Percentile:964.732000
#
# -----------------------------
#
# -----------------------------
#
# percentile values distribution for tcp12
#
# 20th Percentile:610.935000
#
# 25th Percentile:619.848000
#
# 40th Percentile:695.532000
#
# 50th Percentile:801.075000
#
# 60th Percentile:922.926000
#
# 75th Percentile:1157.779000
#
# 80th Percentile:1238.701000
#
# 90th Percentile:1589.021000
#
# 99th Percentile:3766.400000
#
# -----------------------------
#
# -----------------------------
#
# percentile values distribution for Q046
#
# 20th Percentile:320.600000
#
# 25th Percentile:401.079000
#
# 40th Percentile:610.627000
#
# 50th Percentile:674.285000
#
# 60th Percentile:690.362000
#
# 75th Percentile:709.238000
#
# 80th Percentile:716.860000
#
# 90th Percentile:743.266000
#
# 99th Percentile:966.071000
#
# -----------------------------
#
# -----------------------------
#
# percentile values distribution for tcp13
#
# 20th Percentile:308.430000
#
# 25th Percentile:318.246000
#
# 40th Percentile:620.140000
#
# 50th Percentile:655.339000
#
# 60th Percentile:972.626000
#
# 75th Percentile:1173.513000
#
# 80th Percentile:1185.106000
#
# 90th Percentile:1416.656000
#
# 99th Percentile:2227.388000
#
# -----------------------------
#
# -----------------------------
#
# percentile values distribution for IETFh3-24
#
# 20th Percentile:314.845000
#
# 25th Percentile:353.102000
#
# 40th Percentile:448.685000
#
# 50th Percentile:513.588000
#
# 60th Percentile:605.821000
#
# 75th Percentile:722.573000
#
# 80th Percentile:767.049000
#
# 90th Percentile:891.417000
#
# 99th Percentile:955.049000
#
# -----------------------------
#
# -----------------------------
#
# percentile values distribution for Q043
#
# 20th Percentile:358.393000
#
# 25th Percentile:483.062000
#
# 40th Percentile:639.969000
#
# 50th Percentile:680.203000
#
# 60th Percentile:694.805000
#
# 75th Percentile:714.491000
#
# 80th Percentile:722.986000
#
# 90th Percentile:758.733000
#
# 99th Percentile:970.965000
#
# -----------------------------

# %%
data = {'$\\bf{Protocol}$': ['Q043', 'Q046', 'Q050', 'IETF ID-24', 'TCP1.2', 'TCP1.3'],
	'$\\bf{25th}$': ["{:.2f}".format(x.Percentile(25)), "{:.2f}".format(x3.Percentile(25)), "{:.2f}".format(x1.Percentile(25)), "{:.2f}".format(x6.Percentile(25)), "{:.2f}".format(x2.Percentile(25)), "{:.2f}".format(x4.Percentile(25))],
	'$\\bf{50th}$': ["{:.2f}".format(x.Percentile(50)), "{:.2f}".format(x3.Percentile(50)), "{:.2f}".format(x1.Percentile(50)), "{:.2f}".format(x6.Percentile(50)), "{:.2f}".format(x2.Percentile(50)), "{:.2f}".format(x4.Percentile(50))],
	'$\\bf{75th}$': ["{:.2f}".format(x.Percentile(75)), "{:.2f}".format(x3.Percentile(75)), "{:.2f}".format(x1.Percentile(75)), "{:.2f}".format(x6.Percentile(75)), "{:.2f}".format(x2.Percentile(75)), "{:.2f}".format(x4.Percentile(75))],
	'$\\bf{80th}$': ["{:.2f}".format(x.Percentile(80)), "{:.2f}".format(x3.Percentile(80)), "{:.2f}".format(x1.Percentile(80)), "{:.2f}".format(x6.Percentile(80)), "{:.2f}".format(x2.Percentile(80)), "{:.2f}".format(x4.Percentile(80))],
    '$\\bf{90th}$': ["{:.2f}".format(x.Percentile(90)), "{:.2f}".format(x3.Percentile(90)), "{:.2f}".format(x1.Percentile(90)), "{:.2f}".format(x6.Percentile(90)), "{:.2f}".format(x2.Percentile(90)), "{:.2f}".format(x4.Percentile(90))]
        }    

df_percentile = pd.DataFrame(data)

fig, ax = plt.subplots()

# hide axes
fig.patch.set_visible(False)
ax.axis('off')
ax.axis('tight')

ax.table(cellText=df_percentile.values, colLabels=df_percentile.columns, loc='center', cellLoc='center')

fig.tight_layout()
plt.savefig('./AWS/CapeTown/TotalDownloadTime_ipv4_percentile.png', format='png', bbox_inches='tight')
# Out:
# findfont: Font family ['monospace'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['monospace'] not found. Falling back to DejaVu Sans.

# %%
fig = plt.figure(figsize = (10,3))
plt.rcParams['font.size'] = 12
ax = plt.gca()
yticks = np.arange(0,1.1,0.2)

#Q043
plt.plot(x.xs, x.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'orange')
#Q039
plt.plot(x1.xs, x1.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'red')
#Q044
plt.plot(x3.xs, x3.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'cyan')
#Q098
#plt.plot(x5.xs, x5.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'blue')
#IETF h3-24
plt.plot(x6.xs, x6.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'yellow')
#TLS1.2
plt.plot(x2.xs, x2.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'green')
#TLS1.3
plt.plot(x4.xs, x4.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'black')


ax = fig.axes[0]
ax.grid(False)
ax.set_yticks(yticks)
#ax.set_ylim([0,1.05])
#ax.set_xlim([20,1000])
ax.set_xlim([0.01,58000])
ax.set_xscale('log')
ax.set_xlabel('TotalDownloadTime', fontsize=12)
ax.set_ylabel('CDF', fontsize=12)

plt.legend(['Q043', 'Q050', 'Q046', 'IETF h3-24', 'TLS1.2', 'TLS1.3'], fontsize=11, loc='best')

ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.yaxis.set_ticks_position('left')
ax.xaxis.set_ticks_position('bottom')
ax.spines['bottom'].set_position(('axes', -0.05))
ax.spines['left'].set_position(('axes', -0.05))

ax3 = ax.twinx()
ax3.spines['right'].set_color('none')
ax3.spines['top'].set_color('none')
ax3.spines['left'].set_color('none')
ax3.spines['bottom'].set_color('none')
ax3.yaxis.set_ticks_position('none')
##ax3.set_ylabel('[\'16thMay - \'20thMay')
plt.setp(ax3.get_yticklabels(), visible=False)

plt.title('TotalDownloadTime with IPv4', fontsize=12, y=1.05)
plt.savefig('./AWS/CapeTown/TotalDownloadTime_ipv4.png', format='png', bbox_inches='tight')
