# %%
import pandas as pd
import numpy as np
import matplotlib
matplotlib.use('PS') 
import matplotlib.pyplot as plt
import time
import datetime
import filterbyip as fbi
import Cdf
import Pmf

# %%
def print_percentiles(c, name):
	print('-----------------------------\n')
	print('percentile values distribution for %s\n' % name)

	print('50th Percentile:%f\n' % c.Percentile(50))
	print('90th Percentile:%f\n' % c.Percentile(90))
	print('99th Percentile:%f\n' % c.Percentile(99))
	print('25th Percentile:%f\n' % c.Percentile(25))
	print('75th Percentile:%f\n' % c.Percentile(75))
	print('20th Percentile:%f\n' % c.Percentile(50))
	print('40th Percentile:%f\n' % c.Percentile(90))
	print('60th Percentile:%f\n' % c.Percentile(60))
	print('80th Percentile:%f\n' % c.Percentile(25))

	print('-----------------------------\n')

# %%
def write_percentiles(filename, c):
	with open(filename, 'w') as f:
		f.write('values; percentile\n')
		for x, y in zip(c.xs, c.ps):
			f.write('%.2f, %.2f\n'%(x, y))

# %%
# %autosave 20
# Out:
# Autosaving every 20 seconds

# %%
import warnings
warnings.filterwarnings('ignore')

# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from IPython.core.display import HTML
css = open('style-table.css').read() + open('style-notebook.css').read()
HTML('<style>{}</style>'.format(css))
# Out:
# <style>body {
#     margin: 0;
#     font-family: Helvetica;
# }
# table.dataframe {
#     border-collapse: collapse;
#     border: none;
# }
# table.dataframe tr {
#     border: none;
# }
# table.dataframe td, table.dataframe th {
#     margin: 0;
#     border: 1px solid white;
#     padding-left: 0.25em;
#     padding-right: 0.25em;
# }
# table.dataframe th:not(:empty) {
#     background-color: #fec;
#     text-align: left;
#     font-weight: normal;
# }
# table.dataframe tr:nth-child(2) th:empty {
#     border-left: none;
#     border-right: 1px dashed #888;
# }
# table.dataframe td {
#     border: 2px solid #ccf;
#     background-color: #f4f4ff;
# }
# h3 {
#     color: white;
#     background-color: black;
#     padding: 0.5em;
# }
#
# .CodeMirror {
#     font-family: 'Consolas';
# }
#
# div.cell.code_cell {
#     font-family: 'Consolas';
# }
#
# div.output_area pre {
#     font-family: 'Consolas';
# }
# </style>

# %%
tcp_tls_data = "./data2020/output_curl_data.csv"
quic_data = "./data2020/output_quic.csv"

# %%
scol_names = ['TimeOfMeasurement', 'Url', 'Ip', 'Port', 'DnsLookupTime', 'TCPHandshakeTime', 'ConnectionEstablishmentTime', 'TTFB', 'TotalDownloadTime', 'HttpResponse', 'HTTPVersion', 'Protocol']
tcol_names = ['TimeOfMeasurement', 'Url', 'Path', 'Ip', 'Port', 'DNSTime', 'ConnectionEstablishmentTime', 'TTFB', 'TotalDownloadTime', 'HttpResponse', 'Protocol']

# %%
t = pd.read_csv(quic_data, ';', names=tcol_names, header=None)
s = pd.read_csv(tcp_tls_data, ';', names=scol_names, header=None)

# %%
t = t.dropna()
s = s.dropna()

# %%
#t = t[t['TimeOfMeasurement'] > 1581721201]
#s = s[s['TimeOfMeasurement'] > 1581721201]

# %%
s['TTFB']=s['TTFB']-s['DnsLookupTime']
s['TotalDownloadTime']=s['TotalDownloadTime']-s['DnsLookupTime']

# %%
s.count()
# Out:
# TimeOfMeasurement              10521228
# Url                            10521228
# Ip                             10521228
# Port                           10521228
# DnsLookupTime                  10521228
# TCPHandshakeTime               10521228
# ConnectionEstablishmentTime    10521228
# TTFB                           10521228
# TotalDownloadTime              10521228
# HttpResponse                   10521228
# HTTPVersion                    10521228
# Protocol                       10521228
# dtype: int64

# %%
s.head()
# Out:
#    TimeOfMeasurement             Url                        Ip Port  \
# 0         1587124802  www.google.com             216.58.207.36  443
# 1         1587124802  www.google.com             216.58.207.36  443
# 2         1587124802  www.google.com  2a00:1450:4001:824::2004  443
# 3         1587124802  www.google.com  2a00:1450:4001:824::2004  443
# 4         1587124803    facebook.com             185.60.216.35  443
#
#    DnsLookupTime  TCPHandshakeTime  ConnectionEstablishmentTime     TTFB  \
# 0          4.183             8.871                       95.146  150.998
# 1          4.167             9.001                       73.048  127.133
# 2          4.147             8.518                       66.957  118.658
# 3          4.178             8.536                       68.726  122.663
# 4         12.268             9.463                       62.374  363.963
#
#    TotalDownloadTime HttpResponse HTTPVersion    Protocol
# 0            165.778          200    HTTP/1.1  TCP/TLS1.2
# 1            137.560          200       HTTP2  TCP/TLS1.2
# 2            134.236          200    HTTP/1.1  TCP/TLS1.2
# 3            134.412          200       HTTP2  TCP/TLS1.2
# 4            363.992          301    HTTP/1.1  TCP/TLS1.2

# %%
t.count()
# Out:
# TimeOfMeasurement              5411215
# Url                            5411215
# Path                           5411215
# Ip                             5411215
# Port                           5411215
# DNSTime                        5411215
# ConnectionEstablishmentTime    5411215
# TTFB                           5411215
# TotalDownloadTime              5411215
# HttpResponse                   5411215
# Protocol                       5411215
# dtype: int64

# %%
t.head()
# Out:
#    TimeOfMeasurement                        Url Path  \
# 0         1587124802  www.0dayrox2.blogspot.com    /
# 1         1587124802  www.0dayrox2.blogspot.com    /
# 2         1587124802  www.0dayrox2.blogspot.com    /
# 4         1587124803  www.0dayrox2.blogspot.com    /
# 5         1587124803  www.0dayrox2.blogspot.com    /
#
#                          Ip Port  DNSTime  ConnectionEstablishmentTime  \
# 0             216.58.207.33  443   62.308                       44.542
# 1             216.58.207.33  443    0.503                       36.357
# 2             216.58.207.33  443    0.689                       36.670
# 4  2a00:1450:4001:81b::2001  443   18.795                       35.975
# 5  2a00:1450:4001:81b::2001  443    0.545                       35.162
#
#       TTFB  TotalDownloadTime  HttpResponse Protocol
# 0  260.441            350.790         404.0     Q043
# 1  238.053            332.277         404.0     Q046
# 2  234.652            387.210         404.0     Q050
# 4  252.821            403.325         404.0     Q043
# 5  237.424            599.720         404.0     Q046

# %%
def timestamp2human(timestamp):
    return datetime.datetime.fromtimestamp(int(timestamp)).strftime('%c')

# %%
s['TimeOfMeasurement'] = s['TimeOfMeasurement'].apply(timestamp2human)

# %%
s.head()
# Out:
#           TimeOfMeasurement             Url                        Ip Port  \
# 0  Fri Apr 17 14:00:02 2020  www.google.com             216.58.207.36  443
# 1  Fri Apr 17 14:00:02 2020  www.google.com             216.58.207.36  443
# 2  Fri Apr 17 14:00:02 2020  www.google.com  2a00:1450:4001:824::2004  443
# 3  Fri Apr 17 14:00:02 2020  www.google.com  2a00:1450:4001:824::2004  443
# 4  Fri Apr 17 14:00:03 2020    facebook.com             185.60.216.35  443
#
#    DnsLookupTime  TCPHandshakeTime  ConnectionEstablishmentTime     TTFB  \
# 0          4.183             8.871                       95.146  150.998
# 1          4.167             9.001                       73.048  127.133
# 2          4.147             8.518                       66.957  118.658
# 3          4.178             8.536                       68.726  122.663
# 4         12.268             9.463                       62.374  363.963
#
#    TotalDownloadTime HttpResponse HTTPVersion    Protocol
# 0            165.778          200    HTTP/1.1  TCP/TLS1.2
# 1            137.560          200       HTTP2  TCP/TLS1.2
# 2            134.236          200    HTTP/1.1  TCP/TLS1.2
# 3            134.412          200       HTTP2  TCP/TLS1.2
# 4            363.992          301    HTTP/1.1  TCP/TLS1.2

# %%
s.tail()
# Out:
#                  TimeOfMeasurement                 Url  \
# 10521223  Sun May 10 14:01:05 2020      www.tickets.az
# 10521224  Sun May 10 14:01:05 2020     phimsexporn.com
# 10521225  Sun May 10 14:01:05 2020  tabulose-huren.com
# 10521226  Sun May 10 14:01:05 2020      www.tickets.az
# 10521227  Sun May 10 14:01:05 2020              hvg.hu
#
#                                 Ip Port  DnsLookupTime  TCPHandshakeTime  \
# 10521223               104.28.2.67  443        124.427             9.173
# 10521224  2606:4700:3037::681c:478  443          4.145             8.758
# 10521225    2606:4700:20::681a:379  443          4.134             8.716
# 10521226               104.28.2.67  443         14.903             9.676
# 10521227   2606:4700:10::6814:6844  443         29.081             9.350
#
#           ConnectionEstablishmentTime     TTFB  TotalDownloadTime  \
# 10521223                       74.185  132.045            132.098
# 10521224                       77.660  108.711            108.730
# 10521225                       71.559  624.995            636.488
# 10521226                       66.829  188.141            188.165
# 10521227                       83.362  254.051            271.469
#
#          HttpResponse HTTPVersion    Protocol
# 10521223          301    HTTP/1.1  TCP/TLS1.2
# 10521224          301       HTTP2  TCP/TLS1.2
# 10521225          200       HTTP2  TCP/TLS1.2
# 10521226          301       HTTP2  TCP/TLS1.2
# 10521227          200    HTTP/1.1  TCP/TLS1.2

# %%
#t['TimeOfMeasurement'] = t['TimeOfMeasurement'].apply(timestamp2human)

# %%
t.head()
# Out:
#    TimeOfMeasurement                        Url Path  \
# 0         1587124802  www.0dayrox2.blogspot.com    /
# 1         1587124802  www.0dayrox2.blogspot.com    /
# 2         1587124802  www.0dayrox2.blogspot.com    /
# 4         1587124803  www.0dayrox2.blogspot.com    /
# 5         1587124803  www.0dayrox2.blogspot.com    /
#
#                          Ip Port  DNSTime  ConnectionEstablishmentTime  \
# 0             216.58.207.33  443   62.308                       44.542
# 1             216.58.207.33  443    0.503                       36.357
# 2             216.58.207.33  443    0.689                       36.670
# 4  2a00:1450:4001:81b::2001  443   18.795                       35.975
# 5  2a00:1450:4001:81b::2001  443    0.545                       35.162
#
#       TTFB  TotalDownloadTime  HttpResponse Protocol
# 0  260.441            350.790         404.0     Q043
# 1  238.053            332.277         404.0     Q046
# 2  234.652            387.210         404.0     Q050
# 4  252.821            403.325         404.0     Q043
# 5  237.424            599.720         404.0     Q046

# %%
t.tail()
# Out:
#          TimeOfMeasurement                              Url Path  \
# 8660225         1589112032  www.sonidosminimos.blogspot.com    /
# 8660226         1589112032  www.sonidosminimos.blogspot.com    /
# 8660227         1589112033  www.sonidosminimos.blogspot.com    /
# 8660229         1589112033  www.sonidosminimos.blogspot.com    /
# 8660231         1589112033  www.sonidosminimos.blogspot.com    /
#
#                                Ip Port  DNSTime  ConnectionEstablishmentTime  \
# 8660225             172.217.18.97  443   19.496                       34.700
# 8660226             172.217.18.97  443    1.736                       34.586
# 8660227             172.217.18.97  443    4.236                       34.829
# 8660229  2a00:1450:4001:824::2001  443    1.817                       36.797
# 8660231  2a00:1450:4001:824::2001  443    0.819                       36.756
#
#             TTFB  TotalDownloadTime  HttpResponse Protocol
# 8660225  212.051            212.151         301.0     Q043
# 8660226  194.323            194.377         301.0     Q046
# 8660227  201.173            201.231         301.0     Q050
# 8660229  207.400            207.467         301.0     Q043
# 8660231  668.709            668.802         301.0     Q046

# %%
def filter_by_ip(df, column):
  """reads a DataFrame, calls fbi.filter_v{4,6} to get DataFrames with rows
     containing only v4, v6 endpoints. Returns the two DataFrame as a tuple"""

  dfv6 = fbi.filter_v6(df, column)
  dfv4 = fbi.filter_v4(df, column)
  return dfv4, dfv6

# %%
#quic4, quic6 = filter_by_ip(t, column = 'Ip')
quic4 = t[t['Ip'].str.contains("\.")]
quic6 = t[t['Ip'].str.contains("\:")]

# %%
quic4.count()
# Out:
# TimeOfMeasurement              3096593
# Url                            3096593
# Path                           3096593
# Ip                             3096593
# Port                           3096593
# DNSTime                        3096593
# ConnectionEstablishmentTime    3096593
# TTFB                           3096593
# TotalDownloadTime              3096593
# HttpResponse                   3096593
# Protocol                       3096593
# dtype: int64

# %%
quic4.head()
# Out:
#    TimeOfMeasurement                        Url Path             Ip Port  \
# 0         1587124802  www.0dayrox2.blogspot.com    /  216.58.207.33  443
# 1         1587124802  www.0dayrox2.blogspot.com    /  216.58.207.33  443
# 2         1587124802  www.0dayrox2.blogspot.com    /  216.58.207.33  443
# 8         1587124804   www.0dayrox.blogspot.com    /  216.58.207.33  443
# 9         1587124804   www.0dayrox.blogspot.com    /  216.58.207.33  443
#
#    DNSTime  ConnectionEstablishmentTime     TTFB  TotalDownloadTime  \
# 0   62.308                       44.542  260.441            350.790
# 1    0.503                       36.357  238.053            332.277
# 2    0.689                       36.670  234.652            387.210
# 8   29.468                       34.932  246.995            346.056
# 9    2.691                       35.009  237.084            286.407
#
#    HttpResponse Protocol
# 0         404.0     Q043
# 1         404.0     Q046
# 2         404.0     Q050
# 8         404.0     Q043
# 9         404.0     Q046

# %%
quic6.count()
# Out:
# TimeOfMeasurement              2314621
# Url                            2314621
# Path                           2314621
# Ip                             2314621
# Port                           2314621
# DNSTime                        2314621
# ConnectionEstablishmentTime    2314621
# TTFB                           2314621
# TotalDownloadTime              2314621
# HttpResponse                   2314621
# Protocol                       2314621
# dtype: int64

# %%
quic6.head()
# Out:
#     TimeOfMeasurement                        Url Path  \
# 4          1587124803  www.0dayrox2.blogspot.com    /
# 5          1587124803  www.0dayrox2.blogspot.com    /
# 6          1587124804  www.0dayrox2.blogspot.com    /
# 12         1587124805   www.0dayrox.blogspot.com    /
# 13         1587124806   www.0dayrox.blogspot.com    /
#
#                           Ip Port  DNSTime  ConnectionEstablishmentTime  \
# 4   2a00:1450:4001:81b::2001  443   18.795                       35.975
# 5   2a00:1450:4001:81b::2001  443    0.545                       35.162
# 6   2a00:1450:4001:81b::2001  443    0.550                       36.134
# 12  2a00:1450:4001:81b::2001  443    0.634                       35.409
# 13  2a00:1450:4001:81b::2001  443    0.493                       34.702
#
#        TTFB  TotalDownloadTime  HttpResponse Protocol
# 4   252.821            403.325         404.0     Q043
# 5   237.424            599.720         404.0     Q046
# 6   269.986            420.088         404.0     Q050
# 12  245.062            619.198         404.0     Q043
# 13  287.929            348.535         404.0     Q046

# %%
#tcp4, tcp6 = filter_by_ip(s, column = 'Ip')
tcp4 = s[s['Ip'].str.contains("\.")]
tcp6 = s[s['Ip'].str.contains("\:")]

# %%
tcp4.count()
# Out:
# TimeOfMeasurement              5974724
# Url                            5974724
# Ip                             5974724
# Port                           5974724
# DnsLookupTime                  5974724
# TCPHandshakeTime               5974724
# ConnectionEstablishmentTime    5974724
# TTFB                           5974724
# TotalDownloadTime              5974724
# HttpResponse                   5974724
# HTTPVersion                    5974724
# Protocol                       5974724
# dtype: int64

# %%
tcp4.head()
# Out:
#           TimeOfMeasurement             Url             Ip Port  \
# 0  Fri Apr 17 14:00:02 2020  www.google.com  216.58.207.36  443
# 1  Fri Apr 17 14:00:02 2020  www.google.com  216.58.207.36  443
# 4  Fri Apr 17 14:00:03 2020    facebook.com  185.60.216.35  443
# 5  Fri Apr 17 14:00:03 2020    facebook.com  185.60.216.35  443
# 6  Fri Apr 17 14:00:03 2020    facebook.com  185.60.216.35  443
#
#    DnsLookupTime  TCPHandshakeTime  ConnectionEstablishmentTime     TTFB  \
# 0          4.183             8.871                       95.146  150.998
# 1          4.167             9.001                       73.048  127.133
# 4         12.268             9.463                       62.374  363.963
# 5          4.145             9.298                       54.841  167.253
# 6          4.166             9.276                       63.923  184.582
#
#    TotalDownloadTime HttpResponse HTTPVersion    Protocol
# 0            165.778          200    HTTP/1.1  TCP/TLS1.2
# 1            137.560          200       HTTP2  TCP/TLS1.2
# 4            363.992          301    HTTP/1.1  TCP/TLS1.2
# 5            167.281          301    HTTP/1.1  TCP/TLS1.3
# 6            184.612          301       HTTP2  TCP/TLS1.2

# %%
tcp6.count()
# Out:
# TimeOfMeasurement              4546504
# Url                            4546504
# Ip                             4546504
# Port                           4546504
# DnsLookupTime                  4546504
# TCPHandshakeTime               4546504
# ConnectionEstablishmentTime    4546504
# TTFB                           4546504
# TotalDownloadTime              4546504
# HttpResponse                   4546504
# HTTPVersion                    4546504
# Protocol                       4546504
# dtype: int64

# %%
tcp6.head()
# Out:
#            TimeOfMeasurement             Url  \
# 2   Fri Apr 17 14:00:02 2020  www.google.com
# 3   Fri Apr 17 14:00:02 2020  www.google.com
# 8   Fri Apr 17 14:00:03 2020    facebook.com
# 9   Fri Apr 17 14:00:03 2020    facebook.com
# 10  Fri Apr 17 14:00:04 2020    facebook.com
#
#                                     Ip Port  DnsLookupTime  TCPHandshakeTime  \
# 2             2a00:1450:4001:824::2004  443          4.147             8.518
# 3             2a00:1450:4001:824::2004  443          4.178             8.536
# 8   2a03:2880:f12d:83:face:b00c:0:25de  443         12.280             8.707
# 9   2a03:2880:f12d:83:face:b00c:0:25de  443          4.197             8.932
# 10  2a03:2880:f12d:83:face:b00c:0:25de  443          4.148             8.870
#
#     ConnectionEstablishmentTime     TTFB  TotalDownloadTime HttpResponse  \
# 2                        66.957  118.658            134.236          200
# 3                        68.726  122.663            134.412          200
# 8                        62.516  148.004            148.030          301
# 9                        52.744   79.710             79.759          301
# 10                       65.181   92.173             92.206          301
#
#    HTTPVersion    Protocol
# 2     HTTP/1.1  TCP/TLS1.2
# 3        HTTP2  TCP/TLS1.2
# 8     HTTP/1.1  TCP/TLS1.2
# 9     HTTP/1.1  TCP/TLS1.3
# 10       HTTP2  TCP/TLS1.2

# %%
quic43 = quic4.loc[t['Protocol'] == 'Q043']
quic46 = quic4.loc[t['Protocol'] == 'Q046']
quic50 = quic4.loc[t['Protocol'] == 'Q050']
quicID24 = quic4.loc[t['Protocol'] == 'FF000018']
quic98 = quic4.loc[t['Protocol'] == '']

# %%
quic43.count()
# Out:
# TimeOfMeasurement              1036234
# Url                            1036234
# Path                           1036234
# Ip                             1036234
# Port                           1036234
# DNSTime                        1036234
# ConnectionEstablishmentTime    1036234
# TTFB                           1036234
# TotalDownloadTime              1036234
# HttpResponse                   1036234
# Protocol                       1036234
# dtype: int64

# %%
quic43.head()
# Out:
#     TimeOfMeasurement                                      Url Path  \
# 0          1587124802                www.0dayrox2.blogspot.com    /
# 8          1587124804                 www.0dayrox.blogspot.com    /
# 16         1587124807  www.100leccionesdeguitarra.blogspot.com    /
# 24         1587124808                      www.100negocios.com    /
# 40         1587124837                 www.1100021.blogspot.com    /
#
#                Ip Port  DNSTime  ConnectionEstablishmentTime     TTFB  \
# 0   216.58.207.33  443   62.308                       44.542  260.441
# 8   216.58.207.33  443   29.468                       34.932  246.995
# 16  216.58.207.33  443   19.923                       38.386  212.451
# 24  66.198.240.11  443  136.733                      243.528  947.961
# 40  216.58.207.33  443   18.717                       36.285  234.824
#
#     TotalDownloadTime  HttpResponse Protocol
# 0             350.790         404.0     Q043
# 8             346.056         404.0     Q043
# 16            212.518         301.0     Q043
# 24            229.289         200.0     Q043
# 40            235.088         301.0     Q043

# %%
quic43.tail()
# Out:
#          TimeOfMeasurement                               Url Path  \
# 8660190         1589112025     www.some-tg-caps.blogspot.com    /
# 8660199         1589112027  www.sonatapremieres.blogspot.com    /
# 8660208         1589112029    www.so-networking.blogspot.com    /
# 8660216         1589112031        www.songmatin.blogspot.com    /
# 8660225         1589112032   www.sonidosminimos.blogspot.com    /
#
#                     Ip Port  DNSTime  ConnectionEstablishmentTime     TTFB  \
# 8660190  172.217.18.97  443   19.494                       34.573  854.575
# 8660199  172.217.18.97  443   18.924                       34.047  183.309
# 8660208  172.217.18.97  443   19.113                       34.715  696.446
# 8660216  172.217.18.97  443   18.218                       34.779  194.102
# 8660225  172.217.18.97  443   19.496                       34.700  212.051
#
#          TotalDownloadTime  HttpResponse Protocol
# 8660190            854.644         301.0     Q043
# 8660199            183.393         301.0     Q043
# 8660208            696.525         301.0     Q043
# 8660216            194.189         301.0     Q043
# 8660225            212.151         301.0     Q043

# %%
quic46.count()
# Out:
# TimeOfMeasurement              1023043
# Url                            1023043
# Path                           1023043
# Ip                             1023043
# Port                           1023043
# DNSTime                        1023043
# ConnectionEstablishmentTime    1023043
# TTFB                           1023043
# TotalDownloadTime              1023043
# HttpResponse                   1023043
# Protocol                       1023043
# dtype: int64

# %%
quic46.head()
# Out:
#     TimeOfMeasurement                                      Url Path  \
# 1          1587124802                www.0dayrox2.blogspot.com    /
# 9          1587124804                 www.0dayrox.blogspot.com    /
# 17         1587124807  www.100leccionesdeguitarra.blogspot.com    /
# 25         1587124809                      www.100negocios.com    /
# 41         1587124837                 www.1100021.blogspot.com    /
#
#                Ip Port  DNSTime  ConnectionEstablishmentTime     TTFB  \
# 1   216.58.207.33  443    0.503                       36.357  238.053
# 9   216.58.207.33  443    2.691                       35.009  237.084
# 17  216.58.207.33  443    0.631                       36.999  215.492
# 25  66.198.240.11  443    0.587                      245.008  847.518
# 41  216.58.207.33  443    0.674                       34.540  246.736
#
#     TotalDownloadTime  HttpResponse Protocol
# 1             332.277         404.0     Q046
# 9             286.407         404.0     Q046
# 17            215.559         301.0     Q046
# 25            132.469         200.0     Q046
# 41            247.066         301.0     Q046

# %%
quic46.tail()
# Out:
#          TimeOfMeasurement                               Url Path  \
# 8660191         1589112026     www.some-tg-caps.blogspot.com    /
# 8660200         1589112028  www.sonatapremieres.blogspot.com    /
# 8660209         1589112029    www.so-networking.blogspot.com    /
# 8660218         1589112031        www.songmatin.blogspot.com    /
# 8660226         1589112032   www.sonidosminimos.blogspot.com    /
#
#                     Ip Port  DNSTime  ConnectionEstablishmentTime     TTFB  \
# 8660191  172.217.18.97  443    0.604                       35.263  582.526
# 8660200  172.217.18.97  443    0.626                       34.364  180.360
# 8660209  172.217.18.97  443    0.516                       34.562  194.171
# 8660218  172.217.18.97  443    0.617                       35.474  191.044
# 8660226  172.217.18.97  443    1.736                       34.586  194.323
#
#          TotalDownloadTime  HttpResponse Protocol
# 8660191            582.614         301.0     Q046
# 8660200            180.435         301.0     Q046
# 8660209            194.231         301.0     Q046
# 8660218            191.113         301.0     Q046
# 8660226            194.377         301.0     Q046

# %%
quic50.count()
# Out:
# TimeOfMeasurement              1007316
# Url                            1007316
# Path                           1007316
# Ip                             1007316
# Port                           1007316
# DNSTime                        1007316
# ConnectionEstablishmentTime    1007316
# TTFB                           1007316
# TotalDownloadTime              1007316
# HttpResponse                   1007316
# Protocol                       1007316
# dtype: int64

# %%
quic50.head()
# Out:
#     TimeOfMeasurement                                      Url Path  \
# 2          1587124802                www.0dayrox2.blogspot.com    /
# 10         1587124805                 www.0dayrox.blogspot.com    /
# 18         1587124807  www.100leccionesdeguitarra.blogspot.com    /
# 26         1587124810                      www.100negocios.com    /
# 42         1587124838                 www.1100021.blogspot.com    /
#
#                Ip Port  DNSTime  ConnectionEstablishmentTime     TTFB  \
# 2   216.58.207.33  443    0.689                       36.670  234.652
# 10  216.58.207.33  443    0.642                       35.186  250.466
# 18  216.58.207.33  443    0.724                       35.766  206.332
# 26  66.198.240.11  443    0.606                      243.742  841.764
# 42  216.58.207.33  443    0.645                       35.400  242.638
#
#     TotalDownloadTime  HttpResponse Protocol
# 2             387.210         404.0     Q050
# 10            396.386         404.0     Q050
# 18            206.422         301.0     Q050
# 26            137.599         200.0     Q050
# 42            242.731         301.0     Q050

# %%
quic50.tail()
# Out:
#          TimeOfMeasurement                               Url Path  \
# 8660192         1589112027     www.some-tg-caps.blogspot.com    /
# 8660201         1589112028  www.sonatapremieres.blogspot.com    /
# 8660210         1589112029    www.so-networking.blogspot.com    /
# 8660219         1589112031        www.songmatin.blogspot.com    /
# 8660227         1589112033   www.sonidosminimos.blogspot.com    /
#
#                     Ip Port  DNSTime  ConnectionEstablishmentTime     TTFB  \
# 8660192  172.217.18.97  443    0.501                       34.728  207.467
# 8660201  172.217.18.97  443    0.586                       35.999  181.121
# 8660210  172.217.18.97  443    0.552                       34.750  212.956
# 8660219  172.217.18.97  443    1.041                       34.520  194.746
# 8660227  172.217.18.97  443    4.236                       34.829  201.173
#
#          TotalDownloadTime  HttpResponse Protocol
# 8660192            207.545         301.0     Q050
# 8660201            181.183         301.0     Q050
# 8660210            213.014         301.0     Q050
# 8660219            194.843         301.0     Q050
# 8660227            201.231         301.0     Q050

# %%
quicID24.count()
# Out:
# TimeOfMeasurement              30000
# Url                            30000
# Path                           30000
# Ip                             30000
# Port                           30000
# DNSTime                        30000
# ConnectionEstablishmentTime    30000
# TTFB                           30000
# TotalDownloadTime              30000
# HttpResponse                   30000
# Protocol                       30000
# dtype: int64

# %%
quicID24.head()
# Out:
#       TimeOfMeasurement                    Url Path              Ip Port  \
# 75           1587124860        www.12oclock.us    /    23.227.38.64  443
# 91           1587124867     www.1a-gewinner.de    /  194.150.248.63  443
# 516          1587126156  www.85cbakerycafe.com    /   72.249.30.164  443
# 544          1587126171   www.9999999views.com    /  178.32.108.178  443
# 1140         1587126405    www.aibt.qld.edu.au    /   103.9.171.248  443
#
#       DNSTime  ConnectionEstablishmentTime     TTFB  TotalDownloadTime  \
# 75      0.525                       37.791  254.063            272.808
# 91      0.502                       19.069   34.440             34.495
# 516     0.560                      261.403  231.051            532.367
# 544     0.826                       19.917   37.536             37.585
# 1140    0.784                      283.599  563.182            563.251
#
#       HttpResponse  Protocol
# 75           402.0  FF000018
# 91           404.0  FF000018
# 516          200.0  FF000018
# 544          301.0  FF000018
# 1140         301.0  FF000018

# %%
quicID24.tail()
# Out:
#          TimeOfMeasurement                    Url Path               Ip Port  \
# 8658305         1589111182  www.sakhtafzarmag.com    /     104.28.20.77  443
# 8658621         1589111293       www.scaruffi.com    /  162.223.225.219  443
# 8659169         1589111496         www.sermp3.com    /   107.150.53.218  443
# 8659377         1589111638      www.shikocity.xyz    /    150.95.54.158  443
# 8659865         1589111858      www.slotforum.com    /    104.16.249.51  443
#
#          DNSTime  ConnectionEstablishmentTime     TTFB  TotalDownloadTime  \
# 8658305    0.543                       13.765   63.693             63.757
# 8658621    0.620                      179.272  357.149            381.125
# 8659169    0.788                      121.384  240.429            240.500
# 8659377    0.498                      405.255  910.326            910.397
# 8659865    0.522                       16.256  171.885            171.952
#
#          HttpResponse  Protocol
# 8658305         301.0  FF000018
# 8658621         200.0  FF000018
# 8659169         302.0  FF000018
# 8659377         301.0  FF000018
# 8659865         200.0  FF000018

# %%
quic43_6 = quic6.loc[t['Protocol'] == 'Q043']
quic46_6 = quic6.loc[t['Protocol'] == 'Q046']
quic50_6 = quic6.loc[t['Protocol'] == 'Q050']
#quic98_6 = quic6.loc[t['Protocol'] == '']
quicID24_6 = quic6.loc[t['Protocol'] == 'FF000018']

# %%
quic43_6.count()
# Out:
# TimeOfMeasurement              769054
# Url                            769054
# Path                           769054
# Ip                             769054
# Port                           769054
# DNSTime                        769054
# ConnectionEstablishmentTime    769054
# TTFB                           769054
# TotalDownloadTime              769054
# HttpResponse                   769054
# Protocol                       769054
# dtype: int64

# %%
quic43_6.head()
# Out:
#     TimeOfMeasurement                                      Url Path  \
# 4          1587124803                www.0dayrox2.blogspot.com    /
# 12         1587124805                 www.0dayrox.blogspot.com    /
# 20         1587124807  www.100leccionesdeguitarra.blogspot.com    /
# 44         1587124838                 www.1100021.blogspot.com    /
# 68         1587124856                 www.1254375.blogspot.com    /
#
#                           Ip Port  DNSTime  ConnectionEstablishmentTime  \
# 4   2a00:1450:4001:81b::2001  443   18.795                       35.975
# 12  2a00:1450:4001:81b::2001  443    0.634                       35.409
# 20  2a00:1450:4001:81b::2001  443    0.656                       35.059
# 44  2a00:1450:4001:81b::2001  443    0.650                       35.329
# 68  2a00:1450:4001:81b::2001  443    0.496                       34.671
#
#        TTFB  TotalDownloadTime  HttpResponse Protocol
# 4   252.821            403.325         404.0     Q043
# 12  245.062            619.198         404.0     Q043
# 20  223.928            224.038         301.0     Q043
# 44  234.132            234.268         301.0     Q043
# 68  231.910            232.023         301.0     Q043

# %%
quic43_6.tail()
# Out:
#          TimeOfMeasurement                               Url Path  \
# 8660194         1589112027     www.some-tg-caps.blogspot.com    /
# 8660203         1589112028  www.sonatapremieres.blogspot.com    /
# 8660212         1589112030    www.so-networking.blogspot.com    /
# 8660221         1589112032        www.songmatin.blogspot.com    /
# 8660229         1589112033   www.sonidosminimos.blogspot.com    /
#
#                                Ip Port  DNSTime  ConnectionEstablishmentTime  \
# 8660194  2a00:1450:4001:824::2001  443    0.465                       34.254
# 8660203  2a00:1450:4001:824::2001  443    0.518                       35.778
# 8660212  2a00:1450:4001:824::2001  443    0.470                       37.275
# 8660221  2a00:1450:4001:824::2001  443    0.458                       33.927
# 8660229  2a00:1450:4001:824::2001  443    1.817                       36.797
#
#             TTFB  TotalDownloadTime  HttpResponse Protocol
# 8660194  202.566            203.264         301.0     Q043
# 8660203  176.475            176.557         301.0     Q043
# 8660212  208.771            208.854         301.0     Q043
# 8660221  193.163            193.254         301.0     Q043
# 8660229  207.400            207.467         301.0     Q043

# %%
quic46_6.count()
# Out:
# TimeOfMeasurement              769012
# Url                            769012
# Path                           769012
# Ip                             769012
# Port                           769012
# DNSTime                        769012
# ConnectionEstablishmentTime    769012
# TTFB                           769012
# TotalDownloadTime              769012
# HttpResponse                   769012
# Protocol                       769012
# dtype: int64

# %%
quic46_6.head()
# Out:
#     TimeOfMeasurement                                      Url Path  \
# 5          1587124803                www.0dayrox2.blogspot.com    /
# 13         1587124806                 www.0dayrox.blogspot.com    /
# 21         1587124807  www.100leccionesdeguitarra.blogspot.com    /
# 45         1587124838                 www.1100021.blogspot.com    /
# 69         1587124856                 www.1254375.blogspot.com    /
#
#                           Ip Port  DNSTime  ConnectionEstablishmentTime  \
# 5   2a00:1450:4001:81b::2001  443    0.545                       35.162
# 13  2a00:1450:4001:81b::2001  443    0.493                       34.702
# 21  2a00:1450:4001:81b::2001  443    0.789                       34.650
# 45  2a00:1450:4001:81b::2001  443    0.595                       34.327
# 69  2a00:1450:4001:81b::2001  443    0.592                       34.810
#
#        TTFB  TotalDownloadTime  HttpResponse Protocol
# 5   237.424            599.720         404.0     Q046
# 13  287.929            348.535         404.0     Q046
# 21  216.517            217.083         301.0     Q046
# 45  244.607            245.225         301.0     Q046
# 69  216.758            216.832         301.0     Q046

# %%
quic46_6.tail()
# Out:
#          TimeOfMeasurement                               Url Path  \
# 8660195         1589112027     www.some-tg-caps.blogspot.com    /
# 8660204         1589112028  www.sonatapremieres.blogspot.com    /
# 8660213         1589112030    www.so-networking.blogspot.com    /
# 8660222         1589112032        www.songmatin.blogspot.com    /
# 8660231         1589112033   www.sonidosminimos.blogspot.com    /
#
#                                Ip Port  DNSTime  ConnectionEstablishmentTime  \
# 8660195  2a00:1450:4001:824::2001  443    0.504                       33.990
# 8660204  2a00:1450:4001:824::2001  443    0.764                       34.439
# 8660213  2a00:1450:4001:824::2001  443    0.743                       34.449
# 8660222  2a00:1450:4001:824::2001  443    4.321                       34.848
# 8660231  2a00:1450:4001:824::2001  443    0.819                       36.756
#
#             TTFB  TotalDownloadTime  HttpResponse Protocol
# 8660195  199.539            199.662         301.0     Q046
# 8660204  188.578            188.647         301.0     Q046
# 8660213  199.323            199.421         301.0     Q046
# 8660222  192.908            193.025         301.0     Q046
# 8660231  668.709            668.802         301.0     Q046

# %%
quic50_6.count()
# Out:
# TimeOfMeasurement              769000
# Url                            769000
# Path                           769000
# Ip                             769000
# Port                           769000
# DNSTime                        769000
# ConnectionEstablishmentTime    769000
# TTFB                           769000
# TotalDownloadTime              769000
# HttpResponse                   769000
# Protocol                       769000
# dtype: int64

# %%
quic50_6.head()
# Out:
#     TimeOfMeasurement                                      Url Path  \
# 6          1587124804                www.0dayrox2.blogspot.com    /
# 14         1587124806                 www.0dayrox.blogspot.com    /
# 22         1587124808  www.100leccionesdeguitarra.blogspot.com    /
# 46         1587124838                 www.1100021.blogspot.com    /
# 70         1587124856                 www.1254375.blogspot.com    /
#
#                           Ip Port  DNSTime  ConnectionEstablishmentTime  \
# 6   2a00:1450:4001:81b::2001  443    0.550                       36.134
# 14  2a00:1450:4001:81b::2001  443    0.710                       35.382
# 22  2a00:1450:4001:81b::2001  443   98.274                       35.405
# 46  2a00:1450:4001:81b::2001  443    0.559                       34.484
# 70  2a00:1450:4001:81b::2001  443    0.496                       34.486
#
#        TTFB  TotalDownloadTime  HttpResponse Protocol
# 6   269.986            420.088         404.0     Q050
# 14  258.007            392.277         404.0     Q050
# 22  210.195            210.279         301.0     Q050
# 46  228.373            228.522         301.0     Q050
# 70  216.916            217.094         301.0     Q050

# %%
quic50_6.tail()
# Out:
#          TimeOfMeasurement                               Url Path  \
# 8660187         1589112025        www.someguytw.blogspot.com    /
# 8660197         1589112027     www.some-tg-caps.blogspot.com    /
# 8660205         1589112028  www.sonatapremieres.blogspot.com    /
# 8660214         1589112030    www.so-networking.blogspot.com    /
# 8660223         1589112032        www.songmatin.blogspot.com    /
#
#                                Ip Port  DNSTime  ConnectionEstablishmentTime  \
# 8660187  2a00:1450:4001:824::2001  443    0.485                       33.537
# 8660197  2a00:1450:4001:824::2001  443    0.499                       34.427
# 8660205  2a00:1450:4001:824::2001  443    0.762                       34.273
# 8660214  2a00:1450:4001:824::2001  443    3.088                       33.621
# 8660223  2a00:1450:4001:824::2001  443    0.546                       34.318
#
#             TTFB  TotalDownloadTime  HttpResponse Protocol
# 8660187  196.903            196.983         301.0     Q050
# 8660197  196.977            198.255         301.0     Q050
# 8660205  178.895            178.986         301.0     Q050
# 8660214  876.194            876.281         301.0     Q050
# 8660223  186.683            186.844         301.0     Q050

# %%
quicID24_6.count()
# Out:
# TimeOfMeasurement              7555
# Url                            7555
# Path                           7555
# Ip                             7555
# Port                           7555
# DNSTime                        7555
# ConnectionEstablishmentTime    7555
# TTFB                           7555
# TotalDownloadTime              7555
# HttpResponse                   7555
# Protocol                       7555
# dtype: int64

# %%
quicID24_6.head()
# Out:
#        TimeOfMeasurement                        Url Path  \
# 5628          1587128574     www.challengertalk.com    /
# 9480          1587130318       www.elespectador.com    /
# 27162         1587136226  www.medikalakademi.com.tr    /
# 27736         1587136386     www.challengertalk.com    /
# 35123         1587138039       www.elespectador.com    /
#
#                              Ip Port  DNSTime  ConnectionEstablishmentTime  \
# 5628       2606:4700::6812:18aa  443    0.601                       18.155
# 9480       2606:4700::6810:d308  443    0.675                       16.794
# 27162  2606:4700:3035::681c:8d7  443    0.783                       23.618
# 27736      2606:4700::6812:18aa  443    0.574                       23.830
# 35123      2606:4700::6810:d208  443    0.620                       13.425
#
#           TTFB  TotalDownloadTime  HttpResponse  Protocol
# 5628   406.428            424.990         200.0  FF000018
# 9480    75.105             75.203         301.0  FF000018
# 27162  204.043            315.896         200.0  FF000018
# 27736  419.628            439.026         200.0  FF000018
# 35123   37.445             37.497         301.0  FF000018

# %%
quicID24_6.tail()
# Out:
#          TimeOfMeasurement                    Url Path  \
# 8657274         1589110897       www.rosebikes.de    /
# 8657330         1589110906       www.rosebikes.hu    /
# 8657346         1589110915       www.rosebikes.nl    /
# 8658309         1589111186  www.sakhtafzarmag.com    /
# 8659869         1589111862      www.slotforum.com    /
#
#                                 Ip Port  DNSTime  ConnectionEstablishmentTime  \
# 8657274       2606:4700::6810:b817  443    0.620                       17.446
# 8657330       2606:4700::6810:800e  443    0.567                       20.060
# 8657346       2606:4700::6810:a918  443    0.568                       20.420
# 8658309  2606:4700:3030::681c:144d  443    0.704                       12.327
# 8659869       2606:4700::6810:f833  443    0.614                       19.970
#
#             TTFB  TotalDownloadTime  HttpResponse  Protocol
# 8657274  239.068            268.992         200.0  FF000018
# 8657330  346.510            375.064         200.0  FF000018
# 8657346  176.711            205.922         200.0  FF000018
# 8658309   66.576             66.691         301.0  FF000018
# 8659869  171.853            171.960         200.0  FF000018

# %%
tcp12 = tcp4.loc[s['Protocol'] == 'TCP/TLS1.2']
tcp13 = tcp4.loc[s['Protocol'] == 'TCP/TLS1.3']

# %%
tcp12.count()
# Out:
# TimeOfMeasurement              5966995
# Url                            5966995
# Ip                             5966995
# Port                           5966995
# DnsLookupTime                  5966995
# TCPHandshakeTime               5966995
# ConnectionEstablishmentTime    5966995
# TTFB                           5966995
# TotalDownloadTime              5966995
# HttpResponse                   5966995
# HTTPVersion                    5966995
# Protocol                       5966995
# dtype: int64

# %%
tcp12.head()
# Out:
#            TimeOfMeasurement             Url             Ip Port  \
# 0   Fri Apr 17 14:00:02 2020  www.google.com  216.58.207.36  443
# 1   Fri Apr 17 14:00:02 2020  www.google.com  216.58.207.36  443
# 4   Fri Apr 17 14:00:03 2020    facebook.com  185.60.216.35  443
# 6   Fri Apr 17 14:00:03 2020    facebook.com  185.60.216.35  443
# 12  Fri Apr 17 14:00:04 2020   instagram.com   52.7.184.177  443
#
#     DnsLookupTime  TCPHandshakeTime  ConnectionEstablishmentTime     TTFB  \
# 0           4.183             8.871                       95.146  150.998
# 1           4.167             9.001                       73.048  127.133
# 4          12.268             9.463                       62.374  363.963
# 6           4.166             9.276                       63.923  184.582
# 12         28.329           100.039                      372.579  524.830
#
#     TotalDownloadTime HttpResponse HTTPVersion    Protocol
# 0             165.778          200    HTTP/1.1  TCP/TLS1.2
# 1             137.560          200       HTTP2  TCP/TLS1.2
# 4             363.992          301    HTTP/1.1  TCP/TLS1.2
# 6             184.612          301       HTTP2  TCP/TLS1.2
# 12            524.860          301    HTTP/1.1  TCP/TLS1.2

# %%
tcp12.tail()
# Out:
#                  TimeOfMeasurement              Url             Ip Port  \
# 10521218  Sun May 10 14:01:05 2020  phimsexporn.com   104.28.5.120  443
# 10521219  Sun May 10 14:01:05 2020           hvg.hu  104.20.105.68  443
# 10521222  Sun May 10 14:01:05 2020           hvg.hu  104.20.105.68  443
# 10521223  Sun May 10 14:01:05 2020   www.tickets.az    104.28.2.67  443
# 10521226  Sun May 10 14:01:05 2020   www.tickets.az    104.28.2.67  443
#
#           DnsLookupTime  TCPHandshakeTime  ConnectionEstablishmentTime  \
# 10521218          4.152             9.170                       72.225
# 10521219         60.348             9.140                      118.905
# 10521222          4.391             9.381                       75.827
# 10521223        124.427             9.173                       74.185
# 10521226         14.903             9.676                       66.829
#
#              TTFB  TotalDownloadTime HttpResponse HTTPVersion    Protocol
# 10521218   89.000             89.017          301       HTTP2  TCP/TLS1.2
# 10521219  194.850            213.717          200    HTTP/1.1  TCP/TLS1.2
# 10521222  154.939            173.062          200       HTTP2  TCP/TLS1.2
# 10521223  132.045            132.098          301    HTTP/1.1  TCP/TLS1.2
# 10521226  188.141            188.165          301       HTTP2  TCP/TLS1.2

# %%
tcp13.count()
# Out:
# TimeOfMeasurement              7726
# Url                            7726
# Ip                             7726
# Port                           7726
# DnsLookupTime                  7726
# TCPHandshakeTime               7726
# ConnectionEstablishmentTime    7726
# TTFB                           7726
# TotalDownloadTime              7726
# HttpResponse                   7726
# HTTPVersion                    7726
# Protocol                       7726
# dtype: int64

# %%
tcp13.head()
# Out:
#            TimeOfMeasurement               Url             Ip Port  \
# 5   Fri Apr 17 14:00:03 2020      facebook.com  185.60.216.35  443
# 7   Fri Apr 17 14:00:03 2020      facebook.com  185.60.216.35  443
# 13  Fri Apr 17 14:00:05 2020     instagram.com   52.54.232.92  443
# 15  Fri Apr 17 14:00:05 2020     instagram.com  34.233.33.203  443
# 21  Fri Apr 17 14:00:08 2020  www.whatsapp.com  185.60.216.53  443
#
#     DnsLookupTime  TCPHandshakeTime  ConnectionEstablishmentTime     TTFB  \
# 5           4.145             9.298                       54.841  167.253
# 7           4.156             9.587                       56.583  164.175
# 13          4.158            97.051                      239.037  381.658
# 15          6.192           101.120                      249.672  397.329
# 21        124.737             9.328                       55.069  165.304
#
#     TotalDownloadTime HttpResponse HTTPVersion    Protocol
# 5             167.281          301    HTTP/1.1  TCP/TLS1.3
# 7             164.204          301       HTTP2  TCP/TLS1.3
# 13            381.687          301    HTTP/1.1  TCP/TLS1.3
# 15            397.374          301       HTTP2  TCP/TLS1.3
# 21            165.329          302    HTTP/1.1  TCP/TLS1.3

# %%
tcp13.tail()
# Out:
#                  TimeOfMeasurement               Url             Ip Port  \
# 10520752  Sun May 10 14:00:08 2020  www.whatsapp.com  185.60.216.53  443
# 10520776  Sun May 10 14:00:11 2020         fbcdn.net  185.60.216.35  443
# 10520779  Sun May 10 14:00:11 2020         fbcdn.net  185.60.216.35  443
# 10520837  Sun May 10 14:00:20 2020     messenger.com  185.60.216.15  443
# 10520840  Sun May 10 14:00:21 2020     messenger.com  185.60.216.15  443
#
#           DnsLookupTime  TCPHandshakeTime  ConnectionEstablishmentTime  \
# 10520752          4.601             9.065                       53.522
# 10520776          4.223             9.342                       55.151
# 10520779          4.163             9.259                       58.861
# 10520837          4.180            74.119                      118.056
# 10520840          4.135             9.200                       52.866
#
#              TTFB  TotalDownloadTime HttpResponse HTTPVersion    Protocol
# 10520752  165.550            165.580          302       HTTP2  TCP/TLS1.3
# 10520776  162.816            162.845          302    HTTP/1.1  TCP/TLS1.3
# 10520779  165.890            165.918          302       HTTP2  TCP/TLS1.3
# 10520837  256.050            256.071          301    HTTP/1.1  TCP/TLS1.3
# 10520840  201.010            201.039          301       HTTP2  TCP/TLS1.3

# %%
tcp12_6 = tcp6.loc[s['Protocol'] == 'TCP/TLS1.2']
tcp13_6 = tcp6.loc[s['Protocol'] == 'TCP/TLS1.3']

# %%
tcp12_6.count()
# Out:
# TimeOfMeasurement              4541999
# Url                            4541999
# Ip                             4541999
# Port                           4541999
# DnsLookupTime                  4541999
# TCPHandshakeTime               4541999
# ConnectionEstablishmentTime    4541999
# TTFB                           4541999
# TotalDownloadTime              4541999
# HttpResponse                   4541999
# HTTPVersion                    4541999
# Protocol                       4541999
# dtype: int64

# %%
tcp12_6.head()
# Out:
#            TimeOfMeasurement             Url  \
# 2   Fri Apr 17 14:00:02 2020  www.google.com
# 3   Fri Apr 17 14:00:02 2020  www.google.com
# 8   Fri Apr 17 14:00:03 2020    facebook.com
# 10  Fri Apr 17 14:00:04 2020    facebook.com
# 16  Fri Apr 17 14:00:06 2020   instagram.com
#
#                                     Ip Port  DnsLookupTime  TCPHandshakeTime  \
# 2             2a00:1450:4001:824::2004  443          4.147             8.518
# 3             2a00:1450:4001:824::2004  443          4.178             8.536
# 8   2a03:2880:f12d:83:face:b00c:0:25de  443         12.280             8.707
# 10  2a03:2880:f12d:83:face:b00c:0:25de  443          4.148             8.870
# 16             2406:da00:ff00::3e6:95e  443         60.527           104.177
#
#     ConnectionEstablishmentTime     TTFB  TotalDownloadTime HttpResponse  \
# 2                        66.957  118.658            134.236          200
# 3                        68.726  122.663            134.412          200
# 8                        62.516  148.004            148.030          301
# 10                       65.181   92.173             92.206          301
# 16                      352.876  531.920            531.962          301
#
#    HTTPVersion    Protocol
# 2     HTTP/1.1  TCP/TLS1.2
# 3        HTTP2  TCP/TLS1.2
# 8     HTTP/1.1  TCP/TLS1.2
# 10       HTTP2  TCP/TLS1.2
# 16    HTTP/1.1  TCP/TLS1.2

# %%
tcp12_6.tail()
# Out:
#                  TimeOfMeasurement                  Url  \
# 10521220  Sun May 10 14:01:05 2020  www.andertons.co.uk
# 10521221  Sun May 10 14:01:05 2020      phimsexporn.com
# 10521224  Sun May 10 14:01:05 2020      phimsexporn.com
# 10521225  Sun May 10 14:01:05 2020   tabulose-huren.com
# 10521227  Sun May 10 14:01:05 2020               hvg.hu
#
#                                 Ip Port  DnsLookupTime  TCPHandshakeTime  \
# 10521220   2606:4700:10::6814:ab3e  443          4.136             9.087
# 10521221  2606:4700:3036::681c:578  443         28.737             8.760
# 10521224  2606:4700:3037::681c:478  443          4.145             8.758
# 10521225    2606:4700:20::681a:379  443          4.134             8.716
# 10521227   2606:4700:10::6814:6844  443         29.081             9.350
#
#           ConnectionEstablishmentTime     TTFB  TotalDownloadTime  \
# 10521220                      132.835  752.601            779.718
# 10521221                      105.020  131.370            131.389
# 10521224                       77.660  108.711            108.730
# 10521225                       71.559  624.995            636.488
# 10521227                       83.362  254.051            271.469
#
#          HttpResponse HTTPVersion    Protocol
# 10521220          200       HTTP2  TCP/TLS1.2
# 10521221          301    HTTP/1.1  TCP/TLS1.2
# 10521224          301       HTTP2  TCP/TLS1.2
# 10521225          200       HTTP2  TCP/TLS1.2
# 10521227          200    HTTP/1.1  TCP/TLS1.2

# %%
tcp13_6.count()
# Out:
# TimeOfMeasurement              4504
# Url                            4504
# Ip                             4504
# Port                           4504
# DnsLookupTime                  4504
# TCPHandshakeTime               4504
# ConnectionEstablishmentTime    4504
# TTFB                           4504
# TotalDownloadTime              4504
# HttpResponse                   4504
# HTTPVersion                    4504
# Protocol                       4504
# dtype: int64

# %%
tcp13_6.head()
# Out:
#            TimeOfMeasurement               Url  \
# 9   Fri Apr 17 14:00:03 2020      facebook.com
# 11  Fri Apr 17 14:00:04 2020      facebook.com
# 17  Fri Apr 17 14:00:07 2020     instagram.com
# 19  Fri Apr 17 14:00:07 2020     instagram.com
# 25  Fri Apr 17 14:00:09 2020  www.whatsapp.com
#
#                                     Ip Port  DnsLookupTime  TCPHandshakeTime  \
# 9   2a03:2880:f12d:83:face:b00c:0:25de  443          4.197             8.932
# 11  2a03:2880:f12d:83:face:b00c:0:25de  443          4.176             8.898
# 17           2406:da00:ff00::22e1:be08  443          4.148            96.601
# 19           2406:da00:ff00::22c4:a6ae  443          4.153           105.587
# 25   2a03:2880:f22d:c5:face:b00c:0:167  443          4.155             8.883
#
#     ConnectionEstablishmentTime     TTFB  TotalDownloadTime HttpResponse  \
# 9                        52.744   79.710             79.759          301
# 11                       58.333   88.316             88.349          301
# 17                      246.854  440.785            440.826          301
# 19                      254.665  431.282            431.326          301
# 25                       56.487   89.211             89.239          302
#
#    HTTPVersion    Protocol
# 9     HTTP/1.1  TCP/TLS1.3
# 11       HTTP2  TCP/TLS1.3
# 17    HTTP/1.1  TCP/TLS1.3
# 19       HTTP2  TCP/TLS1.3
# 25    HTTP/1.1  TCP/TLS1.3

# %%
tcp13_6.tail()
# Out:
#                  TimeOfMeasurement               Url  \
# 10520757  Sun May 10 14:00:08 2020  www.whatsapp.com
# 10520781  Sun May 10 14:00:11 2020         fbcdn.net
# 10520783  Sun May 10 14:00:12 2020         fbcdn.net
# 10520842  Sun May 10 14:00:21 2020     messenger.com
# 10520845  Sun May 10 14:00:21 2020     messenger.com
#
#                                           Ip Port  DnsLookupTime  \
# 10520757   2a03:2880:f22d:c5:face:b00c:0:167  443          4.149
# 10520781  2a03:2880:f12d:83:face:b00c:0:25de  443          4.163
# 10520783  2a03:2880:f12d:83:face:b00c:0:25de  443          4.179
# 10520842      2a03:2880:f02d:e:face:b00c:0:2  443          4.191
# 10520845      2a03:2880:f02d:e:face:b00c:0:2  443          4.147
#
#           TCPHandshakeTime  ConnectionEstablishmentTime     TTFB  \
# 10520757             8.835                       52.720  155.715
# 10520781             8.881                       53.789   80.223
# 10520783             8.822                       53.217   82.078
# 10520842             8.677                       51.644  106.188
# 10520845             8.661                       53.065  109.027
#
#           TotalDownloadTime HttpResponse HTTPVersion    Protocol
# 10520757            155.744          302       HTTP2  TCP/TLS1.3
# 10520781             80.244          302    HTTP/1.1  TCP/TLS1.3
# 10520783             82.101          302       HTTP2  TCP/TLS1.3
# 10520842            106.220          301    HTTP/1.1  TCP/TLS1.3
# 10520845            109.058          301       HTTP2  TCP/TLS1.3

# %%
x = Cdf.MakeCdfFromList(quic43['ConnectionEstablishmentTime'].values)
x1 =Cdf.MakeCdfFromList(quic50['ConnectionEstablishmentTime'].values)
x3 = Cdf.MakeCdfFromList(quic46['ConnectionEstablishmentTime'].values)
#x5 = Cdf.MakeCdfFromList(quic98['ConnectionEstablishmentTime'].values)
x6 = Cdf.MakeCdfFromList(quicID24['ConnectionEstablishmentTime'].values)
x4 = Cdf.MakeCdfFromList(tcp13['ConnectionEstablishmentTime'].values)
x2 =Cdf.MakeCdfFromList(tcp12['ConnectionEstablishmentTime'].values)

# %%
print_percentiles(x1, 'Q050')
print_percentiles(x2, 'tcp12')
print_percentiles(x3, 'Q046')
print_percentiles(x4, 'tcp13')
#print_percentiles(x5, 'Q098')
print_percentiles(x6, 'IETF h3-24')
print_percentiles(x, 'Q043')
# Out:
# -----------------------------
#
# percentile values distribution for Q050
#
# 50th Percentile:35.051000
#
# 90th Percentile:56.399000
#
# 99th Percentile:398.499000
#
# 25th Percentile:34.400000
#
# 75th Percentile:35.752000
#
# 20th Percentile:35.051000
#
# 40th Percentile:56.399000
#
# 60th Percentile:35.255000
#
# 80th Percentile:34.400000
#
# -----------------------------
#
# -----------------------------
#
# percentile values distribution for tcp12
#
# 50th Percentile:82.492000
#
# 90th Percentile:136.382000
#
# 99th Percentile:654.662000
#
# 25th Percentile:70.051000
#
# 75th Percentile:106.832000
#
# 20th Percentile:82.492000
#
# 40th Percentile:136.382000
#
# 60th Percentile:90.585000
#
# 80th Percentile:70.051000
#
# -----------------------------
#
# -----------------------------
#
# percentile values distribution for Q046
#
# 50th Percentile:35.047000
#
# 90th Percentile:76.152000
#
# 99th Percentile:501.381000
#
# 25th Percentile:34.381000
#
# 75th Percentile:35.985000
#
# 20th Percentile:35.047000
#
# 40th Percentile:76.152000
#
# 60th Percentile:35.281000
#
# 80th Percentile:34.381000
#
# -----------------------------
#
# -----------------------------
#
# percentile values distribution for tcp13
#
# 50th Percentile:72.969000
#
# 90th Percentile:531.101000
#
# 99th Percentile:558.016000
#
# 25th Percentile:59.983000
#
# 75th Percentile:125.474000
#
# 20th Percentile:72.969000
#
# 40th Percentile:531.101000
#
# 60th Percentile:90.567000
#
# 80th Percentile:59.983000
#
# -----------------------------
#
# -----------------------------
#
# percentile values distribution for IETF h3-24
#
# 50th Percentile:46.804000
#
# 90th Percentile:399.865000
#
# 99th Percentile:430.554000
#
# 25th Percentile:21.058000
#
# 75th Percentile:258.177000
#
# 20th Percentile:46.804000
#
# 40th Percentile:399.865000
#
# 60th Percentile:89.085000
#
# 80th Percentile:21.058000
#
# -----------------------------
#
# -----------------------------
#
# percentile values distribution for Q043
#
# 50th Percentile:35.088000
#
# 90th Percentile:81.497000
#
# 99th Percentile:505.701000
#
# 25th Percentile:34.412000
#
# 75th Percentile:36.127000
#
# 20th Percentile:35.088000
#
# 40th Percentile:81.497000
#
# 60th Percentile:35.333000
#
# 80th Percentile:34.412000
#
# -----------------------------

# %%
write_percentiles('Q050.csv', x1)
write_percentiles('tcp12.csv', x2)
write_percentiles('Q046.csv', x3)
write_percentiles('tcp13.csv', x4)
#write_percentiles('Q098.csv', x5)
write_percentiles('IETFh3-24', x6)
write_percentiles('Q043.csv', x)

# %%
fig = plt.figure(figsize = (10,3))
plt.rcParams['font.size'] = 12
ax = plt.gca()
yticks = np.arange(0,1.1,0.2)

#Q043
plt.plot(x.xs, x.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'orange')
#Q050
plt.plot(x1.xs, x1.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'red')
#Q046
plt.plot(x3.xs, x3.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'cyan')
#Q098
#plt.plot(x5.xs, x5.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'blue')
#IETF h3-24
plt.plot(x6.xs, x6.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color='yellow')
#TLS1.2
plt.plot(x2.xs, x2.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'green')
#TLS1.3
plt.plot(x4.xs, x4.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'black')


ax = fig.axes[0]
ax.grid(False)
ax.set_yticks(yticks)
#ax.set_ylim([0,1.05])
ax.set_xlim([0.01, 54000])
ax.set_xscale('log')
ax.set_xlabel('latency (x-axis is cut)', fontsize=12)
ax.set_ylabel('CDF', fontsize=12)

plt.legend(['Q043', 'Q050', 'Q046', 'IETF h3-24', 'TLS1.2', 'TLS1.3'], fontsize=11, loc='best')

ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.yaxis.set_ticks_position('left')
ax.xaxis.set_ticks_position('bottom')
ax.spines['bottom'].set_position(('axes', -0.05))
ax.spines['left'].set_position(('axes', -0.05))

ax3 = ax.twinx()
ax3.spines['right'].set_color('none')
ax3.spines['top'].set_color('none')
ax3.spines['left'].set_color('none')
ax3.spines['bottom'].set_color('none')
ax3.yaxis.set_ticks_position('none')
##ax3.set_ylabel('[\'11th Oct - \'11th Nov')
plt.setp(ax3.get_yticklabels(), visible=False)

plt.title('Handshake Times with IPv4', fontsize=12, y=1.05)
plt.savefig('./plots2020/handshake_times_ipv4.png', format='png', bbox_inches='tight')

# %%
x = Cdf.MakeCdfFromList(quic43_6['ConnectionEstablishmentTime'].values)
x1 =Cdf.MakeCdfFromList(quic50_6['ConnectionEstablishmentTime'].values)
x3 = Cdf.MakeCdfFromList(quic46_6['ConnectionEstablishmentTime'].values)
#x5 = Cdf.MakeCdfFromList(quic98_6['ConnectionEstablishmentTime'].values)
x6 = Cdf.MakeCdfFromList(quicID24_6['ConnectionEstablishmentTime'].values)
x4 = Cdf.MakeCdfFromList(tcp13_6['ConnectionEstablishmentTime'].values)
x2 =Cdf.MakeCdfFromList(tcp12_6['ConnectionEstablishmentTime'].values)

# %%
print_percentiles(x1, 'Q050')
print_percentiles(x2, 'tcp12')
print_percentiles(x3, 'Q046')
print_percentiles(x4, 'tcp13')
#print_percentiles(x5, 'Q098')
print_percentiles(x6, 'IETF h3-24')
print_percentiles(x, 'Q043')
# Out:
# -----------------------------
#
# percentile values distribution for Q050
#
# 50th Percentile:34.299000
#
# 90th Percentile:35.796000
#
# 99th Percentile:93.301000
#
# 25th Percentile:33.849000
#
# 75th Percentile:34.786000
#
# 20th Percentile:34.299000
#
# 40th Percentile:35.796000
#
# 60th Percentile:34.458000
#
# 80th Percentile:33.849000
#
# -----------------------------
#
# -----------------------------
#
# percentile values distribution for tcp12
#
# 50th Percentile:70.500000
#
# 90th Percentile:90.142000
#
# 99th Percentile:169.768000
#
# 25th Percentile:66.992000
#
# 75th Percentile:77.211000
#
# 20th Percentile:70.500000
#
# 40th Percentile:90.142000
#
# 60th Percentile:72.395000
#
# 80th Percentile:66.992000
#
# -----------------------------
#
# -----------------------------
#
# percentile values distribution for Q046
#
# 50th Percentile:34.262000
#
# 90th Percentile:36.157000
#
# 99th Percentile:93.231000
#
# 25th Percentile:33.807000
#
# 75th Percentile:34.809000
#
# 20th Percentile:34.262000
#
# 40th Percentile:36.157000
#
# 60th Percentile:34.433000
#
# 80th Percentile:33.807000
#
# -----------------------------
#
# -----------------------------
#
# percentile values distribution for tcp13
#
# 50th Percentile:63.882000
#
# 90th Percentile:230.876000
#
# 99th Percentile:267.832000
#
# 25th Percentile:54.210000
#
# 75th Percentile:69.537000
#
# 20th Percentile:63.882000
#
# 40th Percentile:230.876000
#
# 60th Percentile:65.123000
#
# 80th Percentile:54.210000
#
# -----------------------------
#
# -----------------------------
#
# percentile values distribution for IETF h3-24
#
# 50th Percentile:16.745000
#
# 90th Percentile:23.993000
#
# 99th Percentile:47.834000
#
# 25th Percentile:14.422000
#
# 75th Percentile:19.937000
#
# 20th Percentile:16.745000
#
# 40th Percentile:23.993000
#
# 60th Percentile:17.849000
#
# 80th Percentile:14.422000
#
# -----------------------------
#
# -----------------------------
#
# percentile values distribution for Q043
#
# 50th Percentile:34.275000
#
# 90th Percentile:36.255000
#
# 99th Percentile:93.555000
#
# 25th Percentile:33.817000
#
# 75th Percentile:34.834000
#
# 20th Percentile:34.275000
#
# 40th Percentile:36.255000
#
# 60th Percentile:34.447000
#
# 80th Percentile:33.817000
#
# -----------------------------

# %%
write_percentiles('Q050.csv', x1)
write_percentiles('tcp12.csv', x2)
write_percentiles('Q046.csv', x3)
write_percentiles('tcp13.csv', x4)
#write_percentiles('Q098.csv', x5)
write_percentiles('IETFh3-34.csv', x6)
write_percentiles('Q043.csv', x)

# %%
fig = plt.figure(figsize = (10,3))
plt.rcParams['font.size'] = 12
ax = plt.gca()
yticks = np.arange(0,1.1,0.2)

#Q043
plt.plot(x.xs, x.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'orange')
#Q050
plt.plot(x1.xs, x1.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'red')
#Q046
plt.plot(x3.xs, x3.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'cyan')
#Q098
#plt.plot(x5.xs, x5.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'blue')
#IETF h3-24
plt.plot(x6.xs, x6.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color='yellow')
#TLS1.2
plt.plot(x2.xs, x2.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'green')
#TLS1.3
plt.plot(x4.xs, x4.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'black')


ax = fig.axes[0]
ax.grid(False)
ax.set_yticks(yticks)
#ax.set_ylim([0,1.05])
ax.set_xlim([0.3,34000])
ax.set_xscale('log')
ax.set_xlabel('latency (x-axis is cut)', fontsize=12)
ax.set_ylabel('CDF', fontsize=12)

plt.legend(['Q043', 'Q050', 'Q046', 'IETF h3-24', 'TLS1.2', 'TLS1.3'], fontsize=11, loc='best')

ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.yaxis.set_ticks_position('left')
ax.xaxis.set_ticks_position('bottom')
ax.spines['bottom'].set_position(('axes', -0.05))
ax.spines['left'].set_position(('axes', -0.05))

ax3 = ax.twinx()
ax3.spines['right'].set_color('none')
ax3.spines['top'].set_color('none')
ax3.spines['left'].set_color('none')
ax3.spines['bottom'].set_color('none')
ax3.yaxis.set_ticks_position('none')
##ax3.set_ylabel('[\'11th Oct - \'11th Nov')
plt.setp(ax3.get_yticklabels(), visible=False)

plt.title('Handshake Times with IPv6', fontsize=12, y=1.05)
plt.savefig('./plots2020/handshake_times_ipv6.png', format='png', bbox_inches='tight')

# %%
#IPv4 and IPv6 comparison

# %%
x = Cdf.MakeCdfFromList(quic43['ConnectionEstablishmentTime'].values)
x1 =Cdf.MakeCdfFromList(quic50['ConnectionEstablishmentTime'].values)
x3 = Cdf.MakeCdfFromList(quic46['ConnectionEstablishmentTime'].values)
#x5 = Cdf.MakeCdfFromList(quic98['ConnectionEstablishmentTime'].values)
x6 = Cdf.MakeCdfFromList(quicID24['ConnectionEstablishmentTime'].values)
x4 = Cdf.MakeCdfFromList(tcp13['ConnectionEstablishmentTime'].values)
x2 =Cdf.MakeCdfFromList(tcp12['ConnectionEstablishmentTime'].values)

x_6 = Cdf.MakeCdfFromList(quic43_6['ConnectionEstablishmentTime'].values)
x1_6 =Cdf.MakeCdfFromList(quic50_6['ConnectionEstablishmentTime'].values)
x3_6 = Cdf.MakeCdfFromList(quic46_6['ConnectionEstablishmentTime'].values)
#x5 = Cdf.MakeCdfFromList(quic98_6['ConnectionEstablishmentTime'].values)
x6_6 = Cdf.MakeCdfFromList(quicID24_6['ConnectionEstablishmentTime'].values)
x4_6 = Cdf.MakeCdfFromList(tcp13_6['ConnectionEstablishmentTime'].values)
x2_6 =Cdf.MakeCdfFromList(tcp12_6['ConnectionEstablishmentTime'].values)

# %%
print_percentiles(x1, 'Q050')
print_percentiles(x2, 'tcp12')
print_percentiles(x3, 'Q046')
print_percentiles(x4, 'tcp13')
#print_percentiles(x5, 'Q098')
print_percentiles(x6, 'IETF h3-24')
print_percentiles(x, 'Q043')

print_percentiles(x1_6, 'Q050')
print_percentiles(x2_6, 'tcp12')
print_percentiles(x3_6, 'Q046')
print_percentiles(x4, 'tcp13')
#print_percentiles(x5, 'Q098')
print_percentiles(x6, 'IETF h3-24')
print_percentiles(x_6, 'Q043')
# Out:
# -----------------------------
#
# percentile values distribution for Q050
#
# 50th Percentile:35.051000
#
# 90th Percentile:56.399000
#
# 99th Percentile:398.499000
#
# 25th Percentile:34.400000
#
# 75th Percentile:35.752000
#
# 20th Percentile:35.051000
#
# 40th Percentile:56.399000
#
# 60th Percentile:35.255000
#
# 80th Percentile:34.400000
#
# -----------------------------
#
# -----------------------------
#
# percentile values distribution for tcp12
#
# 50th Percentile:82.492000
#
# 90th Percentile:136.382000
#
# 99th Percentile:654.662000
#
# 25th Percentile:70.051000
#
# 75th Percentile:106.832000
#
# 20th Percentile:82.492000
#
# 40th Percentile:136.382000
#
# 60th Percentile:90.585000
#
# 80th Percentile:70.051000
#
# -----------------------------
#
# -----------------------------
#
# percentile values distribution for Q046
#
# 50th Percentile:35.047000
#
# 90th Percentile:76.152000
#
# 99th Percentile:501.381000
#
# 25th Percentile:34.381000
#
# 75th Percentile:35.985000
#
# 20th Percentile:35.047000
#
# 40th Percentile:76.152000
#
# 60th Percentile:35.281000
#
# 80th Percentile:34.381000
#
# -----------------------------
#
# -----------------------------
#
# percentile values distribution for tcp13
#
# 50th Percentile:72.969000
#
# 90th Percentile:531.101000
#
# 99th Percentile:558.016000
#
# 25th Percentile:59.983000
#
# 75th Percentile:125.474000
#
# 20th Percentile:72.969000
#
# 40th Percentile:531.101000
#
# 60th Percentile:90.567000
#
# 80th Percentile:59.983000
#
# -----------------------------
#
# -----------------------------
#
# percentile values distribution for IETF h3-24
#
# 50th Percentile:46.804000
#
# 90th Percentile:399.865000
#
# 99th Percentile:430.554000
#
# 25th Percentile:21.058000
#
# 75th Percentile:258.177000
#
# 20th Percentile:46.804000
#
# 40th Percentile:399.865000
#
# 60th Percentile:89.085000
#
# 80th Percentile:21.058000
#
# -----------------------------
#
# -----------------------------
#
# percentile values distribution for Q043
#
# 50th Percentile:35.088000
#
# 90th Percentile:81.497000
#
# 99th Percentile:505.701000
#
# 25th Percentile:34.412000
#
# 75th Percentile:36.127000
#
# 20th Percentile:35.088000
#
# 40th Percentile:81.497000
#
# 60th Percentile:35.333000
#
# 80th Percentile:34.412000
#
# -----------------------------
#
# -----------------------------
#
# percentile values distribution for Q050
#
# 50th Percentile:34.299000
#
# 90th Percentile:35.796000
#
# 99th Percentile:93.301000
#
# 25th Percentile:33.849000
#
# 75th Percentile:34.786000
#
# 20th Percentile:34.299000
#
# 40th Percentile:35.796000
#
# 60th Percentile:34.458000
#
# 80th Percentile:33.849000
#
# -----------------------------
#
# -----------------------------
#
# percentile values distribution for tcp12
#
# 50th Percentile:70.500000
#
# 90th Percentile:90.142000
#
# 99th Percentile:169.768000
#
# 25th Percentile:66.992000
#
# 75th Percentile:77.211000
#
# 20th Percentile:70.500000
#
# 40th Percentile:90.142000
#
# 60th Percentile:72.395000
#
# 80th Percentile:66.992000
#
# -----------------------------
#
# -----------------------------
#
# percentile values distribution for Q046
#
# 50th Percentile:34.262000
#
# 90th Percentile:36.157000
#
# 99th Percentile:93.231000
#
# 25th Percentile:33.807000
#
# 75th Percentile:34.809000
#
# 20th Percentile:34.262000
#
# 40th Percentile:36.157000
#
# 60th Percentile:34.433000
#
# 80th Percentile:33.807000
#
# -----------------------------
#
# -----------------------------
#
# percentile values distribution for tcp13
#
# 50th Percentile:72.969000
#
# 90th Percentile:531.101000
#
# 99th Percentile:558.016000
#
# 25th Percentile:59.983000
#
# 75th Percentile:125.474000
#
# 20th Percentile:72.969000
#
# 40th Percentile:531.101000
#
# 60th Percentile:90.567000
#
# 80th Percentile:59.983000
#
# -----------------------------
#
# -----------------------------
#
# percentile values distribution for IETF h3-24
#
# 50th Percentile:46.804000
#
# 90th Percentile:399.865000
#
# 99th Percentile:430.554000
#
# 25th Percentile:21.058000
#
# 75th Percentile:258.177000
#
# 20th Percentile:46.804000
#
# 40th Percentile:399.865000
#
# 60th Percentile:89.085000
#
# 80th Percentile:21.058000
#
# -----------------------------
#
# -----------------------------
#
# percentile values distribution for Q043
#
# 50th Percentile:34.275000
#
# 90th Percentile:36.255000
#
# 99th Percentile:93.555000
#
# 25th Percentile:33.817000
#
# 75th Percentile:34.834000
#
# 20th Percentile:34.275000
#
# 40th Percentile:36.255000
#
# 60th Percentile:34.447000
#
# 80th Percentile:33.817000
#
# -----------------------------

# %%
write_percentiles('Q050.csv', x1)
write_percentiles('tcp12.csv', x2)
write_percentiles('Q046.csv', x3)
write_percentiles('tcp13.csv', x4)
#write_percentiles('Q098.csv', x5)
write_percentiles('IETFh3-24', x6)
write_percentiles('Q043.csv', x)

write_percentiles('Q050.csv', x1_6)
write_percentiles('tcp12.csv', x2_6)
write_percentiles('Q046.csv', x3_6)
write_percentiles('tcp13.csv', x4_6)
#write_percentiles('Q098.csv', x5)
write_percentiles('IETFh3-34.csv', x6_6)
write_percentiles('Q043.csv', x_6)

# %%
fig = plt.figure(figsize = (10,3))
plt.rcParams['font.size'] = 12
ax = plt.gca()
yticks = np.arange(0,1.1,0.2)

#Q043
plt.plot(x.xs, x.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'orange')
#Q050
plt.plot(x1.xs, x1.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'red')
#Q046
plt.plot(x3.xs, x3.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'green')
#Q098
#plt.plot(x5.xs, x5.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'blue')
#IETF h3-24
plt.plot(x6.xs, x6.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color='yellow')
#TLS1.2
#plt.plot(x2.xs, x2.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'cyan')
#TLS1.3
#plt.plot(x4.xs, x4.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'black')

#Q043
plt.plot(x_6.xs, x_6.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'pink')
#Q050
plt.plot(x1_6.xs, x1_6.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'cyan')
#Q046
plt.plot(x3_6.xs, x3_6.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'blue')
#Q098
#plt.plot(x5.xs, x5.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'blue')
#IETF h3-24
plt.plot(x6_6.xs, x6_6.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color='black')
#TLS1.2
#plt.plot(x2_6.xs, x2_6.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'gray')
#TLS1.3
#plt.plot(x4_6.xs, x4_6.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'olive')


ax = fig.axes[0]
ax.grid(False)
ax.set_yticks(yticks)
#ax.set_ylim([0,1.05])
ax.set_xlim([0.01, 58000])
ax.set_xscale('log')
ax.set_xlabel('latency (x-axis is cut)', fontsize=12)
ax.set_ylabel('CDF', fontsize=12)

plt.legend(['Q043', 'Q050', 'Q046', 'IETF h3-24', 'Q043_6', 'Q050_6', 'Q046_6', 'IETF h3-24_6'], fontsize=11, loc='best')

ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.yaxis.set_ticks_position('left')
ax.xaxis.set_ticks_position('bottom')
ax.spines['bottom'].set_position(('axes', -0.05))
ax.spines['left'].set_position(('axes', -0.05))

ax3 = ax.twinx()
ax3.spines['right'].set_color('none')
ax3.spines['top'].set_color('none')
ax3.spines['left'].set_color('none')
ax3.spines['bottom'].set_color('none')
ax3.yaxis.set_ticks_position('none')
##ax3.set_ylabel('[\'11th Oct - \'11th Nov')
plt.setp(ax3.get_yticklabels(), visible=False)

plt.title('Handshake Times with IPv4 and IPv6 Log', fontsize=12, y=1.05)
plt.savefig('./plots2020/handshake_times_ipv4_ipv6_log.png', format='png', bbox_inches='tight')

# %%
fig = plt.figure(figsize = (10,3))
plt.rcParams['font.size'] = 12
ax = plt.gca()
yticks = np.arange(0,1.1,0.2)

#Q043
plt.plot(x.xs, x.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'orange')
#Q050
plt.plot(x1.xs, x1.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'red')
#Q046
plt.plot(x3.xs, x3.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'green')
#Q098
#plt.plot(x5.xs, x5.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'blue')
#IETF h3-24
plt.plot(x6.xs, x6.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color='yellow')
#TLS1.2
#plt.plot(x2.xs, x2.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'cyan')
#TLS1.3
#plt.plot(x4.xs, x4.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'black')

#Q043
plt.plot(x_6.xs, x_6.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'pink')
#Q050
plt.plot(x1_6.xs, x1_6.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'cyan')
#Q046
plt.plot(x3_6.xs, x3_6.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'blue')
#Q098
#plt.plot(x5.xs, x5.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'blue')
#IETF h3-24
plt.plot(x6_6.xs, x6_6.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color='black')
#TLS1.2
#plt.plot(x2_6.xs, x2_6.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'gray')
#TLS1.3
#plt.plot(x4_6.xs, x4_6.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'olive')


ax = fig.axes[0]
ax.grid(False)
ax.set_yticks(yticks)
#ax.set_ylim([0,1.05])
ax.set_xlim([-200, 1200])
ax.set_xscale('linear')
ax.set_xlabel('latency (x-axis is cut)', fontsize=12)
ax.set_ylabel('CDF', fontsize=12)

plt.legend(['Q043', 'Q050', 'Q046', 'IETF h3-24', 'Q043_6', 'Q050_6', 'Q046_6', 'IETF h3-24_6'], fontsize=11, loc='best')

ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.yaxis.set_ticks_position('left')
ax.xaxis.set_ticks_position('bottom')
ax.spines['bottom'].set_position(('axes', -0.05))
ax.spines['left'].set_position(('axes', -0.05))

ax3 = ax.twinx()
ax3.spines['right'].set_color('none')
ax3.spines['top'].set_color('none')
ax3.spines['left'].set_color('none')
ax3.spines['bottom'].set_color('none')
ax3.yaxis.set_ticks_position('none')
##ax3.set_ylabel('[\'11th Oct - \'11th Nov')
plt.setp(ax3.get_yticklabels(), visible=False)

plt.title('Handshake Times with IPv4 and IPv6 Linear', fontsize=12, y=1.05)
plt.savefig('./plots2020/handshake_times_ipv4_ipv6_linear.png', format='png', bbox_inches='tight')

# %%
fig = plt.figure(figsize = (10,3))
plt.rcParams['font.size'] = 12
ax = plt.gca()
yticks = np.arange(0,1.1,0.2)

#Q043
plt.plot(x.xs, x.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'orange')
#Q050
plt.plot(x1.xs, x1.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'red')
#Q046
plt.plot(x3.xs, x3.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'green')
#Q098
#plt.plot(x5.xs, x5.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'blue')
#IETF h3-24
plt.plot(x6.xs, x6.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color='yellow')
#TLS1.2
#plt.plot(x2.xs, x2.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'cyan')
#TLS1.3
#plt.plot(x4.xs, x4.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'black')

#Q043
plt.plot(x_6.xs, x_6.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'pink')
#Q050
plt.plot(x1_6.xs, x1_6.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'cyan')
#Q046
plt.plot(x3_6.xs, x3_6.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'blue')
#Q098
#plt.plot(x5.xs, x5.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'blue')
#IETF h3-24
plt.plot(x6_6.xs, x6_6.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color='black')
#TLS1.2
#plt.plot(x2_6.xs, x2_6.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'gray')
#TLS1.3
#plt.plot(x4_6.xs, x4_6.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'olive')


ax = fig.axes[0]
ax.grid(False)
ax.set_yticks(yticks)
#ax.set_ylim([0,1.05])
ax.set_xlim([30, 40])
ax.set_xscale('linear')
ax.set_xlabel('latency (x-axis is cut)', fontsize=12)
ax.set_ylabel('CDF', fontsize=12)

plt.legend(['Q043', 'Q050', 'Q046', 'IETF h3-24', 'Q043_6', 'Q050_6', 'Q046_6', 'IETF h3-24_6'], fontsize=11, loc='best')

ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.yaxis.set_ticks_position('left')
ax.xaxis.set_ticks_position('bottom')
ax.spines['bottom'].set_position(('axes', -0.05))
ax.spines['left'].set_position(('axes', -0.05))

ax3 = ax.twinx()
ax3.spines['right'].set_color('none')
ax3.spines['top'].set_color('none')
ax3.spines['left'].set_color('none')
ax3.spines['bottom'].set_color('none')
ax3.yaxis.set_ticks_position('none')
##ax3.set_ylabel('[\'11th Oct - \'11th Nov')
plt.setp(ax3.get_yticklabels(), visible=False)

plt.title('Handshake Times with IPv4 and IPv6 Linear Zoomed', fontsize=12, y=1.05)
plt.savefig('./plots2020/handshake_times_ipv4_ipv6_zoomed_linear.png', format='png', bbox_inches='tight')

# %%
fig = plt.figure(figsize = (10,3))
plt.rcParams['font.size'] = 12
ax = plt.gca()
yticks = np.arange(0,1.1,0.2)

#Q043
plt.plot(x.xs, x.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'orange')
#Q050
plt.plot(x1.xs, x1.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'red')
#Q046
plt.plot(x3.xs, x3.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'green')
#Q098
#plt.plot(x5.xs, x5.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'blue')
#IETF h3-24
plt.plot(x6.xs, x6.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color='yellow')
#TLS1.2
#plt.plot(x2.xs, x2.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'cyan')
#TLS1.3
#plt.plot(x4.xs, x4.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'black')

#Q043
plt.plot(x_6.xs, x_6.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'pink')
#Q050
plt.plot(x1_6.xs, x1_6.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'cyan')
#Q046
plt.plot(x3_6.xs, x3_6.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'blue')
#Q098
#plt.plot(x5.xs, x5.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'blue')
#IETF h3-24
plt.plot(x6_6.xs, x6_6.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color='black')
#TLS1.2
#plt.plot(x2_6.xs, x2_6.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'gray')
#TLS1.3
#plt.plot(x4_6.xs, x4_6.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'olive')


ax = fig.axes[0]
ax.grid(False)
ax.set_yticks(yticks)
#ax.set_ylim([0,1.05])
ax.set_xlim([30, 38])
ax.set_xscale('log')
ax.set_xlabel('latency (x-axis is cut)', fontsize=12)
ax.set_ylabel('CDF', fontsize=12)

plt.legend(['Q043', 'Q050', 'Q046', 'IETF h3-24', 'Q043_6', 'Q050_6', 'Q046_6', 'IETF h3-24_6'], fontsize=11, loc='best')

ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.yaxis.set_ticks_position('left')
ax.xaxis.set_ticks_position('bottom')
ax.spines['bottom'].set_position(('axes', -0.05))
ax.spines['left'].set_position(('axes', -0.05))

ax3 = ax.twinx()
ax3.spines['right'].set_color('none')
ax3.spines['top'].set_color('none')
ax3.spines['left'].set_color('none')
ax3.spines['bottom'].set_color('none')
ax3.yaxis.set_ticks_position('none')
##ax3.set_ylabel('[\'11th Oct - \'11th Nov')
plt.setp(ax3.get_yticklabels(), visible=False)

plt.title('Handshake Times with IPv4 and IPv6 Log Zoomed', fontsize=12, y=1.05)
plt.savefig('./plots2020/handshake_times_ipv4_ipv6_zoomed_log.png', format='png', bbox_inches='tight')

# %%
x = Cdf.MakeCdfFromList(quic43['TTFB'].values)
x1 =Cdf.MakeCdfFromList(quic50['TTFB'].values)
x3 = Cdf.MakeCdfFromList(quic46['TTFB'].values)
#x5 = Cdf.MakeCdfFromList(quic98['TTFB'].values)
x6 = Cdf.MakeCdfFromList(quicID24['TTFB'].values)
x4 = Cdf.MakeCdfFromList(tcp13['TTFB'].values)
x2 =Cdf.MakeCdfFromList(tcp12['TTFB'].values)

# %%
write_percentiles('Q050.csv', x1)
write_percentiles('tcp12.csv', x2)
write_percentiles('Q046.csv', x3)
write_percentiles('tcp13.csv', x4)
#write_percentiles('Q098.csv', x5)
write_percentiles('IETFh3-24.csv', x6)
write_percentiles('Q043.csv', x)

# %%
print_percentiles(x1, 'Q050')
print_percentiles(x2, 'tcp12')
print_percentiles(x3, 'Q046')
print_percentiles(x4, 'tcp13')
#print_percentiles(x5, 'Q098')
print_percentiles(x6, 'IETFh3-24')
print_percentiles(x, 'Q043')
# Out:
# -----------------------------
#
# percentile values distribution for Q050
#
# 50th Percentile:202.207000
#
# 90th Percentile:351.599000
#
# 99th Percentile:866.365000
#
# 25th Percentile:115.638000
#
# 75th Percentile:234.003000
#
# 20th Percentile:202.207000
#
# 40th Percentile:351.599000
#
# 60th Percentile:212.406000
#
# 80th Percentile:115.638000
#
# -----------------------------
#
# -----------------------------
#
# percentile values distribution for tcp12
#
# 50th Percentile:251.544000
#
# 90th Percentile:863.844000
#
# 99th Percentile:2821.991000
#
# 25th Percentile:135.815000
#
# 75th Percentile:543.488000
#
# 20th Percentile:251.544000
#
# 40th Percentile:863.844000
#
# 60th Percentile:337.886000
#
# 80th Percentile:135.815000
#
# -----------------------------
#
# -----------------------------
#
# percentile values distribution for Q046
#
# 50th Percentile:202.299000
#
# 90th Percentile:356.423000
#
# 99th Percentile:875.740000
#
# 25th Percentile:121.617000
#
# 75th Percentile:234.872000
#
# 20th Percentile:202.299000
#
# 40th Percentile:356.423000
#
# 60th Percentile:212.632000
#
# 80th Percentile:121.617000
#
# -----------------------------
#
# -----------------------------
#
# percentile values distribution for tcp13
#
# 50th Percentile:184.670000
#
# 90th Percentile:824.586000
#
# 99th Percentile:1194.861000
#
# 25th Percentile:131.610000
#
# 75th Percentile:228.602000
#
# 20th Percentile:184.670000
#
# 40th Percentile:824.586000
#
# 60th Percentile:194.701000
#
# 80th Percentile:131.610000
#
# -----------------------------
#
# -----------------------------
#
# percentile values distribution for IETFh3-24
#
# 50th Percentile:222.545000
#
# 90th Percentile:765.760000
#
# 99th Percentile:966.507000
#
# 25th Percentile:87.676000
#
# 75th Percentile:546.187000
#
# 20th Percentile:222.545000
#
# 40th Percentile:765.760000
#
# 60th Percentile:307.613000
#
# 80th Percentile:87.676000
#
# -----------------------------
#
# -----------------------------
#
# percentile values distribution for Q043
#
# 50th Percentile:207.634000
#
# 90th Percentile:401.669000
#
# 99th Percentile:899.881000
#
# 25th Percentile:156.921000
#
# 75th Percentile:242.693000
#
# 20th Percentile:207.634000
#
# 40th Percentile:401.669000
#
# 60th Percentile:218.652000
#
# 80th Percentile:156.921000
#
# -----------------------------

# %%
fig = plt.figure(figsize = (10,3))
plt.rcParams['font.size'] = 12
ax = plt.gca()
yticks = np.arange(0,1.1,0.2)

#Q043
plt.plot(x.xs, x.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'orange')
#Q050
plt.plot(x1.xs, x1.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'red')
#Q046
plt.plot(x3.xs, x3.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'cyan')
#Q098
#plt.plot(x5.xs, x5.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'blue')
#IETF h3-24
plt.plot(x6.xs, x6.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'yellow')
#TLS1.2
plt.plot(x2.xs, x2.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'green')
#TLS1.3
plt.plot(x4.xs, x4.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'black')


ax = fig.axes[0]
ax.grid(False)
ax.set_yticks(yticks)
#ax.set_ylim([0,1.05])
ax.set_xlim([0.01,58000])
ax.set_xscale('log')
ax.set_xlabel('TTFB', fontsize=12)
ax.set_ylabel('CDF', fontsize=12)

plt.legend(['Q043', 'Q050', 'Q046', 'IETFh3-24', 'TLS1.2', 'TLS1.3'], fontsize=11, loc='best')

ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.yaxis.set_ticks_position('left')
ax.xaxis.set_ticks_position('bottom')
ax.spines['bottom'].set_position(('axes', -0.05))
ax.spines['left'].set_position(('axes', -0.05))

ax3 = ax.twinx()
ax3.spines['right'].set_color('none')
ax3.spines['top'].set_color('none')
ax3.spines['left'].set_color('none')
ax3.spines['bottom'].set_color('none')
ax3.yaxis.set_ticks_position('none')
##ax3.set_ylabel('[\'11th Oct - \'11th Nov')
plt.setp(ax3.get_yticklabels(), visible=False)

plt.title('TTFB with IPv4', fontsize=12, y=1.05)
plt.savefig('./plots2020/TTFB_ipv4.png', format='png', bbox_inches='tight')

# %%
x = Cdf.MakeCdfFromList(quic43_6['TTFB'].values)
x1 =Cdf.MakeCdfFromList(quic50_6['TTFB'].values)
x3 = Cdf.MakeCdfFromList(quic46_6['TTFB'].values)
#x5 = Cdf.MakeCdfFromList(quic98_6['TTFB'].values)
x6 = Cdf.MakeCdfFromList(quicID24_6['TTFB'].values)
x4 = Cdf.MakeCdfFromList(tcp13_6['TTFB'].values)
x2 =Cdf.MakeCdfFromList(tcp12_6['TTFB'].values)

# %%
write_percentiles('Q050.csv', x1)
write_percentiles('tcp12.csv', x2)
write_percentiles('Q046.csv', x3)
write_percentiles('tcp13.csv', x4)
#write_percentiles('Q098.csv', x5)
write_percentiles('IETFh3-24.csv', x6)
write_percentiles('Q043.csv', x)

# %%
print_percentiles(x1, 'Q050')
print_percentiles(x2, 'tcp12')
print_percentiles(x3, 'Q046')
print_percentiles(x4, 'tcp13')
#print_percentiles(x5, 'Q098')
print_percentiles(x6, 'IETFh3-24')
print_percentiles(x, 'Q043')
# Out:
# -----------------------------
#
# percentile values distribution for Q050
#
# 50th Percentile:203.304000
#
# 90th Percentile:266.738000
#
# 99th Percentile:838.754000
#
# 25th Percentile:174.140000
#
# 75th Percentile:227.336000
#
# 20th Percentile:203.304000
#
# 40th Percentile:266.738000
#
# 60th Percentile:211.322000
#
# 80th Percentile:174.140000
#
# -----------------------------
#
# -----------------------------
#
# percentile values distribution for tcp12
#
# 50th Percentile:210.464000
#
# 90th Percentile:788.260000
#
# 99th Percentile:2557.022000
#
# 25th Percentile:114.078000
#
# 75th Percentile:467.023000
#
# 20th Percentile:210.464000
#
# 40th Percentile:788.260000
#
# 60th Percentile:285.555000
#
# 80th Percentile:114.078000
#
# -----------------------------
#
# -----------------------------
#
# percentile values distribution for Q046
#
# 50th Percentile:203.273000
#
# 90th Percentile:266.889000
#
# 99th Percentile:840.104000
#
# 25th Percentile:174.049000
#
# 75th Percentile:227.196000
#
# 20th Percentile:203.273000
#
# 40th Percentile:266.889000
#
# 60th Percentile:211.293000
#
# 80th Percentile:174.049000
#
# -----------------------------
#
# -----------------------------
#
# percentile values distribution for tcp13
#
# 50th Percentile:109.096000
#
# 90th Percentile:400.195000
#
# 99th Percentile:462.152000
#
# 25th Percentile:91.660000
#
# 75th Percentile:131.755000
#
# 20th Percentile:109.096000
#
# 40th Percentile:400.195000
#
# 60th Percentile:116.970000
#
# 80th Percentile:91.660000
#
# -----------------------------
#
# -----------------------------
#
# percentile values distribution for IETFh3-24
#
# 50th Percentile:164.677000
#
# 90th Percentile:586.360000
#
# 99th Percentile:914.603000
#
# 25th Percentile:63.174000
#
# 75th Percentile:369.070000
#
# 20th Percentile:164.677000
#
# 40th Percentile:586.360000
#
# 60th Percentile:199.917000
#
# 80th Percentile:63.174000
#
# -----------------------------
#
# -----------------------------
#
# percentile values distribution for Q043
#
# 50th Percentile:203.925000
#
# 90th Percentile:267.903000
#
# 99th Percentile:840.908000
#
# 25th Percentile:175.196000
#
# 75th Percentile:228.089000
#
# 20th Percentile:203.925000
#
# 40th Percentile:267.903000
#
# 60th Percentile:212.086000
#
# 80th Percentile:175.196000
#
# -----------------------------

# %%
fig = plt.figure(figsize = (10,3))
plt.rcParams['font.size'] = 12
ax = plt.gca()
yticks = np.arange(0,1.1,0.2)

#Q043
plt.plot(x.xs, x.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'orange')
#Q050
plt.plot(x1.xs, x1.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'red')
#Q046
plt.plot(x3.xs, x3.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'cyan')
#Q098
#plt.plot(x5.xs, x5.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'blue')
#IETF h3-24
plt.plot(x6.xs, x6.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'yellow')
#TLS1.2
plt.plot(x2.xs, x2.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'green')
#TLS1.3
plt.plot(x4.xs, x4.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'black')


ax = fig.axes[0]
ax.grid(False)
ax.set_yticks(yticks)
#ax.set_ylim([0,1.05])
#ax.set_xlim([20,1000])
ax.set_xlim([0.01,58000])
ax.set_xscale('log')
ax.set_xlabel('TTFB', fontsize=12)
ax.set_ylabel('CDF', fontsize=12)

plt.legend(['Q043', 'Q050', 'Q046', 'IETF h3-24', 'TLS1.2', 'TLS1.3'], fontsize=11, loc='best')

ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.yaxis.set_ticks_position('left')
ax.xaxis.set_ticks_position('bottom')
ax.spines['bottom'].set_position(('axes', -0.05))
ax.spines['left'].set_position(('axes', -0.05))

ax3 = ax.twinx()
ax3.spines['right'].set_color('none')
ax3.spines['top'].set_color('none')
ax3.spines['left'].set_color('none')
ax3.spines['bottom'].set_color('none')
ax3.yaxis.set_ticks_position('none')
##ax3.set_ylabel('[\'11th Oct - \'11th Nov')
plt.setp(ax3.get_yticklabels(), visible=False)

plt.title('TTFB with IPv6', fontsize=12, y=1.05)
plt.savefig('./plots2020/TTFB_ipv6.png', format='png', bbox_inches='tight')

# %%
x = Cdf.MakeCdfFromList(quic43['TotalDownloadTime'].values)
x1 =Cdf.MakeCdfFromList(quic50['TotalDownloadTime'].values)
x3 = Cdf.MakeCdfFromList(quic46['TotalDownloadTime'].values)
#x5 = Cdf.MakeCdfFromList(quic98['TotalDownloadTime'].values)
x6 = Cdf.MakeCdfFromList(quicID24['TotalDownloadTime'].values)
x4 = Cdf.MakeCdfFromList(tcp13['TotalDownloadTime'].values)
x2 =Cdf.MakeCdfFromList(tcp12['TotalDownloadTime'].values)

# %%
write_percentiles('Q050.csv', x1)
write_percentiles('tcp12.csv', x2)
write_percentiles('Q046.csv', x3)
write_percentiles('tcp13.csv', x4)
#write_percentiles('Q098.csv', x5)
write_percentiles('IETFh3-24.csv', x6)
write_percentiles('Q043.csv', x)

# %%
print_percentiles(x1, 'Q050')
print_percentiles(x2, 'tcp12')
print_percentiles(x3, 'Q046')
print_percentiles(x4, 'tcp13')
#print_percentiles(x5, 'Q098')
print_percentiles(x6, 'IETFh3-24')
print_percentiles(x, 'Q043')
# Out:
# -----------------------------
#
# percentile values distribution for Q050
#
# 50th Percentile:203.164000
#
# 90th Percentile:438.054000
#
# 99th Percentile:871.133000
#
# 25th Percentile:120.940000
#
# 75th Percentile:236.607000
#
# 20th Percentile:203.164000
#
# 40th Percentile:438.054000
#
# 60th Percentile:213.572000
#
# 80th Percentile:120.940000
#
# -----------------------------
#
# -----------------------------
#
# percentile values distribution for tcp12
#
# 50th Percentile:266.401000
#
# 90th Percentile:970.776000
#
# 99th Percentile:3115.647000
#
# 25th Percentile:140.573000
#
# 75th Percentile:589.321000
#
# 20th Percentile:266.401000
#
# 40th Percentile:970.776000
#
# 60th Percentile:363.450000
#
# 80th Percentile:140.573000
#
# -----------------------------
#
# -----------------------------
#
# percentile values distribution for Q046
#
# 50th Percentile:203.437000
#
# 90th Percentile:449.880000
#
# 99th Percentile:878.723000
#
# 25th Percentile:128.048000
#
# 75th Percentile:238.076000
#
# 20th Percentile:203.437000
#
# 40th Percentile:449.880000
#
# 60th Percentile:214.001000
#
# 80th Percentile:128.048000
#
# -----------------------------
#
# -----------------------------
#
# percentile values distribution for tcp13
#
# 50th Percentile:184.696000
#
# 90th Percentile:825.280000
#
# 99th Percentile:1691.348000
#
# 25th Percentile:131.659000
#
# 75th Percentile:254.467000
#
# 20th Percentile:184.696000
#
# 40th Percentile:825.280000
#
# 60th Percentile:194.749000
#
# 80th Percentile:131.659000
#
# -----------------------------
#
# -----------------------------
#
# percentile values distribution for IETFh3-24
#
# 50th Percentile:249.882000
#
# 90th Percentile:775.050000
#
# 99th Percentile:969.198000
#
# 25th Percentile:92.296000
#
# 75th Percentile:578.245000
#
# 20th Percentile:249.882000
#
# 40th Percentile:775.050000
#
# 60th Percentile:357.702000
#
# 80th Percentile:92.296000
#
# -----------------------------
#
# -----------------------------
#
# percentile values distribution for Q043
#
# 50th Percentile:209.133000
#
# 90th Percentile:488.907000
#
# 99th Percentile:899.511000
#
# 25th Percentile:161.292000
#
# 75th Percentile:248.893000
#
# 20th Percentile:209.133000
#
# 40th Percentile:488.907000
#
# 60th Percentile:220.350000
#
# 80th Percentile:161.292000
#
# -----------------------------

# %%
fig = plt.figure(figsize = (10,3))
plt.rcParams['font.size'] = 12
ax = plt.gca()
yticks = np.arange(0,1.1,0.2)

#Q043
plt.plot(x.xs, x.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'orange')
#Q039
plt.plot(x1.xs, x1.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'red')
#Q044
plt.plot(x3.xs, x3.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'cyan')
#Q098
#plt.plot(x5.xs, x5.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'blue')
#IETF h3-24
plt.plot(x6.xs, x6.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'yellow')
#TLS1.2
plt.plot(x2.xs, x2.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'green')
#TLS1.3
plt.plot(x4.xs, x4.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'black')


ax = fig.axes[0]
ax.grid(False)
ax.set_yticks(yticks)
#ax.set_ylim([0,1.05])
#ax.set_xlim([20,1000])
ax.set_xlim([0.01,58000])
ax.set_xscale('log')
ax.set_xlabel('TotalDownloadTime', fontsize=12)
ax.set_ylabel('CDF', fontsize=12)

plt.legend(['Q043', 'Q050', 'Q046', 'IETF h3-24', 'TLS1.2', 'TLS1.3'], fontsize=11, loc='best')

ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.yaxis.set_ticks_position('left')
ax.xaxis.set_ticks_position('bottom')
ax.spines['bottom'].set_position(('axes', -0.05))
ax.spines['left'].set_position(('axes', -0.05))

ax3 = ax.twinx()
ax3.spines['right'].set_color('none')
ax3.spines['top'].set_color('none')
ax3.spines['left'].set_color('none')
ax3.spines['bottom'].set_color('none')
ax3.yaxis.set_ticks_position('none')
##ax3.set_ylabel('[\'11th Oct - \'11th Nov')
plt.setp(ax3.get_yticklabels(), visible=False)

plt.title('TotalDownloadTime with IPv4', fontsize=12, y=1.05)
plt.savefig('./plots2020/TotalDownloadTime_ipv4.png', format='png', bbox_inches='tight')

# %%
x = Cdf.MakeCdfFromList(quic43_6['TotalDownloadTime'].values)
x1 =Cdf.MakeCdfFromList(quic50_6['TotalDownloadTime'].values)
x3 = Cdf.MakeCdfFromList(quic46_6['TotalDownloadTime'].values)
#x5 = Cdf.MakeCdfFromList(quic98_6['TotalDownloadTime'].values)
x6 = Cdf.MakeCdfFromList(quicID24_6['TotalDownloadTime'].values)
x4 = Cdf.MakeCdfFromList(tcp13_6['TotalDownloadTime'].values)
x2 =Cdf.MakeCdfFromList(tcp12_6['TotalDownloadTime'].values)

# %%
write_percentiles('Q050.csv', x1)
write_percentiles('tcp12.csv', x2)
write_percentiles('Q046.csv', x3)
write_percentiles('tcp13.csv', x4)
#write_percentiles('Q098.csv', x5)
write_percentiles('IETFh3-24.csv', x6)
write_percentiles('Q043.csv', x)

# %%
print_percentiles(x1, 'Q050')
print_percentiles(x2, 'tcp12')
print_percentiles(x3, 'Q046')
print_percentiles(x4, 'tcp13')
#print_percentiles(x5, 'Q098')
print_percentiles(x6, 'IETFh3-24')
print_percentiles(x, 'Q043')
# Out:
# -----------------------------
#
# percentile values distribution for Q050
#
# 50th Percentile:203.661000
#
# 90th Percentile:382.265000
#
# 99th Percentile:838.694000
#
# 25th Percentile:174.510000
#
# 75th Percentile:228.095000
#
# 20th Percentile:203.661000
#
# 40th Percentile:382.265000
#
# 60th Percentile:211.725000
#
# 80th Percentile:174.510000
#
# -----------------------------
#
# -----------------------------
#
# percentile values distribution for tcp12
#
# 50th Percentile:218.911000
#
# 90th Percentile:863.748000
#
# 99th Percentile:2834.853000
#
# 25th Percentile:117.626000
#
# 75th Percentile:505.623000
#
# 20th Percentile:218.911000
#
# 40th Percentile:863.748000
#
# 60th Percentile:299.172000
#
# 80th Percentile:117.626000
#
# -----------------------------
#
# -----------------------------
#
# percentile values distribution for Q046
#
# 50th Percentile:203.635000
#
# 90th Percentile:381.616000
#
# 99th Percentile:839.786000
#
# 25th Percentile:174.402000
#
# 75th Percentile:227.955000
#
# 20th Percentile:203.635000
#
# 40th Percentile:381.616000
#
# 60th Percentile:211.690000
#
# 80th Percentile:174.402000
#
# -----------------------------
#
# -----------------------------
#
# percentile values distribution for tcp13
#
# 50th Percentile:109.119000
#
# 90th Percentile:400.222000
#
# 99th Percentile:462.201000
#
# 25th Percentile:91.689000
#
# 75th Percentile:131.779000
#
# 20th Percentile:109.119000
#
# 40th Percentile:400.222000
#
# 60th Percentile:117.003000
#
# 80th Percentile:91.689000
#
# -----------------------------
#
# -----------------------------
#
# percentile values distribution for IETFh3-24
#
# 50th Percentile:175.492000
#
# 90th Percentile:627.617000
#
# 99th Percentile:928.234000
#
# 25th Percentile:72.406000
#
# 75th Percentile:391.832000
#
# 20th Percentile:175.492000
#
# 40th Percentile:627.617000
#
# 60th Percentile:248.919000
#
# 80th Percentile:72.406000
#
# -----------------------------
#
# -----------------------------
#
# percentile values distribution for Q043
#
# 50th Percentile:204.302000
#
# 90th Percentile:382.114000
#
# 99th Percentile:840.166000
#
# 25th Percentile:175.561000
#
# 75th Percentile:228.876000
#
# 20th Percentile:204.302000
#
# 40th Percentile:382.114000
#
# 60th Percentile:212.501000
#
# 80th Percentile:175.561000
#
# -----------------------------

# %%
fig = plt.figure(figsize = (10,3))
plt.rcParams['font.size'] = 12
ax = plt.gca()
yticks = np.arange(0,1.1,0.2)

#Q043
plt.plot(x.xs, x.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'orange')
#Q050
plt.plot(x1.xs, x1.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'red')
#Q046
plt.plot(x3.xs, x3.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'cyan')
#Q098
#plt.plot(x5.xs, x5.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'blue')
#IETF h3-24
plt.plot(x6.xs, x6.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'yellow')
#TLS1.2
plt.plot(x2.xs, x2.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'green')
#TLS1.3
plt.plot(x4.xs, x4.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'black')


ax = fig.axes[0]
ax.grid(False)
ax.set_yticks(yticks)
ax.set_ylim([0,1.05])
#ax.set_xlim([20,1000])
ax.set_xlim([0.01,58000])
ax.set_xscale('log')
ax.set_xlabel('TotalDownloadTime', fontsize=12)
ax.set_ylabel('CDF', fontsize=12)

plt.legend(['Q043', 'Q050', 'Q046', 'IETF h3-24', 'TLS1.2', 'TLS1.3'], fontsize=11, loc='best')

ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.yaxis.set_ticks_position('left')
ax.xaxis.set_ticks_position('bottom')
ax.spines['bottom'].set_position(('axes', -0.05))
ax.spines['left'].set_position(('axes', -0.05))

ax3 = ax.twinx()
ax3.spines['right'].set_color('none')
ax3.spines['top'].set_color('none')
ax3.spines['left'].set_color('none')
ax3.spines['bottom'].set_color('none')
ax3.yaxis.set_ticks_position('none')
#ax3.set_ylabel('[\'11th Oct - \'11th Nov')
plt.setp(ax3.get_yticklabels(), visible=False)

plt.title('TotalDownloadTime with IPv6', fontsize=12, y=1.05)
plt.savefig('./plots2020/TotalDownloadTime_ipv6.png', format='png', bbox_inches='tight')
