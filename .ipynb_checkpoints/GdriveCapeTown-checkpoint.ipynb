# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import time
import datetime
import filterbyip as fbi
import Cdf
import Pmf

# %%
# %autosave 0
# Out:
# Autosave disabled

# %%
import warnings
warnings.filterwarnings('ignore')

# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from IPython.core.display import HTML
css = open('style-table.css').read() + open('style-notebook.css').read()
HTML('<style>{}</style>'.format(css))
# Out:
# <style>body {
#     margin: 0;
#     font-family: Helvetica;
# }
# table.dataframe {
#     border-collapse: collapse;
#     border: none;
# }
# table.dataframe tr {
#     border: none;
# }
# table.dataframe td, table.dataframe th {
#     margin: 0;
#     border: 1px solid white;
#     padding-left: 0.25em;
#     padding-right: 0.25em;
# }
# table.dataframe th:not(:empty) {
#     background-color: #fec;
#     text-align: left;
#     font-weight: normal;
# }
# table.dataframe tr:nth-child(2) th:empty {
#     border-left: none;
#     border-right: 1px dashed #888;
# }
# table.dataframe td {
#     border: 2px solid #ccf;
#     background-color: #f4f4ff;
# }
# h3 {
#     color: white;
#     background-color: black;
#     padding: 0.5em;
# }
#
# .CodeMirror {
#     font-family: 'Consolas';
# }
#
# div.cell.code_cell {
#     font-family: 'Consolas';
# }
#
# div.output_area pre {
#     font-family: 'Consolas';
# }
# </style>

# %%
#change 
tcp_tls_data = "./AWS_results/CapeTown/data/output_curl_gdrive.csv"
quic_data = "./AWS_results/CapeTown/data/output_quic_gdrive.csv"
gdrive = "./data2020/gdrive_id.csv"

# %%
scol_names = ['TimeOfMeasurement', 'Url', 'Ip', 'Port', 'DnsLookupTime', 'TCPHandshakeTime', 'ConnectionEstablishmentTime', 'TTFB', 'TotalDownloadTime', 'HttpResponse', 'HTTPVersion', 'Protocol']
tcol_names = ['TimeOfMeasurement', 'Url', 'Path', 'Ip', 'Port', 'DNSTime', 'ConnectionEstablishmentTime', 'TTFB', 'TotalDownloadTime', 'HttpResponse', 'Protocol']
g_names = ['size', 'id']

# %%
t = pd.read_csv(quic_data, ';', names=tcol_names, header=None)
s = pd.read_csv(tcp_tls_data, ';', names=scol_names, header=None)
gd = pd.read_csv(gdrive, ',', names=g_names, header=None)

# %%
t = t.dropna()
s=s.dropna()
s['TTFB']=s['TTFB']-s['DnsLookupTime']
s['TotalDownloadTime']=s['TotalDownloadTime']-s['DnsLookupTime']

# %%
import re
def extract_id(path):
    id = re.search('\*\/(.*)\?', path)
    return id.group(1)

# %%
t['id'] = t['Path'].apply(extract_id)

# %%
import re
def substitute(string):
    replaced = string
    if re.search('K', string):
        replaced = re.sub('K','', string)
    if re.search('M', string):
        replaced = re.sub('M','000', string)
    if re.search('G', string):
        replaced = re.sub('G','000000', string)
    return replaced

# %%
gd['size'] = gd['size'].apply(substitute)

# %%
s['id'] = s['Url'].apply(extract_id)

# %%
t['Url'] = t['Url'] + t['Path']

# %%
t = t.join(gd.set_index('id'), on='id', rsuffix='_right')

# %%
s = s.join(gd.set_index('id'), on='id', rsuffix='_right')

# %%
t['size'] = t['size'].astype(int)
s['size'] = s['size'].astype(int)
t['TotalDownloadTime'] = t['TotalDownloadTime'].astype(float)
s['TotalDownloadTime'] = s['TotalDownloadTime'].astype(float)

# %%
t['Throughput'] = (t['size']/t['TotalDownloadTime'])

# %%
s['Throughput'] = (s['size']/s['TotalDownloadTime'])

# %%
t.head()
# Out:
#    TimeOfMeasurement                                                Url  \
# 0       1.589616e+09  doc-10-4c-docs.googleusercontent.com/docs/secu...
# 1       1.589616e+09  doc-10-4c-docs.googleusercontent.com/docs/secu...
# 2       1.589616e+09  doc-10-4c-docs.googleusercontent.com/docs/secu...
# 8       1.589616e+09  doc-0g-4c-docs.googleusercontent.com/docs/secu...
# 9       1.589616e+09  doc-0g-4c-docs.googleusercontent.com/docs/secu...
#
#                                                 Path              Ip Port  \
# 0  /docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp...   172.217.170.1  443
# 1  /docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp...   172.217.170.1  443
# 2  /docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp...   172.217.170.1  443
# 8  /docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp...  216.58.223.129  443
# 9  /docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp...  216.58.223.129  443
#
#    DNSTime  ConnectionEstablishmentTime     TTFB  TotalDownloadTime  \
# 0  341.508                      368.389  661.787            662.328
# 1    0.390                      373.335  656.097            656.131
# 2    0.344                      367.597  663.791            664.468
# 8  165.408                      359.479  658.237            658.291
# 9    0.397                      367.427  655.445            655.492
#
#    HttpResponse Protocol                                 id  size  Throughput
# 0         403.0     Q043  1C45gZCBtJHnjNACQIagfJ2fTRKQaZ9k6     1    0.001510
# 1         403.0     Q046  1C45gZCBtJHnjNACQIagfJ2fTRKQaZ9k6     1    0.001524
# 2         403.0     Q050  1C45gZCBtJHnjNACQIagfJ2fTRKQaZ9k6     1    0.001505
# 8         403.0     Q043  1yv4XxH7R74il-bxBS5Mz8Oiw6W7vwUFM     2    0.003038
# 9         403.0     Q046  1yv4XxH7R74il-bxBS5Mz8Oiw6W7vwUFM     2    0.003051

# %%
t.tail()
# Out:
#        TimeOfMeasurement                                                Url  \
# 31377       1.589989e+09  doc-0o-4c-docs.googleusercontent.com/docs/secu...
# 31378       1.589989e+09  doc-0o-4c-docs.googleusercontent.com/docs/secu...
# 31384       1.589989e+09  doc-0s-4c-docs.googleusercontent.com/docs/secu...
# 31385       1.589989e+09  doc-0s-4c-docs.googleusercontent.com/docs/secu...
# 31386       1.589989e+09  doc-0s-4c-docs.googleusercontent.com/docs/secu...
#
#                                                     Path              Ip Port  \
# 31377  /docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp...  216.58.223.129  443
# 31378  /docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp...  216.58.223.129  443
# 31384  /docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp...  216.58.223.129  443
# 31385  /docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp...  216.58.223.129  443
# 31386  /docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp...  216.58.223.129  443
#
#        DNSTime  ConnectionEstablishmentTime     TTFB  TotalDownloadTime  \
# 31377    0.396                      375.026  901.076            901.125
# 31378    0.386                      382.942  359.148            359.186
# 31384    1.102                      382.347  549.132            549.174
# 31385    0.352                      375.131  971.493            971.545
# 31386    7.111                      376.082  300.861            300.905
#
#        HttpResponse Protocol                                 id  size  \
# 31377         403.0     Q046  1sGGy4K1J3p0OQlLxUgbgsErokyBADg6g     5
# 31378         403.0     Q050  1sGGy4K1J3p0OQlLxUgbgsErokyBADg6g     5
# 31384         403.0     Q043  1k7mg8XpQmW-jpO85yq3giwVUeL82NJhx    10
# 31385         403.0     Q046  1k7mg8XpQmW-jpO85yq3giwVUeL82NJhx    10
# 31386         403.0     Q050  1k7mg8XpQmW-jpO85yq3giwVUeL82NJhx    10
#
#        Throughput
# 31377    0.005549
# 31378    0.013920
# 31384    0.018209
# 31385    0.010293
# 31386    0.033233

# %%
s.head()
# Out:
#    TimeOfMeasurement                                                Url  \
# 0         1589616005  doc-10-4c-docs.googleusercontent.com/docs/secu...
# 1         1589616005  doc-10-4c-docs.googleusercontent.com/docs/secu...
# 2         1589616008  doc-0g-4c-docs.googleusercontent.com/docs/secu...
# 3         1589616009  doc-0g-4c-docs.googleusercontent.com/docs/secu...
# 4         1589616011  doc-0o-4c-docs.googleusercontent.com/docs/secu...
#
#                Ip  Port  DnsLookupTime  TCPHandshakeTime  \
# 0   172.217.170.1   443          4.140            16.342
# 1   172.217.170.1   443          4.133            16.340
# 2  216.58.223.129   443          4.142            16.211
# 3  216.58.223.129   443          4.145            16.381
# 4  216.58.223.129   443          6.148            16.287
#
#    ConnectionEstablishmentTime     TTFB  TotalDownloadTime  HttpResponse  \
# 0                      248.756  530.186            530.205           403
# 1                      245.077  535.730            536.202           403
# 2                      247.661  536.614            536.631           403
# 3                      253.674  544.606            544.730           403
# 4                      248.731  533.544            533.562           403
#
#   HTTPVersion    Protocol                                 id  size  Throughput
# 0    HTTP/1.1  TCP/TLS1.2  1C45gZCBtJHnjNACQIagfJ2fTRKQaZ9k6     1    0.001886
# 1       HTTP2  TCP/TLS1.2  1C45gZCBtJHnjNACQIagfJ2fTRKQaZ9k6     1    0.001865
# 2    HTTP/1.1  TCP/TLS1.2  1yv4XxH7R74il-bxBS5Mz8Oiw6W7vwUFM     2    0.003727
# 3       HTTP2  TCP/TLS1.2  1yv4XxH7R74il-bxBS5Mz8Oiw6W7vwUFM     2    0.003672
# 4    HTTP/1.1  TCP/TLS1.2  1sGGy4K1J3p0OQlLxUgbgsErokyBADg6g     5    0.009371

# %%
s.tail()
# Out:
#       TimeOfMeasurement                                                Url  \
# 7840         1589989287  doc-10-4c-docs.googleusercontent.com/docs/secu...
# 7841         1589989321  doc-0g-4c-docs.googleusercontent.com/docs/secu...
# 7842         1589989329  doc-0g-4c-docs.googleusercontent.com/docs/secu...
# 7843         1589989366  doc-0o-4c-docs.googleusercontent.com/docs/secu...
# 7844         1589989372  doc-0o-4c-docs.googleusercontent.com/docs/secu...
#
#                   Ip  Port  DnsLookupTime  TCPHandshakeTime  \
# 7840  172.217.170.65   443          4.155            17.676
# 7841  216.58.223.129   443          4.172            17.706
# 7842  216.58.223.129   443          4.219            17.752
# 7843  216.58.223.129   443          4.139            17.715
# 7844  216.58.223.129   443          4.141            17.689
#
#       ConnectionEstablishmentTime      TTFB  TotalDownloadTime  HttpResponse  \
# 7840                      257.056  8328.063           8328.107           403
# 7841                      267.368  7326.430           7326.457           403
# 7842                      257.452  8122.905           8122.956           403
# 7843                      251.001  7734.992           7735.027           403
# 7844                      255.048  6785.036           6785.092           403
#
#      HTTPVersion    Protocol                                 id  size  \
# 7840       HTTP2  TCP/TLS1.2  1C45gZCBtJHnjNACQIagfJ2fTRKQaZ9k6     1
# 7841    HTTP/1.1  TCP/TLS1.2  1yv4XxH7R74il-bxBS5Mz8Oiw6W7vwUFM     2
# 7842       HTTP2  TCP/TLS1.2  1yv4XxH7R74il-bxBS5Mz8Oiw6W7vwUFM     2
# 7843    HTTP/1.1  TCP/TLS1.2  1sGGy4K1J3p0OQlLxUgbgsErokyBADg6g     5
# 7844       HTTP2  TCP/TLS1.2  1sGGy4K1J3p0OQlLxUgbgsErokyBADg6g     5
#
#       Throughput
# 7840    0.000120
# 7841    0.000273
# 7842    0.000246
# 7843    0.000646
# 7844    0.000737

# %%
gd.head()
# Out:
#   size                                 id
# 0    1  1C45gZCBtJHnjNACQIagfJ2fTRKQaZ9k6
# 1    2  1yv4XxH7R74il-bxBS5Mz8Oiw6W7vwUFM
# 2    5  1sGGy4K1J3p0OQlLxUgbgsErokyBADg6g
# 3   10  1k7mg8XpQmW-jpO85yq3giwVUeL82NJhx
# 4   20  1Zr-g4qROFzaq_vZ4JnHneEb9JyRSUBXb

# %%
t = t.dropna()
s = s.dropna()

# %%
def filter_by_ip(df, column):
  """reads a DataFrame, calls fbi.filter_v{4,6} to get DataFrames with rows
     containing only v4, v6 endpoints. Returns the two DataFrame as a tuple"""

  dfv6 = fbi.filter_v6(df, column)
  dfv4 = fbi.filter_v4(df, column)
  return dfv4, dfv6

# %%
quic4, quic6 = filter_by_ip(t, column = 'Ip')

# %%
tcp4, tcp6 = filter_by_ip(s, column = 'Ip')

# %%
#quic4 = quic4.loc[quic4['size']<500]
#tcp4 = tcp4.loc[tcp4['size']<500]

# %%
quic43 = quic4.loc[t['Protocol'] == 'Q043']
quic46 = quic4.loc[t['Protocol'] == 'Q046']
quic50 = quic4.loc[t['Protocol'] == 'Q050']
quicietf = quic4.loc[t['Protocol'] == 'FF000018']

# %%
quic43_6 = quic6.loc[t['Protocol'] == 'Q043']
quic46_6 = quic6.loc[t['Protocol'] == 'Q046']
quic50_6 = quic6.loc[t['Protocol'] == 'Q050']
quicietf_6 = quic6.loc[t['Protocol'] == 'FF000018']

# %%
tcp12 = tcp4.loc[s['Protocol'] == 'TCP/TLS1.2']
tcp13 = tcp4.loc[s['Protocol'] == 'TCP/TLS1.3']

# %%
tcp12_6 = tcp6.loc[s['Protocol'] == 'TCP/TLS1.2']
tcp13_6 = tcp6.loc[s['Protocol'] == 'TCP/TLS1.3']

# %%
x = Cdf.MakeCdfFromList(quic43['ConnectionEstablishmentTime'].values)
x1 = Cdf.MakeCdfFromList(quic46['ConnectionEstablishmentTime'].values)
x3 = Cdf.MakeCdfFromList(quic50['ConnectionEstablishmentTime'].values)
x5 = Cdf.MakeCdfFromList(quicietf['ConnectionEstablishmentTime'].values)
x4 = Cdf.MakeCdfFromList(tcp13['ConnectionEstablishmentTime'].values)
x2 = Cdf.MakeCdfFromList(tcp12['ConnectionEstablishmentTime'].values)

# %%
fig = plt.figure(figsize = (10,3))
plt.rcParams['font.size'] = 12
ax = plt.gca()
yticks = np.arange(0,1.1,0.2)

#Q043
plt.plot(x.xs, x.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'orange')
#Q046
plt.plot(x1.xs, x1.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'red')
#Q050
plt.plot(x3.xs, x3.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'green')
#Q0ietf
plt.plot(x5.xs, x5.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'blue')
#TLS1.2
plt.plot(x2.xs, x2.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'cyan')
#TLS1.3
plt.plot(x4.xs, x4.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'black')


ax = fig.axes[0]
ax.grid(False)
ax.set_yticks(yticks)
ax.set_ylim([0,1.05])
#ax.set_xlim([20, 100])
ax.set_xscale('log')
ax.set_xlabel('latency (x-axis is cut)', fontsize=12)
ax.set_ylabel('CDF', fontsize=12)

plt.legend(['Q043', 'Q046', 'Q050', 'IETF', 'TLS1.2', 'TLS 1.3'], fontsize=11, loc='best')

ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.yaxis.set_ticks_position('left')
ax.xaxis.set_ticks_position('bottom')
ax.spines['bottom'].set_position(('axes', -0.05))
ax.spines['left'].set_position(('axes', -0.05))

ax3 = ax.twinx()
ax3.spines['right'].set_color('none')
ax3.spines['top'].set_color('none')
ax3.spines['left'].set_color('none')
ax3.spines['bottom'].set_color('none')
ax3.yaxis.set_ticks_position('none')
plt.setp(ax3.get_yticklabels(), visible=False)

plt.title('Handshake Times with IPv4', fontsize=12, y=1.05)
plt.savefig('./AWS/CapeTown/gdrive/handshake_times_ipv4_otherthan200.png', format='png', bbox_inches='tight')

# %%
x = Cdf.MakeCdfFromList(quic43['TTFB'].values)
x1 =Cdf.MakeCdfFromList(quic46['TTFB'].values)
x3 = Cdf.MakeCdfFromList(quic50['TTFB'].values)
x5 = Cdf.MakeCdfFromList(quicietf['TTFB'].values)
x4 = Cdf.MakeCdfFromList(tcp13['TTFB'].values)
x2 =Cdf.MakeCdfFromList(tcp12['TTFB'].values)

# %%
fig = plt.figure(figsize = (10,3))
plt.rcParams['font.size'] = 12
ax = plt.gca()
yticks = np.arange(0,1.1,0.2)

#Q043
plt.plot(x.xs, x.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'orange')
#Q046
plt.plot(x1.xs, x1.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'red')
#Q050
plt.plot(x3.xs, x3.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'green')
#IETF
plt.plot(x5.xs, x5.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'blue')
#TLS1.2
plt.plot(x2.xs, x2.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'cyan')
#TLS1.3
plt.plot(x4.xs, x4.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'black')


ax = fig.axes[0]
ax.grid(False)
ax.set_yticks(yticks)
ax.set_ylim([0,1.05])
#ax.set_xlim([100, 600])
ax.set_xscale('log')
ax.set_xlabel('TTFB', fontsize=12)
ax.set_ylabel('CDF', fontsize=12)

plt.legend(['Q043', 'Q046', 'Q050', 'IETF', 'TLS1.2', 'TLS 1.3'], fontsize=11, loc='best')

ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.yaxis.set_ticks_position('left')
ax.xaxis.set_ticks_position('bottom')
ax.spines['bottom'].set_position(('axes', -0.05))
ax.spines['left'].set_position(('axes', -0.05))

ax3 = ax.twinx()
ax3.spines['right'].set_color('none')
ax3.spines['top'].set_color('none')
ax3.spines['left'].set_color('none')
ax3.spines['bottom'].set_color('none')
ax3.yaxis.set_ticks_position('none')
plt.setp(ax3.get_yticklabels(), visible=False)

plt.title('TTFB with IPv4', fontsize=12, y=1.05)
plt.savefig('./AWS/CapeTown/gdrive/TTFB_ipv4.png', format='png', bbox_inches='tight')

# %%
x = Cdf.MakeCdfFromList(quic43['TotalDownloadTime'].values)
x1 =Cdf.MakeCdfFromList(quic46['TotalDownloadTime'].values)
x3 = Cdf.MakeCdfFromList(quic50['TotalDownloadTime'].values)
x5 = Cdf.MakeCdfFromList(quicietf['TotalDownloadTime'].values)
x4 = Cdf.MakeCdfFromList(tcp13['TotalDownloadTime'].values)
x2 =Cdf.MakeCdfFromList(tcp12['TotalDownloadTime'].values)

# %%
fig = plt.figure(figsize = (10,3))
plt.rcParams['font.size'] = 12
ax = plt.gca()
yticks = np.arange(0,1.1,0.2)

#Q043
plt.plot(x.xs, x.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'orange')
#Q046
plt.plot(x1.xs, x1.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'red')
#Q050
plt.plot(x3.xs, x3.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'green')
#IETF
plt.plot(x5.xs, x5.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'blue')
#TLS1.2
plt.plot(x2.xs, x2.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'cyan')
#TLS1.3
plt.plot(x4.xs, x4.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'black')


ax = fig.axes[0]
ax.grid(False)
ax.set_yticks(yticks)
ax.set_ylim([0,1.05])
#ax.set_xlim([100,800])
#ax.set_xlim([0,10])
ax.set_xscale('log')
ax.set_xlabel('TotalDownloadTime', fontsize=12)
ax.set_ylabel('CDF', fontsize=12)

plt.legend(['Q043', 'Q046', 'Q050', 'IETF', 'TLS1.2', 'TLS 1.3'], fontsize=11, loc='best')

ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.yaxis.set_ticks_position('left')
ax.xaxis.set_ticks_position('bottom')
ax.spines['bottom'].set_position(('axes', -0.05))
ax.spines['left'].set_position(('axes', -0.05))

ax3 = ax.twinx()
ax3.spines['right'].set_color('none')
ax3.spines['top'].set_color('none')
ax3.spines['left'].set_color('none')
ax3.spines['bottom'].set_color('none')
ax3.yaxis.set_ticks_position('none')
plt.setp(ax3.get_yticklabels(), visible=False)

plt.title('TotalDownloadTime with IPv4', fontsize=12, y=1.05)
plt.savefig('./AWS/CapeTown/gdrive/TotalDownloadTime_ipv4.png', format='png', bbox_inches='tight')

# %%
x = Cdf.MakeCdfFromList(quic43['Throughput'].values)
x1 =Cdf.MakeCdfFromList(quic46['Throughput'].values)
x3 = Cdf.MakeCdfFromList(quic50['Throughput'].values)
x5 = Cdf.MakeCdfFromList(quicietf['Throughput'].values)
x4 = Cdf.MakeCdfFromList(tcp13['Throughput'].values)
x2 =Cdf.MakeCdfFromList(tcp12['Throughput'].values)

# %%
fig = plt.figure(figsize = (10,3))
plt.rcParams['font.size'] = 12
ax = plt.gca()
yticks = np.arange(0,1.1,0.2)

#Q043
plt.plot(x.xs, x.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'orange')
#Q046
plt.plot(x1.xs, x1.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'red')
#Q050
plt.plot(x3.xs, x3.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'green')
#IETF
plt.plot(x5.xs, x5.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'blue')
#TLS1.2
plt.plot(x2.xs, x2.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'cyan')
#TLS1.3
plt.plot(x4.xs, x4.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'black')


ax = fig.axes[0]
ax.grid(False)
ax.set_yticks(yticks)
ax.set_ylim([0,1.05])
#ax.set_xlim([0,700])
#ax.set_xlim([0,10])
ax.set_xscale('log')
ax.set_xlabel('Throughput in MB/s', fontsize=12)
ax.set_ylabel('CDF', fontsize=12)

plt.legend(['Q043', 'Q046', 'Q050', 'IETF', 'TLS1.2', 'TLS 1.3'], fontsize=11, loc='best')

ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.yaxis.set_ticks_position('left')
ax.xaxis.set_ticks_position('bottom')
ax.spines['bottom'].set_position(('axes', -0.05))
ax.spines['left'].set_position(('axes', -0.05))

ax3 = ax.twinx()
ax3.spines['right'].set_color('none')
ax3.spines['top'].set_color('none')
ax3.spines['left'].set_color('none')
ax3.spines['bottom'].set_color('none')
ax3.yaxis.set_ticks_position('none')
#ax3.set_ylabel('[\'16thMay - \'20thMay')
plt.setp(ax3.get_yticklabels(), visible=False)

plt.title('Throughput with IPv4', fontsize=12, y=1.05)
plt.savefig('./AWS/CapeTown/gdrive/Throughput_ipv4.png', format='png', bbox_inches='tight')

# %%
quic_mean= quic4.groupby('size', as_index=False).mean()
tcp_mean= tcp4.groupby('size', as_index=False).mean()

quic_mean.head()

quic_mean.tail()
# Out:
#       size  TimeOfMeasurement    DNSTime  ConnectionEstablishmentTime  \
# 11    5000       1.589800e+09  25.364371                   373.096239
# 12   10000       1.589800e+09  23.680158                   373.627922
# 13   20000       1.589800e+09  23.209325                   373.735035
# 14   50000       1.589800e+09  24.366592                   371.287672
# 15  100000       1.589800e+09  21.519887                   372.735514
#
#           TTFB  TotalDownloadTime  HttpResponse  Throughput
# 11  516.352559         516.402255         403.0   40.165787
# 12  510.021463         510.072604         403.0   60.541279
# 13  515.350682         515.400790         403.0  135.557523
# 14  489.335782         489.385788         403.0  532.602041
# 15  503.839327         503.894805         403.0  529.935372

# %%
fig = plt.figure(figsize = (20,6))
plt.rcParams['font.size'] = 12
ax = plt.gca()
#yticks = np.arange(1000,100000000,10000)

#Quic
#plt.plot(quic4['size'], quic4['Throughput'], marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'orange')

#plt.plot(tcp4['size'], tcp4['Throughput'], marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'blue')
plt.plot(quic_mean['size'], quic_mean['Throughput'], marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'orange')

plt.plot(tcp_mean['size'], tcp_mean['Throughput'], marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'blue')

ax = fig.axes[0]
ax.grid(False)
#ax.set_yticks(yticks)
ax.set_ylim([0,600])
ax.set_xlim([0,60000])
#ax.set_xlim([0,10])
ax.set_xscale('linear')
ax.set_xlabel('Size in KB', fontsize=12)
ax.set_ylabel('Throughput in MB/s', fontsize=12)

plt.legend(['Quic', 'TLS'], fontsize=11, loc='best')

ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.yaxis.set_ticks_position('left')
ax.xaxis.set_ticks_position('bottom')
ax.spines['bottom'].set_position(('axes', -0.05))
ax.spines['left'].set_position(('axes', -0.05))

ax3 = ax.twinx()
ax3.spines['right'].set_color('none')
ax3.spines['top'].set_color('none')
ax3.spines['left'].set_color('none')
ax3.spines['bottom'].set_color('none')
ax3.yaxis.set_ticks_position('none')
plt.setp(ax3.get_yticklabels(), visible=False)

plt.title('Size vs Throughput_ipv4', fontsize=12, y=1.05)
plt.savefig('./AWS/CapeTown/gdrive/sizevsThroughput_ipv4.png', format='png', bbox_inches='tight')
