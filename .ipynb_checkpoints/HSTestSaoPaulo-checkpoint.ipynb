# %%
import pandas as pd
import numpy as np
import matplotlib
matplotlib.use('PS') 
import matplotlib.pyplot as plt
import time
import datetime
import filterbyip as fbi
import Cdf
import Pmf

# %%
def print_percentiles(c, name):
    if c == 0:
        return null
    else:
        print('-----------------------------\n')
        print('percentile values distribution for %s\n' % name)

        print('20th Percentile:%f\n' % c.Percentile(20))    
        print('25th Percentile:%f\n' % c.Percentile(25))
        print('40th Percentile:%f\n' % c.Percentile(40))
        print('50th Percentile:%f\n' % c.Percentile(50))
        print('60th Percentile:%f\n' % c.Percentile(60))
        print('75th Percentile:%f\n' % c.Percentile(75))
        print('80th Percentile:%f\n' % c.Percentile(80))    
        print('90th Percentile:%f\n' % c.Percentile(90))
        print('99th Percentile:%f\n' % c.Percentile(99))

        print('-----------------------------\n')

# %%
def write_percentiles(filename, c):
	with open(filename, 'w') as f:
		f.write('values; percentile\n')
		for x, y in zip(c.xs, c.ps):
			f.write('%.2f, %.2f\n'%(x, y))

# %%
# %autosave 20
# Out:
# Autosaving every 20 seconds

# %%
import warnings
warnings.filterwarnings('ignore')

# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from IPython.core.display import HTML
css = open('style-table.css').read() + open('style-notebook.css').read()
HTML('<style>{}</style>'.format(css))
# Out:
# <style>body {
#     margin: 0;
#     font-family: Helvetica;
# }
# table.dataframe {
#     border-collapse: collapse;
#     border: none;
# }
# table.dataframe tr {
#     border: none;
# }
# table.dataframe td, table.dataframe th {
#     margin: 0;
#     border: 1px solid white;
#     padding-left: 0.25em;
#     padding-right: 0.25em;
# }
# table.dataframe th:not(:empty) {
#     background-color: #fec;
#     text-align: left;
#     font-weight: normal;
# }
# table.dataframe tr:nth-child(2) th:empty {
#     border-left: none;
#     border-right: 1px dashed #888;
# }
# table.dataframe td {
#     border: 2px solid #ccf;
#     background-color: #f4f4ff;
# }
# h3 {
#     color: white;
#     background-color: black;
#     padding: 0.5em;
# }
#
# .CodeMirror {
#     font-family: 'Consolas';
# }
#
# div.cell.code_cell {
#     font-family: 'Consolas';
# }
#
# div.output_area pre {
#     font-family: 'Consolas';
# }
# </style>

# %%
tcp_tls_data = "./AWS_results/N.California/data/output_curl_data.csv"
quic_data = "./AWS_results/N.California/data/output_quic.csv"

# %%
scol_names = ['TimeOfMeasurement', 'Url', 'Ip', 'Port', 'DnsLookupTime', 'TCPHandshakeTime', 'ConnectionEstablishmentTime', 'TTFB', 'TotalDownloadTime', 'HttpResponse', 'HTTPVersion', 'Protocol']
tcol_names = ['TimeOfMeasurement', 'Url', 'Path', 'Ip', 'Port', 'DNSTime', 'ConnectionEstablishmentTime', 'TTFB', 'TotalDownloadTime', 'HttpResponse', 'Protocol']

# %%
t = pd.read_csv(quic_data, ';', names=tcol_names, header=None)
s = pd.read_csv(tcp_tls_data, ';', names=scol_names, header=None)

# %%
t = t.dropna()
s = s.dropna()

# %%
#t = t[t['TimeOfMeasurement'] > 1581721201]
#s = s[s['TimeOfMeasurement'] > 1581721201]

# %%
s['TTFB']=s['TTFB']-s['DnsLookupTime']
s['TotalDownloadTime']=s['TotalDownloadTime']-s['DnsLookupTime']

# %%
s.count()
# Out:
# TimeOfMeasurement              333677
# Url                            333677
# Ip                             333677
# Port                           333677
# DnsLookupTime                  333677
# TCPHandshakeTime               333677
# ConnectionEstablishmentTime    333677
# TTFB                           333677
# TotalDownloadTime              333677
# HttpResponse                   333677
# HTTPVersion                    333677
# Protocol                       333677
# dtype: int64

# %%
s.head()
# Out:
#    TimeOfMeasurement             Url              Ip  Port  DnsLookupTime  \
# 0         1589644802  www.google.com  216.58.194.164   443          5.983
# 1         1589644802  www.google.com  216.58.194.164   443         12.719
# 2         1589644802    facebook.com    157.240.3.35   443         17.493
# 3         1589644803    facebook.com    157.240.3.35   443          5.989
# 4         1589644803    facebook.com    157.240.3.35   443         12.658
#
#    TCPHandshakeTime  ConnectionEstablishmentTime     TTFB  TotalDownloadTime  \
# 0             2.320                      161.516  215.911            226.943
# 1             5.758                      155.791  216.441            235.016
# 2            20.638                      149.535  223.139            223.167
# 3            21.795                      121.031  196.358            196.385
# 4            22.437                      144.358  227.093            227.124
#
#    HttpResponse HTTPVersion    Protocol
# 0           200    HTTP/1.1  TCP/TLS1.2
# 1           200       HTTP2  TCP/TLS1.2
# 2           301    HTTP/1.1  TCP/TLS1.2
# 3           301    HTTP/1.1  TCP/TLS1.3
# 4           301       HTTP2  TCP/TLS1.2

# %%
t.count()
# Out:
# TimeOfMeasurement              739149
# Url                            739149
# Path                           739149
# Ip                             739149
# Port                           739149
# DNSTime                        739149
# ConnectionEstablishmentTime    739149
# TTFB                           739149
# TotalDownloadTime              739149
# HttpResponse                   739149
# Protocol                       739149
# dtype: int64

# %%
t.head()
# Out:
#    TimeOfMeasurement                        Url Path            Ip Port  \
# 0       1.589580e+09  www.0dayrox2.blogspot.com    /  172.217.5.97  443
# 1       1.589580e+09  www.0dayrox2.blogspot.com    /  172.217.5.97  443
# 2       1.589580e+09  www.0dayrox2.blogspot.com    /  172.217.5.97  443
# 8       1.589580e+09   www.0dayrox.blogspot.com    /  172.217.5.97  443
# 9       1.589580e+09   www.0dayrox.blogspot.com    /  172.217.5.97  443
#
#    DNSTime  ConnectionEstablishmentTime     TTFB  TotalDownloadTime  \
# 0   26.789                       44.031  191.520            252.621
# 1    0.833                       43.702  198.238            216.891
# 2   10.528                       44.412  313.128            333.717
# 8   18.358                       48.302  208.418            234.287
# 9    0.970                       44.219  305.459            333.191
#
#    HttpResponse Protocol
# 0         404.0     Q043
# 1         404.0     Q046
# 2         404.0     Q050
# 8         404.0     Q043
# 9         404.0     Q046

# %%
def timestamp2human(timestamp):
    return datetime.datetime.fromtimestamp(int(timestamp)).strftime('%c')

# %%
s['TimeOfMeasurement'] = s['TimeOfMeasurement'].apply(timestamp2human)

# %%
s.head()
# Out:
#           TimeOfMeasurement             Url              Ip  Port  \
# 0  Sat May 16 18:00:02 2020  www.google.com  216.58.194.164   443
# 1  Sat May 16 18:00:02 2020  www.google.com  216.58.194.164   443
# 2  Sat May 16 18:00:02 2020    facebook.com    157.240.3.35   443
# 3  Sat May 16 18:00:03 2020    facebook.com    157.240.3.35   443
# 4  Sat May 16 18:00:03 2020    facebook.com    157.240.3.35   443
#
#    DnsLookupTime  TCPHandshakeTime  ConnectionEstablishmentTime     TTFB  \
# 0          5.983             2.320                      161.516  215.911
# 1         12.719             5.758                      155.791  216.441
# 2         17.493            20.638                      149.535  223.139
# 3          5.989            21.795                      121.031  196.358
# 4         12.658            22.437                      144.358  227.093
#
#    TotalDownloadTime  HttpResponse HTTPVersion    Protocol
# 0            226.943           200    HTTP/1.1  TCP/TLS1.2
# 1            235.016           200       HTTP2  TCP/TLS1.2
# 2            223.167           301    HTTP/1.1  TCP/TLS1.2
# 3            196.385           301    HTTP/1.1  TCP/TLS1.3
# 4            227.124           301       HTTP2  TCP/TLS1.2

# %%
s.tail()
# Out:
#                TimeOfMeasurement             Url             Ip  Port  \
# 333672  Wed May 20 17:31:21 2020      webptt.com  104.31.70.119   443
# 333673  Wed May 20 17:31:32 2020     easyview.eu   54.38.72.112   443
# 333674  Wed May 20 17:31:39 2020       agones.gr  104.27.201.90   443
# 333675  Wed May 20 17:31:53 2020  rapidvideo.com  34.235.250.63   443
# 333676  Wed May 20 17:31:54 2020  siteorigin.com    104.26.5.59   443
#
#         DnsLookupTime  TCPHandshakeTime  ConnectionEstablishmentTime  \
# 333672         84.486             2.132                    11982.722
# 333673        161.576           162.524                    19888.199
# 333674        120.879            40.362                    13762.554
# 333675        118.807            84.626                    15101.080
# 333676        120.462             1.774                    13752.344
#
#              TTFB  TotalDownloadTime  HttpResponse HTTPVersion    Protocol
# 333672  12351.641          12639.428           200       HTTP2  TCP/TLS1.2
# 333673  20054.352          20216.558           200    HTTP/1.1  TCP/TLS1.2
# 333674  14129.757          14331.592           200    HTTP/1.1  TCP/TLS1.2
# 333675  15182.109          15182.155           302    HTTP/1.1  TCP/TLS1.2
# 333676  14203.193          14205.093           200    HTTP/1.1  TCP/TLS1.2

# %%
#t['TimeOfMeasurement'] = t['TimeOfMeasurement'].apply(timestamp2human)

# %%
t.head()
# Out:
#    TimeOfMeasurement                        Url Path            Ip Port  \
# 0       1.589580e+09  www.0dayrox2.blogspot.com    /  172.217.5.97  443
# 1       1.589580e+09  www.0dayrox2.blogspot.com    /  172.217.5.97  443
# 2       1.589580e+09  www.0dayrox2.blogspot.com    /  172.217.5.97  443
# 8       1.589580e+09   www.0dayrox.blogspot.com    /  172.217.5.97  443
# 9       1.589580e+09   www.0dayrox.blogspot.com    /  172.217.5.97  443
#
#    DNSTime  ConnectionEstablishmentTime     TTFB  TotalDownloadTime  \
# 0   26.789                       44.031  191.520            252.621
# 1    0.833                       43.702  198.238            216.891
# 2   10.528                       44.412  313.128            333.717
# 8   18.358                       48.302  208.418            234.287
# 9    0.970                       44.219  305.459            333.191
#
#    HttpResponse Protocol
# 0         404.0     Q043
# 1         404.0     Q046
# 2         404.0     Q050
# 8         404.0     Q043
# 9         404.0     Q046

# %%
t.tail()
# Out:
#          TimeOfMeasurement                             Url Path            Ip  \
# 2097654       1.589989e+09  www.mrshehab-tito.blogspot.com    /  172.217.6.65
# 2097655       1.589989e+09  www.sotakhandmade.blogspot.com    /  172.217.6.65
# 2097657       1.589989e+09  www.sotakhandmade.blogspot.com    /  172.217.6.65
# 2097658       1.589989e+09  www.sotakhandmade.blogspot.com    /  172.217.6.65
# 2097670       1.589989e+09        www.jhrogue.blogspot.com    /  172.217.6.65
#
#         Port  DNSTime  ConnectionEstablishmentTime     TTFB  \
# 2097654  443   43.891                      964.368   84.578
# 2097655  443   81.890                       78.490  199.985
# 2097657  443   37.531                       80.943  165.138
# 2097658  443   39.949                      125.540  206.616
# 2097670  443  123.839                      162.903  323.018
#
#          TotalDownloadTime  HttpResponse Protocol
# 2097654             84.640         301.0     Q050
# 2097655            200.044         301.0     Q043
# 2097657            201.929         301.0     Q046
# 2097658            206.676         301.0     Q050
# 2097670            323.083         301.0     Q043

# %%
def filter_by_ip(df, column):
  """reads a DataFrame, calls fbi.filter_v{4,6} to get DataFrames with rows
     containing only v4, v6 endpoints. Returns the two DataFrame as a tuple"""

  dfv6 = fbi.filter_v6(df, column)
  dfv4 = fbi.filter_v4(df, column)
  return dfv4, dfv6

# %%
#quic4, quic6 = filter_by_ip(t, column = 'Ip')
quic4 = t[t['Ip'].str.contains("\.")]
quic6 = t[t['Ip'].str.contains("\:")]

# %%
quic4.count()
# Out:
# TimeOfMeasurement              739149
# Url                            739149
# Path                           739149
# Ip                             739149
# Port                           739149
# DNSTime                        739149
# ConnectionEstablishmentTime    739149
# TTFB                           739149
# TotalDownloadTime              739149
# HttpResponse                   739149
# Protocol                       739149
# dtype: int64

# %%
quic4.head()
# Out:
#    TimeOfMeasurement                        Url Path            Ip Port  \
# 0       1.589580e+09  www.0dayrox2.blogspot.com    /  172.217.5.97  443
# 1       1.589580e+09  www.0dayrox2.blogspot.com    /  172.217.5.97  443
# 2       1.589580e+09  www.0dayrox2.blogspot.com    /  172.217.5.97  443
# 8       1.589580e+09   www.0dayrox.blogspot.com    /  172.217.5.97  443
# 9       1.589580e+09   www.0dayrox.blogspot.com    /  172.217.5.97  443
#
#    DNSTime  ConnectionEstablishmentTime     TTFB  TotalDownloadTime  \
# 0   26.789                       44.031  191.520            252.621
# 1    0.833                       43.702  198.238            216.891
# 2   10.528                       44.412  313.128            333.717
# 8   18.358                       48.302  208.418            234.287
# 9    0.970                       44.219  305.459            333.191
#
#    HttpResponse Protocol
# 0         404.0     Q043
# 1         404.0     Q046
# 2         404.0     Q050
# 8         404.0     Q043
# 9         404.0     Q046

# %%
quic6.count()
# Out:
# TimeOfMeasurement              0
# Url                            0
# Path                           0
# Ip                             0
# Port                           0
# DNSTime                        0
# ConnectionEstablishmentTime    0
# TTFB                           0
# TotalDownloadTime              0
# HttpResponse                   0
# Protocol                       0
# dtype: int64

# %%
quic6.head()
# Out:
# Empty DataFrame
# Columns: [TimeOfMeasurement, Url, Path, Ip, Port, DNSTime, ConnectionEstablishmentTime, TTFB, TotalDownloadTime, HttpResponse, Protocol]
# Index: []

# %%
#tcp4, tcp6 = filter_by_ip(s, column = 'Ip')
tcp4 = s[s['Ip'].str.contains("\.")]
tcp6 = s[s['Ip'].str.contains("\:")]

# %%
tcp4.count()
# Out:
# TimeOfMeasurement              333677
# Url                            333677
# Ip                             333677
# Port                           333677
# DnsLookupTime                  333677
# TCPHandshakeTime               333677
# ConnectionEstablishmentTime    333677
# TTFB                           333677
# TotalDownloadTime              333677
# HttpResponse                   333677
# HTTPVersion                    333677
# Protocol                       333677
# dtype: int64

# %%
tcp4.head()
# Out:
#           TimeOfMeasurement             Url              Ip  Port  \
# 0  Sat May 16 18:00:02 2020  www.google.com  216.58.194.164   443
# 1  Sat May 16 18:00:02 2020  www.google.com  216.58.194.164   443
# 2  Sat May 16 18:00:02 2020    facebook.com    157.240.3.35   443
# 3  Sat May 16 18:00:03 2020    facebook.com    157.240.3.35   443
# 4  Sat May 16 18:00:03 2020    facebook.com    157.240.3.35   443
#
#    DnsLookupTime  TCPHandshakeTime  ConnectionEstablishmentTime     TTFB  \
# 0          5.983             2.320                      161.516  215.911
# 1         12.719             5.758                      155.791  216.441
# 2         17.493            20.638                      149.535  223.139
# 3          5.989            21.795                      121.031  196.358
# 4         12.658            22.437                      144.358  227.093
#
#    TotalDownloadTime  HttpResponse HTTPVersion    Protocol
# 0            226.943           200    HTTP/1.1  TCP/TLS1.2
# 1            235.016           200       HTTP2  TCP/TLS1.2
# 2            223.167           301    HTTP/1.1  TCP/TLS1.2
# 3            196.385           301    HTTP/1.1  TCP/TLS1.3
# 4            227.124           301       HTTP2  TCP/TLS1.2

# %%
tcp6.count()
# Out:
# TimeOfMeasurement              0
# Url                            0
# Ip                             0
# Port                           0
# DnsLookupTime                  0
# TCPHandshakeTime               0
# ConnectionEstablishmentTime    0
# TTFB                           0
# TotalDownloadTime              0
# HttpResponse                   0
# HTTPVersion                    0
# Protocol                       0
# dtype: int64

# %%
tcp6.head()
# Out:
# Empty DataFrame
# Columns: [TimeOfMeasurement, Url, Ip, Port, DnsLookupTime, TCPHandshakeTime, ConnectionEstablishmentTime, TTFB, TotalDownloadTime, HttpResponse, HTTPVersion, Protocol]
# Index: []

# %%
quic43 = quic4.loc[t['Protocol'] == 'Q043']
quic46 = quic4.loc[t['Protocol'] == 'Q046']
quic50 = quic4.loc[t['Protocol'] == 'Q050']
quicID24 = quic4.loc[t['Protocol'] == 'FF000018']
quic98 = quic4.loc[t['Protocol'] == '']

# %%
quic43.count()
# Out:
# TimeOfMeasurement              247897
# Url                            247897
# Path                           247897
# Ip                             247897
# Port                           247897
# DNSTime                        247897
# ConnectionEstablishmentTime    247897
# TTFB                           247897
# TotalDownloadTime              247897
# HttpResponse                   247897
# Protocol                       247897
# dtype: int64

# %%
quic43.head()
# Out:
#     TimeOfMeasurement                                      Url Path  \
# 0        1.589580e+09                www.0dayrox2.blogspot.com    /
# 8        1.589580e+09                 www.0dayrox.blogspot.com    /
# 16       1.589580e+09  www.100leccionesdeguitarra.blogspot.com    /
# 24       1.589580e+09                      www.100negocios.com    /
# 40       1.589580e+09                 www.1100021.blogspot.com    /
#
#                Ip Port  DNSTime  ConnectionEstablishmentTime     TTFB  \
# 0    172.217.5.97  443   26.789                       44.031  191.520
# 8    172.217.5.97  443   18.358                       48.302  208.418
# 16   172.217.5.97  443   26.432                       47.355  225.455
# 24  66.198.240.11  443  129.079                      123.054  670.904
# 40   172.217.5.97  443   24.731                       43.050  157.375
#
#     TotalDownloadTime  HttpResponse Protocol
# 0             252.621         404.0     Q043
# 8             234.287         404.0     Q043
# 16            225.514         301.0     Q043
# 24            806.319         200.0     Q043
# 40            157.432         301.0     Q043

# %%
quic43.tail()
# Out:
#          TimeOfMeasurement                             Url Path  \
# 2097634       1.589989e+09  www.mrshehab-tito.blogspot.com    /
# 2097638       1.589989e+09   www.winetricks.googlecode.com    /
# 2097642       1.589989e+09       www.foobar.withgoogle.com    /
# 2097655       1.589989e+09  www.sotakhandmade.blogspot.com    /
# 2097670       1.589989e+09        www.jhrogue.blogspot.com    /
#
#                     Ip Port  DNSTime  ConnectionEstablishmentTime     TTFB  \
# 2097634   172.217.6.65  443   39.564                       81.161  328.117
# 2097638  74.125.137.82  443  711.013                       80.984  121.423
# 2097642  172.217.5.113  443   79.503                       81.232  161.958
# 2097655   172.217.6.65  443   81.890                       78.490  199.985
# 2097670   172.217.6.65  443  123.839                      162.903  323.018
#
#          TotalDownloadTime  HttpResponse Protocol
# 2097634            328.176         301.0     Q043
# 2097638            121.487         404.0     Q043
# 2097642            162.021         200.0     Q043
# 2097655            200.044         301.0     Q043
# 2097670            323.083         301.0     Q043

# %%
quic46.count()
# Out:
# TimeOfMeasurement              245193
# Url                            245193
# Path                           245193
# Ip                             245193
# Port                           245193
# DNSTime                        245193
# ConnectionEstablishmentTime    245193
# TTFB                           245193
# TotalDownloadTime              245193
# HttpResponse                   245193
# Protocol                       245193
# dtype: int64

# %%
quic46.head()
# Out:
#     TimeOfMeasurement                                      Url Path  \
# 1        1.589580e+09                www.0dayrox2.blogspot.com    /
# 9        1.589580e+09                 www.0dayrox.blogspot.com    /
# 17       1.589580e+09  www.100leccionesdeguitarra.blogspot.com    /
# 25       1.589580e+09                      www.100negocios.com    /
# 41       1.589580e+09                 www.1100021.blogspot.com    /
#
#                Ip Port  DNSTime  ConnectionEstablishmentTime     TTFB  \
# 1    172.217.5.97  443    0.833                       43.702  198.238
# 9    172.217.5.97  443    0.970                       44.219  305.459
# 17   172.217.5.97  443    0.709                       43.849  199.247
# 25  66.198.240.11  443    0.700                      118.499  651.876
# 41   172.217.5.97  443    0.819                       42.533  140.312
#
#     TotalDownloadTime  HttpResponse Protocol
# 1             216.891         404.0     Q046
# 9             333.191         404.0     Q046
# 17            199.326         301.0     Q046
# 25            790.427         200.0     Q046
# 41            140.388         301.0     Q046

# %%
quic46.tail()
# Out:
#          TimeOfMeasurement                             Url Path  \
# 2097625       1.589989e+09       www.jhchung0.blogspot.com    /
# 2097636       1.589989e+09  www.mrshehab-tito.blogspot.com    /
# 2097639       1.589989e+09   www.winetricks.googlecode.com    /
# 2097645       1.589989e+09       www.foobar.withgoogle.com    /
# 2097657       1.589989e+09  www.sotakhandmade.blogspot.com    /
#
#                     Ip Port  DNSTime  ConnectionEstablishmentTime     TTFB  \
# 2097625   172.217.6.65  443   37.359                       85.023  206.563
# 2097636   172.217.6.65  443   40.902                      120.456  208.450
# 2097639  74.125.137.82  443    2.132                       78.123  118.588
# 2097645  172.217.5.113  443   39.899                       83.164  245.206
# 2097657   172.217.6.65  443   37.531                       80.943  165.138
#
#          TotalDownloadTime  HttpResponse Protocol
# 2097625            206.624         301.0     Q046
# 2097636            208.502         301.0     Q046
# 2097639            118.648         404.0     Q046
# 2097645            245.270         200.0     Q046
# 2097657            201.929         301.0     Q046

# %%
quic50.count()
# Out:
# TimeOfMeasurement              242532
# Url                            242532
# Path                           242532
# Ip                             242532
# Port                           242532
# DNSTime                        242532
# ConnectionEstablishmentTime    242532
# TTFB                           242532
# TotalDownloadTime              242532
# HttpResponse                   242532
# Protocol                       242532
# dtype: int64

# %%
quic50.head()
# Out:
#     TimeOfMeasurement                                      Url Path  \
# 2        1.589580e+09                www.0dayrox2.blogspot.com    /
# 10       1.589580e+09                 www.0dayrox.blogspot.com    /
# 18       1.589580e+09  www.100leccionesdeguitarra.blogspot.com    /
# 26       1.589580e+09                      www.100negocios.com    /
# 42       1.589580e+09                 www.1100021.blogspot.com    /
#
#                Ip Port  DNSTime  ConnectionEstablishmentTime     TTFB  \
# 2    172.217.5.97  443   10.528                       44.412  313.128
# 10   172.217.5.97  443   27.994                       43.858  202.719
# 18   172.217.5.97  443    0.848                       42.363  298.533
# 26  66.198.240.11  443    0.754                      118.943  664.085
# 42   172.217.5.97  443    0.684                       43.279  141.129
#
#     TotalDownloadTime  HttpResponse Protocol
# 2             333.717         404.0     Q050
# 10            280.798         404.0     Q050
# 18            298.594         301.0     Q050
# 26            807.167         200.0     Q050
# 42            141.188         301.0     Q050

# %%
quic50.tail()
# Out:
#          TimeOfMeasurement                             Url Path  \
# 2097643       1.589989e+09          www.sostenibilidad.com    /
# 2097646       1.589989e+09       www.foobar.withgoogle.com    /
# 2097650       1.589989e+09   www.winetricks.googlecode.com    /
# 2097654       1.589989e+09  www.mrshehab-tito.blogspot.com    /
# 2097658       1.589989e+09  www.sotakhandmade.blogspot.com    /
#
#                      Ip Port  DNSTime  ConnectionEstablishmentTime     TTFB  \
# 2097643  192.229.211.16  443    7.137                      592.857  245.983
# 2097646   172.217.5.113  443    2.459                      119.026  203.906
# 2097650   74.125.137.82  443  638.883                      161.600  202.099
# 2097654    172.217.6.65  443   43.891                      964.368   84.578
# 2097658    172.217.6.65  443   39.949                      125.540  206.616
#
#          TotalDownloadTime  HttpResponse Protocol
# 2097643            375.113         200.0     Q050
# 2097646            203.972         200.0     Q050
# 2097650            202.160         404.0     Q050
# 2097654             84.640         301.0     Q050
# 2097658            206.676         301.0     Q050

# %%
quicID24.count()
# Out:
# TimeOfMeasurement              3527
# Url                            3527
# Path                           3527
# Ip                             3527
# Port                           3527
# DNSTime                        3527
# ConnectionEstablishmentTime    3527
# TTFB                           3527
# TotalDownloadTime              3527
# HttpResponse                   3527
# Protocol                       3527
# dtype: int64

# %%
quicID24.head()
# Out:
#       TimeOfMeasurement                    Url Path               Ip Port  \
# 555        1.589580e+09   www.9999999views.com    /   178.32.108.178  443
# 1250       1.589581e+09         www.akaian.com    /     150.95.55.38  443
# 1518       1.589581e+09        www.allzine.org    /  194.150.248.139  443
# 1598       1.589581e+09  www.altoonaworks.info    /    72.249.49.192  443
# 3130       1.589581e+09       www.av-baron.com    /    150.95.52.123  443
#
#       DNSTime  ConnectionEstablishmentTime     TTFB  TotalDownloadTime  \
# 555     0.625                      145.664  289.043            289.121
# 1250    0.772                      215.351  321.896            321.967
# 1518    0.687                      185.364  373.387            373.438
# 1598    0.821                       89.615  134.116            136.782
# 3130    0.676                      217.363  410.334            410.425
#
#       HttpResponse  Protocol
# 555          301.0  FF000018
# 1250         301.0  FF000018
# 1518         200.0  FF000018
# 1598         200.0  FF000018
# 3130         301.0  FF000018

# %%
quicID24.tail()
# Out:
#          TimeOfMeasurement                    Url Path               Ip Port  \
# 2094183       1.589988e+09   www.farangshop.co.uk    /     89.145.92.12  443
# 2094491       1.589988e+09     www.irishtune.info    /    72.249.49.192  443
# 2095708       1.589988e+09        www.filmtett.ro    /  176.126.202.142  443
# 2095730       1.589988e+09        www.bold.expert    /  194.150.248.168  443
# 2096079       1.589988e+09  www.jalopyjournal.com    /  158.106.189.183  443
#
#          DNSTime  ConnectionEstablishmentTime     TTFB  TotalDownloadTime  \
# 2094183   79.101                      368.998  696.655            696.719
# 2094491  224.861                       45.457  123.818            123.981
# 2095708   54.564                      325.595  498.355            752.088
# 2095730   37.788                      174.553  343.021            343.061
# 2096079   39.994                      830.939  281.475            362.447
#
#          HttpResponse  Protocol
# 2094183         303.0  FF000018
# 2094491         200.0  FF000018
# 2095708         200.0  FF000018
# 2095730         301.0  FF000018
# 2096079         200.0  FF000018

# %%
quic43_6 = quic6.loc[t['Protocol'] == 'Q043']
quic46_6 = quic6.loc[t['Protocol'] == 'Q046']
quic50_6 = quic6.loc[t['Protocol'] == 'Q050']
#quic98_6 = quic6.loc[t['Protocol'] == '']
quicID24_6 = quic6.loc[t['Protocol'] == 'FF000018']

# %%
quic43_6.count()
# Out:
# TimeOfMeasurement              0
# Url                            0
# Path                           0
# Ip                             0
# Port                           0
# DNSTime                        0
# ConnectionEstablishmentTime    0
# TTFB                           0
# TotalDownloadTime              0
# HttpResponse                   0
# Protocol                       0
# dtype: int64

# %%
quic43_6.head()
# Out:
# Empty DataFrame
# Columns: [TimeOfMeasurement, Url, Path, Ip, Port, DNSTime, ConnectionEstablishmentTime, TTFB, TotalDownloadTime, HttpResponse, Protocol]
# Index: []

# %%
quic43_6.tail()
# Out:
# Empty DataFrame
# Columns: [TimeOfMeasurement, Url, Path, Ip, Port, DNSTime, ConnectionEstablishmentTime, TTFB, TotalDownloadTime, HttpResponse, Protocol]
# Index: []

# %%
quic46_6.count()
# Out:
# TimeOfMeasurement              0
# Url                            0
# Path                           0
# Ip                             0
# Port                           0
# DNSTime                        0
# ConnectionEstablishmentTime    0
# TTFB                           0
# TotalDownloadTime              0
# HttpResponse                   0
# Protocol                       0
# dtype: int64

# %%
quic46_6.head()
# Out:
# Empty DataFrame
# Columns: [TimeOfMeasurement, Url, Path, Ip, Port, DNSTime, ConnectionEstablishmentTime, TTFB, TotalDownloadTime, HttpResponse, Protocol]
# Index: []

# %%
quic46_6.tail()
# Out:
# Empty DataFrame
# Columns: [TimeOfMeasurement, Url, Path, Ip, Port, DNSTime, ConnectionEstablishmentTime, TTFB, TotalDownloadTime, HttpResponse, Protocol]
# Index: []

# %%
quic50_6.count()
# Out:
# TimeOfMeasurement              0
# Url                            0
# Path                           0
# Ip                             0
# Port                           0
# DNSTime                        0
# ConnectionEstablishmentTime    0
# TTFB                           0
# TotalDownloadTime              0
# HttpResponse                   0
# Protocol                       0
# dtype: int64

# %%
quic50_6.head()
# Out:
# Empty DataFrame
# Columns: [TimeOfMeasurement, Url, Path, Ip, Port, DNSTime, ConnectionEstablishmentTime, TTFB, TotalDownloadTime, HttpResponse, Protocol]
# Index: []

# %%
quic50_6.tail()
# Out:
# Empty DataFrame
# Columns: [TimeOfMeasurement, Url, Path, Ip, Port, DNSTime, ConnectionEstablishmentTime, TTFB, TotalDownloadTime, HttpResponse, Protocol]
# Index: []

# %%
quicID24_6.count()
# Out:
# TimeOfMeasurement              0
# Url                            0
# Path                           0
# Ip                             0
# Port                           0
# DNSTime                        0
# ConnectionEstablishmentTime    0
# TTFB                           0
# TotalDownloadTime              0
# HttpResponse                   0
# Protocol                       0
# dtype: int64

# %%
quicID24_6.head()
# Out:
# Empty DataFrame
# Columns: [TimeOfMeasurement, Url, Path, Ip, Port, DNSTime, ConnectionEstablishmentTime, TTFB, TotalDownloadTime, HttpResponse, Protocol]
# Index: []

# %%
quicID24_6.tail()
# Out:
# Empty DataFrame
# Columns: [TimeOfMeasurement, Url, Path, Ip, Port, DNSTime, ConnectionEstablishmentTime, TTFB, TotalDownloadTime, HttpResponse, Protocol]
# Index: []

# %%
tcp12 = tcp4.loc[s['Protocol'] == 'TCP/TLS1.2']
tcp13 = tcp4.loc[s['Protocol'] == 'TCP/TLS1.3']

# %%
tcp12.count()
# Out:
# TimeOfMeasurement              332700
# Url                            332700
# Ip                             332700
# Port                           332700
# DnsLookupTime                  332700
# TCPHandshakeTime               332700
# ConnectionEstablishmentTime    332700
# TTFB                           332700
# TotalDownloadTime              332700
# HttpResponse                   332700
# HTTPVersion                    332700
# Protocol                       332700
# dtype: int64

# %%
tcp12.head()
# Out:
#           TimeOfMeasurement             Url              Ip  Port  \
# 0  Sat May 16 18:00:02 2020  www.google.com  216.58.194.164   443
# 1  Sat May 16 18:00:02 2020  www.google.com  216.58.194.164   443
# 2  Sat May 16 18:00:02 2020    facebook.com    157.240.3.35   443
# 4  Sat May 16 18:00:03 2020    facebook.com    157.240.3.35   443
# 6  Sat May 16 18:00:04 2020   instagram.com   34.199.183.65   443
#
#    DnsLookupTime  TCPHandshakeTime  ConnectionEstablishmentTime     TTFB  \
# 0          5.983             2.320                      161.516  215.911
# 1         12.719             5.758                      155.791  216.441
# 2         17.493            20.638                      149.535  223.139
# 4         12.658            22.437                      144.358  227.093
# 6          5.173            61.479                      264.150  414.323
#
#    TotalDownloadTime  HttpResponse HTTPVersion    Protocol
# 0            226.943           200    HTTP/1.1  TCP/TLS1.2
# 1            235.016           200       HTTP2  TCP/TLS1.2
# 2            223.167           301    HTTP/1.1  TCP/TLS1.2
# 4            227.124           301       HTTP2  TCP/TLS1.2
# 6            414.368           301    HTTP/1.1  TCP/TLS1.2

# %%
tcp12.tail()
# Out:
#                TimeOfMeasurement             Url             Ip  Port  \
# 333672  Wed May 20 17:31:21 2020      webptt.com  104.31.70.119   443
# 333673  Wed May 20 17:31:32 2020     easyview.eu   54.38.72.112   443
# 333674  Wed May 20 17:31:39 2020       agones.gr  104.27.201.90   443
# 333675  Wed May 20 17:31:53 2020  rapidvideo.com  34.235.250.63   443
# 333676  Wed May 20 17:31:54 2020  siteorigin.com    104.26.5.59   443
#
#         DnsLookupTime  TCPHandshakeTime  ConnectionEstablishmentTime  \
# 333672         84.486             2.132                    11982.722
# 333673        161.576           162.524                    19888.199
# 333674        120.879            40.362                    13762.554
# 333675        118.807            84.626                    15101.080
# 333676        120.462             1.774                    13752.344
#
#              TTFB  TotalDownloadTime  HttpResponse HTTPVersion    Protocol
# 333672  12351.641          12639.428           200       HTTP2  TCP/TLS1.2
# 333673  20054.352          20216.558           200    HTTP/1.1  TCP/TLS1.2
# 333674  14129.757          14331.592           200    HTTP/1.1  TCP/TLS1.2
# 333675  15182.109          15182.155           302    HTTP/1.1  TCP/TLS1.2
# 333676  14203.193          14205.093           200    HTTP/1.1  TCP/TLS1.2

# %%
tcp13.count()
# Out:
# TimeOfMeasurement              977
# Url                            977
# Ip                             977
# Port                           977
# DnsLookupTime                  977
# TCPHandshakeTime               977
# ConnectionEstablishmentTime    977
# TTFB                           977
# TotalDownloadTime              977
# HttpResponse                   977
# HTTPVersion                    977
# Protocol                       977
# dtype: int64

# %%
tcp13.head()
# Out:
#            TimeOfMeasurement               Url              Ip  Port  \
# 3   Sat May 16 18:00:03 2020      facebook.com    157.240.3.35   443
# 5   Sat May 16 18:00:03 2020      facebook.com    157.240.3.35   443
# 7   Sat May 16 18:00:04 2020     instagram.com  34.197.183.108   443
# 9   Sat May 16 18:00:05 2020     instagram.com     34.192.95.2   443
# 11  Sat May 16 18:00:05 2020  www.whatsapp.com    157.240.3.54   443
#
#     DnsLookupTime  TCPHandshakeTime  ConnectionEstablishmentTime     TTFB  \
# 3           5.989            21.795                      121.031  196.358
# 5          12.478            21.692                      121.759  195.096
# 7          12.777            65.604                      208.471  345.289
# 9          10.061            62.057                      186.797  300.402
# 11         18.520            20.249                      133.371  219.775
#
#     TotalDownloadTime  HttpResponse HTTPVersion    Protocol
# 3             196.385           301    HTTP/1.1  TCP/TLS1.3
# 5             195.127           301       HTTP2  TCP/TLS1.3
# 7             345.336           301    HTTP/1.1  TCP/TLS1.3
# 9             300.437           301       HTTP2  TCP/TLS1.3
# 11            219.806           302    HTTP/1.1  TCP/TLS1.3

# %%
tcp13.tail()
# Out:
#                TimeOfMeasurement            Url            Ip  Port  \
# 332597  Wed May 20 16:19:48 2020         fb.com  157.240.3.35   443
# 332623  Wed May 20 16:22:31 2020  messenger.com  157.240.3.20   443
# 332627  Wed May 20 16:23:11 2020  messenger.com  157.240.3.20   443
# 333089  Wed May 20 16:53:55 2020      fbsbx.com  157.240.3.35   443
# 333094  Wed May 20 16:54:32 2020      fbsbx.com  157.240.3.35   443
#
#         DnsLookupTime  TCPHandshakeTime  ConnectionEstablishmentTime  \
# 332597       2699.058            40.443                    18297.558
# 332623         80.420            40.590                    15792.550
# 332627       2744.280            40.586                    17577.751
# 333089        120.267            40.478                    21118.579
# 333094         39.554            40.272                    18748.159
#
#              TTFB  TotalDownloadTime  HttpResponse HTTPVersion    Protocol
# 332597  18377.119          18377.150           302       HTTP2  TCP/TLS1.3
# 332623  15876.261          15876.288           301    HTTP/1.1  TCP/TLS1.3
# 332627  17663.182          17663.211           301       HTTP2  TCP/TLS1.3
# 333089  21238.023          21238.051           302    HTTP/1.1  TCP/TLS1.3
# 333094  18868.217          18868.263           302       HTTP2  TCP/TLS1.3

# %%
tcp12_6 = tcp6.loc[s['Protocol'] == 'TCP/TLS1.2']
tcp13_6 = tcp6.loc[s['Protocol'] == 'TCP/TLS1.3']

# %%
tcp12_6.count()
# Out:
# TimeOfMeasurement              0
# Url                            0
# Ip                             0
# Port                           0
# DnsLookupTime                  0
# TCPHandshakeTime               0
# ConnectionEstablishmentTime    0
# TTFB                           0
# TotalDownloadTime              0
# HttpResponse                   0
# HTTPVersion                    0
# Protocol                       0
# dtype: int64

# %%
tcp12_6.head()
# Out:
# Empty DataFrame
# Columns: [TimeOfMeasurement, Url, Ip, Port, DnsLookupTime, TCPHandshakeTime, ConnectionEstablishmentTime, TTFB, TotalDownloadTime, HttpResponse, HTTPVersion, Protocol]
# Index: []

# %%
tcp12_6.tail()
# Out:
# Empty DataFrame
# Columns: [TimeOfMeasurement, Url, Ip, Port, DnsLookupTime, TCPHandshakeTime, ConnectionEstablishmentTime, TTFB, TotalDownloadTime, HttpResponse, HTTPVersion, Protocol]
# Index: []

# %%
tcp13_6.count()
# Out:
# TimeOfMeasurement              0
# Url                            0
# Ip                             0
# Port                           0
# DnsLookupTime                  0
# TCPHandshakeTime               0
# ConnectionEstablishmentTime    0
# TTFB                           0
# TotalDownloadTime              0
# HttpResponse                   0
# HTTPVersion                    0
# Protocol                       0
# dtype: int64

# %%
tcp13_6.head()
# Out:
# Empty DataFrame
# Columns: [TimeOfMeasurement, Url, Ip, Port, DnsLookupTime, TCPHandshakeTime, ConnectionEstablishmentTime, TTFB, TotalDownloadTime, HttpResponse, HTTPVersion, Protocol]
# Index: []

# %%
tcp13_6.tail()
# Out:
# Empty DataFrame
# Columns: [TimeOfMeasurement, Url, Ip, Port, DnsLookupTime, TCPHandshakeTime, ConnectionEstablishmentTime, TTFB, TotalDownloadTime, HttpResponse, HTTPVersion, Protocol]
# Index: []

# %%
x = Cdf.MakeCdfFromList(quic43['ConnectionEstablishmentTime'].values)
x1 =Cdf.MakeCdfFromList(quic50['ConnectionEstablishmentTime'].values)
x3 = Cdf.MakeCdfFromList(quic46['ConnectionEstablishmentTime'].values)
#x5 = Cdf.MakeCdfFromList(quic98['ConnectionEstablishmentTime'].values)
x6 = Cdf.MakeCdfFromList(quicID24['ConnectionEstablishmentTime'].values)
x4 = Cdf.MakeCdfFromList(tcp13['ConnectionEstablishmentTime'].values)
x2 =Cdf.MakeCdfFromList(tcp12['ConnectionEstablishmentTime'].values)

# %%
print_percentiles(x1, 'Q050')
print_percentiles(x2, 'tcp12')
print_percentiles(x3, 'Q046')
print_percentiles(x4, 'tcp13')
#print_percentiles(x5, 'Q098')
print_percentiles(x6, 'IETF h3-24')
print_percentiles(x, 'Q043')
# Out:
# -----------------------------
#
# percentile values distribution for Q050
#
# 20th Percentile:42.438000
#
# 25th Percentile:42.835000
#
# 40th Percentile:78.217000
#
# 50th Percentile:79.493000
#
# 60th Percentile:80.670000
#
# 75th Percentile:83.358000
#
# 80th Percentile:85.124000
#
# 90th Percentile:286.803000
#
# 99th Percentile:733.971000
#
# -----------------------------
#
# -----------------------------
#
# percentile values distribution for tcp12
#
# 20th Percentile:55.794000
#
# 25th Percentile:64.892000
#
# 40th Percentile:167.340000
#
# 50th Percentile:1525.993000
#
# 60th Percentile:5520.474000
#
# 75th Percentile:9056.842000
#
# 80th Percentile:10280.931000
#
# 90th Percentile:12837.291000
#
# 99th Percentile:18059.642000
#
# -----------------------------
#
# -----------------------------
#
# percentile values distribution for Q046
#
# 20th Percentile:42.409000
#
# 25th Percentile:42.808000
#
# 40th Percentile:78.247000
#
# 50th Percentile:79.529000
#
# 60th Percentile:80.718000
#
# 75th Percentile:83.566000
#
# 80th Percentile:85.364000
#
# 90th Percentile:307.343000
#
# 99th Percentile:724.009000
#
# -----------------------------
#
# -----------------------------
#
# percentile values distribution for tcp13
#
# 20th Percentile:217.368000
#
# 25th Percentile:379.534000
#
# 40th Percentile:4999.173000
#
# 50th Percentile:7775.231000
#
# 60th Percentile:9998.518000
#
# 75th Percentile:13582.945000
#
# 80th Percentile:14890.388000
#
# 90th Percentile:18135.657000
#
# 99th Percentile:27000.854000
#
# -----------------------------
#
# -----------------------------
#
# percentile values distribution for IETF h3-24
#
# 20th Percentile:124.461000
#
# 25th Percentile:152.392000
#
# 40th Percentile:193.934000
#
# 50th Percentile:206.289000
#
# 60th Percentile:215.555000
#
# 75th Percentile:299.686000
#
# 80th Percentile:325.483000
#
# 90th Percentile:365.823000
#
# 99th Percentile:830.939000
#
# -----------------------------
#
# -----------------------------
#
# percentile values distribution for Q043
#
# 20th Percentile:42.453000
#
# 25th Percentile:42.892000
#
# 40th Percentile:78.775000
#
# 50th Percentile:80.592000
#
# 60th Percentile:80.921000
#
# 75th Percentile:84.395000
#
# 80th Percentile:85.279000
#
# 90th Percentile:323.865000
#
# 99th Percentile:694.457000
#
# -----------------------------

# %%
write_percentiles('Q050.csv', x1)
write_percentiles('tcp12.csv', x2)
write_percentiles('Q046.csv', x3)
write_percentiles('tcp13.csv', x4)
#write_percentiles('Q098.csv', x5)
write_percentiles('IETFh3-24', x6)
write_percentiles('Q043.csv', x)

# %%
fig = plt.figure(figsize = (10,3))
plt.rcParams['font.size'] = 12
ax = plt.gca()
yticks = np.arange(0,1.1,0.2)

#Q043
plt.plot(x.xs, x.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'orange')
#Q050
plt.plot(x1.xs, x1.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'red')
#Q046
plt.plot(x3.xs, x3.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'cyan')
#Q098
#plt.plot(x5.xs, x5.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'blue')
#IETF h3-24
plt.plot(x6.xs, x6.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color='yellow')
#TLS1.2
plt.plot(x2.xs, x2.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'green')
#TLS1.3
plt.plot(x4.xs, x4.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'black')


ax = fig.axes[0]
ax.grid(False)
ax.set_yticks(yticks)
#ax.set_ylim([0,1.05])
ax.set_xlim([0.01, 54000])
ax.set_xscale('log')
ax.set_xlabel('latency (x-axis is cut)', fontsize=12)
ax.set_ylabel('CDF', fontsize=12)

plt.legend(['Q043', 'Q050', 'Q046', 'IETF h3-24', 'TLS1.2', 'TLS1.3'], fontsize=11, loc='best')

ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.yaxis.set_ticks_position('left')
ax.xaxis.set_ticks_position('bottom')
ax.spines['bottom'].set_position(('axes', -0.05))
ax.spines['left'].set_position(('axes', -0.05))

ax3 = ax.twinx()
ax3.spines['right'].set_color('none')
ax3.spines['top'].set_color('none')
ax3.spines['left'].set_color('none')
ax3.spines['bottom'].set_color('none')
ax3.yaxis.set_ticks_position('none')
##ax3.set_ylabel('[\'16th May - \'20thMay')
plt.setp(ax3.get_yticklabels(), visible=False)

plt.title('Handshake Times with IPv4', fontsize=12, y=1.05)
plt.savefig('./AWS/N.California/handshake_times_ipv4.png', format='png', bbox_inches='tight')

# %%
x = Cdf.MakeCdfFromList(quic43_6['ConnectionEstablishmentTime'].values)
x1 =Cdf.MakeCdfFromList(quic50_6['ConnectionEstablishmentTime'].values)
x3 = Cdf.MakeCdfFromList(quic46_6['ConnectionEstablishmentTime'].values)
#x5 = Cdf.MakeCdfFromList(quic98_6['ConnectionEstablishmentTime'].values)
x6 = Cdf.MakeCdfFromList(quicID24_6['ConnectionEstablishmentTime'].values)
x4 = Cdf.MakeCdfFromList(tcp13_6['ConnectionEstablishmentTime'].values)
x2 =Cdf.MakeCdfFromList(tcp12_6['ConnectionEstablishmentTime'].values)

# %%
print_percentiles(x1, 'Q050')
print_percentiles(x2, 'tcp12')
print_percentiles(x3, 'Q046')
print_percentiles(x4, 'tcp13')
#print_percentiles(x5, 'Q098')
print_percentiles(x6, 'IETF h3-24')
print_percentiles(x, 'Q043')
# Out:
# -----------------------------
#
# percentile values distribution for Q050
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-621-d1df95b80abf> in <module>
# ----> 1 print_percentiles(x1, 'Q050')
#       2 print_percentiles(x2, 'tcp12')
#       3 print_percentiles(x3, 'Q046')
#       4 print_percentiles(x4, 'tcp13')
#       5 #print_percentiles(x5, 'Q098')
#
# <ipython-input-541-8fe73dac99f9> in print_percentiles(c, name)
#       6         print('percentile values distribution for %s\n' % name)
#       7
# ----> 8         print('20th Percentile:%f\n' % c.Percentile(20))
#       9         print('25th Percentile:%f\n' % c.Percentile(25))
#      10         print('40th Percentile:%f\n' % c.Percentile(40))
#
# ~/master-thesis/Cdf.py in Percentile(self, p)
#      92             number value
#      93         """
# ---> 94         return self.Value(p / 100.0)
#      95
#      96     def Random(self):
#
# ~/master-thesis/Cdf.py in Value(self, p)
#      78         if p == 1: return self.xs[-1]
#      79         index = bisect.bisect(self.ps, p)
# ---> 80         if p == self.ps[index-1]:
#      81             return self.xs[index-1]
#      82         else:
#
# IndexError: list index out of range

# %%
write_percentiles('Q050.csv', x1)
write_percentiles('tcp12.csv', x2)
write_percentiles('Q046.csv', x3)
write_percentiles('tcp13.csv', x4)
#write_percentiles('Q098.csv', x5)
write_percentiles('IETFh3-34.csv', x6)
write_percentiles('Q043.csv', x)

# %%
fig = plt.figure(figsize = (10,3))
plt.rcParams['font.size'] = 12
ax = plt.gca()
yticks = np.arange(0,1.1,0.2)

#Q043
plt.plot(x.xs, x.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'orange')
#Q050
plt.plot(x1.xs, x1.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'red')
#Q046
plt.plot(x3.xs, x3.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'cyan')
#Q098
#plt.plot(x5.xs, x5.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'blue')
#IETF h3-24
plt.plot(x6.xs, x6.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color='yellow')
#TLS1.2
plt.plot(x2.xs, x2.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'green')
#TLS1.3
plt.plot(x4.xs, x4.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'black')


ax = fig.axes[0]
ax.grid(False)
ax.set_yticks(yticks)
#ax.set_ylim([0,1.05])
ax.set_xlim([0.3,34000])
ax.set_xscale('log')
ax.set_xlabel('latency (x-axis is cut)', fontsize=12)
ax.set_ylabel('CDF', fontsize=12)

plt.legend(['Q043', 'Q050', 'Q046', 'IETF h3-24', 'TLS1.2', 'TLS1.3'], fontsize=11, loc='best')

ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.yaxis.set_ticks_position('left')
ax.xaxis.set_ticks_position('bottom')
ax.spines['bottom'].set_position(('axes', -0.05))
ax.spines['left'].set_position(('axes', -0.05))

ax3 = ax.twinx()
ax3.spines['right'].set_color('none')
ax3.spines['top'].set_color('none')
ax3.spines['left'].set_color('none')
ax3.spines['bottom'].set_color('none')
ax3.yaxis.set_ticks_position('none')
##ax3.set_ylabel('[\'11th Oct - \'11th Nov')
plt.setp(ax3.get_yticklabels(), visible=False)

plt.title('Handshake Times with IPv6', fontsize=12, y=1.05)
plt.savefig('./AWS/N.California/handshake_times_ipv6.png', format='png', bbox_inches='tight')

# %%
#IPv4 and IPv6 comparison

# %%
x = Cdf.MakeCdfFromList(quic43['ConnectionEstablishmentTime'].values)
x1 =Cdf.MakeCdfFromList(quic50['ConnectionEstablishmentTime'].values)
x3 = Cdf.MakeCdfFromList(quic46['ConnectionEstablishmentTime'].values)
#x5 = Cdf.MakeCdfFromList(quic98['ConnectionEstablishmentTime'].values)
x6 = Cdf.MakeCdfFromList(quicID24['ConnectionEstablishmentTime'].values)
x4 = Cdf.MakeCdfFromList(tcp13['ConnectionEstablishmentTime'].values)
x2 =Cdf.MakeCdfFromList(tcp12['ConnectionEstablishmentTime'].values)

x_6 = Cdf.MakeCdfFromList(quic43_6['ConnectionEstablishmentTime'].values)
x1_6 =Cdf.MakeCdfFromList(quic50_6['ConnectionEstablishmentTime'].values)
x3_6 = Cdf.MakeCdfFromList(quic46_6['ConnectionEstablishmentTime'].values)
#x5 = Cdf.MakeCdfFromList(quic98_6['ConnectionEstablishmentTime'].values)
x6_6 = Cdf.MakeCdfFromList(quicID24_6['ConnectionEstablishmentTime'].values)
x4_6 = Cdf.MakeCdfFromList(tcp13_6['ConnectionEstablishmentTime'].values)
x2_6 =Cdf.MakeCdfFromList(tcp12_6['ConnectionEstablishmentTime'].values)

# %%
print_percentiles(x1, 'Q050')
print_percentiles(x2, 'tcp12')
print_percentiles(x3, 'Q046')
print_percentiles(x4, 'tcp13')
#print_percentiles(x5, 'Q098')
print_percentiles(x6, 'IETF h3-24')
print_percentiles(x, 'Q043')

print_percentiles(x1_6, 'Q050')
print_percentiles(x2_6, 'tcp12')
print_percentiles(x3_6, 'Q046')
print_percentiles(x4, 'tcp13')
#print_percentiles(x5, 'Q098')
print_percentiles(x6, 'IETF h3-24')
print_percentiles(x_6, 'Q043')
# Out:
# -----------------------------
#
# percentile values distribution for Q050
#
# 20th Percentile:42.438000
#
# 25th Percentile:42.835000
#
# 40th Percentile:78.217000
#
# 50th Percentile:79.493000
#
# 60th Percentile:80.670000
#
# 75th Percentile:83.358000
#
# 80th Percentile:85.124000
#
# 90th Percentile:286.803000
#
# 99th Percentile:733.971000
#
# -----------------------------
#
# -----------------------------
#
# percentile values distribution for tcp12
#
# 20th Percentile:55.794000
#
# 25th Percentile:64.892000
#
# 40th Percentile:167.340000
#
# 50th Percentile:1525.993000
#
# 60th Percentile:5520.474000
#
# 75th Percentile:9056.842000
#
# 80th Percentile:10280.931000
#
# 90th Percentile:12837.291000
#
# 99th Percentile:18059.642000
#
# -----------------------------
#
# -----------------------------
#
# percentile values distribution for Q046
#
# 20th Percentile:42.409000
#
# 25th Percentile:42.808000
#
# 40th Percentile:78.247000
#
# 50th Percentile:79.529000
#
# 60th Percentile:80.718000
#
# 75th Percentile:83.566000
#
# 80th Percentile:85.364000
#
# 90th Percentile:307.343000
#
# 99th Percentile:724.009000
#
# -----------------------------
#
# -----------------------------
#
# percentile values distribution for tcp13
#
# 20th Percentile:217.368000
#
# 25th Percentile:379.534000
#
# 40th Percentile:4999.173000
#
# 50th Percentile:7775.231000
#
# 60th Percentile:9998.518000
#
# 75th Percentile:13582.945000
#
# 80th Percentile:14890.388000
#
# 90th Percentile:18135.657000
#
# 99th Percentile:27000.854000
#
# -----------------------------
#
# -----------------------------
#
# percentile values distribution for IETF h3-24
#
# 20th Percentile:124.461000
#
# 25th Percentile:152.392000
#
# 40th Percentile:193.934000
#
# 50th Percentile:206.289000
#
# 60th Percentile:215.555000
#
# 75th Percentile:299.686000
#
# 80th Percentile:325.483000
#
# 90th Percentile:365.823000
#
# 99th Percentile:830.939000
#
# -----------------------------
#
# -----------------------------
#
# percentile values distribution for Q043
#
# 20th Percentile:42.453000
#
# 25th Percentile:42.892000
#
# 40th Percentile:78.775000
#
# 50th Percentile:80.592000
#
# 60th Percentile:80.921000
#
# 75th Percentile:84.395000
#
# 80th Percentile:85.279000
#
# 90th Percentile:323.865000
#
# 99th Percentile:694.457000
#
# -----------------------------
#
# -----------------------------
#
# percentile values distribution for Q050
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-626-e4ed4ce09ca5> in <module>
#       7 print_percentiles(x, 'Q043')
#       8
# ----> 9 print_percentiles(x1_6, 'Q050')
#      10 print_percentiles(x2_6, 'tcp12')
#      11 print_percentiles(x3_6, 'Q046')
#
# <ipython-input-541-8fe73dac99f9> in print_percentiles(c, name)
#       6         print('percentile values distribution for %s\n' % name)
#       7
# ----> 8         print('20th Percentile:%f\n' % c.Percentile(20))
#       9         print('25th Percentile:%f\n' % c.Percentile(25))
#      10         print('40th Percentile:%f\n' % c.Percentile(40))
#
# ~/master-thesis/Cdf.py in Percentile(self, p)
#      92             number value
#      93         """
# ---> 94         return self.Value(p / 100.0)
#      95
#      96     def Random(self):
#
# ~/master-thesis/Cdf.py in Value(self, p)
#      78         if p == 1: return self.xs[-1]
#      79         index = bisect.bisect(self.ps, p)
# ---> 80         if p == self.ps[index-1]:
#      81             return self.xs[index-1]
#      82         else:
#
# IndexError: list index out of range

# %%
write_percentiles('Q050.csv', x1)
write_percentiles('tcp12.csv', x2)
write_percentiles('Q046.csv', x3)
write_percentiles('tcp13.csv', x4)
#write_percentiles('Q098.csv', x5)
write_percentiles('IETFh3-24', x6)
write_percentiles('Q043.csv', x)

write_percentiles('Q050.csv', x1_6)
write_percentiles('tcp12.csv', x2_6)
write_percentiles('Q046.csv', x3_6)
write_percentiles('tcp13.csv', x4_6)
#write_percentiles('Q098.csv', x5)
write_percentiles('IETFh3-34.csv', x6_6)
write_percentiles('Q043.csv', x_6)

# %%
fig = plt.figure(figsize = (10,3))
plt.rcParams['font.size'] = 12
ax = plt.gca()
yticks = np.arange(0,1.1,0.2)

#Q043
plt.plot(x.xs, x.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'orange')
#Q050
plt.plot(x1.xs, x1.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'red')
#Q046
plt.plot(x3.xs, x3.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'green')
#Q098
#plt.plot(x5.xs, x5.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'blue')
#IETF h3-24
plt.plot(x6.xs, x6.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color='yellow')
#TLS1.2
#plt.plot(x2.xs, x2.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'cyan')
#TLS1.3
#plt.plot(x4.xs, x4.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'black')

#Q043
plt.plot(x_6.xs, x_6.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'pink')
#Q050
plt.plot(x1_6.xs, x1_6.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'cyan')
#Q046
plt.plot(x3_6.xs, x3_6.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'blue')
#Q098
#plt.plot(x5.xs, x5.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'blue')
#IETF h3-24
plt.plot(x6_6.xs, x6_6.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color='black')
#TLS1.2
#plt.plot(x2_6.xs, x2_6.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'gray')
#TLS1.3
#plt.plot(x4_6.xs, x4_6.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'olive')


ax = fig.axes[0]
ax.grid(False)
ax.set_yticks(yticks)
#ax.set_ylim([0,1.05])
ax.set_xlim([0.01, 58000])
ax.set_xscale('log')
ax.set_xlabel('latency (x-axis is cut)', fontsize=12)
ax.set_ylabel('CDF', fontsize=12)

plt.legend(['Q043', 'Q050', 'Q046', 'IETF h3-24', 'Q043_6', 'Q050_6', 'Q046_6', 'IETF h3-24_6'], fontsize=11, loc='best')

ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.yaxis.set_ticks_position('left')
ax.xaxis.set_ticks_position('bottom')
ax.spines['bottom'].set_position(('axes', -0.05))
ax.spines['left'].set_position(('axes', -0.05))

ax3 = ax.twinx()
ax3.spines['right'].set_color('none')
ax3.spines['top'].set_color('none')
ax3.spines['left'].set_color('none')
ax3.spines['bottom'].set_color('none')
ax3.yaxis.set_ticks_position('none')
##ax3.set_ylabel('[\'11th Oct - \'11th Nov')
plt.setp(ax3.get_yticklabels(), visible=False)

plt.title('Handshake Times with IPv4 and IPv6 Log', fontsize=12, y=1.05)
plt.savefig('./AWS/N.California/handshake_times_ipv4_ipv6_log.png', format='png', bbox_inches='tight')

# %%
fig = plt.figure(figsize = (10,3))
plt.rcParams['font.size'] = 12
ax = plt.gca()
yticks = np.arange(0,1.1,0.2)

#Q043
plt.plot(x.xs, x.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'orange')
#Q050
plt.plot(x1.xs, x1.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'red')
#Q046
plt.plot(x3.xs, x3.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'green')
#Q098
#plt.plot(x5.xs, x5.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'blue')
#IETF h3-24
plt.plot(x6.xs, x6.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color='yellow')
#TLS1.2
#plt.plot(x2.xs, x2.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'cyan')
#TLS1.3
#plt.plot(x4.xs, x4.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'black')

#Q043
plt.plot(x_6.xs, x_6.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'pink')
#Q050
plt.plot(x1_6.xs, x1_6.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'cyan')
#Q046
plt.plot(x3_6.xs, x3_6.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'blue')
#Q098
#plt.plot(x5.xs, x5.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'blue')
#IETF h3-24
plt.plot(x6_6.xs, x6_6.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color='black')
#TLS1.2
#plt.plot(x2_6.xs, x2_6.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'gray')
#TLS1.3
#plt.plot(x4_6.xs, x4_6.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'olive')


ax = fig.axes[0]
ax.grid(False)
ax.set_yticks(yticks)
#ax.set_ylim([0,1.05])
ax.set_xlim([-200, 1200])
ax.set_xscale('linear')
ax.set_xlabel('latency (x-axis is cut)', fontsize=12)
ax.set_ylabel('CDF', fontsize=12)

plt.legend(['Q043', 'Q050', 'Q046', 'IETF h3-24', 'Q043_6', 'Q050_6', 'Q046_6', 'IETF h3-24_6'], fontsize=11, loc='best')

ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.yaxis.set_ticks_position('left')
ax.xaxis.set_ticks_position('bottom')
ax.spines['bottom'].set_position(('axes', -0.05))
ax.spines['left'].set_position(('axes', -0.05))

ax3 = ax.twinx()
ax3.spines['right'].set_color('none')
ax3.spines['top'].set_color('none')
ax3.spines['left'].set_color('none')
ax3.spines['bottom'].set_color('none')
ax3.yaxis.set_ticks_position('none')
##ax3.set_ylabel('[\'11th Oct - \'11th Nov')
plt.setp(ax3.get_yticklabels(), visible=False)

plt.title('Handshake Times with IPv4 and IPv6 Linear', fontsize=12, y=1.05)
plt.savefig('./AWS/N.California/handshake_times_ipv4_ipv6_linear.png', format='png', bbox_inches='tight')

# %%
fig = plt.figure(figsize = (10,3))
plt.rcParams['font.size'] = 12
ax = plt.gca()
yticks = np.arange(0,1.1,0.2)

#Q043
plt.plot(x.xs, x.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'orange')
#Q050
plt.plot(x1.xs, x1.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'red')
#Q046
plt.plot(x3.xs, x3.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'green')
#Q098
#plt.plot(x5.xs, x5.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'blue')
#IETF h3-24
plt.plot(x6.xs, x6.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color='yellow')
#TLS1.2
#plt.plot(x2.xs, x2.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'cyan')
#TLS1.3
#plt.plot(x4.xs, x4.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'black')

#Q043
plt.plot(x_6.xs, x_6.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'pink')
#Q050
plt.plot(x1_6.xs, x1_6.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'cyan')
#Q046
plt.plot(x3_6.xs, x3_6.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'blue')
#Q098
#plt.plot(x5.xs, x5.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'blue')
#IETF h3-24
plt.plot(x6_6.xs, x6_6.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color='black')
#TLS1.2
#plt.plot(x2_6.xs, x2_6.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'gray')
#TLS1.3
#plt.plot(x4_6.xs, x4_6.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'olive')


ax = fig.axes[0]
ax.grid(False)
ax.set_yticks(yticks)
#ax.set_ylim([0,1.05])
ax.set_xlim([30, 40])
ax.set_xscale('linear')
ax.set_xlabel('latency (x-axis is cut)', fontsize=12)
ax.set_ylabel('CDF', fontsize=12)

plt.legend(['Q043', 'Q050', 'Q046', 'IETF h3-24', 'Q043_6', 'Q050_6', 'Q046_6', 'IETF h3-24_6'], fontsize=11, loc='best')

ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.yaxis.set_ticks_position('left')
ax.xaxis.set_ticks_position('bottom')
ax.spines['bottom'].set_position(('axes', -0.05))
ax.spines['left'].set_position(('axes', -0.05))

ax3 = ax.twinx()
ax3.spines['right'].set_color('none')
ax3.spines['top'].set_color('none')
ax3.spines['left'].set_color('none')
ax3.spines['bottom'].set_color('none')
ax3.yaxis.set_ticks_position('none')
##ax3.set_ylabel('[\'11th Oct - \'11th Nov')
plt.setp(ax3.get_yticklabels(), visible=False)

plt.title('Handshake Times with IPv4 and IPv6 Linear Zoomed', fontsize=12, y=1.05)
plt.savefig('./AWS/N.California/handshake_times_ipv4_ipv6_zoomed_linear.png', format='png', bbox_inches='tight')

# %%
fig = plt.figure(figsize = (10,3))
plt.rcParams['font.size'] = 12
ax = plt.gca()
yticks = np.arange(0,1.1,0.2)

#Q043
plt.plot(x.xs, x.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'orange')
#Q050
plt.plot(x1.xs, x1.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'red')
#Q046
plt.plot(x3.xs, x3.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'green')
#Q098
#plt.plot(x5.xs, x5.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'blue')
#IETF h3-24
plt.plot(x6.xs, x6.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color='yellow')
#TLS1.2
#plt.plot(x2.xs, x2.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'cyan')
#TLS1.3
#plt.plot(x4.xs, x4.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'black')

#Q043
plt.plot(x_6.xs, x_6.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'pink')
#Q050
plt.plot(x1_6.xs, x1_6.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'cyan')
#Q046
plt.plot(x3_6.xs, x3_6.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'blue')
#Q098
#plt.plot(x5.xs, x5.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'blue')
#IETF h3-24
plt.plot(x6_6.xs, x6_6.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color='black')
#TLS1.2
#plt.plot(x2_6.xs, x2_6.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'gray')
#TLS1.3
#plt.plot(x4_6.xs, x4_6.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'olive')


ax = fig.axes[0]
ax.grid(False)
ax.set_yticks(yticks)
#ax.set_ylim([0,1.05])
ax.set_xlim([30, 38])
ax.set_xscale('log')
ax.set_xlabel('latency (x-axis is cut)', fontsize=12)
ax.set_ylabel('CDF', fontsize=12)

plt.legend(['Q043', 'Q050', 'Q046', 'IETF h3-24', 'Q043_6', 'Q050_6', 'Q046_6', 'IETF h3-24_6'], fontsize=11, loc='best')

ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.yaxis.set_ticks_position('left')
ax.xaxis.set_ticks_position('bottom')
ax.spines['bottom'].set_position(('axes', -0.05))
ax.spines['left'].set_position(('axes', -0.05))

ax3 = ax.twinx()
ax3.spines['right'].set_color('none')
ax3.spines['top'].set_color('none')
ax3.spines['left'].set_color('none')
ax3.spines['bottom'].set_color('none')
ax3.yaxis.set_ticks_position('none')
##ax3.set_ylabel('[\'11th Oct - \'11th Nov')
plt.setp(ax3.get_yticklabels(), visible=False)

plt.title('Handshake Times with IPv4 and IPv6 Log Zoomed', fontsize=12, y=1.05)
plt.savefig('./AWS/N.California/handshake_times_ipv4_ipv6_zoomed_log.png', format='png', bbox_inches='tight')

# %%
x = Cdf.MakeCdfFromList(quic43['TTFB'].values)
x1 =Cdf.MakeCdfFromList(quic50['TTFB'].values)
x3 = Cdf.MakeCdfFromList(quic46['TTFB'].values)
#x5 = Cdf.MakeCdfFromList(quic98['TTFB'].values)
x6 = Cdf.MakeCdfFromList(quicID24['TTFB'].values)
x4 = Cdf.MakeCdfFromList(tcp13['TTFB'].values)
x2 =Cdf.MakeCdfFromList(tcp12['TTFB'].values)

# %%
write_percentiles('Q050.csv', x1)
write_percentiles('tcp12.csv', x2)
write_percentiles('Q046.csv', x3)
write_percentiles('tcp13.csv', x4)
#write_percentiles('Q098.csv', x5)
write_percentiles('IETFh3-24.csv', x6)
write_percentiles('Q043.csv', x)

# %%
print_percentiles(x1, 'Q050')
print_percentiles(x2, 'tcp12')
print_percentiles(x3, 'Q046')
print_percentiles(x4, 'tcp13')
#print_percentiles(x5, 'Q098')
print_percentiles(x6, 'IETFh3-24')
print_percentiles(x, 'Q043')
# Out:
# -----------------------------
#
# percentile values distribution for Q050
#
# 20th Percentile:122.914000
#
# 25th Percentile:140.325000
#
# 40th Percentile:166.020000
#
# 50th Percentile:200.651000
#
# 60th Percentile:206.492000
#
# 75th Percentile:247.494000
#
# 80th Percentile:287.117000
#
# 90th Percentile:490.307000
#
# 99th Percentile:898.244000
#
# -----------------------------
#
# -----------------------------
#
# percentile values distribution for tcp12
#
# 20th Percentile:286.455000
#
# 25th Percentile:392.252000
#
# 40th Percentile:829.195000
#
# 50th Percentile:2100.415000
#
# 60th Percentile:5931.244000
#
# 75th Percentile:9469.089000
#
# 80th Percentile:10711.256000
#
# 90th Percentile:13257.333000
#
# 99th Percentile:18786.857000
#
# -----------------------------
#
# -----------------------------
#
# percentile values distribution for Q046
#
# 20th Percentile:123.408000
#
# 25th Percentile:141.764000
#
# 40th Percentile:166.301000
#
# 50th Percentile:201.033000
#
# 60th Percentile:206.703000
#
# 75th Percentile:256.228000
#
# 80th Percentile:288.229000
#
# 90th Percentile:508.568000
#
# 99th Percentile:899.164000
#
# -----------------------------
#
# -----------------------------
#
# percentile values distribution for tcp13
#
# 20th Percentile:343.189000
#
# 25th Percentile:556.290000
#
# 40th Percentile:5203.195000
#
# 50th Percentile:7857.504000
#
# 60th Percentile:10144.065000
#
# 75th Percentile:13715.483000
#
# 80th Percentile:15058.499000
#
# 90th Percentile:18377.119000
#
# 99th Percentile:27122.500000
#
# -----------------------------
#
# -----------------------------
#
# percentile values distribution for IETFh3-24
#
# 20th Percentile:287.476000
#
# 25th Percentile:321.123000
#
# 40th Percentile:376.218000
#
# 50th Percentile:408.714000
#
# 60th Percentile:445.589000
#
# 75th Percentile:493.446000
#
# 80th Percentile:531.177000
#
# 90th Percentile:617.664000
#
# 99th Percentile:902.450000
#
# -----------------------------
#
# -----------------------------
#
# percentile values distribution for Q043
#
# 20th Percentile:132.309000
#
# 25th Percentile:154.849000
#
# 40th Percentile:176.688000
#
# 50th Percentile:202.600000
#
# 60th Percentile:230.315000
#
# 75th Percentile:283.582000
#
# 80th Percentile:325.233000
#
# 90th Percentile:549.804000
#
# 99th Percentile:903.244000
#
# -----------------------------

# %%
fig = plt.figure(figsize = (10,3))
plt.rcParams['font.size'] = 12
ax = plt.gca()
yticks = np.arange(0,1.1,0.2)

#Q043
plt.plot(x.xs, x.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'orange')
#Q050
plt.plot(x1.xs, x1.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'red')
#Q046
plt.plot(x3.xs, x3.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'cyan')
#Q098
#plt.plot(x5.xs, x5.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'blue')
#IETF h3-24
plt.plot(x6.xs, x6.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'yellow')
#TLS1.2
plt.plot(x2.xs, x2.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'green')
#TLS1.3
plt.plot(x4.xs, x4.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'black')


ax = fig.axes[0]
ax.grid(False)
ax.set_yticks(yticks)
#ax.set_ylim([0,1.05])
ax.set_xlim([0.01,58000])
ax.set_xscale('log')
ax.set_xlabel('TTFB', fontsize=12)
ax.set_ylabel('CDF', fontsize=12)

plt.legend(['Q043', 'Q050', 'Q046', 'IETFh3-24', 'TLS1.2', 'TLS1.3'], fontsize=11, loc='best')

ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.yaxis.set_ticks_position('left')
ax.xaxis.set_ticks_position('bottom')
ax.spines['bottom'].set_position(('axes', -0.05))
ax.spines['left'].set_position(('axes', -0.05))

ax3 = ax.twinx()
ax3.spines['right'].set_color('none')
ax3.spines['top'].set_color('none')
ax3.spines['left'].set_color('none')
ax3.spines['bottom'].set_color('none')
ax3.yaxis.set_ticks_position('none')
##ax3.set_ylabel('[\'11th Oct - \'11th Nov')
plt.setp(ax3.get_yticklabels(), visible=False)

plt.title('TTFB with IPv4', fontsize=12, y=1.05)
plt.savefig('./AWS/N.California/TTFB_ipv4.png', format='png', bbox_inches='tight')

# %%
x = Cdf.MakeCdfFromList(quic43_6['TTFB'].values)
x1 =Cdf.MakeCdfFromList(quic50_6['TTFB'].values)
x3 = Cdf.MakeCdfFromList(quic46_6['TTFB'].values)
#x5 = Cdf.MakeCdfFromList(quic98_6['TTFB'].values)
x6 = Cdf.MakeCdfFromList(quicID24_6['TTFB'].values)
x4 = Cdf.MakeCdfFromList(tcp13_6['TTFB'].values)
x2 =Cdf.MakeCdfFromList(tcp12_6['TTFB'].values)

# %%
write_percentiles('Q050.csv', x1)
write_percentiles('tcp12.csv', x2)
write_percentiles('Q046.csv', x3)
write_percentiles('tcp13.csv', x4)
#write_percentiles('Q098.csv', x5)
write_percentiles('IETFh3-24.csv', x6)
write_percentiles('Q043.csv', x)

# %%
print_percentiles(x1, 'Q050')
print_percentiles(x2, 'tcp12')
print_percentiles(x3, 'Q046')
print_percentiles(x4, 'tcp13')
#print_percentiles(x5, 'Q098')
print_percentiles(x6, 'IETFh3-24')
print_percentiles(x, 'Q043')
# Out:
# -----------------------------
#
# percentile values distribution for Q050
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-638-eb5810b9bba0> in <module>
# ----> 1 print_percentiles(x1, 'Q050')
#       2 print_percentiles(x2, 'tcp12')
#       3 print_percentiles(x3, 'Q046')
#       4 print_percentiles(x4, 'tcp13')
#       5 #print_percentiles(x5, 'Q098')
#
# <ipython-input-541-8fe73dac99f9> in print_percentiles(c, name)
#       6         print('percentile values distribution for %s\n' % name)
#       7
# ----> 8         print('20th Percentile:%f\n' % c.Percentile(20))
#       9         print('25th Percentile:%f\n' % c.Percentile(25))
#      10         print('40th Percentile:%f\n' % c.Percentile(40))
#
# ~/master-thesis/Cdf.py in Percentile(self, p)
#      92             number value
#      93         """
# ---> 94         return self.Value(p / 100.0)
#      95
#      96     def Random(self):
#
# ~/master-thesis/Cdf.py in Value(self, p)
#      78         if p == 1: return self.xs[-1]
#      79         index = bisect.bisect(self.ps, p)
# ---> 80         if p == self.ps[index-1]:
#      81             return self.xs[index-1]
#      82         else:
#
# IndexError: list index out of range

# %%
fig = plt.figure(figsize = (10,3))
plt.rcParams['font.size'] = 12
ax = plt.gca()
yticks = np.arange(0,1.1,0.2)

#Q043
plt.plot(x.xs, x.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'orange')
#Q050
plt.plot(x1.xs, x1.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'red')
#Q046
plt.plot(x3.xs, x3.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'cyan')
#Q098
#plt.plot(x5.xs, x5.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'blue')
#IETF h3-24
plt.plot(x6.xs, x6.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'yellow')
#TLS1.2
plt.plot(x2.xs, x2.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'green')
#TLS1.3
plt.plot(x4.xs, x4.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'black')


ax = fig.axes[0]
ax.grid(False)
ax.set_yticks(yticks)
#ax.set_ylim([0,1.05])
#ax.set_xlim([20,1000])
ax.set_xlim([0.01,58000])
ax.set_xscale('log')
ax.set_xlabel('TTFB', fontsize=12)
ax.set_ylabel('CDF', fontsize=12)

plt.legend(['Q043', 'Q050', 'Q046', 'IETF h3-24', 'TLS1.2', 'TLS1.3'], fontsize=11, loc='best')

ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.yaxis.set_ticks_position('left')
ax.xaxis.set_ticks_position('bottom')
ax.spines['bottom'].set_position(('axes', -0.05))
ax.spines['left'].set_position(('axes', -0.05))

ax3 = ax.twinx()
ax3.spines['right'].set_color('none')
ax3.spines['top'].set_color('none')
ax3.spines['left'].set_color('none')
ax3.spines['bottom'].set_color('none')
ax3.yaxis.set_ticks_position('none')
##ax3.set_ylabel('[\'11th Oct - \'11th Nov')
plt.setp(ax3.get_yticklabels(), visible=False)

plt.title('TTFB with IPv6', fontsize=12, y=1.05)
plt.savefig(' ./AWS/N.California/TTFB_ipv6.png', format='png', bbox_inches='tight')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-639-82267bf1d1ba> in <module>
#      49
#      50 plt.title('TTFB with IPv6', fontsize=12, y=1.05)
# ---> 51 plt.savefig(' ./AWS/N.California/TTFB_ipv6.png', format='png', bbox_inches='tight')
#
# ~/py37-venv/lib/python3.7/site-packages/matplotlib/pyplot.py in savefig(*args, **kwargs)
#     721 def savefig(*args, **kwargs):
#     722     fig = gcf()
# --> 723     res = fig.savefig(*args, **kwargs)
#     724     fig.canvas.draw_idle()   # need this if 'transparent=True' to reset colors
#     725     return res
#
# ~/py37-venv/lib/python3.7/site-packages/matplotlib/figure.py in savefig(self, fname, transparent, **kwargs)
#    2201             self.patch.set_visible(frameon)
#    2202
# -> 2203         self.canvas.print_figure(fname, **kwargs)
#    2204
#    2205         if frameon:
#
# ~/py37-venv/lib/python3.7/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, **kwargs)
#    2103                     orientation=orientation,
#    2104                     bbox_inches_restore=_bbox_inches_restore,
# -> 2105                     **kwargs)
#    2106             finally:
#    2107                 if bbox_inches and restore_bbox:
#
# ~/py37-venv/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py in print_png(self, filename_or_obj, metadata, pil_kwargs, *args, **kwargs)
#     533         else:
#     534             renderer = self.get_renderer()
# --> 535             with cbook.open_file_cm(filename_or_obj, "wb") as fh:
#     536                 _png.write_png(renderer._renderer, fh, self.figure.dpi,
#     537                                metadata={**default_metadata, **metadata})
#
# /usr/lib/python3.7/contextlib.py in __enter__(self)
#     110         del self.args, self.kwds, self.func
#     111         try:
# --> 112             return next(self.gen)
#     113         except StopIteration:
#     114             raise RuntimeError("generator didn't yield") from None
#
# ~/py37-venv/lib/python3.7/site-packages/matplotlib/cbook/__init__.py in open_file_cm(path_or_file, mode, encoding)
#     416 def open_file_cm(path_or_file, mode="r", encoding=None):
#     417     r"""Pass through file objects and context-manage `.PathLike`\s."""
# --> 418     fh, opened = to_filehandle(path_or_file, mode, True, encoding)
#     419     if opened:
#     420         with fh:
#
# ~/py37-venv/lib/python3.7/site-packages/matplotlib/cbook/__init__.py in to_filehandle(fname, flag, return_opened, encoding)
#     401             fh = bz2.BZ2File(fname, flag)
#     402         else:
# --> 403             fh = open(fname, flag, encoding=encoding)
#     404         opened = True
#     405     elif hasattr(fname, 'seek'):
#
# FileNotFoundError: [Errno 2] No such file or directory: ' ./AWS/N.California/TTFB_ipv6.png'

# %%
x = Cdf.MakeCdfFromList(quic43['TotalDownloadTime'].values)
x1 =Cdf.MakeCdfFromList(quic50['TotalDownloadTime'].values)
x3 = Cdf.MakeCdfFromList(quic46['TotalDownloadTime'].values)
#x5 = Cdf.MakeCdfFromList(quic98['TotalDownloadTime'].values)
x6 = Cdf.MakeCdfFromList(quicID24['TotalDownloadTime'].values)
x4 = Cdf.MakeCdfFromList(tcp13['TotalDownloadTime'].values)
x2 =Cdf.MakeCdfFromList(tcp12['TotalDownloadTime'].values)

# %%
write_percentiles('Q050.csv', x1)
write_percentiles('tcp12.csv', x2)
write_percentiles('Q046.csv', x3)
write_percentiles('tcp13.csv', x4)
#write_percentiles('Q098.csv', x5)
write_percentiles('IETFh3-24.csv', x6)
write_percentiles('Q043.csv', x)

# %%
print_percentiles(x1, 'Q050')
print_percentiles(x2, 'tcp12')
print_percentiles(x3, 'Q046')
print_percentiles(x4, 'tcp13')
#print_percentiles(x5, 'Q098')
print_percentiles(x6, 'IETFh3-24')
print_percentiles(x, 'Q043')
# Out:
# -----------------------------
#
# percentile values distribution for Q050
#
# 20th Percentile:125.038000
#
# 25th Percentile:145.748000
#
# 40th Percentile:169.269000
#
# 50th Percentile:202.198000
#
# 60th Percentile:223.506000
#
# 75th Percentile:286.289000
#
# 80th Percentile:327.608000
#
# 90th Percentile:536.547000
#
# 99th Percentile:917.451000
#
# -----------------------------
#
# -----------------------------
#
# percentile values distribution for tcp12
#
# 20th Percentile:306.333000
#
# 25th Percentile:409.100000
#
# 40th Percentile:892.177000
#
# 50th Percentile:2213.797000
#
# 60th Percentile:5976.463000
#
# 75th Percentile:9533.508000
#
# 80th Percentile:10774.073000
#
# 90th Percentile:13329.776000
#
# 99th Percentile:18987.983000
#
# -----------------------------
#
# -----------------------------
#
# percentile values distribution for Q046
#
# 20th Percentile:125.355000
#
# 25th Percentile:146.654000
#
# 40th Percentile:171.084000
#
# 50th Percentile:202.417000
#
# 60th Percentile:232.378000
#
# 75th Percentile:287.397000
#
# 80th Percentile:328.253000
#
# 90th Percentile:559.334000
#
# 99th Percentile:922.067000
#
# -----------------------------
#
# -----------------------------
#
# percentile values distribution for tcp13
#
# 20th Percentile:343.240000
#
# 25th Percentile:556.319000
#
# 40th Percentile:5314.765000
#
# 50th Percentile:7857.536000
#
# 60th Percentile:10151.160000
#
# 75th Percentile:13838.750000
#
# 80th Percentile:15118.819000
#
# 90th Percentile:18377.150000
#
# 99th Percentile:27122.529000
#
# -----------------------------
#
# -----------------------------
#
# percentile values distribution for IETFh3-24
#
# 20th Percentile:247.048000
#
# 25th Percentile:312.834000
#
# 40th Percentile:379.272000
#
# 50th Percentile:409.456000
#
# 60th Percentile:481.337000
#
# 75th Percentile:615.876000
#
# 80th Percentile:652.233000
#
# 90th Percentile:762.316000
#
# 99th Percentile:967.269000
#
# -----------------------------
#
# -----------------------------
#
# percentile values distribution for Q043
#
# 20th Percentile:137.755000
#
# 25th Percentile:158.719000
#
# 40th Percentile:183.611000
#
# 50th Percentile:204.328000
#
# 60th Percentile:242.764000
#
# 75th Percentile:310.436000
#
# 80th Percentile:362.586000
#
# 90th Percentile:594.438000
#
# 99th Percentile:927.124000
#
# -----------------------------

# %%
fig = plt.figure(figsize = (10,3))
plt.rcParams['font.size'] = 12
ax = plt.gca()
yticks = np.arange(0,1.1,0.2)

#Q043
plt.plot(x.xs, x.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'orange')
#Q039
plt.plot(x1.xs, x1.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'red')
#Q044
plt.plot(x3.xs, x3.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'cyan')
#Q098
#plt.plot(x5.xs, x5.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'blue')
#IETF h3-24
plt.plot(x6.xs, x6.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'yellow')
#TLS1.2
plt.plot(x2.xs, x2.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'green')
#TLS1.3
plt.plot(x4.xs, x4.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'black')


ax = fig.axes[0]
ax.grid(False)
ax.set_yticks(yticks)
#ax.set_ylim([0,1.05])
#ax.set_xlim([20,1000])
ax.set_xlim([0.01,58000])
ax.set_xscale('log')
ax.set_xlabel('TotalDownloadTime', fontsize=12)
ax.set_ylabel('CDF', fontsize=12)

plt.legend(['Q043', 'Q050', 'Q046', 'IETF h3-24', 'TLS1.2', 'TLS1.3'], fontsize=11, loc='best')

ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.yaxis.set_ticks_position('left')
ax.xaxis.set_ticks_position('bottom')
ax.spines['bottom'].set_position(('axes', -0.05))
ax.spines['left'].set_position(('axes', -0.05))

ax3 = ax.twinx()
ax3.spines['right'].set_color('none')
ax3.spines['top'].set_color('none')
ax3.spines['left'].set_color('none')
ax3.spines['bottom'].set_color('none')
ax3.yaxis.set_ticks_position('none')
##ax3.set_ylabel('[\'11th Oct - \'11th Nov')
plt.setp(ax3.get_yticklabels(), visible=False)

plt.title('TotalDownloadTime with IPv4', fontsize=12, y=1.05)
plt.savefig('./AWS/N.California/TotalDownloadTime_ipv4.png', format='png', bbox_inches='tight')

# %%
x = Cdf.MakeCdfFromList(quic43_6['TotalDownloadTime'].values)
x1 =Cdf.MakeCdfFromList(quic50_6['TotalDownloadTime'].values)
x3 = Cdf.MakeCdfFromList(quic46_6['TotalDownloadTime'].values)
#x5 = Cdf.MakeCdfFromList(quic98_6['TotalDownloadTime'].values)
x6 = Cdf.MakeCdfFromList(quicID24_6['TotalDownloadTime'].values)
x4 = Cdf.MakeCdfFromList(tcp13_6['TotalDownloadTime'].values)
x2 =Cdf.MakeCdfFromList(tcp12_6['TotalDownloadTime'].values)

# %%
write_percentiles('Q050.csv', x1)
write_percentiles('tcp12.csv', x2)
write_percentiles('Q046.csv', x3)
write_percentiles('tcp13.csv', x4)
#write_percentiles('Q098.csv', x5)
write_percentiles('IETFh3-24.csv', x6)
write_percentiles('Q043.csv', x)

# %%
print_percentiles(x1, 'Q050')
print_percentiles(x2, 'tcp12')
print_percentiles(x3, 'Q046')
print_percentiles(x4, 'tcp13')
#print_percentiles(x5, 'Q098')
print_percentiles(x6, 'IETFh3-24')
print_percentiles(x, 'Q043')
# Out:
# -----------------------------
#
# percentile values distribution for Q050
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-647-eb5810b9bba0> in <module>
# ----> 1 print_percentiles(x1, 'Q050')
#       2 print_percentiles(x2, 'tcp12')
#       3 print_percentiles(x3, 'Q046')
#       4 print_percentiles(x4, 'tcp13')
#       5 #print_percentiles(x5, 'Q098')
#
# <ipython-input-541-8fe73dac99f9> in print_percentiles(c, name)
#       6         print('percentile values distribution for %s\n' % name)
#       7
# ----> 8         print('20th Percentile:%f\n' % c.Percentile(20))
#       9         print('25th Percentile:%f\n' % c.Percentile(25))
#      10         print('40th Percentile:%f\n' % c.Percentile(40))
#
# ~/master-thesis/Cdf.py in Percentile(self, p)
#      92             number value
#      93         """
# ---> 94         return self.Value(p / 100.0)
#      95
#      96     def Random(self):
#
# ~/master-thesis/Cdf.py in Value(self, p)
#      78         if p == 1: return self.xs[-1]
#      79         index = bisect.bisect(self.ps, p)
# ---> 80         if p == self.ps[index-1]:
#      81             return self.xs[index-1]
#      82         else:
#
# IndexError: list index out of range

# %%
fig = plt.figure(figsize = (10,3))
plt.rcParams['font.size'] = 12
ax = plt.gca()
yticks = np.arange(0,1.1,0.2)

#Q043
plt.plot(x.xs, x.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'orange')
#Q050
plt.plot(x1.xs, x1.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'red')
#Q046
plt.plot(x3.xs, x3.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'cyan')
#Q098
#plt.plot(x5.xs, x5.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'blue')
#IETF h3-24
plt.plot(x6.xs, x6.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'yellow')
#TLS1.2
plt.plot(x2.xs, x2.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'green')
#TLS1.3
plt.plot(x4.xs, x4.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'black')


ax = fig.axes[0]
ax.grid(False)
ax.set_yticks(yticks)
ax.set_ylim([0,1.05])
#ax.set_xlim([20,1000])
ax.set_xlim([0.01,58000])
ax.set_xscale('log')
ax.set_xlabel('TotalDownloadTime', fontsize=12)
ax.set_ylabel('CDF', fontsize=12)

plt.legend(['Q043', 'Q050', 'Q046', 'IETF h3-24', 'TLS1.2', 'TLS1.3'], fontsize=11, loc='best')

ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.yaxis.set_ticks_position('left')
ax.xaxis.set_ticks_position('bottom')
ax.spines['bottom'].set_position(('axes', -0.05))
ax.spines['left'].set_position(('axes', -0.05))

ax3 = ax.twinx()
ax3.spines['right'].set_color('none')
ax3.spines['top'].set_color('none')
ax3.spines['left'].set_color('none')
ax3.spines['bottom'].set_color('none')
ax3.yaxis.set_ticks_position('none')
#ax3.set_ylabel('[\'11th Oct - \'11th Nov')
plt.setp(ax3.get_yticklabels(), visible=False)

plt.title('TotalDownloadTime with IPv6', fontsize=12, y=1.05)
plt.savefig('./AWS/N.California/TotalDownloadTime_ipv6.png', format='png', bbox_inches='tight')
