# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import time
import datetime
import filterbyip as fbi
import Cdf
import Pmf

# %%
# %autosave 0
# Out:
# Autosave disabled

# %%
import warnings
warnings.filterwarnings('ignore')

# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from IPython.core.display import HTML
css = open('style-table.css').read() + open('style-notebook.css').read()
HTML('<style>{}</style>'.format(css))
# Out:
# <style>body {
#     margin: 0;
#     font-family: Helvetica;
# }
# table.dataframe {
#     border-collapse: collapse;
#     border: none;
# }
# table.dataframe tr {
#     border: none;
# }
# table.dataframe td, table.dataframe th {
#     margin: 0;
#     border: 1px solid white;
#     padding-left: 0.25em;
#     padding-right: 0.25em;
# }
# table.dataframe th:not(:empty) {
#     background-color: #fec;
#     text-align: left;
#     font-weight: normal;
# }
# table.dataframe tr:nth-child(2) th:empty {
#     border-left: none;
#     border-right: 1px dashed #888;
# }
# table.dataframe td {
#     border: 2px solid #ccf;
#     background-color: #f4f4ff;
# }
# h3 {
#     color: white;
#     background-color: black;
#     padding: 0.5em;
# }
#
# .CodeMirror {
#     font-family: 'Consolas';
# }
#
# div.cell.code_cell {
#     font-family: 'Consolas';
# }
#
# div.output_area pre {
#     font-family: 'Consolas';
# }
# </style>

# %%
#change 
tcp_tls_data = "./AWS_results/London/data/output_curl_gdrive.csv"
quic_data = "./AWS_results/London/data/output_quic_gdrive.csv"
gdrive = "./data2020/gdrive_id.csv"

# %%
scol_names = ['TimeOfMeasurement', 'Url', 'Ip', 'Port', 'DnsLookupTime', 'TCPHandshakeTime', 'ConnectionEstablishmentTime', 'TTFB', 'TotalDownloadTime', 'HttpResponse', 'HTTPVersion', 'Protocol']
tcol_names = ['TimeOfMeasurement', 'Url', 'Path', 'Ip', 'Port', 'DNSTime', 'ConnectionEstablishmentTime', 'TTFB', 'TotalDownloadTime', 'HttpResponse', 'Protocol']
g_names = ['size', 'id']

# %%
t = pd.read_csv(quic_data, ';', names=tcol_names, header=None)
s = pd.read_csv(tcp_tls_data, ';', names=scol_names, header=None)
gd = pd.read_csv(gdrive, ',', names=g_names, header=None)

# %%
t = t.dropna()
s=s.dropna()
s['TTFB']=s['TTFB']-s['DnsLookupTime']
s['TotalDownloadTime']=s['TotalDownloadTime']-s['DnsLookupTime']

# %%
import re
def extract_id(path):
    id = re.search('\*\/(.*)\?', path)
    return id.group(1)

# %%
t['id'] = t['Path'].apply(extract_id)

# %%
import re
def substitute(string):
    replaced = string
    if re.search('K', string):
        replaced = re.sub('K','', string)
    if re.search('M', string):
        replaced = re.sub('M','000', string)
    if re.search('G', string):
        replaced = re.sub('G','000000', string)
    return replaced

# %%
gd['size'] = gd['size'].apply(substitute)

# %%
s['id'] = s['Url'].apply(extract_id)

# %%
t['Url'] = t['Url'] + t['Path']

# %%
t = t.join(gd.set_index('id'), on='id', rsuffix='_right')

# %%
s = s.join(gd.set_index('id'), on='id', rsuffix='_right')

# %%
t['size'] = t['size'].astype(int)
s['size'] = s['size'].astype(int)
t['TotalDownloadTime'] = t['TotalDownloadTime'].astype(float)
s['TotalDownloadTime'] = s['TotalDownloadTime'].astype(float)

# %%
t['Throughput'] = (t['size']/t['TotalDownloadTime'])

# %%
s['Throughput'] = (s['size']/s['TotalDownloadTime'])

# %%
t.head()
# Out:
#    TimeOfMeasurement                                                Url  \
# 0       1.589702e+09  doc-10-4c-docs.googleusercontent.com/docs/secu...
# 1       1.589702e+09  doc-10-4c-docs.googleusercontent.com/docs/secu...
# 2       1.589702e+09  doc-10-4c-docs.googleusercontent.com/docs/secu...
# 8       1.589702e+09  doc-0g-4c-docs.googleusercontent.com/docs/secu...
# 9       1.589702e+09  doc-0g-4c-docs.googleusercontent.com/docs/secu...
#
#                                                 Path             Ip Port  \
# 0  /docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp...  216.58.210.33  443
# 1  /docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp...  216.58.210.33  443
# 2  /docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp...  216.58.210.33  443
# 8  /docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp...  216.58.210.33  443
# 9  /docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp...  216.58.210.33  443
#
#    DNSTime  ConnectionEstablishmentTime     TTFB  TotalDownloadTime  \
# 0   41.763                       57.033  166.229            166.335
# 1    0.855                       75.798  203.659            203.737
# 2    0.779                       80.838  200.621            200.697
# 8  165.786                       78.124  206.239            206.307
# 9   39.188                       81.559  203.815            203.870
#
#    HttpResponse Protocol                                 id  size  Throughput
# 0         403.0     Q043  1C45gZCBtJHnjNACQIagfJ2fTRKQaZ9k6     1    0.006012
# 1         403.0     Q046  1C45gZCBtJHnjNACQIagfJ2fTRKQaZ9k6     1    0.004908
# 2         403.0     Q050  1C45gZCBtJHnjNACQIagfJ2fTRKQaZ9k6     1    0.004983
# 8         403.0     Q043  1yv4XxH7R74il-bxBS5Mz8Oiw6W7vwUFM     2    0.009694
# 9         403.0     Q046  1yv4XxH7R74il-bxBS5Mz8Oiw6W7vwUFM     2    0.009810

# %%
t.tail()
# Out:
#        TimeOfMeasurement                                                Url  \
# 20905       1.589986e+09  doc-0s-4c-docs.googleusercontent.com/docs/secu...
# 20906       1.589986e+09  doc-0s-4c-docs.googleusercontent.com/docs/secu...
# 20912       1.589986e+09  doc-0g-4c-docs.googleusercontent.com/docs/secu...
# 20913       1.589986e+09  doc-0g-4c-docs.googleusercontent.com/docs/secu...
# 20914       1.589986e+09  doc-0g-4c-docs.googleusercontent.com/docs/secu...
#
#                                                     Path             Ip Port  \
# 20905  /docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp...  216.58.204.65  443
# 20906  /docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp...  216.58.204.65  443
# 20912  /docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp...   216.58.204.1  443
# 20913  /docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp...   216.58.204.1  443
# 20914  /docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp...   216.58.204.1  443
#
#        DNSTime  ConnectionEstablishmentTime     TTFB  TotalDownloadTime  \
# 20905   79.199                      124.547  246.191            246.266
# 20906  160.219                       85.151  206.922            206.999
# 20912  124.587                      925.512   47.261             47.325
# 20913    1.739                       78.399  199.863            199.926
# 20914   39.001                       81.507  242.383            242.470
#
#        HttpResponse Protocol                                 id  size  \
# 20905         403.0     Q046  1yaWxao4WnEPwFSifCvpiMNTqnXSinoV3    50
# 20906         403.0     Q050  1yaWxao4WnEPwFSifCvpiMNTqnXSinoV3    50
# 20912         403.0     Q043  1wPfOSKeAVd0KPCIYKDPhC9b4SOwwl1Lc   100
# 20913         403.0     Q046  1wPfOSKeAVd0KPCIYKDPhC9b4SOwwl1Lc   100
# 20914         403.0     Q050  1wPfOSKeAVd0KPCIYKDPhC9b4SOwwl1Lc   100
#
#        Throughput
# 20905    0.203032
# 20906    0.241547
# 20912    2.113048
# 20913    0.500185
# 20914    0.412422

# %%
s.head()
# Out:
#    TimeOfMeasurement                                                Url  \
# 0         1589702407  doc-10-4c-docs.googleusercontent.com/docs/secu...
# 1         1589702414  doc-10-4c-docs.googleusercontent.com/docs/secu...
# 2         1589702423  doc-0g-4c-docs.googleusercontent.com/docs/secu...
# 3         1589702428  doc-0g-4c-docs.googleusercontent.com/docs/secu...
# 4         1589702437  doc-0o-4c-docs.googleusercontent.com/docs/secu...
#
#               Ip  Port  DnsLookupTime  TCPHandshakeTime  \
# 0  216.58.210.33   443         44.347             3.034
# 1  216.58.210.33   443         39.488             1.346
# 2  216.58.210.33   443         39.066             1.494
# 3  216.58.210.33   443         38.511             1.465
# 4  216.58.210.33   443        406.040             1.445
#
#    ConnectionEstablishmentTime      TTFB  TotalDownloadTime  HttpResponse  \
# 0                     3081.275  3207.466           3207.501           403
# 1                     3354.683  3477.287           3477.379           403
# 2                     2789.701  2908.356           2908.385           403
# 3                     3115.614  3237.313           3237.395           403
# 4                     2950.072  3068.560           3068.594           403
#
#   HTTPVersion    Protocol                                 id  size  Throughput
# 0    HTTP/1.1  TCP/TLS1.2  1C45gZCBtJHnjNACQIagfJ2fTRKQaZ9k6     1    0.000312
# 1       HTTP2  TCP/TLS1.2  1C45gZCBtJHnjNACQIagfJ2fTRKQaZ9k6     1    0.000288
# 2    HTTP/1.1  TCP/TLS1.2  1yv4XxH7R74il-bxBS5Mz8Oiw6W7vwUFM     2    0.000688
# 3       HTTP2  TCP/TLS1.2  1yv4XxH7R74il-bxBS5Mz8Oiw6W7vwUFM     2    0.000618
# 4    HTTP/1.1  TCP/TLS1.2  1sGGy4K1J3p0OQlLxUgbgsErokyBADg6g     5    0.001629

# %%
s.tail()
# Out:
#       TimeOfMeasurement                                                Url  \
# 2189         1589984110  doc-10-4c-docs.googleusercontent.com/docs/secu...
# 2190         1589984117  doc-0g-4c-docs.googleusercontent.com/docs/secu...
# 2191         1589985013  doc-10-4c-docs.googleusercontent.com/docs/secu...
# 2192         1589985914  doc-0g-4c-docs.googleusercontent.com/docs/secu...
# 2193         1589985922  doc-0g-4c-docs.googleusercontent.com/docs/secu...
#
#                   Ip  Port  DnsLookupTime  TCPHandshakeTime  \
# 2189  216.58.198.161   443         63.132             1.559
# 2190  216.58.198.161   443         72.751             4.772
# 2191    216.58.213.1   443         74.868             3.989
# 2192    216.58.204.1   443        134.890             2.189
# 2193    216.58.204.1   443         93.948             5.287
#
#       ConnectionEstablishmentTime      TTFB  TotalDownloadTime  HttpResponse  \
# 2189                     1780.198  1890.807           1890.891           403
# 2190                     2268.591  2377.534           2377.561           403
# 2191                     2316.008  2454.997           2455.072           403
# 2192                     2233.896  2345.166           2345.194           403
# 2193                     4606.099  4761.632           4761.714           403
#
#      HTTPVersion    Protocol                                 id  size  \
# 2189       HTTP2  TCP/TLS1.2  1C45gZCBtJHnjNACQIagfJ2fTRKQaZ9k6     1
# 2190    HTTP/1.1  TCP/TLS1.2  1yv4XxH7R74il-bxBS5Mz8Oiw6W7vwUFM     2
# 2191       HTTP2  TCP/TLS1.2  1ELbl7kPrCGNuk_6xX30vE7JBkSg0nLxf   500
# 2192    HTTP/1.1  TCP/TLS1.2  1yv4XxH7R74il-bxBS5Mz8Oiw6W7vwUFM     2
# 2193       HTTP2  TCP/TLS1.2  1yv4XxH7R74il-bxBS5Mz8Oiw6W7vwUFM     2
#
#       Throughput
# 2189    0.000529
# 2190    0.000841
# 2191    0.203660
# 2192    0.000853
# 2193    0.000420

# %%
gd.head()
# Out:
#   size                                 id
# 0    1  1C45gZCBtJHnjNACQIagfJ2fTRKQaZ9k6
# 1    2  1yv4XxH7R74il-bxBS5Mz8Oiw6W7vwUFM
# 2    5  1sGGy4K1J3p0OQlLxUgbgsErokyBADg6g
# 3   10  1k7mg8XpQmW-jpO85yq3giwVUeL82NJhx
# 4   20  1Zr-g4qROFzaq_vZ4JnHneEb9JyRSUBXb

# %%
t = t.dropna()
s = s.dropna()

# %%
def filter_by_ip(df, column):
  """reads a DataFrame, calls fbi.filter_v{4,6} to get DataFrames with rows
     containing only v4, v6 endpoints. Returns the two DataFrame as a tuple"""

  dfv6 = fbi.filter_v6(df, column)
  dfv4 = fbi.filter_v4(df, column)
  return dfv4, dfv6

# %%
quic4, quic6 = filter_by_ip(t, column = 'Ip')

# %%
tcp4, tcp6 = filter_by_ip(s, column = 'Ip')

# %%
#quic4 = quic4.loc[quic4['size']<500]
#tcp4 = tcp4.loc[tcp4['size']<500]

# %%
quic43 = quic4.loc[t['Protocol'] == 'Q043']
quic46 = quic4.loc[t['Protocol'] == 'Q046']
quic50 = quic4.loc[t['Protocol'] == 'Q050']
quicietf = quic4.loc[t['Protocol'] == 'FF000018']

# %%
quic43_6 = quic6.loc[t['Protocol'] == 'Q043']
quic46_6 = quic6.loc[t['Protocol'] == 'Q046']
quic50_6 = quic6.loc[t['Protocol'] == 'Q050']
quicietf_6 = quic6.loc[t['Protocol'] == 'FF000018']

# %%
tcp12 = tcp4.loc[s['Protocol'] == 'TCP/TLS1.2']
tcp13 = tcp4.loc[s['Protocol'] == 'TCP/TLS1.3']

# %%
tcp12_6 = tcp6.loc[s['Protocol'] == 'TCP/TLS1.2']
tcp13_6 = tcp6.loc[s['Protocol'] == 'TCP/TLS1.3']

# %%
x = Cdf.MakeCdfFromList(quic43['ConnectionEstablishmentTime'].values)
x1 = Cdf.MakeCdfFromList(quic46['ConnectionEstablishmentTime'].values)
x3 = Cdf.MakeCdfFromList(quic50['ConnectionEstablishmentTime'].values)
x5 = Cdf.MakeCdfFromList(quicietf['ConnectionEstablishmentTime'].values)
x4 = Cdf.MakeCdfFromList(tcp13['ConnectionEstablishmentTime'].values)
x2 = Cdf.MakeCdfFromList(tcp12['ConnectionEstablishmentTime'].values)

# %%
fig = plt.figure(figsize = (10,3))
plt.rcParams['font.size'] = 12
ax = plt.gca()
yticks = np.arange(0,1.1,0.2)

#Q043
plt.plot(x.xs, x.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'orange')
#Q046
plt.plot(x1.xs, x1.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'red')
#Q050
plt.plot(x3.xs, x3.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'green')
#Q0ietf
plt.plot(x5.xs, x5.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'blue')
#TLS1.2
plt.plot(x2.xs, x2.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'cyan')
#TLS1.3
plt.plot(x4.xs, x4.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'black')


ax = fig.axes[0]
ax.grid(False)
ax.set_yticks(yticks)
ax.set_ylim([0,1.05])
#ax.set_xlim([20, 100])
ax.set_xscale('log')
ax.set_xlabel('latency (x-axis is cut)', fontsize=12)
ax.set_ylabel('CDF', fontsize=12)

plt.legend(['Q043', 'Q046', 'Q050', 'IETF', 'TLS1.2', 'TLS 1.3'], fontsize=11, loc='best')

ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.yaxis.set_ticks_position('left')
ax.xaxis.set_ticks_position('bottom')
ax.spines['bottom'].set_position(('axes', -0.05))
ax.spines['left'].set_position(('axes', -0.05))

ax3 = ax.twinx()
ax3.spines['right'].set_color('none')
ax3.spines['top'].set_color('none')
ax3.spines['left'].set_color('none')
ax3.spines['bottom'].set_color('none')
ax3.yaxis.set_ticks_position('none')
plt.setp(ax3.get_yticklabels(), visible=False)

plt.title('Handshake Times with IPv4', fontsize=12, y=1.05)
plt.savefig('./AWS/London/gdrive/handshake_times_ipv4_otherthan200.png', format='png', bbox_inches='tight')

# %%
x = Cdf.MakeCdfFromList(quic43['TTFB'].values)
x1 =Cdf.MakeCdfFromList(quic46['TTFB'].values)
x3 = Cdf.MakeCdfFromList(quic50['TTFB'].values)
x5 = Cdf.MakeCdfFromList(quicietf['TTFB'].values)
x4 = Cdf.MakeCdfFromList(tcp13['TTFB'].values)
x2 =Cdf.MakeCdfFromList(tcp12['TTFB'].values)

# %%
fig = plt.figure(figsize = (10,3))
plt.rcParams['font.size'] = 12
ax = plt.gca()
yticks = np.arange(0,1.1,0.2)

#Q043
plt.plot(x.xs, x.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'orange')
#Q046
plt.plot(x1.xs, x1.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'red')
#Q050
plt.plot(x3.xs, x3.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'green')
#IETF
plt.plot(x5.xs, x5.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'blue')
#TLS1.2
plt.plot(x2.xs, x2.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'cyan')
#TLS1.3
plt.plot(x4.xs, x4.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'black')


ax = fig.axes[0]
ax.grid(False)
ax.set_yticks(yticks)
ax.set_ylim([0,1.05])
#ax.set_xlim([100, 600])
ax.set_xscale('log')
ax.set_xlabel('TTFB', fontsize=12)
ax.set_ylabel('CDF', fontsize=12)

plt.legend(['Q043', 'Q046', 'Q050', 'IETF', 'TLS1.2', 'TLS 1.3'], fontsize=11, loc='best')

ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.yaxis.set_ticks_position('left')
ax.xaxis.set_ticks_position('bottom')
ax.spines['bottom'].set_position(('axes', -0.05))
ax.spines['left'].set_position(('axes', -0.05))

ax3 = ax.twinx()
ax3.spines['right'].set_color('none')
ax3.spines['top'].set_color('none')
ax3.spines['left'].set_color('none')
ax3.spines['bottom'].set_color('none')
ax3.yaxis.set_ticks_position('none')
plt.setp(ax3.get_yticklabels(), visible=False)

plt.title('TTFB with IPv4', fontsize=12, y=1.05)
plt.savefig('./AWS/London/gdrive/TTFB_ipv4.png', format='png', bbox_inches='tight')

# %%
x = Cdf.MakeCdfFromList(quic43['TotalDownloadTime'].values)
x1 =Cdf.MakeCdfFromList(quic46['TotalDownloadTime'].values)
x3 = Cdf.MakeCdfFromList(quic50['TotalDownloadTime'].values)
x5 = Cdf.MakeCdfFromList(quicietf['TotalDownloadTime'].values)
x4 = Cdf.MakeCdfFromList(tcp13['TotalDownloadTime'].values)
x2 =Cdf.MakeCdfFromList(tcp12['TotalDownloadTime'].values)

# %%
fig = plt.figure(figsize = (10,3))
plt.rcParams['font.size'] = 12
ax = plt.gca()
yticks = np.arange(0,1.1,0.2)

#Q043
plt.plot(x.xs, x.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'orange')
#Q046
plt.plot(x1.xs, x1.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'red')
#Q050
plt.plot(x3.xs, x3.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'green')
#IETF
plt.plot(x5.xs, x5.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'blue')
#TLS1.2
plt.plot(x2.xs, x2.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'cyan')
#TLS1.3
plt.plot(x4.xs, x4.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'black')


ax = fig.axes[0]
ax.grid(False)
ax.set_yticks(yticks)
ax.set_ylim([0,1.05])
#ax.set_xlim([100,800])
#ax.set_xlim([0,10])
ax.set_xscale('log')
ax.set_xlabel('TotalDownloadTime', fontsize=12)
ax.set_ylabel('CDF', fontsize=12)

plt.legend(['Q043', 'Q046', 'Q050', 'IETF', 'TLS1.2', 'TLS 1.3'], fontsize=11, loc='best')

ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.yaxis.set_ticks_position('left')
ax.xaxis.set_ticks_position('bottom')
ax.spines['bottom'].set_position(('axes', -0.05))
ax.spines['left'].set_position(('axes', -0.05))

ax3 = ax.twinx()
ax3.spines['right'].set_color('none')
ax3.spines['top'].set_color('none')
ax3.spines['left'].set_color('none')
ax3.spines['bottom'].set_color('none')
ax3.yaxis.set_ticks_position('none')
plt.setp(ax3.get_yticklabels(), visible=False)

plt.title('TotalDownloadTime with IPv4', fontsize=12, y=1.05)
plt.savefig('./AWS/London/gdrive/TotalDownloadTime_ipv4.png', format='png', bbox_inches='tight')

# %%
x = Cdf.MakeCdfFromList(quic43['Throughput'].values)
x1 =Cdf.MakeCdfFromList(quic46['Throughput'].values)
x3 = Cdf.MakeCdfFromList(quic50['Throughput'].values)
x5 = Cdf.MakeCdfFromList(quicietf['Throughput'].values)
x4 = Cdf.MakeCdfFromList(tcp13['Throughput'].values)
x2 =Cdf.MakeCdfFromList(tcp12['Throughput'].values)

# %%
fig = plt.figure(figsize = (10,3))
plt.rcParams['font.size'] = 12
ax = plt.gca()
yticks = np.arange(0,1.1,0.2)

#Q043
plt.plot(x.xs, x.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'orange')
#Q046
plt.plot(x1.xs, x1.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'red')
#Q050
plt.plot(x3.xs, x3.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'green')
#IETF
plt.plot(x5.xs, x5.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'blue')
#TLS1.2
plt.plot(x2.xs, x2.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'cyan')
#TLS1.3
plt.plot(x4.xs, x4.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'black')


ax = fig.axes[0]
ax.grid(False)
ax.set_yticks(yticks)
ax.set_ylim([0,1.05])
#ax.set_xlim([0,700])
#ax.set_xlim([0,10])
ax.set_xscale('log')
ax.set_xlabel('Throughput in MB/s', fontsize=12)
ax.set_ylabel('CDF', fontsize=12)

plt.legend(['Q043', 'Q046', 'Q050', 'IETF', 'TLS1.2', 'TLS 1.3'], fontsize=11, loc='best')

ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.yaxis.set_ticks_position('left')
ax.xaxis.set_ticks_position('bottom')
ax.spines['bottom'].set_position(('axes', -0.05))
ax.spines['left'].set_position(('axes', -0.05))

ax3 = ax.twinx()
ax3.spines['right'].set_color('none')
ax3.spines['top'].set_color('none')
ax3.spines['left'].set_color('none')
ax3.spines['bottom'].set_color('none')
ax3.yaxis.set_ticks_position('none')
#ax3.set_ylabel('[\'16thMay - \'20thMay')
plt.setp(ax3.get_yticklabels(), visible=False)

plt.title('Throughput with IPv4', fontsize=12, y=1.05)
plt.savefig('./AWS/London/gdrive/Throughput_ipv4.png', format='png', bbox_inches='tight')

# %%
quic_mean= quic4.groupby('size', as_index=False).mean()
tcp_mean= tcp4.groupby('size', as_index=False).mean()

quic_mean.head()

quic_mean.tail()
# Out:
#       size  TimeOfMeasurement    DNSTime  ConnectionEstablishmentTime  \
# 11    5000       1.589833e+09  80.637423                   103.475403
# 12   10000       1.589833e+09  62.272062                   107.431646
# 13   20000       1.589833e+09  73.081041                   111.071842
# 14   50000       1.589833e+09  62.136846                   103.101617
# 15  100000       1.589834e+09  76.764489                   109.056920
#
#           TTFB  TotalDownloadTime  HttpResponse  Throughput
# 11  478.686182         478.759847         403.0   26.245175
# 12  475.662214         475.813212         403.0   64.377987
# 13  496.967373         496.579689         403.0  140.931184
# 14  457.870716         457.992247         403.0  436.755678
# 15  470.466309         472.507538         403.0  743.208289

# %%
fig = plt.figure(figsize = (20,6))
plt.rcParams['font.size'] = 12
ax = plt.gca()
#yticks = np.arange(1000,100000000,10000)

#Quic
#plt.plot(quic4['size'], quic4['Throughput'], marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'orange')

#plt.plot(tcp4['size'], tcp4['Throughput'], marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'blue')
plt.plot(quic_mean['size'], quic_mean['Throughput'], marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'orange')

plt.plot(tcp_mean['size'], tcp_mean['Throughput'], marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'blue')

ax = fig.axes[0]
ax.grid(False)
#ax.set_yticks(yticks)
ax.set_ylim([0,600])
ax.set_xlim([0,60000])
#ax.set_xlim([0,10])
ax.set_xscale('linear')
ax.set_xlabel('Size in KB', fontsize=12)
ax.set_ylabel('Throughput in MB/s', fontsize=12)

plt.legend(['Quic', 'TLS'], fontsize=11, loc='best')

ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.yaxis.set_ticks_position('left')
ax.xaxis.set_ticks_position('bottom')
ax.spines['bottom'].set_position(('axes', -0.05))
ax.spines['left'].set_position(('axes', -0.05))

ax3 = ax.twinx()
ax3.spines['right'].set_color('none')
ax3.spines['top'].set_color('none')
ax3.spines['left'].set_color('none')
ax3.spines['bottom'].set_color('none')
ax3.yaxis.set_ticks_position('none')
plt.setp(ax3.get_yticklabels(), visible=False)

plt.title('Size vs Throughput_ipv4', fontsize=12, y=1.05)
plt.savefig('./AWS/London/gdrive/sizevsThroughput_ipv4.png', format='png', bbox_inches='tight')
