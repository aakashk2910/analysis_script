# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import time
import datetime
import filterbyip as fbi
import Cdf
import Pmf

# %%
# %autosave 0
# Out:
# Autosave disabled

# %%
import warnings
warnings.filterwarnings('ignore')

# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from IPython.core.display import HTML
css = open('style-table.css').read() + open('style-notebook.css').read()
HTML('<style>{}</style>'.format(css))
# Out:
# <style>body {
#     margin: 0;
#     font-family: Helvetica;
# }
# table.dataframe {
#     border-collapse: collapse;
#     border: none;
# }
# table.dataframe tr {
#     border: none;
# }
# table.dataframe td, table.dataframe th {
#     margin: 0;
#     border: 1px solid white;
#     padding-left: 0.25em;
#     padding-right: 0.25em;
# }
# table.dataframe th:not(:empty) {
#     background-color: #fec;
#     text-align: left;
#     font-weight: normal;
# }
# table.dataframe tr:nth-child(2) th:empty {
#     border-left: none;
#     border-right: 1px dashed #888;
# }
# table.dataframe td {
#     border: 2px solid #ccf;
#     background-color: #f4f4ff;
# }
# h3 {
#     color: white;
#     background-color: black;
#     padding: 0.5em;
# }
#
# .CodeMirror {
#     font-family: 'Consolas';
# }
#
# div.cell.code_cell {
#     font-family: 'Consolas';
# }
#
# div.output_area pre {
#     font-family: 'Consolas';
# }
# </style>

# %%
#change 
tcp_tls_data = "./AWS_results/SaoPaulo/data/output_curl_gdrive100.csv"
quic_data = "./AWS_results/SaoPaulo/data/output_quic_gdrive100.csv"
gdrive = "./data2020/gdrive_id.csv"

# %%
scol_names = ['TimeOfMeasurement', 'Url', 'Ip', 'Port', 'DnsLookupTime', 'TCPHandshakeTime', 'ConnectionEstablishmentTime', 'TTFB', 'TotalDownloadTime', 'HttpResponse', 'HTTPVersion', 'Protocol']
tcol_names = ['TimeOfMeasurement', 'Url', 'Path', 'Ip', 'Port', 'DNSTime', 'ConnectionEstablishmentTime', 'TTFB', 'TotalDownloadTime', 'HttpResponse', 'Protocol']
g_names = ['size', 'id']

# %%
t = pd.read_csv(quic_data, ';', names=tcol_names, header=None)
s = pd.read_csv(tcp_tls_data, ';', names=scol_names, header=None)
gd = pd.read_csv(gdrive, ',', names=g_names, header=None)

# %%
t = t.dropna()
s=s.dropna()
s['TTFB']=s['TTFB']-s['DnsLookupTime']
s['TotalDownloadTime']=s['TotalDownloadTime']-s['DnsLookupTime']

# %%
import re
def extract_id(path):
    id = re.search('\*\/(.*)\?', path)
    return id.group(1)

# %%
t['id'] = t['Path'].apply(extract_id)

# %%
import re
def substitute(string):
    replaced = string
    if re.search('K', string):
        replaced = re.sub('K','', string)
    if re.search('M', string):
        replaced = re.sub('M','000', string)
    if re.search('G', string):
        replaced = re.sub('G','000000', string)
    return replaced

# %%
gd['size'] = gd['size'].apply(substitute)

# %%
s['id'] = s['Url'].apply(extract_id)

# %%
t['Url'] = t['Url'] + t['Path']

# %%
t = t.join(gd.set_index('id'), on='id', rsuffix='_right')

# %%
s = s.join(gd.set_index('id'), on='id', rsuffix='_right')

# %%
t['size'] = t['size'].astype(int)
s['size'] = s['size'].astype(int)
t['TotalDownloadTime'] = t['TotalDownloadTime'].astype(float)
s['TotalDownloadTime'] = s['TotalDownloadTime'].astype(float)

# %%
t['Throughput'] = (t['size']/t['TotalDownloadTime'])

# %%
s['Throughput'] = (s['size']/s['TotalDownloadTime'])

# %%
t.head()
# Out:
#    TimeOfMeasurement                                                Url  \
# 0       1.589598e+09  doc-04-4c-docs.googleusercontent.com/docs/secu...
# 1       1.589598e+09  doc-04-4c-docs.googleusercontent.com/docs/secu...
# 2       1.589598e+09  doc-04-4c-docs.googleusercontent.com/docs/secu...
# 8       1.589598e+09  doc-0o-4c-docs.googleusercontent.com/docs/secu...
# 9       1.589598e+09  doc-0o-4c-docs.googleusercontent.com/docs/secu...
#
#                                                 Path               Ip Port  \
# 0  /docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp...  172.217.172.193  443
# 1  /docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp...  172.217.172.193  443
# 2  /docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp...  172.217.172.193  443
# 8  /docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp...  172.217.172.193  443
# 9  /docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp...  172.217.172.193  443
#
#    DNSTime  ConnectionEstablishmentTime     TTFB  TotalDownloadTime  \
# 0    2.764                       98.822  306.820            306.923
# 1    1.015                       95.978  301.961            302.045
# 2    2.298                       97.123  290.456            290.559
# 8    1.924                       96.392  291.863            291.971
# 9    0.855                       96.361  307.362            307.434
#
#    HttpResponse Protocol                                 id    size  \
# 0         403.0     Q043  1lsRzxeAEzsM1KVu6oQ88LgUYuDSKjhmw  200000
# 1         403.0     Q046  1lsRzxeAEzsM1KVu6oQ88LgUYuDSKjhmw  200000
# 2         403.0     Q050  1lsRzxeAEzsM1KVu6oQ88LgUYuDSKjhmw  200000
# 8         403.0     Q043  1XSSiVM3jWJC09nZxWAYkYMgtGUwCfuEI  500000
# 9         403.0     Q046  1XSSiVM3jWJC09nZxWAYkYMgtGUwCfuEI  500000
#
#     Throughput
# 0   651.629236
# 1   662.152990
# 2   688.328360
# 8  1712.498844
# 9  1626.365334

# %%
t.tail()
# Out:
#       TimeOfMeasurement                                                Url  \
# 7985       1.589967e+09  doc-14-4c-docs.googleusercontent.com/docs/secu...
# 7986       1.589967e+09  doc-14-4c-docs.googleusercontent.com/docs/secu...
# 7992       1.589967e+09  doc-0g-4c-docs.googleusercontent.com/docs/secu...
# 7993       1.589967e+09  doc-0g-4c-docs.googleusercontent.com/docs/secu...
# 7994       1.589967e+09  doc-0g-4c-docs.googleusercontent.com/docs/secu...
#
#                                                    Path              Ip Port  \
# 7985  /docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp...   172.217.30.97  443
# 7986  /docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp...   172.217.28.65  443
# 7992  /docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp...  172.217.29.129  443
# 7993  /docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp...  172.217.29.129  443
# 7994  /docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp...  172.217.29.129  443
#
#       DNSTime  ConnectionEstablishmentTime     TTFB  TotalDownloadTime  \
# 7985    2.104                      163.629  671.548            671.626
# 7986    2.754                      161.467  637.386            637.454
# 7992   42.456                      160.987  789.115            789.184
# 7993   40.901                      160.855  242.663            242.734
# 7994   41.582                      164.473  507.488            507.567
#
#       HttpResponse Protocol                                 id     size  \
# 7985         403.0     Q046  1eIPPQQ3b2GY1jx79eHJn5XF1eSng3my0  1000000
# 7986         403.0     Q050  1eIPPQQ3b2GY1jx79eHJn5XF1eSng3my0  1000000
# 7992         403.0     Q043  1qOoLPlJS5mqHmQfwrAoKwXB5kDyiclPw  2000000
# 7993         403.0     Q046  1qOoLPlJS5mqHmQfwrAoKwXB5kDyiclPw  2000000
# 7994         403.0     Q050  1qOoLPlJS5mqHmQfwrAoKwXB5kDyiclPw  2000000
#
#        Throughput
# 7985  1488.923895
# 7986  1568.740646
# 7992  2534.263239
# 7993  8239.472015
# 7994  3940.366493

# %%
s.head()
# Out:
#    TimeOfMeasurement                                                Url  \
# 0         1589684402  doc-04-4c-docs.googleusercontent.com/docs/secu...
# 1         1589684403  doc-04-4c-docs.googleusercontent.com/docs/secu...
# 2         1589684404  doc-0o-4c-docs.googleusercontent.com/docs/secu...
# 3         1589684404  doc-0o-4c-docs.googleusercontent.com/docs/secu...
# 4         1589684406  doc-14-4c-docs.googleusercontent.com/docs/secu...
#
#              Ip  Port  DnsLookupTime  TCPHandshakeTime  \
# 0  172.217.28.1   443         12.415             0.654
# 1  172.217.28.1   443          4.231             0.618
# 2  172.217.28.1   443          4.228             0.643
# 3  172.217.28.1   443          4.180             0.585
# 4  172.217.28.1   443          4.222             0.616
#
#    ConnectionEstablishmentTime     TTFB  TotalDownloadTime  HttpResponse  \
# 0                      133.793  337.030            337.062           403
# 1                       89.903  291.498            291.606           403
# 2                      101.679  305.361            305.399           403
# 3                       90.425  293.520            293.614           403
# 4                       90.532  297.294            297.325           403
#
#   HTTPVersion    Protocol                                 id     size  \
# 0    HTTP/1.1  TCP/TLS1.2  1lsRzxeAEzsM1KVu6oQ88LgUYuDSKjhmw   200000
# 1       HTTP2  TCP/TLS1.2  1lsRzxeAEzsM1KVu6oQ88LgUYuDSKjhmw   200000
# 2    HTTP/1.1  TCP/TLS1.2  1XSSiVM3jWJC09nZxWAYkYMgtGUwCfuEI   500000
# 3       HTTP2  TCP/TLS1.2  1XSSiVM3jWJC09nZxWAYkYMgtGUwCfuEI   500000
# 4    HTTP/1.1  TCP/TLS1.2  1eIPPQQ3b2GY1jx79eHJn5XF1eSng3my0  1000000
#
#     Throughput
# 0   593.362645
# 1   685.856944
# 2  1637.202479
# 3  1702.916073
# 4  3363.322963

# %%
s.tail()
# Out:
#      TimeOfMeasurement                                                Url  \
# 767         1589962518  doc-0o-4c-docs.googleusercontent.com/docs/secu...
# 768         1589963413  doc-04-4c-docs.googleusercontent.com/docs/secu...
# 769         1589966111  doc-14-4c-docs.googleusercontent.com/docs/secu...
# 770         1589966128  doc-14-4c-docs.googleusercontent.com/docs/secu...
# 771         1589967021  doc-0o-4c-docs.googleusercontent.com/docs/secu...
#
#                  Ip  Port  DnsLookupTime  TCPHandshakeTime  \
# 767  216.58.202.129   443         56.697             1.035
# 768  172.217.30.161   443         56.564             2.557
# 769    172.217.29.1   443        159.655             0.648
# 770    172.217.29.1   443         64.229             1.011
# 771  172.217.30.161   443         55.002             1.894
#
#      ConnectionEstablishmentTime       TTFB  TotalDownloadTime  HttpResponse  \
# 767                     1540.192   6596.713           6597.450           403
# 768                     1574.740   7831.364           7831.466           403
# 769                     7895.336  13123.564          13123.606           403
# 770                     4246.930  13173.773          13173.857           403
# 771                     3158.729  11515.896          11515.939           403
#
#     HTTPVersion    Protocol                                 id     size  \
# 767       HTTP2  TCP/TLS1.2  1XSSiVM3jWJC09nZxWAYkYMgtGUwCfuEI   500000
# 768       HTTP2  TCP/TLS1.2  1lsRzxeAEzsM1KVu6oQ88LgUYuDSKjhmw   200000
# 769    HTTP/1.1  TCP/TLS1.2  1eIPPQQ3b2GY1jx79eHJn5XF1eSng3my0  1000000
# 770       HTTP2  TCP/TLS1.2  1eIPPQQ3b2GY1jx79eHJn5XF1eSng3my0  1000000
# 771    HTTP/1.1  TCP/TLS1.2  1XSSiVM3jWJC09nZxWAYkYMgtGUwCfuEI   500000
#
#      Throughput
# 767   75.786857
# 768   25.538003
# 769   76.198569
# 770   75.907914
# 771   43.418083

# %%
gd.head()
# Out:
#   size                                 id
# 0    1  1C45gZCBtJHnjNACQIagfJ2fTRKQaZ9k6
# 1    2  1yv4XxH7R74il-bxBS5Mz8Oiw6W7vwUFM
# 2    5  1sGGy4K1J3p0OQlLxUgbgsErokyBADg6g
# 3   10  1k7mg8XpQmW-jpO85yq3giwVUeL82NJhx
# 4   20  1Zr-g4qROFzaq_vZ4JnHneEb9JyRSUBXb

# %%
t = t.dropna()
s = s.dropna()

# %%
def filter_by_ip(df, column):
  """reads a DataFrame, calls fbi.filter_v{4,6} to get DataFrames with rows
     containing only v4, v6 endpoints. Returns the two DataFrame as a tuple"""

  dfv6 = fbi.filter_v6(df, column)
  dfv4 = fbi.filter_v4(df, column)
  return dfv4, dfv6

# %%
quic4, quic6 = filter_by_ip(t, column = 'Ip')

# %%
tcp4, tcp6 = filter_by_ip(s, column = 'Ip')

# %%
#quic4 = quic4.loc[quic4['size']<500]
#tcp4 = tcp4.loc[tcp4['size']<500]

# %%
quic43 = quic4.loc[t['Protocol'] == 'Q043']
quic46 = quic4.loc[t['Protocol'] == 'Q046']
quic50 = quic4.loc[t['Protocol'] == 'Q050']
quicietf = quic4.loc[t['Protocol'] == 'FF000018']

# %%
quic43_6 = quic6.loc[t['Protocol'] == 'Q043']
quic46_6 = quic6.loc[t['Protocol'] == 'Q046']
quic50_6 = quic6.loc[t['Protocol'] == 'Q050']
quicietf_6 = quic6.loc[t['Protocol'] == 'FF000018']

# %%
tcp12 = tcp4.loc[s['Protocol'] == 'TCP/TLS1.2']
tcp13 = tcp4.loc[s['Protocol'] == 'TCP/TLS1.3']

# %%
tcp12_6 = tcp6.loc[s['Protocol'] == 'TCP/TLS1.2']
tcp13_6 = tcp6.loc[s['Protocol'] == 'TCP/TLS1.3']

# %%
x = Cdf.MakeCdfFromList(quic43['ConnectionEstablishmentTime'].values)
x1 = Cdf.MakeCdfFromList(quic46['ConnectionEstablishmentTime'].values)
x3 = Cdf.MakeCdfFromList(quic50['ConnectionEstablishmentTime'].values)
x5 = Cdf.MakeCdfFromList(quicietf['ConnectionEstablishmentTime'].values)
x4 = Cdf.MakeCdfFromList(tcp13['ConnectionEstablishmentTime'].values)
x2 = Cdf.MakeCdfFromList(tcp12['ConnectionEstablishmentTime'].values)

# %%
fig = plt.figure(figsize = (10,3))
plt.rcParams['font.size'] = 12
ax = plt.gca()
yticks = np.arange(0,1.1,0.2)

#Q043
plt.plot(x.xs, x.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'orange')
#Q046
plt.plot(x1.xs, x1.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'red')
#Q050
plt.plot(x3.xs, x3.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'green')
#Q0ietf
plt.plot(x5.xs, x5.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'blue')
#TLS1.2
plt.plot(x2.xs, x2.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'cyan')
#TLS1.3
plt.plot(x4.xs, x4.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'black')


ax = fig.axes[0]
ax.grid(False)
ax.set_yticks(yticks)
ax.set_ylim([0,1.05])
#ax.set_xlim([20, 100])
ax.set_xscale('log')
ax.set_xlabel('latency (x-axis is cut)', fontsize=12)
ax.set_ylabel('CDF', fontsize=12)

plt.legend(['Q043', 'Q046', 'Q050', 'IETF', 'TLS1.2', 'TLS 1.3'], fontsize=11, loc='best')

ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.yaxis.set_ticks_position('left')
ax.xaxis.set_ticks_position('bottom')
ax.spines['bottom'].set_position(('axes', -0.05))
ax.spines['left'].set_position(('axes', -0.05))

ax3 = ax.twinx()
ax3.spines['right'].set_color('none')
ax3.spines['top'].set_color('none')
ax3.spines['left'].set_color('none')
ax3.spines['bottom'].set_color('none')
ax3.yaxis.set_ticks_position('none')
plt.setp(ax3.get_yticklabels(), visible=False)

plt.title('Handshake Times with IPv4', fontsize=12, y=1.05)
plt.savefig('./AWS/SaoPaulo/gdrive100/handshake_times_ipv4_otherthan200.png', format='png', bbox_inches='tight')

# %%
x = Cdf.MakeCdfFromList(quic43['TTFB'].values)
x1 =Cdf.MakeCdfFromList(quic46['TTFB'].values)
x3 = Cdf.MakeCdfFromList(quic50['TTFB'].values)
x5 = Cdf.MakeCdfFromList(quicietf['TTFB'].values)
x4 = Cdf.MakeCdfFromList(tcp13['TTFB'].values)
x2 =Cdf.MakeCdfFromList(tcp12['TTFB'].values)

# %%
fig = plt.figure(figsize = (10,3))
plt.rcParams['font.size'] = 12
ax = plt.gca()
yticks = np.arange(0,1.1,0.2)

#Q043
plt.plot(x.xs, x.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'orange')
#Q046
plt.plot(x1.xs, x1.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'red')
#Q050
plt.plot(x3.xs, x3.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'green')
#IETF
plt.plot(x5.xs, x5.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'blue')
#TLS1.2
plt.plot(x2.xs, x2.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'cyan')
#TLS1.3
plt.plot(x4.xs, x4.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'black')


ax = fig.axes[0]
ax.grid(False)
ax.set_yticks(yticks)
ax.set_ylim([0,1.05])
#ax.set_xlim([100, 600])
ax.set_xscale('log')
ax.set_xlabel('TTFB', fontsize=12)
ax.set_ylabel('CDF', fontsize=12)

plt.legend(['Q043', 'Q046', 'Q050', 'IETF', 'TLS1.2', 'TLS 1.3'], fontsize=11, loc='best')

ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.yaxis.set_ticks_position('left')
ax.xaxis.set_ticks_position('bottom')
ax.spines['bottom'].set_position(('axes', -0.05))
ax.spines['left'].set_position(('axes', -0.05))

ax3 = ax.twinx()
ax3.spines['right'].set_color('none')
ax3.spines['top'].set_color('none')
ax3.spines['left'].set_color('none')
ax3.spines['bottom'].set_color('none')
ax3.yaxis.set_ticks_position('none')
plt.setp(ax3.get_yticklabels(), visible=False)

plt.title('TTFB with IPv4', fontsize=12, y=1.05)
plt.savefig('./AWS/SaoPaulo/gdrive100/TTFB_ipv4.png', format='png', bbox_inches='tight')

# %%
x = Cdf.MakeCdfFromList(quic43['TotalDownloadTime'].values)
x1 =Cdf.MakeCdfFromList(quic46['TotalDownloadTime'].values)
x3 = Cdf.MakeCdfFromList(quic50['TotalDownloadTime'].values)
x5 = Cdf.MakeCdfFromList(quicietf['TotalDownloadTime'].values)
x4 = Cdf.MakeCdfFromList(tcp13['TotalDownloadTime'].values)
x2 =Cdf.MakeCdfFromList(tcp12['TotalDownloadTime'].values)

# %%
fig = plt.figure(figsize = (10,3))
plt.rcParams['font.size'] = 12
ax = plt.gca()
yticks = np.arange(0,1.1,0.2)

#Q043
plt.plot(x.xs, x.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'orange')
#Q046
plt.plot(x1.xs, x1.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'red')
#Q050
plt.plot(x3.xs, x3.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'green')
#IETF
plt.plot(x5.xs, x5.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'blue')
#TLS1.2
plt.plot(x2.xs, x2.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'cyan')
#TLS1.3
plt.plot(x4.xs, x4.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'black')


ax = fig.axes[0]
ax.grid(False)
ax.set_yticks(yticks)
ax.set_ylim([0,1.05])
#ax.set_xlim([100,800])
#ax.set_xlim([0,10])
ax.set_xscale('log')
ax.set_xlabel('TotalDownloadTime', fontsize=12)
ax.set_ylabel('CDF', fontsize=12)

plt.legend(['Q043', 'Q046', 'Q050', 'IETF', 'TLS1.2', 'TLS 1.3'], fontsize=11, loc='best')

ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.yaxis.set_ticks_position('left')
ax.xaxis.set_ticks_position('bottom')
ax.spines['bottom'].set_position(('axes', -0.05))
ax.spines['left'].set_position(('axes', -0.05))

ax3 = ax.twinx()
ax3.spines['right'].set_color('none')
ax3.spines['top'].set_color('none')
ax3.spines['left'].set_color('none')
ax3.spines['bottom'].set_color('none')
ax3.yaxis.set_ticks_position('none')
plt.setp(ax3.get_yticklabels(), visible=False)

plt.title('TotalDownloadTime with IPv4', fontsize=12, y=1.05)
plt.savefig('./AWS/SaoPaulo/gdrive100/TotalDownloadTime_ipv4.png', format='png', bbox_inches='tight')

# %%
x = Cdf.MakeCdfFromList(quic43['Throughput'].values)
x1 =Cdf.MakeCdfFromList(quic46['Throughput'].values)
x3 = Cdf.MakeCdfFromList(quic50['Throughput'].values)
x5 = Cdf.MakeCdfFromList(quicietf['Throughput'].values)
x4 = Cdf.MakeCdfFromList(tcp13['Throughput'].values)
x2 =Cdf.MakeCdfFromList(tcp12['Throughput'].values)

# %%
fig = plt.figure(figsize = (10,3))
plt.rcParams['font.size'] = 12
ax = plt.gca()
yticks = np.arange(0,1.1,0.2)

#Q043
plt.plot(x.xs, x.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'orange')
#Q046
plt.plot(x1.xs, x1.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'red')
#Q050
plt.plot(x3.xs, x3.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'green')
#IETF
plt.plot(x5.xs, x5.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'blue')
#TLS1.2
plt.plot(x2.xs, x2.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'cyan')
#TLS1.3
plt.plot(x4.xs, x4.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'black')


ax = fig.axes[0]
ax.grid(False)
ax.set_yticks(yticks)
ax.set_ylim([0,1.05])
#ax.set_xlim([0,700])
#ax.set_xlim([0,10])
ax.set_xscale('log')
ax.set_xlabel('Throughput in MB/s', fontsize=12)
ax.set_ylabel('CDF', fontsize=12)

plt.legend(['Q043', 'Q046', 'Q050', 'IETF', 'TLS1.2', 'TLS 1.3'], fontsize=11, loc='best')

ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.yaxis.set_ticks_position('left')
ax.xaxis.set_ticks_position('bottom')
ax.spines['bottom'].set_position(('axes', -0.05))
ax.spines['left'].set_position(('axes', -0.05))

ax3 = ax.twinx()
ax3.spines['right'].set_color('none')
ax3.spines['top'].set_color('none')
ax3.spines['left'].set_color('none')
ax3.spines['bottom'].set_color('none')
ax3.yaxis.set_ticks_position('none')
#ax3.set_ylabel('[\'16thMay - \'20thMay')
plt.setp(ax3.get_yticklabels(), visible=False)

plt.title('Throughput with IPv4', fontsize=12, y=1.05)
plt.savefig('./AWS/SaoPaulo/gdrive100/Throughput_ipv4.png', format='png', bbox_inches='tight')

# %%
quic_mean= quic4.groupby('size', as_index=False).mean()
tcp_mean= tcp4.groupby('size', as_index=False).mean()

quic_mean.head()

quic_mean.tail()
# Out:
#       size  TimeOfMeasurement    DNSTime  ConnectionEstablishmentTime  \
# 0   200000       1.589777e+09  48.232319                   148.235150
# 1   500000       1.589777e+09  47.894097                   140.478708
# 2  1000000       1.589777e+09  49.013318                   141.388538
# 3  2000000       1.589777e+09  46.859684                   152.738916
#
#          TTFB  TotalDownloadTime  HttpResponse    Throughput
# 0  477.186610         476.767145         403.0   1572.500200
# 1  473.161077         473.519278         403.0   3359.927867
# 2  485.347003         485.423334         403.0   9347.223631
# 3  475.787734         477.064866         403.0  13509.386573

# %%
fig = plt.figure(figsize = (20,6))
plt.rcParams['font.size'] = 12
ax = plt.gca()
#yticks = np.arange(1000,100000000,10000)

#Quic
#plt.plot(quic4['size'], quic4['Throughput'], marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'orange')

#plt.plot(tcp4['size'], tcp4['Throughput'], marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'blue')
plt.plot(quic_mean['size'], quic_mean['Throughput'], marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'orange')

plt.plot(tcp_mean['size'], tcp_mean['Throughput'], marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'blue')

ax = fig.axes[0]
ax.grid(False)
#ax.set_yticks(yticks)
#ax.set_ylim([0,600])
#ax.set_xlim([0,60000])
#ax.set_xlim([0,10])
ax.set_xscale('linear')
ax.set_xlabel('Size in KB', fontsize=12)
ax.set_ylabel('Throughput in MB/s', fontsize=12)

plt.legend(['Quic', 'TLS'], fontsize=11, loc='best')

ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.yaxis.set_ticks_position('left')
ax.xaxis.set_ticks_position('bottom')
ax.spines['bottom'].set_position(('axes', -0.05))
ax.spines['left'].set_position(('axes', -0.05))

ax3 = ax.twinx()
ax3.spines['right'].set_color('none')
ax3.spines['top'].set_color('none')
ax3.spines['left'].set_color('none')
ax3.spines['bottom'].set_color('none')
ax3.yaxis.set_ticks_position('none')
plt.setp(ax3.get_yticklabels(), visible=False)

plt.title('Size vs Throughput_ipv4', fontsize=12, y=1.05)
plt.savefig('./AWS/SaoPaulo/gdrive100/sizevsThroughput_ipv4.png', format='png', bbox_inches='tight')
