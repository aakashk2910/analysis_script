# %%
import pandas as pd
import numpy as np
import matplotlib
matplotlib.use('PS') 
import matplotlib.pyplot as plt
import time
import datetime
import filterbyip as fbi
import Cdf
import Pmf

# %%
def print_percentiles(c, name):
    if c == 0:
        return null
    else:
        print('-----------------------------\n')
        print('percentile values distribution for %s\n' % name)

        print('20th Percentile:%f\n' % c.Percentile(20))    
        print('25th Percentile:%f\n' % c.Percentile(25))
        print('40th Percentile:%f\n' % c.Percentile(40))
        print('50th Percentile:%f\n' % c.Percentile(50))
        print('60th Percentile:%f\n' % c.Percentile(60))
        print('75th Percentile:%f\n' % c.Percentile(75))
        print('80th Percentile:%f\n' % c.Percentile(80))    
        print('90th Percentile:%f\n' % c.Percentile(90))
        print('99th Percentile:%f\n' % c.Percentile(99))

        print('-----------------------------\n')

# %%
def write_percentiles(filename, c):
	with open(filename, 'w') as f:
		f.write('values; percentile\n')
		for x, y in zip(c.xs, c.ps):
			f.write('%.2f, %.2f\n'%(x, y))

# %%
# %autosave 20
# Out:
# Autosaving every 20 seconds

# %%
import warnings
warnings.filterwarnings('ignore')

# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from IPython.core.display import HTML
css = open('style-table.css').read() + open('style-notebook.css').read()
HTML('<style>{}</style>'.format(css))
# Out:
# <style>body {
#     margin: 0;
#     font-family: Helvetica;
# }
# table.dataframe {
#     border-collapse: collapse;
#     border: none;
# }
# table.dataframe tr {
#     border: none;
# }
# table.dataframe td, table.dataframe th {
#     margin: 0;
#     border: 1px solid white;
#     padding-left: 0.25em;
#     padding-right: 0.25em;
# }
# table.dataframe th:not(:empty) {
#     background-color: #fec;
#     text-align: left;
#     font-weight: normal;
# }
# table.dataframe tr:nth-child(2) th:empty {
#     border-left: none;
#     border-right: 1px dashed #888;
# }
# table.dataframe td {
#     border: 2px solid #ccf;
#     background-color: #f4f4ff;
# }
# h3 {
#     color: white;
#     background-color: black;
#     padding: 0.5em;
# }
#
# .CodeMirror {
#     font-family: 'Consolas';
# }
#
# div.cell.code_cell {
#     font-family: 'Consolas';
# }
#
# div.output_area pre {
#     font-family: 'Consolas';
# }
# </style>

# %%
tcp_tls_data = "./AWS_results/Mumbai/data/output_curl_data.csv"
quic_data = "./AWS_results/Mumbai/data/output_quic.csv"

# %%
scol_names = ['TimeOfMeasurement', 'Url', 'Ip', 'Port', 'DnsLookupTime', 'TCPHandshakeTime', 'ConnectionEstablishmentTime', 'TTFB', 'TotalDownloadTime', 'HttpResponse', 'HTTPVersion', 'Protocol']
tcol_names = ['TimeOfMeasurement', 'Url', 'Path', 'Ip', 'Port', 'DNSTime', 'ConnectionEstablishmentTime', 'TTFB', 'TotalDownloadTime', 'HttpResponse', 'Protocol']

# %%
t = pd.read_csv(quic_data, ';', names=tcol_names, header=None)
s = pd.read_csv(tcp_tls_data, ';', names=scol_names, header=None)

# %%
t = t.dropna()
s = s.dropna()

# %%
#t = t[t['TimeOfMeasurement'] > 1581721201]
#s = s[s['TimeOfMeasurement'] > 1581721201]

# %%
s['TTFB']=s['TTFB']-s['DnsLookupTime']
s['TotalDownloadTime']=s['TotalDownloadTime']-s['DnsLookupTime']

# %%
s.count()
# Out:
# TimeOfMeasurement              323675
# Url                            323675
# Ip                             323675
# Port                           323675
# DnsLookupTime                  323675
# TCPHandshakeTime               323675
# ConnectionEstablishmentTime    323675
# TTFB                           323675
# TotalDownloadTime              323675
# HttpResponse                   323675
# HTTPVersion                    323675
# Protocol                       323675
# dtype: int64

# %%
s.head()
# Out:
#    TimeOfMeasurement             Url               Ip  Port  DnsLookupTime  \
# 0         1589644802  www.google.com  172.217.166.164   443          4.214
# 1         1589644802  www.google.com  172.217.166.164   443          4.231
# 2         1589644802    facebook.com    185.60.216.35   443          4.210
# 3         1589644803    facebook.com    185.60.216.35   443         12.354
# 4         1589644803    facebook.com    185.60.216.35   443          4.223
#
#    TCPHandshakeTime  ConnectionEstablishmentTime     TTFB  TotalDownloadTime  \
# 0             1.237                      115.980  217.613            223.776
# 1             1.420                      106.879  216.857            223.681
# 2           109.707                      370.281  510.005            510.031
# 3           107.612                      256.224  389.083            389.111
# 4           107.117                      363.922  503.310            503.342
#
#    HttpResponse HTTPVersion    Protocol
# 0           200    HTTP/1.1  TCP/TLS1.2
# 1           200       HTTP2  TCP/TLS1.2
# 2           301    HTTP/1.1  TCP/TLS1.2
# 3           301    HTTP/1.1  TCP/TLS1.3
# 4           301       HTTP2  TCP/TLS1.2

# %%
t.count()
# Out:
# TimeOfMeasurement              721382
# Url                            721382
# Path                           721382
# Ip                             721382
# Port                           721382
# DNSTime                        721382
# ConnectionEstablishmentTime    721382
# TTFB                           721382
# TotalDownloadTime              721382
# HttpResponse                   721382
# Protocol                       721382
# dtype: int64

# %%
t.head()
# Out:
#    TimeOfMeasurement                        Url Path              Ip Port  \
# 0       1.589587e+09  www.0dayrox2.blogspot.com    /  216.58.199.129  443
# 1       1.589587e+09  www.0dayrox2.blogspot.com    /  216.58.199.129  443
# 2       1.589587e+09  www.0dayrox2.blogspot.com    /  216.58.199.129  443
# 8       1.589587e+09   www.0dayrox.blogspot.com    /  216.58.199.129  443
# 9       1.589587e+09   www.0dayrox.blogspot.com    /  216.58.199.129  443
#
#    DNSTime  ConnectionEstablishmentTime     TTFB  TotalDownloadTime  \
# 0  173.387                      125.274  511.025             60.569
# 1    0.693                      125.736  579.538            878.539
# 2    0.753                      125.767  602.459            918.512
# 8   71.259                      128.807  577.817            879.955
# 9    1.193                      135.858  628.999            930.813
#
#    HttpResponse Protocol
# 0         404.0     Q043
# 1         404.0     Q046
# 2         404.0     Q050
# 8         404.0     Q043
# 9         404.0     Q046

# %%
def timestamp2human(timestamp):
    return datetime.datetime.fromtimestamp(int(timestamp)).strftime('%c')

# %%
s['TimeOfMeasurement'] = s['TimeOfMeasurement'].apply(timestamp2human)

# %%
s.head()
# Out:
#           TimeOfMeasurement             Url               Ip  Port  \
# 0  Sat May 16 18:00:02 2020  www.google.com  172.217.166.164   443
# 1  Sat May 16 18:00:02 2020  www.google.com  172.217.166.164   443
# 2  Sat May 16 18:00:02 2020    facebook.com    185.60.216.35   443
# 3  Sat May 16 18:00:03 2020    facebook.com    185.60.216.35   443
# 4  Sat May 16 18:00:03 2020    facebook.com    185.60.216.35   443
#
#    DnsLookupTime  TCPHandshakeTime  ConnectionEstablishmentTime     TTFB  \
# 0          4.214             1.237                      115.980  217.613
# 1          4.231             1.420                      106.879  216.857
# 2          4.210           109.707                      370.281  510.005
# 3         12.354           107.612                      256.224  389.083
# 4          4.223           107.117                      363.922  503.310
#
#    TotalDownloadTime  HttpResponse HTTPVersion    Protocol
# 0            223.776           200    HTTP/1.1  TCP/TLS1.2
# 1            223.681           200       HTTP2  TCP/TLS1.2
# 2            510.031           301    HTTP/1.1  TCP/TLS1.2
# 3            389.111           301    HTTP/1.1  TCP/TLS1.3
# 4            503.342           301       HTTP2  TCP/TLS1.2

# %%
s.tail()
# Out:
#                TimeOfMeasurement             Url              Ip  Port  \
# 323670  Wed May 20 18:00:41 2020    facebook.com  157.240.221.35   443
# 323671  Wed May 20 18:00:50 2020  newgrounds.com    51.79.77.158   443
# 323672  Wed May 20 18:01:01 2020     femefun.com     37.1.206.35   443
# 323673  Wed May 20 18:01:04 2020    facebook.com  157.240.221.35   443
# 323674  Wed May 20 18:01:06 2020  getcomics.info   104.28.10.112   443
#
#         DnsLookupTime  TCPHandshakeTime  ConnectionEstablishmentTime  \
# 323670         50.777           121.452                    17921.827
# 323671        696.561           248.038                    22611.067
# 323672       2704.233           121.778                    23479.967
# 323673        169.547           159.154                    22035.326
# 323674        165.296            81.316                    11105.768
#
#              TTFB  TotalDownloadTime  HttpResponse HTTPVersion    Protocol
# 323670  18085.301          18085.337           301       HTTP2  TCP/TLS1.2
# 323671  22858.196          22858.224           301    HTTP/1.1  TCP/TLS1.2
# 323672  23723.961          23970.857           200    HTTP/1.1  TCP/TLS1.2
# 323673  22199.867          22199.898           301       HTTP2  TCP/TLS1.3
# 323674  11641.041          11803.024           200       HTTP2  TCP/TLS1.2

# %%
#t['TimeOfMeasurement'] = t['TimeOfMeasurement'].apply(timestamp2human)

# %%
t.head()
# Out:
#    TimeOfMeasurement                        Url Path              Ip Port  \
# 0       1.589587e+09  www.0dayrox2.blogspot.com    /  216.58.199.129  443
# 1       1.589587e+09  www.0dayrox2.blogspot.com    /  216.58.199.129  443
# 2       1.589587e+09  www.0dayrox2.blogspot.com    /  216.58.199.129  443
# 8       1.589587e+09   www.0dayrox.blogspot.com    /  216.58.199.129  443
# 9       1.589587e+09   www.0dayrox.blogspot.com    /  216.58.199.129  443
#
#    DNSTime  ConnectionEstablishmentTime     TTFB  TotalDownloadTime  \
# 0  173.387                      125.274  511.025             60.569
# 1    0.693                      125.736  579.538            878.539
# 2    0.753                      125.767  602.459            918.512
# 8   71.259                      128.807  577.817            879.955
# 9    1.193                      135.858  628.999            930.813
#
#    HttpResponse Protocol
# 0         404.0     Q043
# 1         404.0     Q046
# 2         404.0     Q050
# 8         404.0     Q043
# 9         404.0     Q046

# %%
t.tail()
# Out:
#          TimeOfMeasurement                                Url Path  \
# 2050064       1.589990e+09  www.hqnetflixcookies.blogspot.com    /
# 2050068       1.589990e+09           www.yyoossk.blogspot.com    /
# 2050069       1.589990e+09  www.hqnetflixcookies.blogspot.com    /
# 2050070       1.589990e+09       www.mexicocomic.blogspot.com    /
# 2050071       1.589990e+09           www.yyoossk.blogspot.com    /
#
#                      Ip Port  DNSTime  ConnectionEstablishmentTime     TTFB  \
# 2050064  216.58.203.161  443  120.259                      166.214  819.493
# 2050068  216.58.203.161  443   84.050                      162.605  491.129
# 2050069  216.58.203.161  443   36.078                      205.196  574.523
# 2050070  216.58.203.161  443    2.406                      163.568  491.533
# 2050071  216.58.203.161  443    0.958                      161.045  490.260
#
#          TotalDownloadTime  HttpResponse Protocol
# 2050064            819.552         301.0     Q046
# 2050068            491.186         301.0     Q046
# 2050069            574.576         301.0     Q050
# 2050070            491.596         301.0     Q046
# 2050071            491.823         301.0     Q050

# %%
def filter_by_ip(df, column):
  """reads a DataFrame, calls fbi.filter_v{4,6} to get DataFrames with rows
     containing only v4, v6 endpoints. Returns the two DataFrame as a tuple"""

  dfv6 = fbi.filter_v6(df, column)
  dfv4 = fbi.filter_v4(df, column)
  return dfv4, dfv6

# %%
#quic4, quic6 = filter_by_ip(t, column = 'Ip')
quic4 = t[t['Ip'].str.contains("\.")]
quic6 = t[t['Ip'].str.contains("\:")]

# %%
quic4.count()
# Out:
# TimeOfMeasurement              721382
# Url                            721382
# Path                           721382
# Ip                             721382
# Port                           721382
# DNSTime                        721382
# ConnectionEstablishmentTime    721382
# TTFB                           721382
# TotalDownloadTime              721382
# HttpResponse                   721382
# Protocol                       721382
# dtype: int64

# %%
quic4.head()
# Out:
#    TimeOfMeasurement                        Url Path              Ip Port  \
# 0       1.589587e+09  www.0dayrox2.blogspot.com    /  216.58.199.129  443
# 1       1.589587e+09  www.0dayrox2.blogspot.com    /  216.58.199.129  443
# 2       1.589587e+09  www.0dayrox2.blogspot.com    /  216.58.199.129  443
# 8       1.589587e+09   www.0dayrox.blogspot.com    /  216.58.199.129  443
# 9       1.589587e+09   www.0dayrox.blogspot.com    /  216.58.199.129  443
#
#    DNSTime  ConnectionEstablishmentTime     TTFB  TotalDownloadTime  \
# 0  173.387                      125.274  511.025             60.569
# 1    0.693                      125.736  579.538            878.539
# 2    0.753                      125.767  602.459            918.512
# 8   71.259                      128.807  577.817            879.955
# 9    1.193                      135.858  628.999            930.813
#
#    HttpResponse Protocol
# 0         404.0     Q043
# 1         404.0     Q046
# 2         404.0     Q050
# 8         404.0     Q043
# 9         404.0     Q046

# %%
quic6.count()
# Out:
# TimeOfMeasurement              0
# Url                            0
# Path                           0
# Ip                             0
# Port                           0
# DNSTime                        0
# ConnectionEstablishmentTime    0
# TTFB                           0
# TotalDownloadTime              0
# HttpResponse                   0
# Protocol                       0
# dtype: int64

# %%
quic6.head()
# Out:
# Empty DataFrame
# Columns: [TimeOfMeasurement, Url, Path, Ip, Port, DNSTime, ConnectionEstablishmentTime, TTFB, TotalDownloadTime, HttpResponse, Protocol]
# Index: []

# %%
#tcp4, tcp6 = filter_by_ip(s, column = 'Ip')
tcp4 = s[s['Ip'].str.contains("\.")]
tcp6 = s[s['Ip'].str.contains("\:")]

# %%
tcp4.count()
# Out:
# TimeOfMeasurement              323675
# Url                            323675
# Ip                             323675
# Port                           323675
# DnsLookupTime                  323675
# TCPHandshakeTime               323675
# ConnectionEstablishmentTime    323675
# TTFB                           323675
# TotalDownloadTime              323675
# HttpResponse                   323675
# HTTPVersion                    323675
# Protocol                       323675
# dtype: int64

# %%
tcp4.head()
# Out:
#           TimeOfMeasurement             Url               Ip  Port  \
# 0  Sat May 16 18:00:02 2020  www.google.com  172.217.166.164   443
# 1  Sat May 16 18:00:02 2020  www.google.com  172.217.166.164   443
# 2  Sat May 16 18:00:02 2020    facebook.com    185.60.216.35   443
# 3  Sat May 16 18:00:03 2020    facebook.com    185.60.216.35   443
# 4  Sat May 16 18:00:03 2020    facebook.com    185.60.216.35   443
#
#    DnsLookupTime  TCPHandshakeTime  ConnectionEstablishmentTime     TTFB  \
# 0          4.214             1.237                      115.980  217.613
# 1          4.231             1.420                      106.879  216.857
# 2          4.210           109.707                      370.281  510.005
# 3         12.354           107.612                      256.224  389.083
# 4          4.223           107.117                      363.922  503.310
#
#    TotalDownloadTime  HttpResponse HTTPVersion    Protocol
# 0            223.776           200    HTTP/1.1  TCP/TLS1.2
# 1            223.681           200       HTTP2  TCP/TLS1.2
# 2            510.031           301    HTTP/1.1  TCP/TLS1.2
# 3            389.111           301    HTTP/1.1  TCP/TLS1.3
# 4            503.342           301       HTTP2  TCP/TLS1.2

# %%
tcp6.count()
# Out:
# TimeOfMeasurement              0
# Url                            0
# Ip                             0
# Port                           0
# DnsLookupTime                  0
# TCPHandshakeTime               0
# ConnectionEstablishmentTime    0
# TTFB                           0
# TotalDownloadTime              0
# HttpResponse                   0
# HTTPVersion                    0
# Protocol                       0
# dtype: int64

# %%
tcp6.head()
# Out:
# Empty DataFrame
# Columns: [TimeOfMeasurement, Url, Ip, Port, DnsLookupTime, TCPHandshakeTime, ConnectionEstablishmentTime, TTFB, TotalDownloadTime, HttpResponse, HTTPVersion, Protocol]
# Index: []

# %%
quic43 = quic4.loc[t['Protocol'] == 'Q043']
quic46 = quic4.loc[t['Protocol'] == 'Q046']
quic50 = quic4.loc[t['Protocol'] == 'Q050']
quicID24 = quic4.loc[t['Protocol'] == 'FF000018']
quic98 = quic4.loc[t['Protocol'] == '']

# %%
quic43.count()
# Out:
# TimeOfMeasurement              241990
# Url                            241990
# Path                           241990
# Ip                             241990
# Port                           241990
# DNSTime                        241990
# ConnectionEstablishmentTime    241990
# TTFB                           241990
# TotalDownloadTime              241990
# HttpResponse                   241990
# Protocol                       241990
# dtype: int64

# %%
quic43.head()
# Out:
#     TimeOfMeasurement                                      Url Path  \
# 0        1.589587e+09                www.0dayrox2.blogspot.com    /
# 8        1.589587e+09                 www.0dayrox.blogspot.com    /
# 16       1.589587e+09  www.100leccionesdeguitarra.blogspot.com    /
# 24       1.589587e+09                      www.100negocios.com    /
# 40       1.589587e+09                 www.1100021.blogspot.com    /
#
#                 Ip Port  DNSTime  ConnectionEstablishmentTime     TTFB  \
# 0   216.58.199.129  443  173.387                      125.274  511.025
# 8   216.58.199.129  443   71.259                      128.807  577.817
# 16  216.58.199.129  443  110.570                      125.044  536.556
# 24   66.198.240.11  443  922.571                      419.492  112.632
# 40  216.58.199.129  443   63.276                      126.107  565.770
#
#     TotalDownloadTime  HttpResponse Protocol
# 0              60.569         404.0     Q043
# 8             879.955         404.0     Q043
# 16            536.615         301.0     Q043
# 24            606.883         200.0     Q043
# 40            565.850         301.0     Q043

# %%
quic43.tail()
# Out:
#          TimeOfMeasurement                                 Url Path  \
# 2050033       1.589990e+09  www.finnishnightmares.blogspot.com    /
# 2050044       1.589990e+09       www.char7nas-1er.blogspot.com    /
# 2050053       1.589990e+09        www.mexicocomic.blogspot.com    /
# 2050055       1.589990e+09   www.hqnetflixcookies.blogspot.com    /
# 2050063       1.589990e+09            www.yyoossk.blogspot.com    /
#
#                      Ip Port  DNSTime  ConnectionEstablishmentTime     TTFB  \
# 2050033  216.58.203.161  443  125.057                      162.229  491.253
# 2050044  216.58.203.161  443   80.473                      166.475  531.146
# 2050053  216.58.203.161  443  120.639                      166.385  698.335
# 2050055  216.58.203.161  443  165.693                      162.155  489.972
# 2050063  216.58.203.161  443   79.347                      161.751  491.138
#
#          TotalDownloadTime  HttpResponse Protocol
# 2050033            491.312         301.0     Q043
# 2050044            531.209         301.0     Q043
# 2050053            698.374         301.0     Q043
# 2050055            490.035         301.0     Q043
# 2050063            491.195         301.0     Q043

# %%
quic46.count()
# Out:
# TimeOfMeasurement              239284
# Url                            239284
# Path                           239284
# Ip                             239284
# Port                           239284
# DNSTime                        239284
# ConnectionEstablishmentTime    239284
# TTFB                           239284
# TotalDownloadTime              239284
# HttpResponse                   239284
# Protocol                       239284
# dtype: int64

# %%
quic46.head()
# Out:
#     TimeOfMeasurement                                      Url Path  \
# 1        1.589587e+09                www.0dayrox2.blogspot.com    /
# 9        1.589587e+09                 www.0dayrox.blogspot.com    /
# 17       1.589587e+09  www.100leccionesdeguitarra.blogspot.com    /
# 25       1.589587e+09                      www.100negocios.com    /
# 41       1.589587e+09                 www.1100021.blogspot.com    /
#
#                 Ip Port  DNSTime  ConnectionEstablishmentTime     TTFB  \
# 1   216.58.199.129  443    0.693                      125.736  579.538
# 9   216.58.199.129  443    1.193                      135.858  628.999
# 17  216.58.199.129  443    1.535                      128.932  574.515
# 25   66.198.240.11  443    3.666                      415.011  144.847
# 41  216.58.199.129  443    0.565                      124.828  499.045
#
#     TotalDownloadTime  HttpResponse Protocol
# 1             878.539         404.0     Q046
# 9             930.813         404.0     Q046
# 17            574.593         301.0     Q046
# 25            632.249         200.0     Q046
# 41            499.106         301.0     Q046

# %%
quic46.tail()
# Out:
#          TimeOfMeasurement                                 Url Path  \
# 2050037       1.589990e+09  www.finnishnightmares.blogspot.com    /
# 2050052       1.589990e+09       www.char7nas-1er.blogspot.com    /
# 2050064       1.589990e+09   www.hqnetflixcookies.blogspot.com    /
# 2050068       1.589990e+09            www.yyoossk.blogspot.com    /
# 2050070       1.589990e+09        www.mexicocomic.blogspot.com    /
#
#                      Ip Port  DNSTime  ConnectionEstablishmentTime     TTFB  \
# 2050037  216.58.203.161  443   80.376                      166.475  494.909
# 2050052  216.58.203.161  443   81.256                      244.583  609.509
# 2050064  216.58.203.161  443  120.259                      166.214  819.493
# 2050068  216.58.203.161  443   84.050                      162.605  491.129
# 2050070  216.58.203.161  443    2.406                      163.568  491.533
#
#          TotalDownloadTime  HttpResponse Protocol
# 2050037            494.969         301.0     Q046
# 2050052            609.566         301.0     Q046
# 2050064            819.552         301.0     Q046
# 2050068            491.186         301.0     Q046
# 2050070            491.596         301.0     Q046

# %%
quic50.count()
# Out:
# TimeOfMeasurement              236722
# Url                            236722
# Path                           236722
# Ip                             236722
# Port                           236722
# DNSTime                        236722
# ConnectionEstablishmentTime    236722
# TTFB                           236722
# TotalDownloadTime              236722
# HttpResponse                   236722
# Protocol                       236722
# dtype: int64

# %%
quic50.head()
# Out:
#     TimeOfMeasurement                                      Url Path  \
# 2        1.589587e+09                www.0dayrox2.blogspot.com    /
# 10       1.589587e+09                 www.0dayrox.blogspot.com    /
# 18       1.589587e+09  www.100leccionesdeguitarra.blogspot.com    /
# 26       1.589587e+09                      www.100negocios.com    /
# 42       1.589587e+09                 www.1100021.blogspot.com    /
#
#                 Ip Port  DNSTime  ConnectionEstablishmentTime     TTFB  \
# 2   216.58.199.129  443    0.753                      125.767  602.459
# 10  216.58.199.129  443    0.741                      124.476  569.623
# 18  216.58.199.129  443    4.932                      128.900  531.482
# 26   66.198.240.11  443    0.728                      413.455   96.477
# 42  216.58.199.129  443    0.872                      142.099  538.234
#
#     TotalDownloadTime  HttpResponse Protocol
# 2             918.512         404.0     Q050
# 10            872.200         404.0     Q050
# 18            531.543         301.0     Q050
# 26            594.103         200.0     Q050
# 42            538.299         301.0     Q050

# %%
quic50.tail()
# Out:
#          TimeOfMeasurement                                 Url Path  \
# 2050049       1.589990e+09  www.finnishnightmares.blogspot.com    /
# 2050054       1.589990e+09    www.retroitunesplus.blogspot.com    /
# 2050056       1.589990e+09       www.char7nas-1er.blogspot.com    /
# 2050069       1.589990e+09   www.hqnetflixcookies.blogspot.com    /
# 2050071       1.589990e+09            www.yyoossk.blogspot.com    /
#
#                      Ip Port  DNSTime  ConnectionEstablishmentTime     TTFB  \
# 2050049  216.58.203.161  443    1.987                      159.732  595.944
# 2050054  216.58.203.161  443   41.718                      160.516  533.479
# 2050056  216.58.203.161  443   39.599                      160.721  610.799
# 2050069  216.58.203.161  443   36.078                      205.196  574.523
# 2050071  216.58.203.161  443    0.958                      161.045  490.260
#
#          TotalDownloadTime  HttpResponse Protocol
# 2050049            596.023         301.0     Q050
# 2050054            893.673         404.0     Q050
# 2050056            610.870         301.0     Q050
# 2050069            574.576         301.0     Q050
# 2050071            491.823         301.0     Q050

# %%
quicID24.count()
# Out:
# TimeOfMeasurement              3386
# Url                            3386
# Path                           3386
# Ip                             3386
# Port                           3386
# DNSTime                        3386
# ConnectionEstablishmentTime    3386
# TTFB                           3386
# TotalDownloadTime              3386
# HttpResponse                   3386
# Protocol                       3386
# dtype: int64

# %%
quicID24.head()
# Out:
#       TimeOfMeasurement                    Url Path               Ip Port  \
# 555        1.589588e+09   www.9999999views.com    /   178.32.108.178  443
# 1251       1.589588e+09         www.akaian.com    /     150.95.55.38  443
# 1519       1.589588e+09        www.allzine.org    /  194.150.248.139  443
# 1599       1.589588e+09  www.altoonaworks.info    /    72.249.49.192  443
# 3127       1.589589e+09       www.av-baron.com    /    150.95.52.123  443
#
#       DNSTime  ConnectionEstablishmentTime     TTFB  TotalDownloadTime  \
# 555     0.821                      115.718  229.643            229.710
# 1251    0.732                      275.292  411.994            412.067
# 1519    0.752                      125.874  251.947            251.995
# 1599    0.676                      376.595  602.578            608.181
# 3127    0.647                      255.463  501.134            501.219
#
#       HttpResponse  Protocol
# 555          301.0  FF000018
# 1251         301.0  FF000018
# 1519         200.0  FF000018
# 1599         200.0  FF000018
# 3127         301.0  FF000018

# %%
quicID24.tail()
# Out:
#          TimeOfMeasurement                       Url Path               Ip  \
# 2045735       1.589990e+09  www.xn--juhlapyht-22a.fi    /   185.179.116.91
# 2045919       1.589990e+09       www.xpeedstudio.com    /   158.106.138.24
# 2048069       1.589990e+09          www.hlondres.com    /    89.145.92.138
# 2049689       1.589990e+09           www.filmtett.ro    /  176.126.202.142
# 2049763       1.589990e+09         www.howafrica.com    /   67.222.152.216
#
#         Port  DNSTime  ConnectionEstablishmentTime     TTFB  \
# 2045735  443   20.321                      154.619  324.260
# 2045919  443   44.041                      371.941  861.139
# 2048069  443  119.120                      289.626  536.624
# 2049689  443   41.073                      331.334  177.303
# 2049763  443  877.718                      409.749  656.913
#
#          TotalDownloadTime  HttpResponse  Protocol
# 2045735             43.180         200.0  FF000018
# 2045919            861.223         301.0  FF000018
# 2048069            536.672         301.0  FF000018
# 2049689            384.505         200.0  FF000018
# 2049763            656.975         301.0  FF000018

# %%
quic43_6 = quic6.loc[t['Protocol'] == 'Q043']
quic46_6 = quic6.loc[t['Protocol'] == 'Q046']
quic50_6 = quic6.loc[t['Protocol'] == 'Q050']
#quic98_6 = quic6.loc[t['Protocol'] == '']
quicID24_6 = quic6.loc[t['Protocol'] == 'FF000018']

# %%
quic43_6.count()
# Out:
# TimeOfMeasurement              0
# Url                            0
# Path                           0
# Ip                             0
# Port                           0
# DNSTime                        0
# ConnectionEstablishmentTime    0
# TTFB                           0
# TotalDownloadTime              0
# HttpResponse                   0
# Protocol                       0
# dtype: int64

# %%
quic43_6.head()
# Out:
# Empty DataFrame
# Columns: [TimeOfMeasurement, Url, Path, Ip, Port, DNSTime, ConnectionEstablishmentTime, TTFB, TotalDownloadTime, HttpResponse, Protocol]
# Index: []

# %%
quic43_6.tail()
# Out:
# Empty DataFrame
# Columns: [TimeOfMeasurement, Url, Path, Ip, Port, DNSTime, ConnectionEstablishmentTime, TTFB, TotalDownloadTime, HttpResponse, Protocol]
# Index: []

# %%
quic46_6.count()
# Out:
# TimeOfMeasurement              0
# Url                            0
# Path                           0
# Ip                             0
# Port                           0
# DNSTime                        0
# ConnectionEstablishmentTime    0
# TTFB                           0
# TotalDownloadTime              0
# HttpResponse                   0
# Protocol                       0
# dtype: int64

# %%
quic46_6.head()
# Out:
# Empty DataFrame
# Columns: [TimeOfMeasurement, Url, Path, Ip, Port, DNSTime, ConnectionEstablishmentTime, TTFB, TotalDownloadTime, HttpResponse, Protocol]
# Index: []

# %%
quic46_6.tail()
# Out:
# Empty DataFrame
# Columns: [TimeOfMeasurement, Url, Path, Ip, Port, DNSTime, ConnectionEstablishmentTime, TTFB, TotalDownloadTime, HttpResponse, Protocol]
# Index: []

# %%
quic50_6.count()
# Out:
# TimeOfMeasurement              0
# Url                            0
# Path                           0
# Ip                             0
# Port                           0
# DNSTime                        0
# ConnectionEstablishmentTime    0
# TTFB                           0
# TotalDownloadTime              0
# HttpResponse                   0
# Protocol                       0
# dtype: int64

# %%
quic50_6.head()
# Out:
# Empty DataFrame
# Columns: [TimeOfMeasurement, Url, Path, Ip, Port, DNSTime, ConnectionEstablishmentTime, TTFB, TotalDownloadTime, HttpResponse, Protocol]
# Index: []

# %%
quic50_6.tail()
# Out:
# Empty DataFrame
# Columns: [TimeOfMeasurement, Url, Path, Ip, Port, DNSTime, ConnectionEstablishmentTime, TTFB, TotalDownloadTime, HttpResponse, Protocol]
# Index: []

# %%
quicID24_6.count()
# Out:
# TimeOfMeasurement              0
# Url                            0
# Path                           0
# Ip                             0
# Port                           0
# DNSTime                        0
# ConnectionEstablishmentTime    0
# TTFB                           0
# TotalDownloadTime              0
# HttpResponse                   0
# Protocol                       0
# dtype: int64

# %%
quicID24_6.head()
# Out:
# Empty DataFrame
# Columns: [TimeOfMeasurement, Url, Path, Ip, Port, DNSTime, ConnectionEstablishmentTime, TTFB, TotalDownloadTime, HttpResponse, Protocol]
# Index: []

# %%
quicID24_6.tail()
# Out:
# Empty DataFrame
# Columns: [TimeOfMeasurement, Url, Path, Ip, Port, DNSTime, ConnectionEstablishmentTime, TTFB, TotalDownloadTime, HttpResponse, Protocol]
# Index: []

# %%
tcp12 = tcp4.loc[s['Protocol'] == 'TCP/TLS1.2']
tcp13 = tcp4.loc[s['Protocol'] == 'TCP/TLS1.3']

# %%
tcp12.count()
# Out:
# TimeOfMeasurement              322708
# Url                            322708
# Ip                             322708
# Port                           322708
# DnsLookupTime                  322708
# TCPHandshakeTime               322708
# ConnectionEstablishmentTime    322708
# TTFB                           322708
# TotalDownloadTime              322708
# HttpResponse                   322708
# HTTPVersion                    322708
# Protocol                       322708
# dtype: int64

# %%
tcp12.head()
# Out:
#           TimeOfMeasurement             Url               Ip  Port  \
# 0  Sat May 16 18:00:02 2020  www.google.com  172.217.166.164   443
# 1  Sat May 16 18:00:02 2020  www.google.com  172.217.166.164   443
# 2  Sat May 16 18:00:02 2020    facebook.com    185.60.216.35   443
# 4  Sat May 16 18:00:03 2020    facebook.com    185.60.216.35   443
# 6  Sat May 16 18:00:05 2020   instagram.com     107.21.50.66   443
#
#    DnsLookupTime  TCPHandshakeTime  ConnectionEstablishmentTime     TTFB  \
# 0          4.214             1.237                      115.980  217.613
# 1          4.231             1.420                      106.879  216.857
# 2          4.210           109.707                      370.281  510.005
# 4          4.223           107.117                      363.922  503.310
# 6          4.275           182.152                      590.752  837.942
#
#    TotalDownloadTime  HttpResponse HTTPVersion    Protocol
# 0            223.776           200    HTTP/1.1  TCP/TLS1.2
# 1            223.681           200       HTTP2  TCP/TLS1.2
# 2            510.031           301    HTTP/1.1  TCP/TLS1.2
# 4            503.342           301       HTTP2  TCP/TLS1.2
# 6            837.993           301    HTTP/1.1  TCP/TLS1.2

# %%
tcp12.tail()
# Out:
#                TimeOfMeasurement              Url              Ip  Port  \
# 323669  Wed May 20 18:00:38 2020  devsjournal.com  104.27.137.253   443
# 323670  Wed May 20 18:00:41 2020     facebook.com  157.240.221.35   443
# 323671  Wed May 20 18:00:50 2020   newgrounds.com    51.79.77.158   443
# 323672  Wed May 20 18:01:01 2020      femefun.com     37.1.206.35   443
# 323674  Wed May 20 18:01:06 2020   getcomics.info   104.28.10.112   443
#
#         DnsLookupTime  TCPHandshakeTime  ConnectionEstablishmentTime  \
# 323669         72.126            56.965                    13569.177
# 323670         50.777           121.452                    17921.827
# 323671        696.561           248.038                    22611.067
# 323672       2704.233           121.778                    23479.967
# 323674        165.296            81.316                    11105.768
#
#              TTFB  TotalDownloadTime  HttpResponse HTTPVersion    Protocol
# 323669  13938.611          14105.269           200    HTTP/1.1  TCP/TLS1.2
# 323670  18085.301          18085.337           301       HTTP2  TCP/TLS1.2
# 323671  22858.196          22858.224           301    HTTP/1.1  TCP/TLS1.2
# 323672  23723.961          23970.857           200    HTTP/1.1  TCP/TLS1.2
# 323674  11641.041          11803.024           200       HTTP2  TCP/TLS1.2

# %%
tcp13.count()
# Out:
# TimeOfMeasurement              967
# Url                            967
# Ip                             967
# Port                           967
# DnsLookupTime                  967
# TCPHandshakeTime               967
# ConnectionEstablishmentTime    967
# TTFB                           967
# TotalDownloadTime              967
# HttpResponse                   967
# HTTPVersion                    967
# Protocol                       967
# dtype: int64

# %%
tcp13.head()
# Out:
#            TimeOfMeasurement               Url             Ip  Port  \
# 3   Sat May 16 18:00:03 2020      facebook.com  185.60.216.35   443
# 5   Sat May 16 18:00:04 2020      facebook.com  185.60.216.35   443
# 7   Sat May 16 18:00:05 2020     instagram.com    52.5.39.111   443
# 9   Sat May 16 18:00:07 2020     instagram.com    52.2.38.102   443
# 11  Sat May 16 18:00:08 2020  www.whatsapp.com  185.60.216.53   443
#
#     DnsLookupTime  TCPHandshakeTime  ConnectionEstablishmentTime     TTFB  \
# 3          12.354           107.612                      256.224  389.083
# 5           4.201           107.084                      254.697  390.977
# 7           4.216           181.874                      415.187  645.929
# 9           4.223           181.428                      412.784  651.878
# 11          4.202           109.485                      260.161  402.874
#
#     TotalDownloadTime  HttpResponse HTTPVersion    Protocol
# 3             389.111           301    HTTP/1.1  TCP/TLS1.3
# 5             391.012           301       HTTP2  TCP/TLS1.3
# 7             645.977           301    HTTP/1.1  TCP/TLS1.3
# 9             651.915           301       HTTP2  TCP/TLS1.3
# 11            402.908           302    HTTP/1.1  TCP/TLS1.3

# %%
tcp13.tail()
# Out:
#                TimeOfMeasurement           Url              Ip  Port  \
# 323214  Wed May 20 17:31:30 2020        fb.com   185.60.216.35   443
# 323222  Wed May 20 17:32:14 2020        fb.com   185.60.216.35   443
# 323447  Wed May 20 17:46:44 2020  oculusvr.com  157.240.221.54   443
# 323654  Wed May 20 18:00:23 2020  facebook.com  157.240.221.35   443
# 323673  Wed May 20 18:01:04 2020  facebook.com  157.240.221.35   443
#
#         DnsLookupTime  TCPHandshakeTime  ConnectionEstablishmentTime  \
# 323214        119.054           125.665                    23267.337
# 323222         84.587           121.605                    22302.211
# 323447        120.438           121.864                    11510.546
# 323654         57.618           118.720                     3849.742
# 323673        169.547           159.154                    22035.326
#
#              TTFB  TotalDownloadTime  HttpResponse HTTPVersion    Protocol
# 323214  23432.171          23432.198           302    HTTP/1.1  TCP/TLS1.3
# 323222  22467.027          22467.060           302       HTTP2  TCP/TLS1.3
# 323447  11634.768          11634.798           301       HTTP2  TCP/TLS1.3
# 323654   3981.605           3981.632           301    HTTP/1.1  TCP/TLS1.3
# 323673  22199.867          22199.898           301       HTTP2  TCP/TLS1.3

# %%
tcp12_6 = tcp6.loc[s['Protocol'] == 'TCP/TLS1.2']
tcp13_6 = tcp6.loc[s['Protocol'] == 'TCP/TLS1.3']

# %%
tcp12_6.count()
# Out:
# TimeOfMeasurement              0
# Url                            0
# Ip                             0
# Port                           0
# DnsLookupTime                  0
# TCPHandshakeTime               0
# ConnectionEstablishmentTime    0
# TTFB                           0
# TotalDownloadTime              0
# HttpResponse                   0
# HTTPVersion                    0
# Protocol                       0
# dtype: int64

# %%
tcp12_6.head()
# Out:
# Empty DataFrame
# Columns: [TimeOfMeasurement, Url, Ip, Port, DnsLookupTime, TCPHandshakeTime, ConnectionEstablishmentTime, TTFB, TotalDownloadTime, HttpResponse, HTTPVersion, Protocol]
# Index: []

# %%
tcp12_6.tail()
# Out:
# Empty DataFrame
# Columns: [TimeOfMeasurement, Url, Ip, Port, DnsLookupTime, TCPHandshakeTime, ConnectionEstablishmentTime, TTFB, TotalDownloadTime, HttpResponse, HTTPVersion, Protocol]
# Index: []

# %%
tcp13_6.count()
# Out:
# TimeOfMeasurement              0
# Url                            0
# Ip                             0
# Port                           0
# DnsLookupTime                  0
# TCPHandshakeTime               0
# ConnectionEstablishmentTime    0
# TTFB                           0
# TotalDownloadTime              0
# HttpResponse                   0
# HTTPVersion                    0
# Protocol                       0
# dtype: int64

# %%
tcp13_6.head()
# Out:
# Empty DataFrame
# Columns: [TimeOfMeasurement, Url, Ip, Port, DnsLookupTime, TCPHandshakeTime, ConnectionEstablishmentTime, TTFB, TotalDownloadTime, HttpResponse, HTTPVersion, Protocol]
# Index: []

# %%
tcp13_6.tail()
# Out:
# Empty DataFrame
# Columns: [TimeOfMeasurement, Url, Ip, Port, DnsLookupTime, TCPHandshakeTime, ConnectionEstablishmentTime, TTFB, TotalDownloadTime, HttpResponse, HTTPVersion, Protocol]
# Index: []

# %%
x = Cdf.MakeCdfFromList(quic43['ConnectionEstablishmentTime'].values)
x1 =Cdf.MakeCdfFromList(quic50['ConnectionEstablishmentTime'].values)
x3 = Cdf.MakeCdfFromList(quic46['ConnectionEstablishmentTime'].values)
#x5 = Cdf.MakeCdfFromList(quic98['ConnectionEstablishmentTime'].values)
x6 = Cdf.MakeCdfFromList(quicID24['ConnectionEstablishmentTime'].values)
x4 = Cdf.MakeCdfFromList(tcp13['ConnectionEstablishmentTime'].values)
x2 =Cdf.MakeCdfFromList(tcp12['ConnectionEstablishmentTime'].values)

# %%
print_percentiles(x1, 'Q050')
print_percentiles(x2, 'tcp12')
print_percentiles(x3, 'Q046')
print_percentiles(x4, 'tcp13')
#print_percentiles(x5, 'Q098')
print_percentiles(x6, 'IETF h3-24')
print_percentiles(x, 'Q043')
# Out:
# -----------------------------
#
# percentile values distribution for Q050
#
# 20th Percentile:124.923000
#
# 25th Percentile:125.588000
#
# 40th Percentile:158.747000
#
# 50th Percentile:160.799000
#
# 60th Percentile:162.210000
#
# 75th Percentile:165.691000
#
# 80th Percentile:166.431000
#
# 90th Percentile:322.807000
#
# 99th Percentile:765.788000
#
# -----------------------------
#
# -----------------------------
#
# percentile values distribution for tcp12
#
# 20th Percentile:228.392000
#
# 25th Percentile:246.574000
#
# 40th Percentile:481.345000
#
# 50th Percentile:889.803000
#
# 60th Percentile:5383.143000
#
# 75th Percentile:9503.941000
#
# 80th Percentile:10728.104000
#
# 90th Percentile:13139.160000
#
# 99th Percentile:19053.469000
#
# -----------------------------
#
# -----------------------------
#
# percentile values distribution for Q046
#
# 20th Percentile:124.905000
#
# 25th Percentile:125.559000
#
# 40th Percentile:158.877000
#
# 50th Percentile:160.875000
#
# 60th Percentile:162.228000
#
# 75th Percentile:165.813000
#
# 80th Percentile:166.541000
#
# 90th Percentile:325.703000
#
# 99th Percentile:758.023000
#
# -----------------------------
#
# -----------------------------
#
# percentile values distribution for tcp13
#
# 20th Percentile:279.213000
#
# 25th Percentile:308.674000
#
# 40th Percentile:745.093000
#
# 50th Percentile:3849.742000
#
# 60th Percentile:8267.129000
#
# 75th Percentile:13401.629000
#
# 80th Percentile:15013.632000
#
# 90th Percentile:18877.615000
#
# 99th Percentile:26785.913000
#
# -----------------------------
#
# -----------------------------
#
# percentile values distribution for IETF h3-24
#
# 20th Percentile:162.443000
#
# 25th Percentile:166.422000
#
# 40th Percentile:244.242000
#
# 50th Percentile:251.243000
#
# 60th Percentile:288.160000
#
# 75th Percentile:332.507000
#
# 80th Percentile:374.496000
#
# 90th Percentile:410.265000
#
# 99th Percentile:851.638000
#
# -----------------------------
#
# -----------------------------
#
# percentile values distribution for Q043
#
# 20th Percentile:124.942000
#
# 25th Percentile:125.613000
#
# 40th Percentile:159.957000
#
# 50th Percentile:162.002000
#
# 60th Percentile:162.496000
#
# 75th Percentile:166.264000
#
# 80th Percentile:166.637000
#
# 90th Percentile:325.997000
#
# 99th Percentile:673.271000
#
# -----------------------------

# %%
data = {'$\\bf{Protocol}$': ['Q043', 'Q046', 'Q050', 'IETF ID-24', 'TCP1.2', 'TCP1.3'],
	'$\\bf{25th}$': ["{:.2f}".format(x.Percentile(25)), "{:.2f}".format(x3.Percentile(25)), "{:.2f}".format(x1.Percentile(25)), "{:.2f}".format(x6.Percentile(25)), "{:.2f}".format(x2.Percentile(25)), "{:.2f}".format(x4.Percentile(25))],
	'$\\bf{50th}$': ["{:.2f}".format(x.Percentile(50)), "{:.2f}".format(x3.Percentile(50)), "{:.2f}".format(x1.Percentile(50)), "{:.2f}".format(x6.Percentile(50)), "{:.2f}".format(x2.Percentile(50)), "{:.2f}".format(x4.Percentile(50))],
	'$\\bf{75th}$': ["{:.2f}".format(x.Percentile(75)), "{:.2f}".format(x3.Percentile(75)), "{:.2f}".format(x1.Percentile(75)), "{:.2f}".format(x6.Percentile(75)), "{:.2f}".format(x2.Percentile(75)), "{:.2f}".format(x4.Percentile(75))],
	'$\\bf{80th}$': ["{:.2f}".format(x.Percentile(80)), "{:.2f}".format(x3.Percentile(80)), "{:.2f}".format(x1.Percentile(80)), "{:.2f}".format(x6.Percentile(80)), "{:.2f}".format(x2.Percentile(80)), "{:.2f}".format(x4.Percentile(80))],
    '$\\bf{90th}$': ["{:.2f}".format(x.Percentile(90)), "{:.2f}".format(x3.Percentile(90)), "{:.2f}".format(x1.Percentile(90)), "{:.2f}".format(x6.Percentile(90)), "{:.2f}".format(x2.Percentile(90)), "{:.2f}".format(x4.Percentile(90))]
        }    

df_percentile = pd.DataFrame(data)

fig, ax = plt.subplots()

# hide axes
fig.patch.set_visible(False)
ax.axis('off')
ax.axis('tight')

ax.table(cellText=df_percentile.values, colLabels=df_percentile.columns, loc='center', cellLoc='center')

fig.tight_layout()
plt.savefig('./AWS/Mumbai/handshake_times_ipv4_percentile.png', format='png', bbox_inches='tight')
# Out:
# findfont: Font family ['monospace'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['monospace'] not found. Falling back to DejaVu Sans.

# %%
write_percentiles('Q050.csv', x1)
write_percentiles('tcp12.csv', x2)
write_percentiles('Q046.csv', x3)
write_percentiles('tcp13.csv', x4)
#write_percentiles('Q098.csv', x5)
write_percentiles('IETFh3-24', x6)
write_percentiles('Q043.csv', x)

# %%
fig = plt.figure(figsize = (10,3))
plt.rcParams['font.size'] = 12
ax = plt.gca()
yticks = np.arange(0,1.1,0.2)

#Q043
plt.plot(x.xs, x.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'orange')
#Q050
plt.plot(x1.xs, x1.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'red')
#Q046
plt.plot(x3.xs, x3.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'cyan')
#Q098
#plt.plot(x5.xs, x5.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'blue')
#IETF h3-24
plt.plot(x6.xs, x6.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color='yellow')
#TLS1.2
plt.plot(x2.xs, x2.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'green')
#TLS1.3
plt.plot(x4.xs, x4.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'black')


ax = fig.axes[0]
ax.grid(False)
ax.set_yticks(yticks)
#ax.set_ylim([0,1.05])
ax.set_xlim([0.01, 54000])
ax.set_xscale('log')
ax.set_xlabel('latency (x-axis is cut)', fontsize=12)
ax.set_ylabel('CDF', fontsize=12)

plt.legend(['Q043', 'Q050', 'Q046', 'IETF h3-24', 'TLS1.2', 'TLS1.3'], fontsize=11, loc='best')

ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.yaxis.set_ticks_position('left')
ax.xaxis.set_ticks_position('bottom')
ax.spines['bottom'].set_position(('axes', -0.05))
ax.spines['left'].set_position(('axes', -0.05))

ax3 = ax.twinx()
ax3.spines['right'].set_color('none')
ax3.spines['top'].set_color('none')
ax3.spines['left'].set_color('none')
ax3.spines['bottom'].set_color('none')
ax3.yaxis.set_ticks_position('none')
##ax3.set_ylabel('[\'16th May - \'20thMay')
plt.setp(ax3.get_yticklabels(), visible=False)

plt.title('Handshake Times with IPv4', fontsize=12, y=1.05)
plt.savefig('./AWS/Mumbai/handshake_times_ipv4.png', format='png', bbox_inches='tight')
# Out:
# findfont: Font family ['monospace'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['monospace'] not found. Falling back to DejaVu Sans.

# %%
x = Cdf.MakeCdfFromList(quic43['TTFB'].values)
x1 =Cdf.MakeCdfFromList(quic50['TTFB'].values)
x3 = Cdf.MakeCdfFromList(quic46['TTFB'].values)
#x5 = Cdf.MakeCdfFromList(quic98['TTFB'].values)
x6 = Cdf.MakeCdfFromList(quicID24['TTFB'].values)
x4 = Cdf.MakeCdfFromList(tcp13['TTFB'].values)
x2 =Cdf.MakeCdfFromList(tcp12['TTFB'].values)

# %%
write_percentiles('Q050.csv', x1)
write_percentiles('tcp12.csv', x2)
write_percentiles('Q046.csv', x3)
write_percentiles('tcp13.csv', x4)
#write_percentiles('Q098.csv', x5)
write_percentiles('IETFh3-24.csv', x6)
write_percentiles('Q043.csv', x)

# %%
print_percentiles(x1, 'Q050')
print_percentiles(x2, 'tcp12')
print_percentiles(x3, 'Q046')
print_percentiles(x4, 'tcp13')
#print_percentiles(x5, 'Q098')
print_percentiles(x6, 'IETFh3-24')
print_percentiles(x, 'Q043')
# Out:
# -----------------------------
#
# percentile values distribution for Q050
#
# 20th Percentile:247.526000
#
# 25th Percentile:326.999000
#
# 40th Percentile:448.350000
#
# 50th Percentile:473.658000
#
# 60th Percentile:491.079000
#
# 75th Percentile:533.221000
#
# 80th Percentile:568.366000
#
# 90th Percentile:726.594000
#
# 99th Percentile:926.459000
#
# -----------------------------
#
# -----------------------------
#
# percentile values distribution for tcp12
#
# 20th Percentile:655.331000
#
# 25th Percentile:780.795000
#
# 40th Percentile:1215.438000
#
# 50th Percentile:1792.608000
#
# 60th Percentile:5961.555000
#
# 75th Percentile:10068.003000
#
# 80th Percentile:11305.417000
#
# 90th Percentile:13708.378000
#
# 99th Percentile:19839.898000
#
# -----------------------------
#
# -----------------------------
#
# percentile values distribution for Q046
#
# 20th Percentile:249.082000
#
# 25th Percentile:336.563000
#
# 40th Percentile:448.710000
#
# 50th Percentile:475.921000
#
# 60th Percentile:491.321000
#
# 75th Percentile:533.629000
#
# 80th Percentile:569.280000
#
# 90th Percentile:727.609000
#
# 99th Percentile:926.623000
#
# -----------------------------
#
# -----------------------------
#
# percentile values distribution for tcp13
#
# 20th Percentile:426.286000
#
# 25th Percentile:457.640000
#
# 40th Percentile:982.908000
#
# 50th Percentile:4222.271000
#
# 60th Percentile:8474.433000
#
# 75th Percentile:13601.624000
#
# 80th Percentile:15199.571000
#
# 90th Percentile:19039.197000
#
# 99th Percentile:26986.544000
#
# -----------------------------
#
# -----------------------------
#
# percentile values distribution for IETFh3-24
#
# 20th Percentile:291.737000
#
# 25th Percentile:326.473000
#
# 40th Percentile:369.806000
#
# 50th Percentile:447.983000
#
# 60th Percentile:491.188000
#
# 75th Percentile:575.952000
#
# 80th Percentile:615.104000
#
# 90th Percentile:701.149000
#
# 99th Percentile:947.344000
#
# -----------------------------
#
# -----------------------------
#
# percentile values distribution for Q043
#
# 20th Percentile:287.991000
#
# 25th Percentile:384.444000
#
# 40th Percentile:452.011000
#
# 50th Percentile:489.198000
#
# 60th Percentile:494.635000
#
# 75th Percentile:536.054000
#
# 80th Percentile:575.560000
#
# 90th Percentile:738.061000
#
# 99th Percentile:938.482000
#
# -----------------------------

# %%
data = {'$\\bf{Protocol}$': ['Q043', 'Q046', 'Q050', 'IETF ID-24', 'TCP1.2', 'TCP1.3'],
	'$\\bf{25th}$': ["{:.2f}".format(x.Percentile(25)), "{:.2f}".format(x3.Percentile(25)), "{:.2f}".format(x1.Percentile(25)), "{:.2f}".format(x6.Percentile(25)), "{:.2f}".format(x2.Percentile(25)), "{:.2f}".format(x4.Percentile(25))],
	'$\\bf{50th}$': ["{:.2f}".format(x.Percentile(50)), "{:.2f}".format(x3.Percentile(50)), "{:.2f}".format(x1.Percentile(50)), "{:.2f}".format(x6.Percentile(50)), "{:.2f}".format(x2.Percentile(50)), "{:.2f}".format(x4.Percentile(50))],
	'$\\bf{75th}$': ["{:.2f}".format(x.Percentile(75)), "{:.2f}".format(x3.Percentile(75)), "{:.2f}".format(x1.Percentile(75)), "{:.2f}".format(x6.Percentile(75)), "{:.2f}".format(x2.Percentile(75)), "{:.2f}".format(x4.Percentile(75))],
	'$\\bf{80th}$': ["{:.2f}".format(x.Percentile(80)), "{:.2f}".format(x3.Percentile(80)), "{:.2f}".format(x1.Percentile(80)), "{:.2f}".format(x6.Percentile(80)), "{:.2f}".format(x2.Percentile(80)), "{:.2f}".format(x4.Percentile(80))],
    '$\\bf{90th}$': ["{:.2f}".format(x.Percentile(90)), "{:.2f}".format(x3.Percentile(90)), "{:.2f}".format(x1.Percentile(90)), "{:.2f}".format(x6.Percentile(90)), "{:.2f}".format(x2.Percentile(90)), "{:.2f}".format(x4.Percentile(90))]
        }    

df_percentile = pd.DataFrame(data)

fig, ax = plt.subplots()

# hide axes
fig.patch.set_visible(False)
ax.axis('off')
ax.axis('tight')

ax.table(cellText=df_percentile.values, colLabels=df_percentile.columns, loc='center', cellLoc='center')

fig.tight_layout()
plt.savefig('./AWS/Mumbai/TTFB_ipv4_percentile.png', format='png', bbox_inches='tight')
# Out:
# findfont: Font family ['monospace'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['monospace'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['monospace'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['monospace'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['monospace'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['monospace'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['monospace'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['monospace'] not found. Falling back to DejaVu Sans.

# %%
fig = plt.figure(figsize = (10,3))
plt.rcParams['font.size'] = 12
ax = plt.gca()
yticks = np.arange(0,1.1,0.2)

#Q043
plt.plot(x.xs, x.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'orange')
#Q050
plt.plot(x1.xs, x1.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'red')
#Q046
plt.plot(x3.xs, x3.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'cyan')
#Q098
#plt.plot(x5.xs, x5.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'blue')
#IETF h3-24
plt.plot(x6.xs, x6.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'yellow')
#TLS1.2
plt.plot(x2.xs, x2.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'green')
#TLS1.3
plt.plot(x4.xs, x4.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'black')


ax = fig.axes[0]
ax.grid(False)
ax.set_yticks(yticks)
#ax.set_ylim([0,1.05])
ax.set_xlim([0.01,58000])
ax.set_xscale('log')
ax.set_xlabel('TTFB', fontsize=12)
ax.set_ylabel('CDF', fontsize=12)

plt.legend(['Q043', 'Q050', 'Q046', 'IETFh3-24', 'TLS1.2', 'TLS1.3'], fontsize=11, loc='best')

ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.yaxis.set_ticks_position('left')
ax.xaxis.set_ticks_position('bottom')
ax.spines['bottom'].set_position(('axes', -0.05))
ax.spines['left'].set_position(('axes', -0.05))

ax3 = ax.twinx()
ax3.spines['right'].set_color('none')
ax3.spines['top'].set_color('none')
ax3.spines['left'].set_color('none')
ax3.spines['bottom'].set_color('none')
ax3.yaxis.set_ticks_position('none')
##ax3.set_ylabel('[\'11th Oct - \'11th Nov')
plt.setp(ax3.get_yticklabels(), visible=False)

plt.title('TTFB with IPv4', fontsize=12, y=1.05)
plt.savefig('./AWS/Mumbai/TTFB_ipv4.png', format='png', bbox_inches='tight')

# %%
x = Cdf.MakeCdfFromList(quic43['TotalDownloadTime'].values)
x1 =Cdf.MakeCdfFromList(quic50['TotalDownloadTime'].values)
x3 = Cdf.MakeCdfFromList(quic46['TotalDownloadTime'].values)
#x5 = Cdf.MakeCdfFromList(quic98['TotalDownloadTime'].values)
x6 = Cdf.MakeCdfFromList(quicID24['TotalDownloadTime'].values)
x4 = Cdf.MakeCdfFromList(tcp13['TotalDownloadTime'].values)
x2 =Cdf.MakeCdfFromList(tcp12['TotalDownloadTime'].values)

# %%
write_percentiles('Q050.csv', x1)
write_percentiles('tcp12.csv', x2)
write_percentiles('Q046.csv', x3)
write_percentiles('tcp13.csv', x4)
#write_percentiles('Q098.csv', x5)
write_percentiles('IETFh3-24.csv', x6)
write_percentiles('Q043.csv', x)

# %%
print_percentiles(x1, 'Q050')
print_percentiles(x2, 'tcp12')
print_percentiles(x3, 'Q046')
print_percentiles(x4, 'tcp13')
#print_percentiles(x5, 'Q098')
print_percentiles(x6, 'IETFh3-24')
print_percentiles(x, 'Q043')
# Out:
# -----------------------------
#
# percentile values distribution for Q050
#
# 20th Percentile:241.089000
#
# 25th Percentile:284.989000
#
# 40th Percentile:442.567000
#
# 50th Percentile:464.916000
#
# 60th Percentile:490.465000
#
# 75th Percentile:533.962000
#
# 80th Percentile:575.483000
#
# 90th Percentile:763.523000
#
# 99th Percentile:944.593000
#
# -----------------------------
#
# -----------------------------
#
# percentile values distribution for tcp12
#
# 20th Percentile:697.269000
#
# 25th Percentile:844.557000
#
# 40th Percentile:1325.117000
#
# 50th Percentile:1978.763000
#
# 60th Percentile:6061.625000
#
# 75th Percentile:10157.285000
#
# 80th Percentile:11400.120000
#
# 90th Percentile:13810.117000
#
# 99th Percentile:20088.824000
#
# -----------------------------
#
# -----------------------------
#
# percentile values distribution for Q046
#
# 20th Percentile:242.315000
#
# 25th Percentile:285.764000
#
# 40th Percentile:444.348000
#
# 50th Percentile:467.102000
#
# 60th Percentile:490.715000
#
# 75th Percentile:534.561000
#
# 80th Percentile:578.917000
#
# 90th Percentile:765.321000
#
# 99th Percentile:944.581000
#
# -----------------------------
#
# -----------------------------
#
# percentile values distribution for tcp13
#
# 20th Percentile:426.318000
#
# 25th Percentile:457.689000
#
# 40th Percentile:1073.951000
#
# 50th Percentile:4222.300000
#
# 60th Percentile:8474.463000
#
# 75th Percentile:13643.256000
#
# 80th Percentile:15264.275000
#
# 90th Percentile:19051.602000
#
# 99th Percentile:26986.607000
#
# -----------------------------
#
# -----------------------------
#
# percentile values distribution for IETFh3-24
#
# 20th Percentile:288.279000
#
# 25th Percentile:326.092000
#
# 40th Percentile:415.207000
#
# 50th Percentile:490.575000
#
# 60th Percentile:531.001000
#
# 75th Percentile:626.959000
#
# 80th Percentile:656.313000
#
# 90th Percentile:739.007000
#
# 99th Percentile:981.660000
#
# -----------------------------
#
# -----------------------------
#
# percentile values distribution for Q043
#
# 20th Percentile:254.399000
#
# 25th Percentile:344.611000
#
# 40th Percentile:450.269000
#
# 50th Percentile:484.145000
#
# 60th Percentile:494.174000
#
# 75th Percentile:536.824000
#
# 80th Percentile:605.055000
#
# 90th Percentile:777.629000
#
# 99th Percentile:948.752000
#
# -----------------------------

# %%
data = {'$\\bf{Protocol}$': ['Q043', 'Q046', 'Q050', 'IETF ID-24', 'TCP1.2', 'TCP1.3'],
	'$\\bf{25th}$': ["{:.2f}".format(x.Percentile(25)), "{:.2f}".format(x3.Percentile(25)), "{:.2f}".format(x1.Percentile(25)), "{:.2f}".format(x6.Percentile(25)), "{:.2f}".format(x2.Percentile(25)), "{:.2f}".format(x4.Percentile(25))],
	'$\\bf{50th}$': ["{:.2f}".format(x.Percentile(50)), "{:.2f}".format(x3.Percentile(50)), "{:.2f}".format(x1.Percentile(50)), "{:.2f}".format(x6.Percentile(50)), "{:.2f}".format(x2.Percentile(50)), "{:.2f}".format(x4.Percentile(50))],
	'$\\bf{75th}$': ["{:.2f}".format(x.Percentile(75)), "{:.2f}".format(x3.Percentile(75)), "{:.2f}".format(x1.Percentile(75)), "{:.2f}".format(x6.Percentile(75)), "{:.2f}".format(x2.Percentile(75)), "{:.2f}".format(x4.Percentile(75))],
	'$\\bf{80th}$': ["{:.2f}".format(x.Percentile(80)), "{:.2f}".format(x3.Percentile(80)), "{:.2f}".format(x1.Percentile(80)), "{:.2f}".format(x6.Percentile(80)), "{:.2f}".format(x2.Percentile(80)), "{:.2f}".format(x4.Percentile(80))],
    '$\\bf{90th}$': ["{:.2f}".format(x.Percentile(90)), "{:.2f}".format(x3.Percentile(90)), "{:.2f}".format(x1.Percentile(90)), "{:.2f}".format(x6.Percentile(90)), "{:.2f}".format(x2.Percentile(90)), "{:.2f}".format(x4.Percentile(90))]
        }    

df_percentile = pd.DataFrame(data)

fig, ax = plt.subplots()

# hide axes
fig.patch.set_visible(False)
ax.axis('off')
ax.axis('tight')

ax.table(cellText=df_percentile.values, colLabels=df_percentile.columns, loc='center', cellLoc='center')

fig.tight_layout()
plt.savefig('./AWS/Mumbai/TotalDownloadTime_ipv4_percentile.png', format='png', bbox_inches='tight')
# Out:
# findfont: Font family ['monospace'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['monospace'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['monospace'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['monospace'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['monospace'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['monospace'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['monospace'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['monospace'] not found. Falling back to DejaVu Sans.

# %%
fig = plt.figure(figsize = (10,3))
plt.rcParams['font.size'] = 12
ax = plt.gca()
yticks = np.arange(0,1.1,0.2)

#Q043
plt.plot(x.xs, x.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'orange')
#Q039
plt.plot(x1.xs, x1.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'red')
#Q044
plt.plot(x3.xs, x3.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'cyan')
#Q098
#plt.plot(x5.xs, x5.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'blue')
#IETF h3-24
plt.plot(x6.xs, x6.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'yellow')
#TLS1.2
plt.plot(x2.xs, x2.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'green')
#TLS1.3
plt.plot(x4.xs, x4.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'black')


ax = fig.axes[0]
ax.grid(False)
ax.set_yticks(yticks)
#ax.set_ylim([0,1.05])
#ax.set_xlim([20,1000])
ax.set_xlim([0.01,58000])
ax.set_xscale('log')
ax.set_xlabel('TotalDownloadTime', fontsize=12)
ax.set_ylabel('CDF', fontsize=12)

plt.legend(['Q043', 'Q050', 'Q046', 'IETF h3-24', 'TLS1.2', 'TLS1.3'], fontsize=11, loc='best')

ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.yaxis.set_ticks_position('left')
ax.xaxis.set_ticks_position('bottom')
ax.spines['bottom'].set_position(('axes', -0.05))
ax.spines['left'].set_position(('axes', -0.05))

ax3 = ax.twinx()
ax3.spines['right'].set_color('none')
ax3.spines['top'].set_color('none')
ax3.spines['left'].set_color('none')
ax3.spines['bottom'].set_color('none')
ax3.yaxis.set_ticks_position('none')
##ax3.set_ylabel('[\'11th Oct - \'11th Nov')
plt.setp(ax3.get_yticklabels(), visible=False)

plt.title('TotalDownloadTime with IPv4', fontsize=12, y=1.05)
plt.savefig('./AWS/Mumbai/TotalDownloadTime_ipv4.png', format='png', bbox_inches='tight')
