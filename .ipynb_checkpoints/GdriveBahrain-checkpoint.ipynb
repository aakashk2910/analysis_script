# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import time
import datetime
import filterbyip as fbi
import Cdf
import Pmf

# %%
# %autosave 0
# Out:
# Autosave disabled

# %%
import warnings
warnings.filterwarnings('ignore')

# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from IPython.core.display import HTML
css = open('style-table.css').read() + open('style-notebook.css').read()
HTML('<style>{}</style>'.format(css))
# Out:
# <style>body {
#     margin: 0;
#     font-family: Helvetica;
# }
# table.dataframe {
#     border-collapse: collapse;
#     border: none;
# }
# table.dataframe tr {
#     border: none;
# }
# table.dataframe td, table.dataframe th {
#     margin: 0;
#     border: 1px solid white;
#     padding-left: 0.25em;
#     padding-right: 0.25em;
# }
# table.dataframe th:not(:empty) {
#     background-color: #fec;
#     text-align: left;
#     font-weight: normal;
# }
# table.dataframe tr:nth-child(2) th:empty {
#     border-left: none;
#     border-right: 1px dashed #888;
# }
# table.dataframe td {
#     border: 2px solid #ccf;
#     background-color: #f4f4ff;
# }
# h3 {
#     color: white;
#     background-color: black;
#     padding: 0.5em;
# }
#
# .CodeMirror {
#     font-family: 'Consolas';
# }
#
# div.cell.code_cell {
#     font-family: 'Consolas';
# }
#
# div.output_area pre {
#     font-family: 'Consolas';
# }
# </style>

# %%
#change 
tcp_tls_data = "./AWS_results/Bahrain/data/output_curl_gdrive.csv"
quic_data = "./AWS_results/Bahrain/data/output_quic_gdrive.csv"
gdrive = "./data2020/gdrive_id.csv"

# %%
scol_names = ['TimeOfMeasurement', 'Url', 'Ip', 'Port', 'DnsLookupTime', 'TCPHandshakeTime', 'ConnectionEstablishmentTime', 'TTFB', 'TotalDownloadTime', 'HttpResponse', 'HTTPVersion', 'Protocol']
tcol_names = ['TimeOfMeasurement', 'Url', 'Path', 'Ip', 'Port', 'DNSTime', 'ConnectionEstablishmentTime', 'TTFB', 'TotalDownloadTime', 'HttpResponse', 'Protocol']
g_names = ['size', 'id']

# %%
t = pd.read_csv(quic_data, ';', names=tcol_names, header=None)
s = pd.read_csv(tcp_tls_data, ';', names=scol_names, header=None)
gd = pd.read_csv(gdrive, ',', names=g_names, header=None)

# %%
t = t.dropna()
s=s.dropna()
s['TTFB']=s['TTFB']-s['DnsLookupTime']
s['TotalDownloadTime']=s['TotalDownloadTime']-s['DnsLookupTime']

# %%
import re
def extract_id(path):
    id = re.search('\*\/(.*)\?', path)
    return id.group(1)

# %%
t['id'] = t['Path'].apply(extract_id)

# %%
import re
def substitute(string):
    replaced = string
    if re.search('K', string):
        replaced = re.sub('K','', string)
    if re.search('M', string):
        replaced = re.sub('M','000', string)
    if re.search('G', string):
        replaced = re.sub('G','000000', string)
    return replaced

# %%
gd['size'] = gd['size'].apply(substitute)

# %%
s['id'] = s['Url'].apply(extract_id)

# %%
t['Url'] = t['Url'] + t['Path']

# %%
t = t.join(gd.set_index('id'), on='id', rsuffix='_right')

# %%
s = s.join(gd.set_index('id'), on='id', rsuffix='_right')

# %%
t['size'] = t['size'].astype(int)
s['size'] = s['size'].astype(int)
t['TotalDownloadTime'] = t['TotalDownloadTime'].astype(float)
s['TotalDownloadTime'] = s['TotalDownloadTime'].astype(float)

# %%
t['Throughput'] = (t['size']/t['TotalDownloadTime'])

# %%
s['Throughput'] = (s['size']/s['TotalDownloadTime'])

# %%
t.head()
# Out:
#    TimeOfMeasurement                                                Url  \
# 0       1.589616e+09  doc-10-4c-docs.googleusercontent.com/docs/secu...
# 1       1.589616e+09  doc-10-4c-docs.googleusercontent.com/docs/secu...
# 2       1.589616e+09  doc-10-4c-docs.googleusercontent.com/docs/secu...
# 8       1.589616e+09  doc-0g-4c-docs.googleusercontent.com/docs/secu...
# 9       1.589616e+09  doc-0g-4c-docs.googleusercontent.com/docs/secu...
#
#                                                 Path              Ip Port  \
# 0  /docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp...  216.58.208.225  443
# 1  /docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp...  216.58.208.225  443
# 2  /docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp...  216.58.208.225  443
# 8  /docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp...  216.58.208.225  443
# 9  /docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp...  216.58.208.225  443
#
#    DNSTime  ConnectionEstablishmentTime     TTFB  TotalDownloadTime  \
# 0  123.299                      236.873  461.705            461.770
# 1    1.402                      236.897  472.002            472.054
# 2   78.057                      249.816  474.559            474.608
# 8   17.431                      240.862  461.163            461.228
# 9   21.204                      249.999  479.340            479.391
#
#    HttpResponse Protocol                                 id  size  Throughput
# 0         403.0     Q043  1C45gZCBtJHnjNACQIagfJ2fTRKQaZ9k6     1    0.002166
# 1         403.0     Q046  1C45gZCBtJHnjNACQIagfJ2fTRKQaZ9k6     1    0.002118
# 2         403.0     Q050  1C45gZCBtJHnjNACQIagfJ2fTRKQaZ9k6     1    0.002107
# 8         403.0     Q043  1yv4XxH7R74il-bxBS5Mz8Oiw6W7vwUFM     2    0.004336
# 9         403.0     Q046  1yv4XxH7R74il-bxBS5Mz8Oiw6W7vwUFM     2    0.004172

# %%
t.tail()
# Out:
#        TimeOfMeasurement                                                Url  \
# 31840       1.589991e+09  doc-10-4c-docs.googleusercontent.com/docs/secu...
# 31841       1.589991e+09  doc-10-4c-docs.googleusercontent.com/docs/secu...
# 31842       1.589991e+09  doc-10-4c-docs.googleusercontent.com/docs/secu...
# 31848       1.589991e+09  doc-00-4c-docs.googleusercontent.com/docs/secu...
# 31849       1.589991e+09  doc-00-4c-docs.googleusercontent.com/docs/secu...
#
#                                                     Path              Ip Port  \
# 31840  /docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp...  216.58.208.225  443
# 31841  /docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp...  216.58.208.225  443
# 31842  /docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp...  216.58.208.225  443
# 31848  /docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp...   172.217.21.33  443
# 31849  /docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp...   172.217.21.33  443
#
#        DNSTime  ConnectionEstablishmentTime     TTFB  TotalDownloadTime  \
# 31840    1.117                      237.103  279.247            279.288
# 31841    0.416                      236.214  720.629            720.675
# 31842    0.389                      238.603  915.822            915.871
# 31848    1.137                      239.058  354.372            354.437
# 31849    0.512                      236.691  537.850            537.898
#
#        HttpResponse Protocol                                 id   size  \
# 31840         403.0     Q043  17FDkQ_mxEpI6k2q5pFZSS2VL0F0W8T-j  10000
# 31841         403.0     Q046  17FDkQ_mxEpI6k2q5pFZSS2VL0F0W8T-j  10000
# 31842         403.0     Q050  17FDkQ_mxEpI6k2q5pFZSS2VL0F0W8T-j  10000
# 31848         403.0     Q043  1n4w3UAJg8_g3RKTlEnfbqi10NbywEpRS  20000
# 31849         403.0     Q046  1n4w3UAJg8_g3RKTlEnfbqi10NbywEpRS  20000
#
#        Throughput
# 31840   35.805334
# 31841   13.875880
# 31842   10.918568
# 31848   56.427517
# 31849   37.181771

# %%
s.head()
# Out:
#    TimeOfMeasurement                                                Url  \
# 0         1589702404  doc-10-4c-docs.googleusercontent.com/docs/secu...
# 1         1589702405  doc-10-4c-docs.googleusercontent.com/docs/secu...
# 2         1589702407  doc-0g-4c-docs.googleusercontent.com/docs/secu...
# 3         1589702408  doc-0g-4c-docs.googleusercontent.com/docs/secu...
# 4         1589702410  doc-0o-4c-docs.googleusercontent.com/docs/secu...
#
#                Ip  Port  DnsLookupTime  TCPHandshakeTime  \
# 0  172.217.19.161   443         64.888             9.577
# 1  172.217.19.161   443         14.538             9.951
# 2  216.58.208.225   443          8.015             9.576
# 3  216.58.208.225   443         60.435             9.978
# 4  216.58.208.225   443          5.780            11.925
#
#    ConnectionEstablishmentTime     TTFB  TotalDownloadTime  HttpResponse  \
# 0                      492.132  713.357            713.380           403
# 1                      243.840  468.142            468.426           403
# 2                      248.296  469.418            469.439           403
# 3                      180.880  397.887            397.998           403
# 4                      275.980  502.655            502.682           403
#
#   HTTPVersion    Protocol                                 id  size  Throughput
# 0    HTTP/1.1  TCP/TLS1.2  1C45gZCBtJHnjNACQIagfJ2fTRKQaZ9k6     1    0.001402
# 1       HTTP2  TCP/TLS1.2  1C45gZCBtJHnjNACQIagfJ2fTRKQaZ9k6     1    0.002135
# 2    HTTP/1.1  TCP/TLS1.2  1yv4XxH7R74il-bxBS5Mz8Oiw6W7vwUFM     2    0.004260
# 3       HTTP2  TCP/TLS1.2  1yv4XxH7R74il-bxBS5Mz8Oiw6W7vwUFM     2    0.005025
# 4    HTTP/1.1  TCP/TLS1.2  1sGGy4K1J3p0OQlLxUgbgsErokyBADg6g     5    0.009947

# %%
s.tail()
# Out:
#       TimeOfMeasurement                                                Url  \
# 6357         1589990772  doc-0k-4c-docs.googleusercontent.com/docs/secu...
# 6358         1589990802  doc-0o-4c-docs.googleusercontent.com/docs/secu...
# 6359         1589990811  doc-0o-4c-docs.googleusercontent.com/docs/secu...
# 6360         1589990840  doc-10-4c-docs.googleusercontent.com/docs/secu...
# 6361         1589990847  doc-10-4c-docs.googleusercontent.com/docs/secu...
#
#                   Ip  Port  DnsLookupTime  TCPHandshakeTime  \
# 6357  216.58.208.225   443          4.159            10.016
# 6358    216.58.207.1   443          4.148             9.467
# 6359    216.58.207.1   443          4.151             9.843
# 6360  216.58.208.225   443          4.170             9.838
# 6361  216.58.208.225   443          4.159             9.518
#
#       ConnectionEstablishmentTime      TTFB  TotalDownloadTime  HttpResponse  \
# 6357                      177.447  7932.331           7932.389           403
# 6358                      182.242  9041.061           9041.089           403
# 6359                      172.858  8940.121           8940.175           403
# 6360                      183.086  6129.469           6129.499           403
# 6361                      211.531  7410.469           7410.540           403
#
#      HTTPVersion    Protocol                                 id   size  \
# 6357       HTTP2  TCP/TLS1.2  1YwHj4UwGJav3iDkkStK7wMkxwqv9awo2   2000
# 6358    HTTP/1.1  TCP/TLS1.2  1lRw0EJonTmPHAOFvI4HvnvERfIbe8E_D   5000
# 6359       HTTP2  TCP/TLS1.2  1lRw0EJonTmPHAOFvI4HvnvERfIbe8E_D   5000
# 6360    HTTP/1.1  TCP/TLS1.2  17FDkQ_mxEpI6k2q5pFZSS2VL0F0W8T-j  10000
# 6361       HTTP2  TCP/TLS1.2  17FDkQ_mxEpI6k2q5pFZSS2VL0F0W8T-j  10000
#
#       Throughput
# 6357    0.252131
# 6358    0.553031
# 6359    0.559273
# 6360    1.631455
# 6361    1.349429

# %%
gd.head()
# Out:
#   size                                 id
# 0    1  1C45gZCBtJHnjNACQIagfJ2fTRKQaZ9k6
# 1    2  1yv4XxH7R74il-bxBS5Mz8Oiw6W7vwUFM
# 2    5  1sGGy4K1J3p0OQlLxUgbgsErokyBADg6g
# 3   10  1k7mg8XpQmW-jpO85yq3giwVUeL82NJhx
# 4   20  1Zr-g4qROFzaq_vZ4JnHneEb9JyRSUBXb

# %%
t = t.dropna()
s = s.dropna()

# %%
def filter_by_ip(df, column):
  """reads a DataFrame, calls fbi.filter_v{4,6} to get DataFrames with rows
     containing only v4, v6 endpoints. Returns the two DataFrame as a tuple"""

  dfv6 = fbi.filter_v6(df, column)
  dfv4 = fbi.filter_v4(df, column)
  return dfv4, dfv6

# %%
quic4, quic6 = filter_by_ip(t, column = 'Ip')

# %%
tcp4, tcp6 = filter_by_ip(s, column = 'Ip')

# %%
#quic4 = quic4.loc[quic4['size']<500]
#tcp4 = tcp4.loc[tcp4['size']<500]

# %%
quic43 = quic4.loc[t['Protocol'] == 'Q043']
quic46 = quic4.loc[t['Protocol'] == 'Q046']
quic50 = quic4.loc[t['Protocol'] == 'Q050']
quicietf = quic4.loc[t['Protocol'] == 'FF000018']

# %%
quic43_6 = quic6.loc[t['Protocol'] == 'Q043']
quic46_6 = quic6.loc[t['Protocol'] == 'Q046']
quic50_6 = quic6.loc[t['Protocol'] == 'Q050']
quicietf_6 = quic6.loc[t['Protocol'] == 'FF000018']

# %%
tcp12 = tcp4.loc[s['Protocol'] == 'TCP/TLS1.2']
tcp13 = tcp4.loc[s['Protocol'] == 'TCP/TLS1.3']

# %%
tcp12_6 = tcp6.loc[s['Protocol'] == 'TCP/TLS1.2']
tcp13_6 = tcp6.loc[s['Protocol'] == 'TCP/TLS1.3']

# %%
x = Cdf.MakeCdfFromList(quic43['ConnectionEstablishmentTime'].values)
x1 = Cdf.MakeCdfFromList(quic46['ConnectionEstablishmentTime'].values)
x3 = Cdf.MakeCdfFromList(quic50['ConnectionEstablishmentTime'].values)
x5 = Cdf.MakeCdfFromList(quicietf['ConnectionEstablishmentTime'].values)
x4 = Cdf.MakeCdfFromList(tcp13['ConnectionEstablishmentTime'].values)
x2 = Cdf.MakeCdfFromList(tcp12['ConnectionEstablishmentTime'].values)

# %%
fig = plt.figure(figsize = (10,3))
plt.rcParams['font.size'] = 12
ax = plt.gca()
yticks = np.arange(0,1.1,0.2)

#Q043
plt.plot(x.xs, x.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'orange')
#Q046
plt.plot(x1.xs, x1.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'red')
#Q050
plt.plot(x3.xs, x3.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'green')
#Q0ietf
plt.plot(x5.xs, x5.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'blue')
#TLS1.2
plt.plot(x2.xs, x2.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'cyan')
#TLS1.3
plt.plot(x4.xs, x4.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'black')


ax = fig.axes[0]
ax.grid(False)
ax.set_yticks(yticks)
ax.set_ylim([0,1.05])
#ax.set_xlim([20, 100])
ax.set_xscale('log')
ax.set_xlabel('latency (x-axis is cut)', fontsize=12)
ax.set_ylabel('CDF', fontsize=12)

plt.legend(['Q043', 'Q046', 'Q050', 'IETF', 'TLS1.2', 'TLS 1.3'], fontsize=11, loc='best')

ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.yaxis.set_ticks_position('left')
ax.xaxis.set_ticks_position('bottom')
ax.spines['bottom'].set_position(('axes', -0.05))
ax.spines['left'].set_position(('axes', -0.05))

ax3 = ax.twinx()
ax3.spines['right'].set_color('none')
ax3.spines['top'].set_color('none')
ax3.spines['left'].set_color('none')
ax3.spines['bottom'].set_color('none')
ax3.yaxis.set_ticks_position('none')
plt.setp(ax3.get_yticklabels(), visible=False)

plt.title('Handshake Times with IPv4', fontsize=12, y=1.05)
plt.savefig('./AWS/Bahrain/gdrive/handshake_times_ipv4_otherthan200.png', format='png', bbox_inches='tight')

# %%
x = Cdf.MakeCdfFromList(quic43['TTFB'].values)
x1 =Cdf.MakeCdfFromList(quic46['TTFB'].values)
x3 = Cdf.MakeCdfFromList(quic50['TTFB'].values)
x5 = Cdf.MakeCdfFromList(quicietf['TTFB'].values)
x4 = Cdf.MakeCdfFromList(tcp13['TTFB'].values)
x2 =Cdf.MakeCdfFromList(tcp12['TTFB'].values)

# %%
fig = plt.figure(figsize = (10,3))
plt.rcParams['font.size'] = 12
ax = plt.gca()
yticks = np.arange(0,1.1,0.2)

#Q043
plt.plot(x.xs, x.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'orange')
#Q046
plt.plot(x1.xs, x1.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'red')
#Q050
plt.plot(x3.xs, x3.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'green')
#IETF
plt.plot(x5.xs, x5.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'blue')
#TLS1.2
plt.plot(x2.xs, x2.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'cyan')
#TLS1.3
plt.plot(x4.xs, x4.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'black')


ax = fig.axes[0]
ax.grid(False)
ax.set_yticks(yticks)
ax.set_ylim([0,1.05])
#ax.set_xlim([100, 600])
ax.set_xscale('log')
ax.set_xlabel('TTFB', fontsize=12)
ax.set_ylabel('CDF', fontsize=12)

plt.legend(['Q043', 'Q046', 'Q050', 'IETF', 'TLS1.2', 'TLS 1.3'], fontsize=11, loc='best')

ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.yaxis.set_ticks_position('left')
ax.xaxis.set_ticks_position('bottom')
ax.spines['bottom'].set_position(('axes', -0.05))
ax.spines['left'].set_position(('axes', -0.05))

ax3 = ax.twinx()
ax3.spines['right'].set_color('none')
ax3.spines['top'].set_color('none')
ax3.spines['left'].set_color('none')
ax3.spines['bottom'].set_color('none')
ax3.yaxis.set_ticks_position('none')
plt.setp(ax3.get_yticklabels(), visible=False)

plt.title('TTFB with IPv4', fontsize=12, y=1.05)
plt.savefig('./AWS/Bahrain/gdrive/TTFB_ipv4.png', format='png', bbox_inches='tight')

# %%
x = Cdf.MakeCdfFromList(quic43['TotalDownloadTime'].values)
x1 =Cdf.MakeCdfFromList(quic46['TotalDownloadTime'].values)
x3 = Cdf.MakeCdfFromList(quic50['TotalDownloadTime'].values)
x5 = Cdf.MakeCdfFromList(quicietf['TotalDownloadTime'].values)
x4 = Cdf.MakeCdfFromList(tcp13['TotalDownloadTime'].values)
x2 =Cdf.MakeCdfFromList(tcp12['TotalDownloadTime'].values)

# %%
fig = plt.figure(figsize = (10,3))
plt.rcParams['font.size'] = 12
ax = plt.gca()
yticks = np.arange(0,1.1,0.2)

#Q043
plt.plot(x.xs, x.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'orange')
#Q046
plt.plot(x1.xs, x1.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'red')
#Q050
plt.plot(x3.xs, x3.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'green')
#IETF
plt.plot(x5.xs, x5.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'blue')
#TLS1.2
plt.plot(x2.xs, x2.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'cyan')
#TLS1.3
plt.plot(x4.xs, x4.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'black')


ax = fig.axes[0]
ax.grid(False)
ax.set_yticks(yticks)
ax.set_ylim([0,1.05])
#ax.set_xlim([100,800])
#ax.set_xlim([0,10])
ax.set_xscale('log')
ax.set_xlabel('TotalDownloadTime', fontsize=12)
ax.set_ylabel('CDF', fontsize=12)

plt.legend(['Q043', 'Q046', 'Q050', 'IETF', 'TLS1.2', 'TLS 1.3'], fontsize=11, loc='best')

ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.yaxis.set_ticks_position('left')
ax.xaxis.set_ticks_position('bottom')
ax.spines['bottom'].set_position(('axes', -0.05))
ax.spines['left'].set_position(('axes', -0.05))

ax3 = ax.twinx()
ax3.spines['right'].set_color('none')
ax3.spines['top'].set_color('none')
ax3.spines['left'].set_color('none')
ax3.spines['bottom'].set_color('none')
ax3.yaxis.set_ticks_position('none')
plt.setp(ax3.get_yticklabels(), visible=False)

plt.title('TotalDownloadTime with IPv4', fontsize=12, y=1.05)
plt.savefig('./AWS/Bahrain/gdrive/TotalDownloadTime_ipv4.png', format='png', bbox_inches='tight')

# %%
x = Cdf.MakeCdfFromList(quic43['Throughput'].values)
x1 =Cdf.MakeCdfFromList(quic46['Throughput'].values)
x3 = Cdf.MakeCdfFromList(quic50['Throughput'].values)
x5 = Cdf.MakeCdfFromList(quicietf['Throughput'].values)
x4 = Cdf.MakeCdfFromList(tcp13['Throughput'].values)
x2 =Cdf.MakeCdfFromList(tcp12['Throughput'].values)

# %%
fig = plt.figure(figsize = (10,3))
plt.rcParams['font.size'] = 12
ax = plt.gca()
yticks = np.arange(0,1.1,0.2)

#Q043
plt.plot(x.xs, x.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'orange')
#Q046
plt.plot(x1.xs, x1.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'red')
#Q050
plt.plot(x3.xs, x3.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'green')
#IETF
plt.plot(x5.xs, x5.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'blue')
#TLS1.2
plt.plot(x2.xs, x2.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'cyan')
#TLS1.3
plt.plot(x4.xs, x4.ps, marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'black')


ax = fig.axes[0]
ax.grid(False)
ax.set_yticks(yticks)
ax.set_ylim([0,1.05])
#ax.set_xlim([0,700])
#ax.set_xlim([0,10])
ax.set_xscale('log')
ax.set_xlabel('Throughput in MB/s', fontsize=12)
ax.set_ylabel('CDF', fontsize=12)

plt.legend(['Q043', 'Q046', 'Q050', 'IETF', 'TLS1.2', 'TLS 1.3'], fontsize=11, loc='best')

ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.yaxis.set_ticks_position('left')
ax.xaxis.set_ticks_position('bottom')
ax.spines['bottom'].set_position(('axes', -0.05))
ax.spines['left'].set_position(('axes', -0.05))

ax3 = ax.twinx()
ax3.spines['right'].set_color('none')
ax3.spines['top'].set_color('none')
ax3.spines['left'].set_color('none')
ax3.spines['bottom'].set_color('none')
ax3.yaxis.set_ticks_position('none')
#ax3.set_ylabel('[\'16thMay - \'20thMay')
plt.setp(ax3.get_yticklabels(), visible=False)

plt.title('Throughput with IPv4', fontsize=12, y=1.05)
plt.savefig('./AWS/Bahrain/gdrive/Throughput_ipv4.png', format='png', bbox_inches='tight')

# %%
quic_mean= quic4.groupby('size', as_index=False).mean()
tcp_mean= tcp4.groupby('size', as_index=False).mean()

quic_mean.head()

quic_mean.tail()
# Out:
#       size  TimeOfMeasurement   DNSTime  ConnectionEstablishmentTime  \
# 11    5000       1.589801e+09  4.496454                   237.664635
# 12   10000       1.589801e+09  5.661365                   237.552898
# 13   20000       1.589801e+09  4.764138                   237.293450
# 14   50000       1.589800e+09  5.546801                   237.776685
# 15  100000       1.589800e+09  4.512995                   237.953876
#
#           TTFB  TotalDownloadTime  HttpResponse  Throughput
# 11  504.403941         504.460497         403.0   29.753919
# 12  491.925367         491.980605         403.0   74.734862
# 13  499.734229         499.792269         403.0  403.909801
# 14  504.788668         504.845380         403.0  399.454378
# 15  495.459929         495.515423         403.0  912.364580

# %%
fig = plt.figure(figsize = (20,6))
plt.rcParams['font.size'] = 12
ax = plt.gca()
#yticks = np.arange(1000,100000000,10000)

#Quic
#plt.plot(quic4['size'], quic4['Throughput'], marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'orange')

#plt.plot(tcp4['size'], tcp4['Throughput'], marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'blue')
plt.plot(quic_mean['size'], quic_mean['Throughput'], marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'orange')

plt.plot(tcp_mean['size'], tcp_mean['Throughput'], marker='s', linewidth=0.3, markersize=5, fillstyle='none', color = 'blue')

ax = fig.axes[0]
ax.grid(False)
#ax.set_yticks(yticks)
ax.set_ylim([0,600])
ax.set_xlim([0,60000])
#ax.set_xlim([0,10])
ax.set_xscale('linear')
ax.set_xlabel('Size in KB', fontsize=12)
ax.set_ylabel('Throughput in MB/s', fontsize=12)

plt.legend(['Quic', 'TLS'], fontsize=11, loc='best')

ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.yaxis.set_ticks_position('left')
ax.xaxis.set_ticks_position('bottom')
ax.spines['bottom'].set_position(('axes', -0.05))
ax.spines['left'].set_position(('axes', -0.05))

ax3 = ax.twinx()
ax3.spines['right'].set_color('none')
ax3.spines['top'].set_color('none')
ax3.spines['left'].set_color('none')
ax3.spines['bottom'].set_color('none')
ax3.yaxis.set_ticks_position('none')
plt.setp(ax3.get_yticklabels(), visible=False)

plt.title('Size vs Throughput_ipv4', fontsize=12, y=1.05)
plt.savefig('./AWS/Bahrain/gdrive/sizevsThroughput_ipv4.png', format='png', bbox_inches='tight')
